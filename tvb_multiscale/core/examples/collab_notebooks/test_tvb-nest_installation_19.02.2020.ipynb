# %% [markdown]
# # TVB NEST

# %% [markdown]
# ## This example shows how to test that TVB and NEST are deployed correctly on CSCS infrastructure for the current user

# %%
# !pip install pyunicore --upgrade
import pyunicore.client as unicore_client

tr = unicore_client.Transport(oauth.get_token())
r = unicore_client.Registry(tr, unicore_client._HBP_REGISTRY_URL)

# use "DAINT-CSCS" -- change if another supercomputer is prepared for usage
site_client = r.site('DAINT-CSCS')
site_client.site_url
# Out:
# Requirement already up-to-date: pyunicore in /opt/conda/lib/python3.6/site-packages (0.5.7)
# 'https://brissago.cscs.ch:8080/DAINT-CSCS/rest/core'

# %%
job_configuration = "job_config.sh"

job_config = {
    "From": "https://raw.githubusercontent.com/the-virtual-brain/tvb-multiscale/update-collab-examples/docker/cosimulate_tvb_nest.sh",
    "To" : job_configuration
}

my_job = {}
my_job['Executable'] = job_configuration
my_job['Imports'] = [job_config]
my_job['Resources'] = {  
    "CPUs": "1"}
my_job
# Out:
# {'Executable': 'job_config.sh',
#  'Imports': [{'From': 'https://raw.githubusercontent.com/the-virtual-brain/tvb-multiscale/update-collab-examples/docker/cosimulate_tvb_nest.sh',
#    'To': 'job_config.sh'}],
#  'Resources': {'CPUs': '1'}}

# %%
# Actual job submission
job = site_client.new_job(job_description=my_job, inputs=[])
job.properties
# Out:
# {'_links': {'action:abort': {'description': 'Abort',
#    'href': 'https://brissago.cscs.ch:8080/DAINT-CSCS/rest/core/jobs/4e5e88b1-46a7-403b-8dd8-6c4af1f5b207/actions/abort'},
#   'action:restart': {'description': 'Restart',
#    'href': 'https://brissago.cscs.ch:8080/DAINT-CSCS/rest/core/jobs/4e5e88b1-46a7-403b-8dd8-6c4af1f5b207/actions/restart'},
#   'action:start': {'description': 'Start',
#    'href': 'https://brissago.cscs.ch:8080/DAINT-CSCS/rest/core/jobs/4e5e88b1-46a7-403b-8dd8-6c4af1f5b207/actions/start'},
#   'parentTSS': {'description': 'Parent TSS',
#    'href': 'https://brissago.cscs.ch:8080/DAINT-CSCS/rest/core/sites/715f1b74-9ea5-4443-a293-b3514bc13673'},
#   'self': {'href': 'https://brissago.cscs.ch:8080/DAINT-CSCS/rest/core/jobs/4e5e88b1-46a7-403b-8dd8-6c4af1f5b207'},
#   'workingDirectory': {'description': 'Working directory',
#    'href': 'https://brissago.cscs.ch:8080/DAINT-CSCS/rest/core/storages/4e5e88b1-46a7-403b-8dd8-6c4af1f5b207-uspace'}},
#  'acl': [],
#  'currentTime': '2020-02-18T10:39:39+0100',
#  'log': ['Tue Feb 18 10:39:38 CET 2020: Created with ID 4e5e88b1-46a7-403b-8dd8-6c4af1f5b207',
#   "Tue Feb 18 10:39:38 CET 2020: Created with type 'JSDL'",
#   "Tue Feb 18 10:39:38 CET 2020: Client: Name: CN=Valean Bogdan 308596,O=HBP\nXlogin: uid: [bp000309], gids: [addingOSgroups: true]\nRole: user: role from attribute source\nSecurity tokens: User name: CN=Valean Bogdan 308596,O=HBP\nDelegation to consignor status: true, core delegation status: false\nMessage signature status: UNCHECKED\nClient's original IP: 148.187.97.187",
#   'Tue Feb 18 10:39:39 CET 2020: Using default execution environment.',
#   'Tue Feb 18 10:39:39 CET 2020: Status set to PREPROCESSING (staging in).',
#   'Tue Feb 18 10:39:39 CET 2020: Adding stage in subaction with id=aab0757f-b555-4019-8307-56a8d6640c1c'],
#  'name': 'UNICORE_Job',
#  'owner': 'CN=Valean Bogdan 308596,O=HBP',
#  'queue': 'N/A',
#  'resourceStatus': 'READY',
#  'status': 'STAGINGIN',
#  'statusMessage': '',
#  'submissionPreferences': {'UC_OAUTH_BEARER_TOKEN': ['eyJhbGciOiJSUzI1NiIsImtpZCI6ImJicC1vaWRjIn0..Lls7-QJqY-B78tbGv6GgB-3KwRxtFndDq6VK5t2m_tMoEhez431MmZwQDrZpJ4W5vnfLd9t8k1N6gTaq6BQ_CbzX-2T6wGXsqv3h4tzJSkv88nVN7RGnI2-PdALTyOBYN2gzOvfbcifbAHRpK3zhAVMSxl214bDnj-GiPtUrtjM']},
#  'submissionTime': '2020-02-18T10:39:39+0100',
#  'tags': [],
#  'terminationTime': '2020-03-19T10:39:38+0100'}

# %%
job.is_running()
# Out:
# True

# %%
wd = job.working_dir
wd.properties
# Out:
# {'_links': {'copy': {'description': "Copy file 'from' to file 'to'.",
#    'href': 'https://brissago.cscs.ch:8080/DAINT-CSCS/rest/core/storages/4e5e88b1-46a7-403b-8dd8-6c4af1f5b207-uspace/actions/copy'},
#   'files': {'description': 'Files',
#    'href': 'https://brissago.cscs.ch:8080/DAINT-CSCS/rest/core/storages/4e5e88b1-46a7-403b-8dd8-6c4af1f5b207-uspace/files'},
#   'rename': {'description': "Rename file 'from' to file 'to'.",
#    'href': 'https://brissago.cscs.ch:8080/DAINT-CSCS/rest/core/storages/4e5e88b1-46a7-403b-8dd8-6c4af1f5b207-uspace/actions/rename'},
#   'self': {'href': 'https://brissago.cscs.ch:8080/DAINT-CSCS/rest/core/storages/4e5e88b1-46a7-403b-8dd8-6c4af1f5b207-uspace'}},
#  'acl': [],
#  'currentTime': '2020-02-18T10:39:48+0100',
#  'description': "Job's workspace",
#  'metadataSupported': False,
#  'mountPoint': '/scratch/snx3000/unicore/FILESPACE/4e5e88b1-46a7-403b-8dd8-6c4af1f5b207/',
#  'owner': 'CN=Valean Bogdan 308596,O=HBP',
#  'protocols': ['BFT', 'SBYTEIO', 'UFTP', 'RBYTEIO'],
#  'resourceStatus': 'READY',
#  'tags': [],
#  'umask': '77'}

# %% [markdown]
# ## Result
# The following cell should be run and inspected several times, until you see that the operation is done:

# %%
out = wd.stat("stdout")
f = out.raw()

all_lines = f.read().splitlines()
all_lines[-20:]
# Out:
# [b'[417649.539477168] [nid00085-19046] [CLI] [INFO] Successfully executed run command',
#  b'TVB-NEST test completed in 152 seconds',
#  b' ',
#  b'Batch Job Summary Report for Job "UNICORE_Job" (20372365) on daint',
#  b'-----------------------------------------------------------------------------------------------------',
#  b'             Submit            Eligible               Start                 End    Elapsed  Timelimit ',
#  b'------------------- ------------------- ------------------- ------------------- ---------- ---------- ',
#  b'2020-02-18T10:40:19 2020-02-18T10:40:19 2020-02-18T10:40:53 2020-02-18T10:44:28   00:03:35   01:00:00 ',
#  b'-----------------------------------------------------------------------------------------------------',
#  b'Username    Account     Partition   NNodes   Energy',
#  b'----------  ----------  ----------  ------  --------------',
#  b'bp000309    ich012      normal           1   17.70K joules',
#  b' ',
#  b'This job did not utilize any GPUs',
#  b' ',
#  b'----------------------------------------------------------',
#  b'Scratch File System        Files       Quota',
#  b'--------------------  ----------  ----------',
#  b'/scratch/snx3000             852     1000000',
#  b' ']

# %%
err = wd.stat("stderr")
f = err.raw()
f.readlines()
# Out:
# [b'/home/docker/packages/tvb-root/scientific_library/tvb/datatypes/surfaces.py:61: UserWarning: Geodesic distance module is unavailable; some functionality for surfaces will be unavailable.\n',
#  b'  warnings.warn(msg)\n']
