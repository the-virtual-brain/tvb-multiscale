# %% [markdown]
# # TVB-ANNarchy: Bridging multiscale activity by co-simulation
#
# ## Step-by-step learn how to perform a co-simulation embedding spiking neural networks into large-scale brain networks using TVB.

# %% [markdown]
# ## Izhikevich Spiking network model in ANNarchy
#
# For every neuron $i$ in region node $n$ modelled in ANNarchy as a spiking network:
#
# Membrane potential:
#
# $ \dot{V}_m = n_2V_m^2 + n_1V_m + n_0140 - U_m/C $
#
# $\;\;\;\;\;\;\;- g_{AMPA}(V_m-E_{AMPA}) - g_{GABA}(V_m-E_{GABA}) - g_{BASE}V_m + I_e $
#
# where the conductances follow the equations:
#
# $ \dot{g}_{AMPA} = - g_{AMPA} / \tau_{AMPA} + \left[\sum_k \delta(t-t_k) \right]_{Exc}$
#
# $ \dot{g}_{GABA} = - g_{GABA} / \tau_{GABA} + \left[\sum_k \delta(t-t_k) \right]_{Inh}$
#
# $ \dot{g}_{BASE} = - g_{BASE} / \tau_{BASE} + \left[\sum_k \delta(t-t_k) \right]_{BASE}$
#
# and recovery variable:
#
# $ \dot{U}_m = a(bV_m - U_m)$
#
#
# When $ V_m > V_{th} $ , $ V_m $ is set to $ c $, and $ U_m $ is incremented by $ d $.

# %% [markdown]
# # WORKFLOW:

# %%
import os
from collections import OrderedDict
import time
import numpy as np

from tvb.basic.profile import TvbProfile
TvbProfile.set_profile(TvbProfile.LIBRARY_PROFILE)

from tvb_multiscale.tvb_annarchy.config import *

work_path = os.getcwd()
data_path = os.path.expanduser("~/packages/tvb-multiscale/examples/data/basal_ganglia")
fit_data_path = os.path.join(data_path, "ANNarchyFittedModels/dataFits_2020_02_05/databestfits", )
data_mode = "control" # "control" "patient"
control_data = os.path.join(fit_data_path, "controlleft/OutputSim_Patient08.mat")
patient_data = os.path.join(fit_data_path, "patientleft/OutputSim_Patient09.mat")
if data_mode == "patient":
    subject_data = patient_data
else:
    subject_data = control_data
    
simulation_length = 1500.0
transient = 400.0
start_stimulus = 400.0
init_cond_jitter = 0.0

TVB_DT = 0.01

SPIKING_NODES_DELAYS = False
SPIKING_NODES_FIXED_DELAY = 0.1 # ms

SPIKING_CORTICAL_I = 7.0

ANNARCHY_CORTEX_MODE = "Izhikevich" # "Izhikevich", "PoissonCorr", or "Poisson"

CORTICAL_SPIKING_NOISE = 35.0

simulation_mode = "rs"       # "stim" or "rs"
stim_target = "STN"          #     "STN"          "GPi"
stim_mode = "bi"         # "bi"  | "mono" | "simple"
                             # -------------------------
stim_freq = 130.0              # 130.0 |  120.0 |    0.0 
stim_ampl =20.0            #  20.0 |  -35.0 |  -10.0 
stim_duration = 0.3          #   0.3 |    0.3 |    -
if simulation_mode == "stim":
    simulation_mode = simulation_mode + "_%s_%s" % (stim_target, stim_mode)
    if CORTICAL_SPIKING_NOISE > 0.0:
        simulation_mode += "_n%g" % CORTICAL_SPIKING_NOISE
        
outputs_path = os.path.join(work_path, "outputs")
sim_mode_dirname = "SpikingPoissonCortex" if ANNARCHY_CORTEX_MODE=="PoissonCorr" else "SpikingCortex"
sim_mode_path = os.path.join(outputs_path, sim_mode_dirname, data_mode, simulation_mode)
config = Config(output_base=sim_mode_path)
config.figures.SHOW_FLAG = True 
config.figures.SAVE_FLAG = True
config.figures.FIG_FORMAT = 'png'
config.figures.DEFAULT_SIZE= config.figures.NOTEBOOK_SIZE
FIGSIZE = config.figures.DEFAULT_SIZE

from tvb_multiscale.core.plot.plotter import Plotter
plotter = Plotter(config.figures)

# For interactive plotting:
# %matplotlib notebook  

# Otherwise:
# %matplotlib inline
# Out:
# 2026-03-31 09:40:36,931 - WARNING - tvb.simulator.plot.tools - You need mpl_toolkits for some axe related features
# /home/docker/venv/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "

# %% [markdown]
# ## 1. Load structural data <br> (minimally a TVB connectivity)  <br> & prepare TVB simulator  <br> (region mean field model, integrator, monitors etc)

# %%
from tvb_multiscale.core.tvb.cosimulator.models.reduced_wong_wang_exc_io import ReducedWongWangExcIO

# ----------------------------------------------------------------------------------------------------------------
# ----Uncomment below to modify the simulator by changing the default options:--------------------------------------
# ----------------------------------------------------------------------------------------------------------------

from tvb.datatypes.connectivity import Connectivity
from tvb_multiscale.core.tvb.cosimulator.cosimulator_serial import CoSimulatorSerial as CoSimulator
from tvb.simulator.integrators import HeunStochastic
from tvb.simulator.monitors import Raw  # , Bold, EEG
    

conn_path = os.path.join(data_path, "conn_incl_cortex")

w=np.zeros((11,11))
c=np.loadtxt(os.path.join(conn_path, "aal_plus_BG_centers_incl_cortex.txt"), usecols=range(1,4))
rl= np.loadtxt(os.path.join(conn_path, "aal_plus_BG_centers_incl_cortex.txt"), dtype="str", usecols=(0,))
t= np.loadtxt(os.path.join(conn_path, "BGplusAAL_tract_lengths_incl_cortex.txt"))

# Keep only the BG and a single Cortex node:
c = c[:11]
rl = rl[:11]
rl[10] = "Cortex"
w = w[:11][:, :11]
t = t[:11][:, :11]

# Keep only left hemisphere and the Cortex:
inds = np.arange(0,10,2).astype("i").tolist() + [10]
c = c[inds] 
rl = rl[inds]
print("Region labels:\n%s" % rl)
# 0. GPe_Left, 1. GPi_Left, 2. STN_Left, 3. Striatum_Left, 4. Thal_Left, 5. Cortex
w = w[inds][:, inds]
t = t[inds][:, inds]

# % loadedParams ={
# %     	'D1GPi_probs': probs[0],
# %     	'D1GPi_weights'  : weights[0],
# %     	'D2GPe_probs'   : probs[1],
# %     	'D2GPe_weights'  : weights[1],
# %     	'GPeSTN_probs'   : probs[2],
# %     	'GPeSTN_weights'  : weights[2],
# %     	'STNGPe_probs'   : probs[3],
# %     	'STNGPe_weights'  : weights[3],
# %     	'STNGPi_probs'   : probs[4],
# %     	'STNGPi_weights' : weights[4],
# %     	'GPeGPi_probs'   : probs[5],
# %     	'GPeGPi_weights'  : weights[5],
# %     	'GPeGPe_probs'   : probs[6],
# %     	'GPeGPe_weights'  : weights[6],
# %     	'GPiGPi_probs'   : probs[7],
# %     	'GPiGPi_weights'  : weights[7],
# %     	'GPiThal_probs'   : probs[8],
# %     	'GPiThal_weights'  : weights[8],
# %     	'ThaliSN_probs'   : probs[9],
# %     	'ThaliSN_weights'  : weights[9],
# %     	'ThaldSN_probs'   : probs[10],
# %     	'ThaldSN_weights'  : weights[10],
# %     	'dSNdSN_probs'   : probs[11],
# %     	'dSNdSN_weights'  : weights[11],
# %     	'iSNiSN_probs'   : probs[12],
# %     	'iSNiSN_weights'  : weights[12],
# %     	'CdSN_probs'   : probs[13],
# %     	'CdSN_weights'  : weights[13],
# %     	'CiSN_probs'   : probs[14],
# %     	'CiSN_weights'  : weights[14],
# %     	'CSTN_probs'   : probs[15],
# %     	'CSTN_weights'  : weights[15],
# %     	'V1Inh_probs'    : probs[16],
# %     	'V1Inh_weights'  : weights[16],
# %     	'InhV1_probs'    : probs[17],
# %     	'InhV1_weights'  : weights[17],
# %     	'InhInh_probs'   : probs[18],
# %     	'InhInh_weights'  : weights[18]}


# 0. GPe_Left, 1. GPi_Left, 2. STN_Left, 3. Striatum_Left, 4. Thal_Left
BG_opt_matrix_weights = np.zeros((5, 5))
conn_mode = "subject" # "average"
if conn_mode == "average":
    weights_maith = np.array([1.93, 3.56, 1.46, 4.51, 3.52, 2.30, 2.34, 3.78, 1.98, 
                             1.30, 1.82, 3.56, 3.02, 1.78, 1.36, 2.27, 4.13, 2.74, 3.27])*1e-3  # controls
#     weights_maith = np.array([3.27, 3.80, 2.65, 3.66, 3.06, 3.06, 3.25, 4.02, 3.32, 
#                             2.98, 3.45, 3.64, 2.50, 2.12, 2.86, 2.79, 3.96, 3.69, 3.87])*1e-3   # patients
    # probs_maith = ????
else:
    import scipy.io as sio
    weights=sio.loadmat(subject_data) # weights start from index 19
    weights_maith = weights["X"][0, 19:] # these are indices 19 till 37
    probs_maith = weights["X"][0, :19] # these are indices 0 till 18

wdSNGPi = BG_opt_matrix_weights[3, 1] = weights_maith[0]
wiSNGPe = BG_opt_matrix_weights[3, 0] = weights_maith[1]
wGPeSTN = BG_opt_matrix_weights[0, 2] = weights_maith[2]
wSTNGPe = BG_opt_matrix_weights[2, 0] = weights_maith[3]
wSTNGPi = BG_opt_matrix_weights[2, 1] = weights_maith[4]
wGPeGPi = BG_opt_matrix_weights[0, 1] = weights_maith[5]  
wGPiTh = BG_opt_matrix_weights[1, 4] = weights_maith[8]
wThdSN = BG_opt_matrix_weights[4, 3] = weights_maith[10] # Th -> dSN
    
sliceBGnet = slice(0,5)
w[sliceBGnet, sliceBGnet] = BG_opt_matrix_weights

wGPeGPe = weights_maith[6]             # "GPe" -> "GPe" 
wGPiGPi = weights_maith[7]             # "GPi" -> "GPi" 
wThiSN = weights_maith[9]              # "Eth" -> "IiSN" 

wdSNdSN = weights_maith[11]            # "IdSN" -> "IdSN" 
wiSNiSN = weights_maith[12]            # "IiSN" -> "IiSN" 
wCtxdSN = w[5, 3] = weights_maith[13]  # "CxE" -> "IdSN" 
wCtxiSN = weights_maith[14]            # "CxE" -> "IiSN" 
wCtxSTN = w[5, 2] = weights_maith[15]  # "CxE" -> "Estn"
wCtxEtoI = weights_maith[16]           # "CxE" -> "CxI"
wCtxItoE = weights_maith[17]           # "CxI" -> "CxE"
wCtxItoI = weights_maith[18]           # "CxI" -> "CxI"

pdSNGPi = probs_maith[0]
piSNGPe = probs_maith[1]
pGPeSTN = probs_maith[2]
pSTNGPe = probs_maith[3]
pSTNGPi = probs_maith[4]
pGPeGPi = probs_maith[5]  
pGPeGPe = probs_maith[6]            # "GPe" -> "GPe" 
pGPiGPi = probs_maith[7]            # "GPi" -> "GPi" 
pGPiTh = probs_maith[8]
pThiSN =  probs_maith[9]            # "Eth" -> "IiSN
pThdSN = probs_maith[10]            # Th --> dSN
pdSNdSN = probs_maith[11]           # "IdSN" -> "IdSN" 
piSNiSN = probs_maith[12]           # "IiSN" -> "IiSN" 
pCtxdSN = probs_maith[13]           # "CxE" -> "IdSN" 
pCtxiSN = probs_maith[14]           # "CxE" -> "IiSN" 
pCtxSTN = probs_maith[15]           # "CxE" -> "Estn"
pCtxEtoI = probs_maith[16]          # "CxE" -> "CxI"
pCtxItoE = probs_maith[17]          # "CxI" -> "CxE"
pCtxItoI = probs_maith[18]          # "CxI" -> "CxI"

pCtxCtx = probs_maith[16:19].mean() # "Ctx" <-> "Ctx"

loadedParams ={'dSNGPi_probs': probs_maith[0],
    	'dSNGPi_weights'  : weights_maith[0],
    	'iSNGPe_probs'   : probs_maith[1],
    	'iSNGPe_weights'  : weights_maith[1],
    	'GPeSTN_probs'   : probs_maith[2],
    	'GPeSTN_weights'  : weights_maith[2],
    	'STNGPe_probs'   : probs_maith[3],
    	'STNGPe_weights'  : weights_maith[3],
    	'STNGPi_probs'   : probs_maith[4],
    	'STNGPi_weights' : weights_maith[4],
    	'GPeGPi_probs'   : probs_maith[5],
    	'GPeGPi_weights'  : weights_maith[5],
    	'GPeGPe_probs'   : probs_maith[6],
    	'GPeGPe_weights'  : weights_maith[6],
    	'GPiGPi_probs'   : probs_maith[7],
    	'GPiGPi_weights'  : weights_maith[7],
    	'GPiThal_probs'   : probs_maith[8],
    	'GPiThal_weights'  : weights_maith[8],
    	'ThaliSN_probs'   : probs_maith[9],
    	'ThaliSN_weights'  : weights_maith[9],
    	'ThaldSN_probs'   : probs_maith[10],
    	'ThaldSN_weights'  : weights_maith[10],
    	'dSNdSN_probs'   : probs_maith[11],
    	'dSNdSN_weights'  : weights_maith[11],
    	'iSNiSN_probs'   : probs_maith[12],
    	'iSNiSN_weights'  : weights_maith[12],
    	'CtxdSN_probs'   : probs_maith[13],
    	'CtxdSN_weights'  : weights_maith[13],
    	'CtxiSN_probs'   : probs_maith[14],
    	'CtxiSN_weights'  : weights_maith[14],
    	'CtxSTN_probs'   : probs_maith[15],
    	'CtxSTN_weights'  : weights_maith[15],
    	'CtxECtxI_probs'    : probs_maith[16],
    	'CtxECtxI_weights'  : weights_maith[16],
    	'CtxICtxE_probs'    : probs_maith[17],
    	'CtxICtxE_weights'  : weights_maith[17],
    	'CtxICtxI_probs'   : probs_maith[18],
    	'CtxICtxI_weights'  : weights_maith[18],
        'CtxThal_weights': 0.0,
        'CtxThal_probs': 1.0}
print(loadedParams)

assert_loadedParams = dict(zip(loadedParams.values(), loadedParams.keys()))

# Finally form the TVB Connectivity
dt = TVB_DT  # 1.0  # 0.1
speed = 4.0
if not SPIKING_NODES_DELAYS:
    t = dt * speed * np.ones(t.shape)
connectivity=Connectivity(region_labels=rl, weights=w.T, # !!!NOTE TVB indices convention!!!
                          centres=c, tract_lengths=t)

connectivity.speed = np.array([speed])
connectivity.configure()

# Create a TVB simulator
# We choose all defaults in this example
simulator = CoSimulator()
#simulator.use_numba = False
model_params = {}
simulator.model = ReducedWongWangExcIO(**model_params)

simulator.connectivity = connectivity

simulator.integrator = HeunStochastic()
simulator.integrator.dt = dt
simulator.integrator.noise.nsig = np.array([0.001])

mon_raw = Raw(period=1.0)  # ms
simulator.monitors = (mon_raw, )

plotter.plot_tvb_connectivity(simulator.connectivity);
# Out:
# Region labels:
# ['GPe_Left' 'GPi_Left' 'STN_Left' 'Striatum_Left' 'Thal_Left' 'Cortex']
# {'dSNGPi_probs': 0.12319446388873984, 'dSNGPi_weights': 0.008834496734754112, 'iSNGPe_probs': 0.3899984160345866, 'iSNGPe_weights': 0.008037575418074995, 'GPeSTN_probs': 0.21771167778806555, 'GPeSTN_weights': 0.0061748118049342795, 'STNGPe_probs': 0.3836721138933171, 'STNGPe_weights': 0.011368010759969138, 'STNGPi_probs': 0.2505941996110323, 'STNGPi_weights': 0.012951692093784004, 'GPeGPi_probs': 0.29925252129182806, 'GPeGPi_weights': 0.007933935912619745, 'GPeGPe_probs': 0.3547969181458484, 'GPeGPe_weights': 0.00542683131081617, 'GPiGPi_probs': 0.3326961142340224, 'GPiGPi_weights': 0.01258230160804601, 'GPiThal_probs': 0.20701840718120362, 'GPiThal_weights': 0.006948128598027098, 'ThaliSN_probs': 0.13269466938659205, 'ThaliSN_weights': 0.005984228937275021, 'ThaldSN_probs': 0.10018580922442194, 'ThaldSN_weights': 0.011550731621297246, 'dSNdSN_probs': 0.48747340479430934, 'dSNdSN_weights': 0.008960226825254268, 'iSNiSN_probs': 0.2457256934459565, 'iSNiSN_weights': 0.01425022013189391, 'CtxdSN_probs': 0.17319504160782342, 'CtxdSN_weights': 0.009480287664590605, 'CtxiSN_probs': 0.10073285859098174, 'CtxiSN_weights': 0.011297310193527891, 'CtxSTN_probs': 0.14839350138822735, 'CtxSTN_weights': 0.013792751275625506, 'CtxECtxI_probs': 0.42255305960948136, 'CtxECtxI_weights': 0.008730271117196936, 'CtxICtxE_probs': 0.20418028060357754, 'CtxICtxE_weights': 0.012366721941610877, 'CtxICtxI_probs': 0.3263646729295033, 'CtxICtxI_weights': 0.009615817286005496, 'CtxThal_weights': 0.0, 'CtxThal_probs': 1.0}

# %% [markdown]
# ## 2. Build and connect the ANNarchy network model <br> (networks of spiking neural populations for fine-scale <br>regions, stimulation devices, spike detectors etc)

# %%
from tvb_multiscale.tvb_annarchy.annarchy_models.models.basal_ganglia_izhikevich import BasalGangliaIzhikevichBuilder
from tvb_multiscale.tvb_annarchy.annarchy.models import Izhikevich_Hamker
from examples.tvb_netpyne.notebooks.conn import lorentzian
from ANNarchy import HomogeneousCorrelatedSpikeTrains, PoissonPopulation
import ANNarchy as ann

# Select the regions for the fine scale modeling with ANNarchy spiking networks
#including cortex node:
spiking_nodes_ids = [0, 1, 2, 3, 4, 5]  # the indices of fine scale regions modeled with ANNarchy

# Build a ANNarchy network model with the corresponding builder
ann_model_builder = BasalGangliaIzhikevichBuilder(simulator, spiking_nodes_ids, config=config)


# or...

# # ----------------------------------------------------------------------------------------------------------------
# # ----Uncomment below to modify the builder by changing the default options:--------------------------------------
# # ----------------------------------------------------------------------------------------------------------------
from copy import deepcopy

population_neuron_model = Izhikevich_Hamker

ann_model_builder.population_order = 200 # reduce for speed

# When any of the properties model, params and scale below depends on regions,
# set a handle to a function with
# arguments (region_index=None) returning the corresponding property

ann_model_builder.params_common = \
    {"v": -70.0, "u": -18.55, "E_ampa": 0.0, "E_gaba": -90.0, "v_th": 30.0, "Vr": 0.0, "c": -65.0,
     "C": 1.0, "I": 0.0,
     "tau_syn": 1.0, "tau_ampa": 10.0, "tau_gaba": 10.0,
     "n0": 140.0, "n1": 5.0, "n2": 0.04, 
     "v": -72.0, "u": -14.0, 
     "noise": 0.0}

ann_model_builder._paramsI = deepcopy(ann_model_builder.params_common)
ann_model_builder._paramsI.update({"a": 0.005, "b": 0.585, "d": 4.0, 
                                   "v": -70.0, "u": -18.55})
ann_model_builder._paramsE = deepcopy(ann_model_builder.params_common)
ann_model_builder._paramsE.update({"v": -70.0, "u": -18.55})

ann_model_builder.paramsStr = deepcopy(ann_model_builder.params_common)
ann_model_builder.paramsStr.update({"v_th": 40.0, "C": 50.0, "Vr": -80.0,
                                    "n0": 61.65119, "n1": 2.594639, "n2": 0.022799, 
                                    "a": 0.05, "b": -20.0, "c": -55.0, "d": 377.0, 
                                    "v": -70.0, "u": -18.55})

ann_model_builder.Igpe_nodes_ids = [0]
ann_model_builder.Igpi_nodes_ids = [1]
ann_model_builder.Estn_nodes_ids = [2]
ann_model_builder.Eth_nodes_ids = [4]
ann_model_builder.Istr_nodes_ids = [3]
#including cortex node:
ann_model_builder.Crtx_nodes_ids = [5]

I_nodes_ids = ann_model_builder.Igpe_nodes_ids + ann_model_builder.Igpi_nodes_ids
E_nodes_ids = ann_model_builder.Estn_nodes_ids + ann_model_builder.Eth_nodes_ids


SPIKING_CORTICAL_I_D = np.maximum(np.abs(0.01*SPIKING_CORTICAL_I), 0.01)


def paramsE_fun(node_id, cortex_noise=CORTICAL_SPIKING_NOISE):
    paramsE = deepcopy(ann_model_builder._paramsE)
    if node_id in ann_model_builder.Estn_nodes_ids:
        paramsE.update({"a": 0.005, "b": 0.265, "d": 2.0, "I": 3.0})  # dictionary of params for Estn
    elif node_id in ann_model_builder.Eth_nodes_ids:
        paramsE.update({"a": 0.02, "b": 0.25, "d": 0.05, "I": 3.5}) # dictionary of params for Eth
    elif node_id in ann_model_builder.Crtx_nodes_ids:
        paramsE.update({"v": -72.0, "u": -14.0, 
                        "a": 0.02, "b": 0.2, "d": 6.0,"c": -72.0, 
                        "tau_refrac": 5.0,
                        "I": lorentzian(SPIKING_CORTICAL_I, SPIKING_CORTICAL_I_D, 600, deterministic=True), # 7.0,  # 50.0 dictionary of params for CortexExcitatory
                        "noise": cortex_noise})
    return paramsE
    
def paramsI_fun(node_id):
    # For the moment they are identical, unless you differentiate the noise parameters
    paramsI = deepcopy(ann_model_builder._paramsI)
    if node_id in ann_model_builder.Igpe_nodes_ids:
        paramsI.update({"I": 12.0})
    elif node_id in ann_model_builder.Igpi_nodes_ids:
        paramsI.update({"I": 30.0})
    elif node_id in ann_model_builder.Crtx_nodes_ids:
        paramsI.update({"v": -72.0, "u": -14.0, 
                        "c": -72.0,"a": 0.02, "b": 0.2, "d": 6.0, 
                        "tau_refrac": 5.0,
                        "I_e": lorentzian(SPIKING_CORTICAL_I, SPIKING_CORTICAL_I_D, 600, deterministic=True) # 0.0
                       })
    return paramsI



ann_model_builder.populations = []
if ANNARCHY_CORTEX_MODE == "Izhikevich":
    E_nodes_ids += ann_model_builder.Crtx_nodes_ids
    I_nodes_ids += ann_model_builder.Crtx_nodes_ids
    Ectx = "E"
    ann_model_builder.populations += [
        {"label": "E", "model": population_neuron_model,  
          "params":  paramsE_fun, 
          "nodes": E_nodes_ids,  # Estn in [2], Eth in [4], Cortex in [5]
          "scale": lambda node_id: 3.0 if node_id in ann_model_builder.Crtx_nodes_ids else 1.0},
        {"label": "I", "model": population_neuron_model,  
          "params": paramsI_fun, 
          "nodes": I_nodes_ids,  # Igpe in [0], Igpi in [1], Cortex in [5]
          "scale": lambda node_id: 0.75 if node_id in ann_model_builder.Crtx_nodes_ids else 1.0}
    ]
     
else:
    Ectx = "Ectx"

    if "corr" in ANNARCHY_CORTEX_MODE.lower():
        crtx_model = HomogeneousCorrelatedSpikeTrains
        # For Homogeneous Correlated Poisson SpikeTrains Cortex:
        # Populations' configurations
        # When any of the properties model, params and scale below depends on regions,
        # set a handle to a function with
        # arguments (region_index=None) returning the corresponding property
        #  "corr"     "tau"     cortex eff rate: 0.9pCtxCtx, 
        #   0.99       1.7       35
        #   0.9        1.5       31
        #   0.5        0.9       29
        #   0.3        0.5       20+ for Thal: 17
        #   0.25       0.4       21 for Thal: 16
        crtx_params = {"rates": 15.0, "corr": 0.3, "tau": 10.0}
    else:
        crtx_model = PoissonPopulation
        crtx_params = {"rates": 15.0}
        
    ann_model_builder.populations += [
        {"label": Ectx, "model": crtx_model, 
         "params": crtx_params, 
         "nodes": ann_model_builder.Crtx_nodes_ids,
         "scale": 3.0},  # Cortex in [5]
        {"label": "E", "model": population_neuron_model,  
         "params":  paramsE_fun, 
         "nodes": E_nodes_ids,  # Estn in [2], Eth in [4]
         "scale": 1.0},
        {"label": "I", "model": population_neuron_model,  
         "params": paramsI_fun, 
         "nodes": I_nodes_ids,  # Igpe in [0], Igpi in [1]
         "scale": 1.0}
    ]

        
ann_model_builder.populations += [
    {"label": "IdSN", "model": population_neuron_model,   
     "params": ann_model_builder.paramsStr, 
     "nodes": ann_model_builder.Istr_nodes_ids,  # IdSN in [3]
     "scale": 1.0},
    {"label": "IiSN", "model": population_neuron_model,   # IiSN in [3]
     "params": ann_model_builder.paramsStr, 
     "nodes": ann_model_builder.Istr_nodes_ids,  # None means "all"
     "scale": 1.0}
]

# Within region-node connections
# When any of the properties model, conn_spec, weight, delay, receptor_type below
# set a handle to a function with
# arguments (region_index=None) returning the corresponding property

synapse_model = "DefaultSpikingSynapse"
conn_spec = {'rule': "all_to_all", 
             "allow_self_connections": True, "force_multiple_weights": False}
conn_spec_fixed_probability = conn_spec.copy()
conn_spec_fixed_probability.update({'rule': "fixed_probability", "probability": 0.1})

def conn_spec_fixed_prob(prob=None):
    output = conn_spec_fixed_probability.copy()
    if prob is not None:
        output["probability"] = prob
    return output

within_node_delay = SPIKING_NODES_FIXED_DELAY
        

# for each connection, we have a different probability
ann_model_builder.populations_connections = []
if ANNARCHY_CORTEX_MODE == "Izhikevich":
    ann_model_builder.populations_connections += [
        {"source": "I", "target": "I",  # I -> I This is a self-connection for population "CxI"
         "synapse_model": synapse_model, "conn_spec": conn_spec_fixed_prob(pCtxItoI),  # conn_spec
         "weight": np.abs(wCtxItoI), "delay": within_node_delay,
         "receptor_type": "gaba", "nodes": ann_model_builder.Crtx_nodes_ids},  # None means apply to all
        {"source": "E", "target": "I",          # "CxE" -> "CxI" #
         "synapse_model": synapse_model, "conn_spec": conn_spec_fixed_prob(pCtxEtoI),  # conn_spec
         "weight": np.abs(wCtxEtoI), "delay": within_node_delay,  
         "receptor_type": "ampa", "nodes": ann_model_builder.Crtx_nodes_ids},  # None means apply to all
        {"source": "I", "target": "E",          # "CxI" -> "CxE" 
         "synapse_model": synapse_model, "conn_spec": conn_spec_fixed_prob(pCtxItoE),  # conn_spec
         "weight": np.abs(wCtxItoE), "delay": within_node_delay,  
         "receptor_type": "gaba", "nodes": ann_model_builder.Crtx_nodes_ids}  # None means apply to all   
    ]
    
ann_model_builder.populations_connections += [
     #        source   ->   target
    {"source": "I", "target": "I",  # I -> I This is a self-connection for population "Igpe"
     "synapse_model": synapse_model, "conn_spec": conn_spec_fixed_prob(pGPeGPe),  # conn_spec
     "weight": np.abs(wGPeGPe), "delay": within_node_delay,
     "receptor_type": "gaba", "nodes": ann_model_builder.Igpe_nodes_ids},  # None means apply to all
    {"source": "I", "target": "I",  # I -> I This is a self-connection for population "Igpi"
     "synapse_model": synapse_model, "conn_spec": conn_spec_fixed_prob(pGPiGPi),  # conn_spec
     "weight": np.abs(wGPiGPi), "delay": within_node_delay,
     "receptor_type": "gaba", "nodes": ann_model_builder.Igpi_nodes_ids},  # None means apply to all
    {"source": "IdSN", "target": "IdSN",  # IdSN -> IdSN This is a self-connection for population "IdSN"
     "synapse_model": synapse_model, "conn_spec": conn_spec_fixed_prob(pdSNdSN),  # conn_spec
     "weight": np.abs(wdSNdSN), "delay": within_node_delay,
     "receptor_type": "gaba", "nodes": ann_model_builder.Istr_nodes_ids},
    {"source": "IiSN", "target": "IiSN",  # IiSN -> IiSN This is a self-connection for population "IiSN"
     "synapse_model": synapse_model, "conn_spec": conn_spec_fixed_prob(piSNiSN),  # conn_spec
     "weight": np.abs(wiSNiSN), "delay": within_node_delay,
     "receptor_type": "gaba", "nodes": ann_model_builder.Istr_nodes_ids},
    ]



# Among/Between region-node connections
# Given that only the AMPA population of one region-node couples to
# all populations of another region-node,
# we need only one connection type
        
# When any of the properties model, conn_spec, weight, delay, receptor_type below
# depends on regions, set a handle to a function with
# arguments (source_region_index=None, target_region_index=None)

from tvb_multiscale.core.spiking_models.builders.templates import scale_tvb_weight, tvb_delay

# We set global coupling scaling to 1.0,
# because we need the Maith et al optimized weights without any scaling:
ann_model_builder.global_coupling_scaling = 1.0 
        
# Function that will return the TVB weight with optional scaling:
class TVBWeightFun(object):
    
    def __init__(self, 
                 global_coupling_scaling=ann_model_builder.global_coupling_scaling, 
                 tvb_weights = ann_model_builder.tvb_weights):
        self.global_coupling_scaling = float(global_coupling_scaling)
        self.tvb_weights = tvb_weights.copy()
    
    def __call__(self, source_node, target_node):
        return scale_tvb_weight(source_node, target_node, self.tvb_weights,
                                scale=self.global_coupling_scaling)

# Function that will return the TVB delay unless SPIKING_NODES_DELAYS == False:
tvb_delay_fun = \
    lambda source_node, target_node: \
        np.maximum(ann_model_builder.tvb_dt, 
                   tvb_delay(source_node, target_node, ann_model_builder.tvb_delays)) \
            if SPIKING_NODES_DELAYS else within_node_delay


# Total excitatory spikes of one region node will be distributed to
ann_model_builder.nodes_connections = [
    #        source    ->     target
    {"source": "IdSN", "target": "I",             # "IdSN" -> "Igpi"
     "synapse_model": synapse_model, "conn_spec": conn_spec_fixed_prob(pdSNGPi),  # conn_spec
     "weight": TVBWeightFun(),
     "delay": lambda source_node, target_node: tvb_delay_fun(source_node, target_node),  
     "receptor_type": "gaba", 
     "source_nodes": ann_model_builder.Istr_nodes_ids, 
     "target_nodes": ann_model_builder.Igpi_nodes_ids},  # None means apply to all
    {"source": "IiSN", "target": "I",            # "IiSN" -> "Igpe"
     "synapse_model": synapse_model, "conn_spec": conn_spec_fixed_prob(piSNGPe),  # conn_spec
     "weight": TVBWeightFun(),
     "delay": lambda source_node, target_node: tvb_delay_fun(source_node, target_node),  
     "receptor_type": "gaba", 
     "source_nodes": ann_model_builder.Istr_nodes_ids, 
     "target_nodes": ann_model_builder.Igpe_nodes_ids},  # None means apply to all
    {"source": "I", "target": "I",             # "Igpe" -> "Igpi"
     "synapse_model": synapse_model, "conn_spec": conn_spec_fixed_prob(pGPeGPi),  # conn_spec
     "weight": TVBWeightFun(),
     "delay": lambda source_node, target_node: tvb_delay_fun(source_node, target_node),  
     "receptor_type": "gaba", 
     "source_nodes": ann_model_builder.Igpe_nodes_ids, 
     "target_nodes": ann_model_builder.Igpi_nodes_ids},  # None means apply to all
    {"source": "I", "target": "E",              # "Igpi" -> "Eth"
     "synapse_model": synapse_model, "conn_spec": conn_spec_fixed_prob(pGPiTh),  # conn_spec
     "weight": TVBWeightFun(),
     "delay": lambda source_node, target_node: tvb_delay_fun(source_node, target_node),  
     "receptor_type": "gaba", 
     "source_nodes": ann_model_builder.Igpi_nodes_ids, 
     "target_nodes": ann_model_builder.Eth_nodes_ids},  # None means apply to all
    {"source": "I", "target": "E",             # "Igpe" -> "Estn"
     "synapse_model": synapse_model, "conn_spec": conn_spec_fixed_prob(pGPeSTN),  # conn_spec
     "weight": TVBWeightFun(),
     "delay": lambda source_node, target_node: tvb_delay_fun(source_node, target_node),  
     "receptor_type": "gaba", 
     "source_nodes": ann_model_builder.Igpe_nodes_ids, 
     "target_nodes": ann_model_builder.Estn_nodes_ids},  # None means apply to all
    {"source": "E", "target": "IdSN",   # "Eth" -> ["IdSN"] 
     "synapse_model": synapse_model, "conn_spec": conn_spec_fixed_prob(pThdSN),  # conn_spec
     "weight": wThdSN, # TVBWeightFun(),
     "delay": lambda source_node, target_node: tvb_delay_fun(source_node, target_node),  
     "receptor_type": "ampa", 
     "source_nodes": ann_model_builder.Eth_nodes_ids, 
     "target_nodes": ann_model_builder.Istr_nodes_ids},  # None means apply to all
    {"source": "E", "target": "IiSN",   # "Eth" -> ["IiSN"] 
     "synapse_model": synapse_model, "conn_spec": conn_spec_fixed_prob(pThiSN),  # conn_spec
     "weight": wThiSN,
     "delay": lambda source_node, target_node: tvb_delay_fun(source_node, target_node),  
     "receptor_type": "ampa", 
     "source_nodes": ann_model_builder.Eth_nodes_ids, 
     "target_nodes": ann_model_builder.Istr_nodes_ids},  # No
    {"source": "E", "target": "I",          # "Estn" -> ["Igpe"]
     "synapse_model": synapse_model, "conn_spec": conn_spec_fixed_prob(pSTNGPe),  # conn_spec
     "weight": TVBWeightFun(),
     "delay": lambda source_node, target_node: tvb_delay_fun(source_node, target_node),  
     "receptor_type": "ampa", 
     "source_nodes": ann_model_builder.Estn_nodes_ids, 
     "target_nodes": ann_model_builder.Igpe_nodes_ids},
    {"source": "E", "target": "I",          # "Estn" -> ["Igpi"]
     "synapse_model": synapse_model, "conn_spec": conn_spec_fixed_prob(pSTNGPi),  # conn_spec
     "weight": TVBWeightFun(),
     "delay": lambda source_node, target_node: tvb_delay_fun(source_node, target_node),  
     "receptor_type": "ampa", 
     "source_nodes": ann_model_builder.Estn_nodes_ids, 
     "target_nodes": ann_model_builder.Igpi_nodes_ids},
    {"source": Ectx, "target": "E",          # "Ectx" -> "Eth"
     "model": synapse_model, "conn_spec": conn_spec, # No probability here?!
     "weight": TVBWeightFun(),
     "delay": lambda source_node, target_node: tvb_delay_fun(source_node, target_node),  
     "receptor_type": "ampa", 
     "source_nodes": ann_model_builder.Crtx_nodes_ids, 
     "target_nodes": ann_model_builder.Eth_nodes_ids},  # None means apply to all
    {"source": Ectx, "target": "E",          # "Ectx" -> "Estn"
     "synapse_model": synapse_model, "conn_spec": conn_spec_fixed_prob(pCtxSTN),  # conn_spec
     "weight": TVBWeightFun(),
     "delay": lambda source_node, target_node: tvb_delay_fun(source_node, target_node),  
     "receptor_type": "ampa", 
     "source_nodes": ann_model_builder.Crtx_nodes_ids, 
     "target_nodes": ann_model_builder.Estn_nodes_ids},  # None means apply to all
    {"source": Ectx, "target": "IdSN",          # "Ectx" -> "IdSN" 
     "synapse_model": synapse_model, "conn_spec": conn_spec_fixed_prob(pCtxdSN),  # conn_spec
     "weight": wCtxdSN, # TVBWeightFun(),
     "delay": lambda source_node, target_node: tvb_delay_fun(source_node, target_node),  
     "receptor_type": "ampa", 
     "source_nodes": ann_model_builder.Crtx_nodes_ids, 
     "target_nodes": ann_model_builder.Istr_nodes_ids},  # None means apply to all
    {"source": Ectx, "target": "IiSN",          # "Ectx" -> "IiSN" 
     "synapse_model": synapse_model, "conn_spec": conn_spec_fixed_prob(pCtxiSN),  # conn_spec
     "weight": wCtxiSN, # TVBWeightFun(ann_model_builder.tvb_weights, 
                            # wCrtxdSNtoCrtxiSN * ann_model_builder.global_coupling_scaling),
     "delay": lambda source_node, target_node: tvb_delay_fun(source_node, target_node),  
     "receptor_type": "ampa", 
     "source_nodes": ann_model_builder.Crtx_nodes_ids,
     "target_nodes": ann_model_builder.Istr_nodes_ids}  # None means apply to all
     ]


# Creating  devices to be able to observe ANNarchy activity:

ann_model_builder.output_devices = []

period = 1.0

# Creating  devices to be able to observe ANNarchy activity:
params = deepcopy(ann_model_builder.config.ANNARCHY_OUTPUT_DEVICES_PARAMS_DEF["SpikeMonitor"])
for pop in ann_model_builder.populations:
    connections = OrderedDict({})
    #                      label <- target population
    connections[pop["label"]] = pop["label"]
    ann_model_builder.output_devices.append(
        {"model": "SpikeMonitor", "params": deepcopy(params),
         "connections": connections, "nodes": pop["nodes"]})  # None means apply to "all"

# Labels have to be different for every connection to every distinct population
# params for baladron implementation commented out for the moment
# TODO: use baladron neurons
params = deepcopy(ann_model_builder.config.ANNARCHY_OUTPUT_DEVICES_PARAMS_DEF["Monitor"])
params.update({"period": period,  
               'variables': ["v", "u", "I_syn", "I_syn_ex", "I_syn_in", "g_ampa", "g_gaba", "g_base"]})
for pop in ann_model_builder.populations:
    if pop['label'] != "Ectx":
        connections = OrderedDict({})
        #               label    <- target population
        connections[pop["label"] + "_ts"] = pop["label"]
        ann_model_builder.output_devices.append(
            {"model": "Monitor", "params": deepcopy(params),
             "connections": connections, "nodes": pop["nodes"]})  # None means apply to all
    
    
# # Create a spike stimulus input device
ann_model_builder.input_devices = []  #

# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------
# ----------------------------------------------------------------------------------------------------------------

ann_model_builder.configure()

ann_network = ann_model_builder.build(set_defaults=False)
# Out:
# ANNarchy 5.0 (5.0.1) on linux (posix).
# 2026-03-31 09:40:38,665 - INFO - tvb-multiscale - Loading an ANNarchy instance...
# 2026-03-31 09:40:38,665 - INFO - tvb-multiscale - Loading an ANNarchy instance...
# 2026-03-31 09:40:38,665 - INFO - tvb-multiscale - Loading an ANNarchy instance...
# 2026-03-31 09:40:38,667 - INFO - tvb-multiscale - Cleaning ANNarchy compilation directory, if any...
# 2026-03-31 09:40:38,667 - INFO - tvb-multiscale - Cleaning ANNarchy compilation directory, if any...
# 2026-03-31 09:40:38,667 - INFO - tvb-multiscale - Cleaning ANNarchy compilation directory, if any...
# 2026-03-31 09:40:38,669 - INFO - tvb-multiscale - Configuring spiking network builder...
# 2026-03-31 09:40:38,669 - INFO - tvb-multiscale - Configuring spiking network builder...
# 2026-03-31 09:40:38,669 - INFO - tvb-multiscale - Configuring spiking network builder...
# 2026-03-31 09:40:38,670 - INFO - tvb-multiscale - Configuring populations...
# 2026-03-31 09:40:38,670 - INFO - tvb-multiscale - Configuring populations...
# 2026-03-31 09:40:38,670 - INFO - tvb-multiscale - Configuring populations...
# 2026-03-31 09:40:38,671 - INFO - tvb-multiscale - Configuring populations' connections within spiking region nodes...
# 2026-03-31 09:40:38,671 - INFO - tvb-multiscale - Configuring populations' connections within spiking region nodes...
# 2026-03-31 09:40:38,671 - INFO - tvb-multiscale - Configuring populations' connections within spiking region nodes...
# 2026-03-31 09:40:38,673 - INFO - tvb-multiscale - Configuring populations' connections among spiking region nodes...
# 2026-03-31 09:40:38,673 - INFO - tvb-multiscale - Configuring populations' connections among spiking region nodes...
# 2026-03-31 09:40:38,673 - INFO - tvb-multiscale - Configuring populations' connections among spiking region nodes...
# 2026-03-31 09:40:38,675 - INFO - tvb-multiscale - Configuring output devices, if any...
# 2026-03-31 09:40:38,675 - INFO - tvb-multiscale - Configuring output devices, if any...
# 2026-03-31 09:40:38,675 - INFO - tvb-multiscale - Configuring output devices, if any...
# 2026-03-31 09:40:38,676 - INFO - tvb-multiscale - Configuring input devices, if any...
# 2026-03-31 09:40:38,676 - INFO - tvb-multiscale - Configuring input devices, if any...
# 2026-03-31 09:40:38,676 - INFO - tvb-multiscale - Configuring input devices, if any...
# 2026-03-31 09:40:38,678 - INFO - tvb-multiscale - Generating spiking brain...
# 2026-03-31 09:40:38,678 - INFO - tvb-multiscale - Generating spiking brain...
# 2026-03-31 09:40:38,678 - INFO - tvb-multiscale - Generating spiking brain...
# 2026-03-31 09:40:38,680 - INFO - tvb-multiscale - Generating spiking brain regions...
# 2026-03-31 09:40:38,680 - INFO - tvb-multiscale - Generating spiking brain regions...
# 2026-03-31 09:40:38,680 - INFO - tvb-multiscale - Generating spiking brain regions...
# 2026-03-31 09:40:38,682 - INFO - tvb-multiscale - Generating spiking region node: GPe_Left...
# 2026-03-31 09:40:38,682 - INFO - tvb-multiscale - Generating spiking region node: GPe_Left...
# 2026-03-31 09:40:38,682 - INFO - tvb-multiscale - Generating spiking region node: GPe_Left...
# 2026-03-31 09:40:38,684 - INFO - tvb-multiscale - Generating population: I...
# 2026-03-31 09:40:38,684 - INFO - tvb-multiscale - Generating population: I...
# 2026-03-31 09:40:38,684 - INFO - tvb-multiscale - Generating population: I...
# 2026-03-31 09:40:38,845 - INFO - tvb-multiscale - Generating spiking region node: GPi_Left...
# 2026-03-31 09:40:38,845 - INFO - tvb-multiscale - Generating spiking region node: GPi_Left...
# 2026-03-31 09:40:38,845 - INFO - tvb-multiscale - Generating spiking region node: GPi_Left...
# 2026-03-31 09:40:38,847 - INFO - tvb-multiscale - Generating population: I...
# 2026-03-31 09:40:38,847 - INFO - tvb-multiscale - Generating population: I...
# 2026-03-31 09:40:38,847 - INFO - tvb-multiscale - Generating population: I...
# 2026-03-31 09:40:38,891 - INFO - tvb-multiscale - Generating spiking region node: STN_Left...
# 2026-03-31 09:40:38,891 - INFO - tvb-multiscale - Generating spiking region node: STN_Left...
# 2026-03-31 09:40:38,891 - INFO - tvb-multiscale - Generating spiking region node: STN_Left...
# 2026-03-31 09:40:38,893 - INFO - tvb-multiscale - Generating population: E...
# 2026-03-31 09:40:38,893 - INFO - tvb-multiscale - Generating population: E...
# 2026-03-31 09:40:38,893 - INFO - tvb-multiscale - Generating population: E...
# 2026-03-31 09:40:38,938 - INFO - tvb-multiscale - Generating spiking region node: Striatum_Left...
# 2026-03-31 09:40:38,938 - INFO - tvb-multiscale - Generating spiking region node: Striatum_Left...
# 2026-03-31 09:40:38,938 - INFO - tvb-multiscale - Generating spiking region node: Striatum_Left...
# 2026-03-31 09:40:38,940 - INFO - tvb-multiscale - Generating population: IdSN...
# 2026-03-31 09:40:38,940 - INFO - tvb-multiscale - Generating population: IdSN...
# 2026-03-31 09:40:38,940 - INFO - tvb-multiscale - Generating population: IdSN...
# 2026-03-31 09:40:38,984 - INFO - tvb-multiscale - Generating population: IiSN...
# 2026-03-31 09:40:38,984 - INFO - tvb-multiscale - Generating population: IiSN...
# 2026-03-31 09:40:38,984 - INFO - tvb-multiscale - Generating population: IiSN...
# 2026-03-31 09:40:39,029 - INFO - tvb-multiscale - Generating spiking region node: Thal_Left...
# 2026-03-31 09:40:39,029 - INFO - tvb-multiscale - Generating spiking region node: Thal_Left...
# 2026-03-31 09:40:39,029 - INFO - tvb-multiscale - Generating spiking region node: Thal_Left...
# 2026-03-31 09:40:39,031 - INFO - tvb-multiscale - Generating population: E...
# 2026-03-31 09:40:39,031 - INFO - tvb-multiscale - Generating population: E...
# 2026-03-31 09:40:39,031 - INFO - tvb-multiscale - Generating population: E...
# 2026-03-31 09:40:39,078 - INFO - tvb-multiscale - Generating spiking region node: Cortex...
# 2026-03-31 09:40:39,078 - INFO - tvb-multiscale - Generating spiking region node: Cortex...
# 2026-03-31 09:40:39,078 - INFO - tvb-multiscale - Generating spiking region node: Cortex...
# 2026-03-31 09:40:39,081 - INFO - tvb-multiscale - Generating population: E...
# 2026-03-31 09:40:39,081 - INFO - tvb-multiscale - Generating population: E...
# 2026-03-31 09:40:39,081 - INFO - tvb-multiscale - Generating population: E...
# 2026-03-31 09:40:39,127 - INFO - tvb-multiscale - Generating population: I...
# 2026-03-31 09:40:39,127 - INFO - tvb-multiscale - Generating population: I...
# 2026-03-31 09:40:39,127 - INFO - tvb-multiscale - Generating population: I...
# 2026-03-31 09:40:39,174 - INFO - tvb-multiscale - Connecting populations within spiking brain regions...
# 2026-03-31 09:40:39,174 - INFO - tvb-multiscale - Connecting populations within spiking brain regions...
# 2026-03-31 09:40:39,174 - INFO - tvb-multiscale - Connecting populations within spiking brain regions...
# 2026-03-31 09:40:39,176 - INFO - tvb-multiscale - Connecting I -> I populations
# for spiking region nodes
# [5]...
# 2026-03-31 09:40:39,176 - INFO - tvb-multiscale - Connecting I -> I populations
# for spiking region nodes
# [5]...
# 2026-03-31 09:40:39,176 - INFO - tvb-multiscale - Connecting I -> I populations
# for spiking region nodes
# [5]...
# 2026-03-31 09:40:39,178 - INFO - tvb-multiscale - Connecting E -> I populations
# for spiking region nodes
# [5]...
# 2026-03-31 09:40:39,178 - INFO - tvb-multiscale - Connecting E -> I populations
# for spiking region nodes
# [5]...
# 2026-03-31 09:40:39,178 - INFO - tvb-multiscale - Connecting E -> I populations
# for spiking region nodes
# [5]...
# 2026-03-31 09:40:39,180 - INFO - tvb-multiscale - Connecting I -> E populations
# for spiking region nodes
# [5]...
# 2026-03-31 09:40:39,180 - INFO - tvb-multiscale - Connecting I -> E populations
# for spiking region nodes
# [5]...
# 2026-03-31 09:40:39,180 - INFO - tvb-multiscale - Connecting I -> E populations
# for spiking region nodes
# [5]...
# 2026-03-31 09:40:39,182 - INFO - tvb-multiscale - Connecting I -> I populations
# for spiking region nodes
# [0]...
# 2026-03-31 09:40:39,182 - INFO - tvb-multiscale - Connecting I -> I populations
# for spiking region nodes
# [0]...
# 2026-03-31 09:40:39,182 - INFO - tvb-multiscale - Connecting I -> I populations
# for spiking region nodes
# [0]...
# 2026-03-31 09:40:39,185 - INFO - tvb-multiscale - Connecting I -> I populations
# for spiking region nodes
# [1]...
# 2026-03-31 09:40:39,185 - INFO - tvb-multiscale - Connecting I -> I populations
# for spiking region nodes
# [1]...
# 2026-03-31 09:40:39,185 - INFO - tvb-multiscale - Connecting I -> I populations
# for spiking region nodes
# [1]...
# 2026-03-31 09:40:39,187 - INFO - tvb-multiscale - Connecting IdSN -> IdSN populations
# for spiking region nodes
# [3]...
# 2026-03-31 09:40:39,187 - INFO - tvb-multiscale - Connecting IdSN -> IdSN populations
# for spiking region nodes
# [3]...
# 2026-03-31 09:40:39,187 - INFO - tvb-multiscale - Connecting IdSN -> IdSN populations
# for spiking region nodes
# [3]...
# 2026-03-31 09:40:39,189 - INFO - tvb-multiscale - Connecting IiSN -> IiSN populations
# for spiking region nodes
# [3]...
# 2026-03-31 09:40:39,189 - INFO - tvb-multiscale - Connecting IiSN -> IiSN populations
# for spiking region nodes
# [3]...
# 2026-03-31 09:40:39,189 - INFO - tvb-multiscale - Connecting IiSN -> IiSN populations
# for spiking region nodes
# [3]...
# 2026-03-31 09:40:39,190 - INFO - tvb-multiscale - Connecting populations among spiking brain regions...
# 2026-03-31 09:40:39,190 - INFO - tvb-multiscale - Connecting populations among spiking brain regions...
# 2026-03-31 09:40:39,190 - INFO - tvb-multiscale - Connecting populations among spiking brain regions...
# 2026-03-31 09:40:39,192 - INFO - tvb-multiscale - Connecting for 3 -> 1 spiking region nodes ...
# 2026-03-31 09:40:39,192 - INFO - tvb-multiscale - Connecting for 3 -> 1 spiking region nodes ...
# 2026-03-31 09:40:39,192 - INFO - tvb-multiscale - Connecting for 3 -> 1 spiking region nodes ...
# 2026-03-31 09:40:39,193 - INFO - tvb-multiscale - IdSN -> I populations ...
# 2026-03-31 09:40:39,193 - INFO - tvb-multiscale - IdSN -> I populations ...
# 2026-03-31 09:40:39,193 - INFO - tvb-multiscale - IdSN -> I populations ...
# 2026-03-31 09:40:39,195 - INFO - tvb-multiscale - Connecting for 3 -> 0 spiking region nodes ...
# 2026-03-31 09:40:39,195 - INFO - tvb-multiscale - Connecting for 3 -> 0 spiking region nodes ...
# 2026-03-31 09:40:39,195 - INFO - tvb-multiscale - Connecting for 3 -> 0 spiking region nodes ...
# 2026-03-31 09:40:39,197 - INFO - tvb-multiscale - IiSN -> I populations ...
# 2026-03-31 09:40:39,197 - INFO - tvb-multiscale - IiSN -> I populations ...
# 2026-03-31 09:40:39,197 - INFO - tvb-multiscale - IiSN -> I populations ...
# 2026-03-31 09:40:39,198 - INFO - tvb-multiscale - Connecting for 0 -> 1 spiking region nodes ...
# 2026-03-31 09:40:39,198 - INFO - tvb-multiscale - Connecting for 0 -> 1 spiking region nodes ...
# 2026-03-31 09:40:39,198 - INFO - tvb-multiscale - Connecting for 0 -> 1 spiking region nodes ...
# 2026-03-31 09:40:39,200 - INFO - tvb-multiscale - I -> I populations ...
# 2026-03-31 09:40:39,200 - INFO - tvb-multiscale - I -> I populations ...
# 2026-03-31 09:40:39,200 - INFO - tvb-multiscale - I -> I populations ...
# 2026-03-31 09:40:39,202 - INFO - tvb-multiscale - Connecting for 1 -> 4 spiking region nodes ...
# 2026-03-31 09:40:39,202 - INFO - tvb-multiscale - Connecting for 1 -> 4 spiking region nodes ...
# 2026-03-31 09:40:39,202 - INFO - tvb-multiscale - Connecting for 1 -> 4 spiking region nodes ...
# 2026-03-31 09:40:39,203 - INFO - tvb-multiscale - I -> E populations ...
# 2026-03-31 09:40:39,203 - INFO - tvb-multiscale - I -> E populations ...
# 2026-03-31 09:40:39,203 - INFO - tvb-multiscale - I -> E populations ...
# 2026-03-31 09:40:39,205 - INFO - tvb-multiscale - Connecting for 0 -> 2 spiking region nodes ...
# 2026-03-31 09:40:39,205 - INFO - tvb-multiscale - Connecting for 0 -> 2 spiking region nodes ...
# 2026-03-31 09:40:39,205 - INFO - tvb-multiscale - Connecting for 0 -> 2 spiking region nodes ...
# 2026-03-31 09:40:39,207 - INFO - tvb-multiscale - I -> E populations ...
# 2026-03-31 09:40:39,207 - INFO - tvb-multiscale - I -> E populations ...
# 2026-03-31 09:40:39,207 - INFO - tvb-multiscale - I -> E populations ...
# 2026-03-31 09:40:39,209 - INFO - tvb-multiscale - Connecting for 4 -> 3 spiking region nodes ...
# 2026-03-31 09:40:39,209 - INFO - tvb-multiscale - Connecting for 4 -> 3 spiking region nodes ...
# 2026-03-31 09:40:39,209 - INFO - tvb-multiscale - Connecting for 4 -> 3 spiking region nodes ...
# 2026-03-31 09:40:39,210 - INFO - tvb-multiscale - E -> IdSN populations ...
# 2026-03-31 09:40:39,210 - INFO - tvb-multiscale - E -> IdSN populations ...
# 2026-03-31 09:40:39,210 - INFO - tvb-multiscale - E -> IdSN populations ...
# 2026-03-31 09:40:39,212 - INFO - tvb-multiscale - Connecting for 4 -> 3 spiking region nodes ...
# 2026-03-31 09:40:39,212 - INFO - tvb-multiscale - Connecting for 4 -> 3 spiking region nodes ...
# 2026-03-31 09:40:39,212 - INFO - tvb-multiscale - Connecting for 4 -> 3 spiking region nodes ...
# 2026-03-31 09:40:39,213 - INFO - tvb-multiscale - E -> IiSN populations ...
# 2026-03-31 09:40:39,213 - INFO - tvb-multiscale - E -> IiSN populations ...
# 2026-03-31 09:40:39,213 - INFO - tvb-multiscale - E -> IiSN populations ...
# 2026-03-31 09:40:39,215 - INFO - tvb-multiscale - Connecting for 2 -> 0 spiking region nodes ...
# 2026-03-31 09:40:39,215 - INFO - tvb-multiscale - Connecting for 2 -> 0 spiking region nodes ...
# 2026-03-31 09:40:39,215 - INFO - tvb-multiscale - Connecting for 2 -> 0 spiking region nodes ...
# 2026-03-31 09:40:39,216 - INFO - tvb-multiscale - E -> I populations ...
# 2026-03-31 09:40:39,216 - INFO - tvb-multiscale - E -> I populations ...
# 2026-03-31 09:40:39,216 - INFO - tvb-multiscale - E -> I populations ...
# 2026-03-31 09:40:39,219 - INFO - tvb-multiscale - Connecting for 2 -> 1 spiking region nodes ...
# 2026-03-31 09:40:39,219 - INFO - tvb-multiscale - Connecting for 2 -> 1 spiking region nodes ...
# 2026-03-31 09:40:39,219 - INFO - tvb-multiscale - Connecting for 2 -> 1 spiking region nodes ...
# 2026-03-31 09:40:39,220 - INFO - tvb-multiscale - E -> I populations ...
# 2026-03-31 09:40:39,220 - INFO - tvb-multiscale - E -> I populations ...
# 2026-03-31 09:40:39,220 - INFO - tvb-multiscale - E -> I populations ...
# 2026-03-31 09:40:39,222 - INFO - tvb-multiscale - Connecting for 5 -> 4 spiking region nodes ...
# 2026-03-31 09:40:39,222 - INFO - tvb-multiscale - Connecting for 5 -> 4 spiking region nodes ...
# 2026-03-31 09:40:39,222 - INFO - tvb-multiscale - Connecting for 5 -> 4 spiking region nodes ...
# 2026-03-31 09:40:39,223 - INFO - tvb-multiscale - E -> E populations ...
# 2026-03-31 09:40:39,223 - INFO - tvb-multiscale - E -> E populations ...
# 2026-03-31 09:40:39,223 - INFO - tvb-multiscale - E -> E populations ...
# 2026-03-31 09:40:39,225 - INFO - tvb-multiscale - Connecting for 5 -> 2 spiking region nodes ...
# 2026-03-31 09:40:39,225 - INFO - tvb-multiscale - Connecting for 5 -> 2 spiking region nodes ...
# 2026-03-31 09:40:39,225 - INFO - tvb-multiscale - Connecting for 5 -> 2 spiking region nodes ...
# 2026-03-31 09:40:39,226 - INFO - tvb-multiscale - E -> E populations ...
# 2026-03-31 09:40:39,226 - INFO - tvb-multiscale - E -> E populations ...
# 2026-03-31 09:40:39,226 - INFO - tvb-multiscale - E -> E populations ...
# 2026-03-31 09:40:39,229 - INFO - tvb-multiscale - Connecting for 5 -> 3 spiking region nodes ...
# 2026-03-31 09:40:39,229 - INFO - tvb-multiscale - Connecting for 5 -> 3 spiking region nodes ...
# 2026-03-31 09:40:39,229 - INFO - tvb-multiscale - Connecting for 5 -> 3 spiking region nodes ...
# 2026-03-31 09:40:39,230 - INFO - tvb-multiscale - E -> IdSN populations ...
# 2026-03-31 09:40:39,230 - INFO - tvb-multiscale - E -> IdSN populations ...
# 2026-03-31 09:40:39,230 - INFO - tvb-multiscale - E -> IdSN populations ...
# 2026-03-31 09:40:39,233 - INFO - tvb-multiscale - Connecting for 5 -> 3 spiking region nodes ...
# 2026-03-31 09:40:39,233 - INFO - tvb-multiscale - Connecting for 5 -> 3 spiking region nodes ...
# 2026-03-31 09:40:39,233 - INFO - tvb-multiscale - Connecting for 5 -> 3 spiking region nodes ...
# 2026-03-31 09:40:39,234 - INFO - tvb-multiscale - E -> IiSN populations ...
# 2026-03-31 09:40:39,234 - INFO - tvb-multiscale - E -> IiSN populations ...
# 2026-03-31 09:40:39,234 - INFO - tvb-multiscale - E -> IiSN populations ...
# 2026-03-31 09:40:39,235 - INFO - tvb-multiscale - Generating and connecting output devices, if any...
# 2026-03-31 09:40:39,235 - INFO - tvb-multiscale - Generating and connecting output devices, if any...
# 2026-03-31 09:40:39,235 - INFO - tvb-multiscale - Generating and connecting output devices, if any...
# 2026-03-31 09:40:39,237 - INFO - tvb-multiscale - Generating and connecting ['E'] -> ['E'] device set of model SpikeMonitor
# for nodes [2, 4, 5]...
# 2026-03-31 09:40:39,237 - INFO - tvb-multiscale - Generating and connecting ['E'] -> ['E'] device set of model SpikeMonitor
# for nodes [2, 4, 5]...
# 2026-03-31 09:40:39,237 - INFO - tvb-multiscale - Generating and connecting ['E'] -> ['E'] device set of model SpikeMonitor
# for nodes [2, 4, 5]...
# 2026-03-31 09:40:39,239 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E created!
# 2026-03-31 09:40:39,239 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E created!
# 2026-03-31 09:40:39,241 - INFO - tvb-multiscale - Generating and connecting ['I'] -> ['I'] device set of model SpikeMonitor
# for nodes [0, 1, 5]...
# 2026-03-31 09:40:39,241 - INFO - tvb-multiscale - Generating and connecting ['I'] -> ['I'] device set of model SpikeMonitor
# for nodes [0, 1, 5]...
# 2026-03-31 09:40:39,241 - INFO - tvb-multiscale - Generating and connecting ['I'] -> ['I'] device set of model SpikeMonitor
# for nodes [0, 1, 5]...
# 2026-03-31 09:40:39,243 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for I created!
# 2026-03-31 09:40:39,243 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for I created!
# 2026-03-31 09:40:39,246 - INFO - tvb-multiscale - Generating and connecting ['IdSN'] -> ['IdSN'] device set of model SpikeMonitor
# for nodes [3]...
# 2026-03-31 09:40:39,246 - INFO - tvb-multiscale - Generating and connecting ['IdSN'] -> ['IdSN'] device set of model SpikeMonitor
# for nodes [3]...
# 2026-03-31 09:40:39,246 - INFO - tvb-multiscale - Generating and connecting ['IdSN'] -> ['IdSN'] device set of model SpikeMonitor
# for nodes [3]...
# 2026-03-31 09:40:39,248 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for IdSN created!
# 2026-03-31 09:40:39,248 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for IdSN created!
# 2026-03-31 09:40:39,250 - INFO - tvb-multiscale - Generating and connecting ['IiSN'] -> ['IiSN'] device set of model SpikeMonitor
# for nodes [3]...
# 2026-03-31 09:40:39,250 - INFO - tvb-multiscale - Generating and connecting ['IiSN'] -> ['IiSN'] device set of model SpikeMonitor
# for nodes [3]...
# 2026-03-31 09:40:39,250 - INFO - tvb-multiscale - Generating and connecting ['IiSN'] -> ['IiSN'] device set of model SpikeMonitor
# for nodes [3]...
# 2026-03-31 09:40:39,252 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for IiSN created!
# 2026-03-31 09:40:39,252 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for IiSN created!
# 2026-03-31 09:40:39,254 - INFO - tvb-multiscale - Generating and connecting ['E_ts'] -> ['E'] device set of model Monitor
# for nodes [2, 4, 5]...
# 2026-03-31 09:40:39,254 - INFO - tvb-multiscale - Generating and connecting ['E_ts'] -> ['E'] device set of model Monitor
# for nodes [2, 4, 5]...
# 2026-03-31 09:40:39,254 - INFO - tvb-multiscale - Generating and connecting ['E_ts'] -> ['E'] device set of model Monitor
# for nodes [2, 4, 5]...
# 2026-03-31 09:40:39,256 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for E_ts created!
# 2026-03-31 09:40:39,256 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for E_ts created!
# 2026-03-31 09:40:39,259 - INFO - tvb-multiscale - Generating and connecting ['I_ts'] -> ['I'] device set of model Monitor
# for nodes [0, 1, 5]...
# 2026-03-31 09:40:39,259 - INFO - tvb-multiscale - Generating and connecting ['I_ts'] -> ['I'] device set of model Monitor
# for nodes [0, 1, 5]...
# 2026-03-31 09:40:39,259 - INFO - tvb-multiscale - Generating and connecting ['I_ts'] -> ['I'] device set of model Monitor
# for nodes [0, 1, 5]...
# 2026-03-31 09:40:39,261 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for I_ts created!
# 2026-03-31 09:40:39,261 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for I_ts created!
# 2026-03-31 09:40:39,264 - INFO - tvb-multiscale - Generating and connecting ['IdSN_ts'] -> ['IdSN'] device set of model Monitor
# for nodes [3]...
# 2026-03-31 09:40:39,264 - INFO - tvb-multiscale - Generating and connecting ['IdSN_ts'] -> ['IdSN'] device set of model Monitor
# for nodes [3]...
# 2026-03-31 09:40:39,264 - INFO - tvb-multiscale - Generating and connecting ['IdSN_ts'] -> ['IdSN'] device set of model Monitor
# for nodes [3]...
# 2026-03-31 09:40:39,266 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for IdSN_ts created!
# 2026-03-31 09:40:39,266 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for IdSN_ts created!
# 2026-03-31 09:40:39,268 - INFO - tvb-multiscale - Generating and connecting ['IiSN_ts'] -> ['IiSN'] device set of model Monitor
# for nodes [3]...
# 2026-03-31 09:40:39,268 - INFO - tvb-multiscale - Generating and connecting ['IiSN_ts'] -> ['IiSN'] device set of model Monitor
# for nodes [3]...
# 2026-03-31 09:40:39,268 - INFO - tvb-multiscale - Generating and connecting ['IiSN_ts'] -> ['IiSN'] device set of model Monitor
# for nodes [3]...
# 2026-03-31 09:40:39,269 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for IiSN_ts created!
# 2026-03-31 09:40:39,269 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for IiSN_ts created!
# 2026-03-31 09:40:39,272 - INFO - tvb-multiscale - Generating and connecting input devices, if any...
# 2026-03-31 09:40:39,272 - INFO - tvb-multiscale - Generating and connecting input devices, if any...
# 2026-03-31 09:40:39,272 - INFO - tvb-multiscale - Generating and connecting input devices, if any...
# 2026-03-31 09:40:39,274 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-03-31 09:40:39,274 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-03-31 09:40:39,274 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-03-31 09:40:39,274 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!

# %%
# The stimuli models:

if simulation_mode != "rs":

    # amplitude in mV or V? Was V in Michmizos paper, but had value 5.
    # frequency in Hz and later divided by 1000 because time scale is ms
    # duration in ms!
    #dt inside annarchy needs to be <=0.01 to realize a 60µs pulse width, but setting it to that leads to errors. 
    # realistic "duration" parameter for DBSInput would be 0.06

    if stim_mode.find("mono") > -1:
        DBSInput = ann.Neuron(
            parameters="""
                amplitude = 5.0
                kappa = 8
                frequency = 130
                duration = 0.1
            """,
            equations="""
                h1 = if sin(2*pi*(frequency/1000)*t) > 0 : 1 else : 0
                h2 = if sin(2*pi*(frequency/1000)*(t+duration)) > 0 : 1 else : 0
                r = amplitude*kappa*h1*(1-h2)
            """
        )
    elif stim_mode.find("bi") > -1:
        DBSInput = ann.Neuron(
            parameters="""
                amplitude = 5.0
                ampfactor = 10
                kappa = 8
                frequency = 130
                duration = 0.3
            """,
            equations="""
                h1 = if sin(2*pi*(frequency/1000)*t) > 0 : 1 else : 0
                h2 = if sin(2*pi*(frequency/1000)*(t-duration)) > 0 : 1 else : 0
                h4 = if sin(2*pi*(frequency/1000)*(t-((ampfactor+1)*duration))) > 0 : 1 else : 0
                i1 = amplitude*(1+ 1/ampfactor)*kappa*h1*(1-h2)
                i2 = (-amplitude/ampfactor) *kappa *h1*(1-h4)
                r = i1 + i2
            """
        )

# %%
# Prepare the stimuli:

if simulation_mode != "rs":
    
    if stim_target.find("STN") > -1:
        stim_target = "STN_Left" 
    else:
        stim_target = "GPi_Left" 
        
    if stim_mode != "simple":
        # now add DBS population invisible to TVB for now
        target_pop = ann_network.brain_regions[stim_target][0].population
        dbs_pop = annarchy_network.annarchy_network.create(target_pop.size, DBSInput)
        dbs_proj = annarchy_network.annarchy_network.CurrentInjection(dbs_pop, target_pop, 'dbs')
        dbs_proj.connect_current()
        # switch the stimulation off for the first time segment
        dbs_pop.amplitude = 0
        dbs_pop.frequency = stim_freq
        dbs_pop.duration = stim_duration
    #     # if a pulse duration that is not zero is given, set it
    #     if pulse_width is not None:
    #         dbs_pop.duration = pulse_width

        # just to check, add some annarchy monitors -> delete later    
        m1 = annarchy_network.annarchy_network.monitor(dbs_pop, "r")
        m2 = annarchy_network.annarchy_network.monitor(target_pop, ["g_dbs", "spike"])

# %% [markdown]
# ## 3. Configure simulator, simulate, gather results

# %%
t = time.time()
ann_network.configure()
print("\nCompiled in %g secs!" % (time.time() - t))
# Out:
# Compiled in 0.187137 secs!

# %%
ann_network.print_summary_info_details(recursive=2, connectivity=False)
# Out:
# ANNarchyNetwork (
#   title .......................................... 'ANNarchyNetwork gid: d7917531-5712-4e1a-be19-28aa3e155429'
#   Type ........................................... 'ANNarchyNetwork'
#   annarchy_network ............................... <ANNarchy.core.Network.Network object at 0xffff1b1c0140>
#   config ......................................... '--------------------'
#   config.title ................................... 'Config gid: 75a04616-379b-43e5-90df-67aa9dafc54f'
#   config.Type .................................... 'Config'
#   config.gid ..................................... UUID('75a04616-379b-43e5-90df-67aa9dafc54f')
#   brain_regions .................................. '--------------------'
#   brain_regions.title ............................ 'ANNarchyBrain gid: fe4a373b-2b5f-4113-ad7f-51c343a40407'
#   brain_regions.Type ............................. 'ANNarchyBrain'
#   brain_regions.gid .............................. UUID('fe4a373b-2b5f-4113-ad7f-51c343a40407')
#   brain_regions.label ............................ ''
#   brain_regions.size ............................. 6
#   brain_regions.Regions .......................... --------------------
#   brain_regions.Regions: shape ................... (6,)
#   brain_regions.Regions: dtype ................... <U13
#   brain_regions.Regions: values .................. ['GPe_Left' 'GPi_Left' 'STN_Left' 'Striatum_Left' 'Thal_Left' 'Cortex']
#   brain_regions.GPe_Left ......................... '--------------------'
#   brain_regions[GPe_Left].title .................. 'ANNarchyRegionNode gid: a97626aa-3453-49d3-b5bd-b5598d1a8eca'
#   brain_regions[GPe_Left].Type ................... 'ANNarchyRegionNode'
#   brain_regions[GPe_Left].gid .................... UUID('a97626aa-3453-49d3-b5bd-b5598d1a8eca')
#   brain_regions[GPe_Left].label .................. 'GPe_Left'
#   brain_regions[GPe_Left].size ................... 1
#   brain_regions[GPe_Left].Populations ............ --------------------
#   brain_regions[GPe_Left].Populations: shape ..... (1,)
#   brain_regions[GPe_Left].Populations: dtype ..... <U1
#   brain_regions[GPe_Left].Populations: values .... I
#   brain_regions.GPi_Left ......................... '--------------------'
#   brain_regions[GPi_Left].title .................. 'ANNarchyRegionNode gid: 23f1ee7e-1c2a-4dce-9252-054f07582fb7'
#   brain_regions[GPi_Left].Type ................... 'ANNarchyRegionNode'
#   brain_regions[GPi_Left].gid .................... UUID('23f1ee7e-1c2a-4dce-9252-054f07582fb7')
#   brain_regions[GPi_Left].label .................. 'GPi_Left'
#   brain_regions[GPi_Left].size ................... 1
#   brain_regions[GPi_Left].Populations ............ --------------------
#   brain_regions[GPi_Left].Populations: shape ..... (1,)
#   brain_regions[GPi_Left].Populations: dtype ..... <U1
#   brain_regions[GPi_Left].Populations: values .... I
#   brain_regions.STN_Left ......................... '--------------------'
#   brain_regions[STN_Left].title .................. 'ANNarchyRegionNode gid: ce69d9f4-a6d9-4591-b31c-12b8bbf5af23'
#   brain_regions[STN_Left].Type ................... 'ANNarchyRegionNode'
#   brain_regions[STN_Left].gid .................... UUID('ce69d9f4-a6d9-4591-b31c-12b8bbf5af23')
#   brain_regions[STN_Left].label .................. 'STN_Left'
#   brain_regions[STN_Left].size ................... 1
#   brain_regions[STN_Left].Populations ............ --------------------
#   brain_regions[STN_Left].Populations: shape ..... (1,)
#   brain_regions[STN_Left].Populations: dtype ..... <U1
#   brain_regions[STN_Left].Populations: values .... E
#   brain_regions.Striatum_Left .................... '--------------------'
#   brain_regions[Striatum_Left].title ............. 'ANNarchyRegionNode gid: 76f10d76-de74-4da6-b38f-74ff97003df3'
#   brain_regions[Striatum_Left].Type .............. 'ANNarchyRegionNode'
#   brain_regions[Striatum_Left].gid ............... UUID('76f10d76-de74-4da6-b38f-74ff97003df3')
#   brain_regions[Striatum_Left].label ............. 'Striatum_Left'
#   brain_regions[Striatum_Left].size .............. 2
#   brain_regions[Striatum_Left].Populations ....... --------------------
#   brain_regions[Striatum_Left].Populations: shape  (2,)
#   brain_regions[Striatum_Left].Populations: dtype  <U4
#   brain_regions[Striatum_Left].Populations: values  ['IdSN' 'IiSN']
#   brain_regions.Thal_Left ........................ '--------------------'
#   brain_regions[Thal_Left].title ................. 'ANNarchyRegionNode gid: 721ec7b3-344f-4954-9ab7-f4000cf8dd7d'
#   brain_regions[Thal_Left].Type .................. 'ANNarchyRegionNode'
#   brain_regions[Thal_Left].gid ................... UUID('721ec7b3-344f-4954-9ab7-f4000cf8dd7d')
#   brain_regions[Thal_Left].label ................. 'Thal_Left'
#   brain_regions[Thal_Left].size .................. 1
#   brain_regions[Thal_Left].Populations ........... --------------------
#   brain_regions[Thal_Left].Populations: shape .... (1,)
#   brain_regions[Thal_Left].Populations: dtype .... <U1
#   brain_regions[Thal_Left].Populations: values ... E
#   brain_regions.Cortex ........................... '--------------------'
#   brain_regions[Cortex].title .................... 'ANNarchyRegionNode gid: b1d0e0f2-9e68-461e-b5bd-bd1b7b32aba5'
#   brain_regions[Cortex].Type ..................... 'ANNarchyRegionNode'
#   brain_regions[Cortex].gid ...................... UUID('b1d0e0f2-9e68-461e-b5bd-bd1b7b32aba5')
#   brain_regions[Cortex].label .................... 'Cortex'
#   brain_regions[Cortex].size ..................... 2
#   brain_regions[Cortex].Populations .............. --------------------
#   brain_regions[Cortex].Populations: shape ....... (2,)
#   brain_regions[Cortex].Populations: dtype ....... <U1
#   brain_regions[Cortex].Populations: values ...... ['E' 'I']
#   network_path ................................... 'outputs/SpikingCortex/control/rs/ANNarchyNetwork'
#   logger ......................................... <Logger tvb-multiscale (DEBUG)>
#   output_devices ................................. '--------------------'
#   output_devices.title ........................... 'DeviceSets gid: 9d9e0362-576e-4721-8332-e103a78501e5'
#   output_devices.Type ............................ 'DeviceSets'
#   output_devices.gid ............................. UUID('9d9e0362-576e-4721-8332-e103a78501e5')
#   output_devices.label ........................... 'output_devices'
#   output_devices.size ............................ 8
#   output_devices.DeviceSets ...................... --------------------
#   output_devices.DeviceSets: shape ............... (8,)
#   output_devices.DeviceSets: dtype ............... <U7
#   output_devices.DeviceSets: values .............. ['E' 'I' 'IdSN' 'IiSN' 'E_ts' 'I_ts' 'IdSN_ts' 'IiSN_ts']
#   output_devices.E ............................... '--------------------'
#   output_devices[E].title ........................ 'DeviceSet gid: c66af2e8-51fd-4cd8-a4ac-46f7f29f1bc5'
#   output_devices[E].Type ......................... 'DeviceSet'
#   output_devices[E].model ........................ 'SpikeMonitor'
#   output_devices[E].gid .......................... UUID('c66af2e8-51fd-4cd8-a4ac-46f7f29f1bc5')
#   output_devices[E].label ........................ 'E'
#   output_devices[E].size ......................... 3
#   output_devices[E].Devices ...................... --------------------
#   output_devices[E].Devices: shape ............... (3,)
#   output_devices[E].Devices: dtype ............... <U9
#   output_devices[E].Devices: values .............. ['STN_Left' 'Thal_Left' 'Cortex']
#   output_devices.I ............................... '--------------------'
#   output_devices[I].title ........................ 'DeviceSet gid: 3fc75dea-f239-4536-b323-04f4238d0480'
#   output_devices[I].Type ......................... 'DeviceSet'
#   output_devices[I].model ........................ 'SpikeMonitor'
#   output_devices[I].gid .......................... UUID('3fc75dea-f239-4536-b323-04f4238d0480')
#   output_devices[I].label ........................ 'I'
#   output_devices[I].size ......................... 3
#   output_devices[I].Devices ...................... --------------------
#   output_devices[I].Devices: shape ............... (3,)
#   output_devices[I].Devices: dtype ............... <U8
#   output_devices[I].Devices: values .............. ['GPe_Left' 'GPi_Left' 'Cortex']
#   output_devices.IdSN ............................ '--------------------'
#   output_devices[IdSN].title ..................... 'DeviceSet gid: 33871846-5c5f-4cd3-92b8-e0d549ecef13'
#   output_devices[IdSN].Type ...................... 'DeviceSet'
#   output_devices[IdSN].model ..................... 'SpikeMonitor'
#   output_devices[IdSN].gid ....................... UUID('33871846-5c5f-4cd3-92b8-e0d549ecef13')
#   output_devices[IdSN].label ..................... 'IdSN'
#   output_devices[IdSN].size ...................... 1
#   output_devices[IdSN].Devices ................... --------------------
#   output_devices[IdSN].Devices: shape ............ (1,)
#   output_devices[IdSN].Devices: dtype ............ <U13
#   output_devices[IdSN].Devices: values ........... Striatum_Left
#   output_devices.IiSN ............................ '--------------------'
#   output_devices[IiSN].title ..................... 'DeviceSet gid: 9b239ecf-44b0-4b74-8fbe-0aa4e6d9860b'
#   output_devices[IiSN].Type ...................... 'DeviceSet'
#   output_devices[IiSN].model ..................... 'SpikeMonitor'
#   output_devices[IiSN].gid ....................... UUID('9b239ecf-44b0-4b74-8fbe-0aa4e6d9860b')
#   output_devices[IiSN].label ..................... 'IiSN'
#   output_devices[IiSN].size ...................... 1
#   output_devices[IiSN].Devices ................... --------------------
#   output_devices[IiSN].Devices: shape ............ (1,)
#   output_devices[IiSN].Devices: dtype ............ <U13
#   output_devices[IiSN].Devices: values ........... Striatum_Left
#   output_devices.E_ts ............................ '--------------------'
#   output_devices[E_ts].title ..................... 'DeviceSet gid: f93e0a34-e009-45e4-a0c5-550fdfd84255'
#   output_devices[E_ts].Type ...................... 'DeviceSet'
#   output_devices[E_ts].model ..................... 'Monitor'
#   output_devices[E_ts].gid ....................... UUID('f93e0a34-e009-45e4-a0c5-550fdfd84255')
#   output_devices[E_ts].label ..................... 'E_ts'
#   output_devices[E_ts].size ...................... 3
#   output_devices[E_ts].Devices ................... --------------------
#   output_devices[E_ts].Devices: shape ............ (3,)
#   output_devices[E_ts].Devices: dtype ............ <U9
#   output_devices[E_ts].Devices: values ........... ['STN_Left' 'Thal_Left' 'Cortex']
#   output_devices.I_ts ............................ '--------------------'
#   output_devices[I_ts].title ..................... 'DeviceSet gid: 26ba672a-c04f-48ba-984f-1dbf88de2d8c'
#   output_devices[I_ts].Type ...................... 'DeviceSet'
#   output_devices[I_ts].model ..................... 'Monitor'
#   output_devices[I_ts].gid ....................... UUID('26ba672a-c04f-48ba-984f-1dbf88de2d8c')
#   output_devices[I_ts].label ..................... 'I_ts'
#   output_devices[I_ts].size ...................... 3
#   output_devices[I_ts].Devices ................... --------------------
#   output_devices[I_ts].Devices: shape ............ (3,)
#   output_devices[I_ts].Devices: dtype ............ <U8
#   output_devices[I_ts].Devices: values ........... ['GPe_Left' 'GPi_Left' 'Cortex']
#   output_devices.IdSN_ts ......................... '--------------------'
#   output_devices[IdSN_ts].title .................. 'DeviceSet gid: 70bca780-279f-47e2-8b99-14d5036222ab'
#   output_devices[IdSN_ts].Type ................... 'DeviceSet'
#   output_devices[IdSN_ts].model .................. 'Monitor'
#   output_devices[IdSN_ts].gid .................... UUID('70bca780-279f-47e2-8b99-14d5036222ab')
#   output_devices[IdSN_ts].label .................. 'IdSN_ts'
#   output_devices[IdSN_ts].size ................... 1
#   output_devices[IdSN_ts].Devices ................ --------------------
#   output_devices[IdSN_ts].Devices: shape ......... (1,)
#   output_devices[IdSN_ts].Devices: dtype ......... <U13
#   output_devices[IdSN_ts].Devices: values ........ Striatum_Left
#   output_devices.IiSN_ts ......................... '--------------------'
#   output_devices[IiSN_ts].title .................. 'DeviceSet gid: 90f6d7fa-16b6-48ea-9128-565ced1d2bd6'
#   output_devices[IiSN_ts].Type ................... 'DeviceSet'
#   output_devices[IiSN_ts].model .................. 'Monitor'
#   output_devices[IiSN_ts].gid .................... UUID('90f6d7fa-16b6-48ea-9128-565ced1d2bd6')
#   output_devices[IiSN_ts].label .................. 'IiSN_ts'
#   output_devices[IiSN_ts].size ................... 1
#   output_devices[IiSN_ts].Devices ................ --------------------
#   output_devices[IiSN_ts].Devices: shape ......... (1,)
#   output_devices[IiSN_ts].Devices: dtype ......... <U13
#   output_devices[IiSN_ts].Devices: values ........ Striatum_Left
#   input_devices .................................. '--------------------'
#   input_devices.title ............................ 'DeviceSets gid: 1b0c8e7d-35e9-4700-97f2-9c0f96ecdc67'
#   input_devices.Type ............................. 'DeviceSets'
#   input_devices.gid .............................. UUID('1b0c8e7d-35e9-4700-97f2-9c0f96ecdc67')
#   input_devices.label ............................ 'input_devices'
#   input_devices.size ............................. 0
#   input_devices.DeviceSets ....................... --------------------
#   shape .......................................... (0,)
#   dtype .......................................... float64
#   is empty ....................................... True
#   output_proxies ................................. '--------------------'
#   output_proxies.title ........................... 'DeviceSets gid: 439056a7-29ef-40c4-b467-c0ee3244f079'
#   output_proxies.Type ............................ 'DeviceSets'
#   output_proxies.gid ............................. UUID('439056a7-29ef-40c4-b467-c0ee3244f079')
#   output_proxies.label ........................... 'output_proxies'
#   output_proxies.size ............................ 0
#   output_proxies.DeviceSets ...................... --------------------
#   input_proxies .................................. '--------------------'
#   input_proxies.title ............................ 'DeviceSets gid: 6e1e3a96-2902-42d2-9ebc-f21e7cc7cf77'
#   input_proxies.Type ............................. 'DeviceSets'
#   input_proxies.gid .............................. UUID('6e1e3a96-2902-42d2-9ebc-f21e7cc7cf77')
#   input_proxies.label ............................ ''
#   input_proxies.size ............................. 0
#   input_proxies.DeviceSets ....................... --------------------
#   gid ............................................ UUID('d7917531-5712-4e1a-be19-28aa3e155429')
# )

# %%
 # -----------------------------------5. Simulate and gather results-------------------------------------------------
# simulation_length = 1500.0
# transient = 400.0 # simulation_length/11
# ...and simulate!
t_start = time.time()

if simulation_mode == "rs":
    simulation_length1 = simulation_length
else:
    simulation_length1 = start_stimulus

ann_network.Run(simulation_length1)

if simulation_mode != "rs":
    
    if simulation_mode.find("simpl") > -1:
         # for stimulus application:
        if stim_target.find("STN") > -1:
            pop = "E" 
        else:
            pop = "I" 
        ann_network.brain_regions[stim_target][pop].Set(
            {"I": stim_ampl + ann_network.brain_regions[stim_target][pop].Get("I")["I"]})

    else:
        
        # for stimulus application:
        dbs_pop.amplitude = stim_ampl
        
    ann_network.Run(simulation_length=(simulation_length-simulation_length1)) 
    
print("\nSimulated in %f secs!" % (time.time() - t_start))
# Out:
# Simulated in 12.839548 secs!

# %% [markdown]
# ## 4. Plot results and write them to HDF5 files

# %%
# set to False for faster plotting of only mean field variables and dates, apart from spikes" rasters:
plot_per_neuron = False  
MAX_VARS_IN_COLS = 3
MAX_REGIONS_IN_ROWS = 10
MIN_REGIONS_FOR_RASTER_PLOT = 9
# from examples.plot_write_results import plot_write_results
# populations = []
# populations_sizes = []
# for pop in ann_model_builder.populations:
#     populations.append(pop["label"])
#     populations_sizes.append(int(np.round(pop["scale"] * ann_model_builder.population_order)))
# plot_write_results(results, simulator, populations=populations, populations_sizes=populations_sizes, 
#                    transient=transient, tvb_state_variable_type_label="State Variables", 
#                    tvb_state_variables_labels=simulator.model.variables_of_interest, 
#                    plot_per_neuron=plot_per_neuron, plotter=plotter, config=config)

# If you want to see what the function above does, take the steps, one by one
try:
    # We need framework_tvb for writing and reading from HDF5 files
    from tvb_multiscale.core.io.h5_writer import H5Writer
    from examples.plot_write_results import write_RegionTimeSeriesXarray_to_h5
    writer = H5Writer()
except:
    writer = None

# %% [markdown]
# ### Spiking Network plots

# %%
from tvb_multiscale.core.data_analysis.spiking_network_analyser import SpikingNetworkAnalyser
# Create a SpikingNetworkAnalyzer:
spikeNet_analyzer = \
    SpikingNetworkAnalyser(spikeNet=ann_network,
                           start_time=period, end_time=simulation_length, 
                           period=period, transient=transient,
                           time_series_output_type="TVB", return_data=True,
                           # elephant_mean_firing_rate=False,
                           force_homogeneous_results=True, connectivity=simulator.connectivity)

# %% [markdown]
# ### Plot spikes' raster and mean spike rates and correlations

# %%
# Spikes rates and correlations per Population and Region
spikes_res = \
    spikeNet_analyzer.\
        compute_spikeNet_spikes_rates_and_correlations(
            populations_devices=None, regions=None,
            rates_methods=[], rates_kwargs=[{}],rate_results_names=[],
            corrs_methods=[], corrs_kwargs=[{}], corrs_results_names=[], bin_kwargs={},
            data_method=spikeNet_analyzer.get_spikes_from_device, data_kwargs={},
            return_devices=False
        );
# Out:
# 2026-03-31 09:40:52,357 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# 2026-03-31 09:40:52,357 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model  for  created!
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File ~/packages/tvb-multiscale/tvb_multiscale/tvb_elephant/spiking_network_analyser.py:230, in SpikingNetworkAnalyser.compute_rate_time_series(self, spikes_train, number_of_neurons, **elephant_kwargs)
#     228 try:
#     229     # Call the elephant method for the actual computation
# --> 230     rates = instantaneous_rate(spikes_train, self.period * ms, **kwargs).flatten().__array__()
#     231 except:
#     232     # If it fails, compute a delta spike instantaneous rate with any kernel smoothing:
#     233     # LOG.warning("Failed to compute instantaneous rate with a sliding timing window!\n"
#     234     #             "Computing instantaneous rate without any smoothing...")
#
# File ~/venv/lib/python3.12/site-packages/elephant/utils.py:96, in deprecated_alias.<locals>.deco.<locals>.wrapper(*args, **kwargs)
#      95 _rename_kwargs(func.__name__, kwargs, aliases)
# ---> 96 return func(*args, **kwargs)
#
# File ~/venv/lib/python3.12/site-packages/elephant/statistics.py:934, in instantaneous_rate(spiketrains, sampling_period, kernel, cutoff, t_start, t_stop, trim, center_kernel, border_correction, pool_trials, pool_spike_trains)
#     933 if not is_time_quantity(t_start, allow_none=True):
# --> 934     raise TypeError("'t_start' must be a time Quantity")
#     935 if not is_time_quantity(t_stop, allow_none=True):
#
# TypeError: 't_start' must be a time Quantity
#
# During handling of the above exception, another exception occurred:
#
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[11], line 4
#       1 # Spikes rates and correlations per Population and Region
#       2 spikes_res = \
#       3     spikeNet_analyzer.\
# ----> 4         compute_spikeNet_spikes_rates_and_correlations(
#       5             populations_devices=None, regions=None,
#       6             rates_methods=[], rates_kwargs=[{}],rate_results_names=[],
#       7             corrs_methods=[], corrs_kwargs=[{}], corrs_results_names=[], bin_kwargs={},
#       8             data_method=spikeNet_analyzer.get_spikes_from_device, data_kwargs={},
#       9             return_devices=False
#      10         );
#
# File ~/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:1074, in SpikingNetworkAnalyser.compute_spikeNet_spikes_rates_and_correlations(self, populations_devices, regions, rates_methods, rates_kwargs, rate_results_names, corrs_methods, corrs_kwargs, corrs_results_names, bin_kwargs, data_method, data_kwargs, return_devices)
#    1072 if data_method is None:
#    1073     data_method = self.get_spikes_times_from_device
# -> 1074 results = self.compute_spikes_rates_and_correlations(spikes_devices, [],
#    1075                                                      rates_methods, rates_kwargs, rate_results_names,
#    1076                                                      corrs_methods, corrs_kwargs, corrs_results_names,
#    1077                                                      bin_kwargs, data_method, data_kwargs)
#    1078 if len(results) == 1:
#    1079     results = list(results.values())[0]
#
# File ~/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:686, in SpikingNetworkAnalyser.compute_spikes_rates_and_correlations(self, spikes_data, populations_sizes, rates_methods, rates_kwargs, rate_results_names, corrs_methods, corrs_kwargs, corrs_results_names, bin_kwargs, data_method, data_kwargs)
#     648 """A method to compute several spikes' rates and correlations' measures
#     649    on the same spikes' data or recording Devices.
#     650    Arguments:
#    (...)    683
#     684 """
#     685 # Compute first the spikes' rate results:
# --> 686 results = self.compute_spikes_measures(spikes_data, populations_sizes,
#     687                                        rates_methods, rates_kwargs, rate_results_names,
#     688                                        data_method, data_kwargs, return_spikes_trains=self.spikes_train_name)
#     689 # Loop over the resulting Spikes Trains and prepare for the correlations' computations:
#     690 pop_labels = []
#
# File ~/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:551, in SpikingNetworkAnalyser.compute_spikes_measures(self, spikes_data, populations_sizes, computations_methods, computations_kwargs, results_names, data_method, data_kwargs, return_spikes_trains)
#     547     results[return_spikes_trains] = Series(name="Spikes Trains", dtype='object')
#     548 if len(spikes_data):
#     549     # If there are any spikes" data or recording devices, proceed to computation and collect the results...
#     550     results = \
# --> 551         self._compute_results_from_population_generator(results,
#     552                                                         self._populations_generator(spikes_data,
#     553                                                                                     populations_sizes,
#     554                                                                                     computations_methods,
#     555                                                                                     computations_kwargs,
#     556                                                                                     data_method,
#     557                                                                                     data_kwargs)
#     558                                                         )
#     559     # Remove the spikes_rates_by_neuron false results name for the per neuron computations:
#     560     # TODO: find a more elegant solution to remove this entry from results' dict
#     561     false_res_name = self._get_comput_res_type(self.compute_spikes_rates_by_neuron)
#
# File ~/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:248, in SpikingNetworkAnalyser._compute_results_from_population_generator(self, results, population_generator)
#     246 data_name = None
#     247 # For every population's DeviceSet
# --> 248 for pop_label, pop_results in population_generator:
#     249     data_name = pop_results.pop("data_name", data_name)
#     250     # ...and for every result...
#
# File ~/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:208, in SpikingNetworkAnalyser._populations_generator(self, pop_device_or_data, populations_sizes, computation_methods, computation_kwargs, data_method, data_kwargs)
#     206 pop_results = OrderedDict()
#     207 # ...for every region Device or data...
# --> 208 for reg_label, reg_results in \
#     209         self._regions_generator(pop_data, _get_safely_list_item(i_pop, populations_sizes, 1),
#     210                                 computation_methods, computation_kwargs,
#     211                                 data_method, data_kwargs):
#     212     # ...get the data_name if it exists....
#     213     data_name = reg_results.pop("data_name", data_name)
#     214     # ...if this is the first population's DeviceSet...
#
# File ~/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser.py:167, in SpikingNetworkAnalyser._regions_generator(self, reg_device_or_data, population_sizes, computation_methods, computations_kwargs, data_method, data_kwargs)
#     165         this_data = outputs.get(self.spikes_trains_name, this_data)
#     166     # ...and eventually call the computation and collect the results:
# --> 167     outputs.update(computation_method(this_data, number_of_neurons=population_size,
#     168                                       **self._get_safely_computation_kwargs(i_comput, computations_kwargs)))
#     169 # ...finally yield the region label and the the outputs dictionary:
#     170 yield reg_label, outputs
#
# File ~/packages/tvb-multiscale/tvb_multiscale/tvb_elephant/spiking_network_analyser.py:284, in SpikingNetworkAnalyser.compute_mean_rate_time_series(self, spikes, number_of_neurons, **kwargs)
#     282 res_type = self._get_comput_res_type()
#     283 res2_type = self._get_comput_res_type(self.compute_rate_time_series)
# --> 284 results = self.compute_rate_time_series(spikes, **kwargs)
#     285 results[res_type] = results[res2_type] / number_of_neurons
#     286 del results[res2_type]
#
# File ~/packages/tvb-multiscale/tvb_multiscale/tvb_elephant/spiking_network_analyser.py:235, in SpikingNetworkAnalyser.compute_rate_time_series(self, spikes_train, number_of_neurons, **elephant_kwargs)
#     230         rates = instantaneous_rate(spikes_train, self.period * ms, **kwargs).flatten().__array__()
#     231     except:
#     232         # If it fails, compute a delta spike instantaneous rate with any kernel smoothing:
#     233         # LOG.warning("Failed to compute instantaneous rate with a sliding timing window!\n"
#     234         #             "Computing instantaneous rate without any smoothing...")
# --> 235         rates = 1000 * self._compute_delta_rate(time, spikes_train.__array__(), t_start, t_stop)
#     236 else:
#     237     rates = 0.0 * time
#
# File ~/packages/tvb-multiscale/tvb_multiscale/core/data_analysis/spiking_network_analyser_base.py:461, in SpikingNetworkAnalyserBase._compute_delta_rate(self, time, spikes_times, t_start, t_stop)
#     458 for spike_time in np.unique(spikes_times):
#     459     if spike_time >= t_start and spike_time <= t_stop:
#     460         result[int(np.floor((spike_time - time[0]) / self.period))] += \
# --> 461             np.sum(spikes_times == spike_time) / self.period
#     462 return result
#
# File ~/venv/lib/python3.12/site-packages/numpy/core/fromnumeric.py:2172, in _sum_dispatcher(a, axis, dtype, out, keepdims, initial, where)
#    2102     """
#    2103     Clip (limit) the values in an array.
#    2104
#    (...)   2167
#    2168     """
#    2169     return _wrapfunc(a, 'clip', a_min, a_max, out=out, **kwargs)
# -> 2172 def _sum_dispatcher(a, axis=None, dtype=None, out=None, keepdims=None,
#    2173                     initial=None, where=None):
#    2174     return (a, out)
#    2177 @array_function_dispatch(_sum_dispatcher)
#    2178 def sum(a, axis=None, dtype=None, out=None, keepdims=np._NoValue,
#    2179         initial=np._NoValue, where=np._NoValue):
#
# KeyboardInterrupt:
# WARNING:tornado.general:Got events for closed stream <zmq.eventloop.zmqstream.ZMQStream object at 0xffff80e4a630>

# %%
if spikes_res:
    print(spikes_res["mean_rate"])
    print(spikes_res["spikes_correlation_coefficient"])
    # Plot spikes' rasters together with mean population's spikes' rates' time series
    if plotter:
        plotter.config.FONTSIZE = 14 # plotter.config.LARGE_FONTSIZE  # LARGE = 12, default = 10
        plotter.plot_spike_events(spikes_res["spikes"], time_series=spikes_res["mean_rate_time_series"], 
                                  mean_results=spikes_res["mean_rate"], #
                                  stimulus=[start_stimulus] if simulation_mode != "rs" else None,
                                  mean_results_units="Hz", stimulus_linewidth=5.0,
                                  spikes_markersize=1.0, figsize=(20, 40), 
                                  n_time_ticks=3, show_time_axis=True, 
                                  time_axis_min=0.0, time_axis_max=simulation_length
                                 ) # 
        from tvb_multiscale.core.plot.correlations_plot import plot_correlations
        plot_correlations(spikes_res["spikes_correlation_coefficient"], plotter)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[12], line 1
# ----> 1 if spikes_res:
#       2     print(spikes_res["mean_rate"])
#       3     print(spikes_res["spikes_correlation_coefficient"])
#
# NameError: name 'spikes_res' is not defined

# %%
print("Mean spike rates:")
for pop in spikes_res["mean_rate"].coords["Population"]:
    for reg in spikes_res["mean_rate"].coords["Region"]:
        if not np.isnan(spikes_res["mean_rate"].loc[pop, reg]):
            print("%s - %s: %0.1f" % (pop.values.item().split("_spikes")[0], reg.values.item(), 
                                   spikes_res["mean_rate"].loc[pop, reg].values.item()))

# %%
spikeNet_analyzer.resample = True
spikes_sync = \
    spikeNet_analyzer.compute_spikeNet_synchronization(populations_devices=None, regions=None,
                                                       comp_methods=[spikeNet_analyzer.compute_spikes_sync, 
                                                                     spikeNet_analyzer.compute_spikes_sync_time_series],
                                                       computations_kwargs=[{}], data_kwargs={},
                                                       return_spikes_trains=False, return_devices=False)
# print(spikes_sync)

# %%
plotter.config.FONTSIZE = 20 # plotter.config.LARGE_FONTSIZE  # LARGE = 12, default = 10
plotter.plot_spike_events(spikes_res["spikes"], 
                          time_series=spikes_sync["spikes_sync_time_series"], mean_results=spikes_sync["spikes_sync"], 
                          stimulus=[start_stimulus] if simulation_mode != "rs" else None,
                          plot_spikes=True, spikes_alpha=0.25,
                          spikes_markersize=1.0, stimulus_linewidth=5.0, time_series_marker="*", 
                          figsize=(20, 40), n_y_ticks=3, n_time_ticks=4, show_time_axis=True,
                          time_axis_min=0.0, time_axis_max=simulation_length
                                 )

# %%
print("Spike synchronization:")
for pop in spikes_sync["spikes_sync"].coords["Population"]:
    for reg in spikes_sync["spikes_sync"].coords["Region"]:
        if not np.isnan(spikes_sync["spikes_sync"].loc[pop, reg]):
            print("%s - %s: %g" % (pop.values.item().split("_spikes")[0], reg.values.item(), 
                                   spikes_sync["spikes_sync"].loc[pop, reg].values.item()))

# %%
if spikes_res and writer:
    writer.write_object(spikes_res["spikes"].to_dict(), 
                        path=os.path.join(config.out.FOLDER_RES,  "Spikes") + ".h5");
    writer.write_object(spikes_res["mean_rate"].to_dict(),
                        path=os.path.join(config.out.FOLDER_RES,
                                          spikes_res["mean_rate"].name) + ".h5");
    write_RegionTimeSeriesXarray_to_h5(spikes_res["mean_rate_time_series"], writer,
                                       os.path.join(config.out.FOLDER_RES, 
                                                    spikes_res["mean_rate_time_series"].title) + ".h5",
                                       recursive=False);
    writer.write_object(spikes_res["spikes_correlation_coefficient"].to_dict(),
                        path=os.path.join(config.out.FOLDER_RES,
                                          spikes_res["spikes_correlation_coefficient"].name) + ".h5");
    
    if spikes_sync is not None:
        writer.write_object(spikes_sync["spikes_sync"].to_dict(),
                        path=os.path.join(config.out.FOLDER_RES,
                                          spikes_sync["spikes_sync"].name) + ".h5");
        write_RegionTimeSeriesXarray_to_h5(spikes_sync["spikes_sync_time_series"], writer,
                                           os.path.join(config.out.FOLDER_RES,
                                                        spikes_sync["spikes_sync_time_series"].title) + ".h5",
                                           recursive=False);

# %% [markdown]
# ### Get  SpikingNetwork mean field variable time series and plot them

# %%
# Continuous time variables' data of spiking neurons

if plot_per_neuron:
    spikeNet_analyzer.return_data = True
else:
    spikeNet_analyzer.return_data = False
spikeNet_ts = \
    spikeNet_analyzer. \
         compute_spikeNet_mean_field_time_series(populations_devices=None, regions=None, variables=None,
                                                 computations_kwargs={}, data_kwargs={}, return_devices=False)
if spikeNet_ts:
    if plot_per_neuron:
        mean_field_ts = spikeNet_ts["mean_field_time_series"]  # mean field
        spikeNet_ts = spikeNet_ts["data_by_neuron"]  # per neuron data
    else:
        mean_field_ts = spikeNet_ts
    if mean_field_ts and mean_field_ts.size > 0:
        mean_field_ts.plot_timeseries(plotter_config=plotter.config, 
                                      per_variable=mean_field_ts.shape[1] > MAX_VARS_IN_COLS)
        if mean_field_ts.number_of_labels > MIN_REGIONS_FOR_RASTER_PLOT:
            mean_field_ts.plot_raster(plotter_config=plotter.config, 
                                      per_variable=mean_field_ts.shape[1] > MAX_VARS_IN_COLS,
                                      linestyle="--", alpha=0.5, linewidth=0.5)
else:
    mean_field_ts = None

# %%
# Write results to file:
if mean_field_ts and writer:
    write_RegionTimeSeriesXarray_to_h5(mean_field_ts, writer,
                                       os.path.join(config.out.FOLDER_RES, mean_field_ts.title) + ".h5", 
                                       recursive=False)

# %% [markdown]
# ### Compute per neuron spikes' rates times series and plot them

# %%
if spikes_res and plot_per_neuron:
    from tvb.simulator.plot.base_plotter import pyplot
    spikeNet_analyzer.return_data = False
    rates_ts_per_neuron = \
        spikeNet_analyzer. \
            compute_spikeNet_rates_time_series(populations_devices=None, regions=None,
                                               computations_kwargs={}, data_kwargs={},
                                               return_spikes_trains=False, return_devices=False);
    if rates_ts_per_neuron is not None and rates_ts_per_neuron.size:
        # Regions in rows
        row = rates_ts_per_neuron.dims[2] if rates_ts_per_neuron.shape[2] > 1 else None
        if row is None:
            # Populations in rows
            row = rates_ts_per_neuron.dims[1] if rates_ts_per_neuron.shape[1] > 1 else None
            col = None
        else:
            # Populations in columns
            col = rates_ts_per_neuron.dims[1] if rates_ts_per_neuron.shape[1] > 1 else None
        pyplot.figure()
        rates_ts_per_neuron.plot(y=rates_ts_per_neuron.dims[3], row=row, col=col, cmap="jet")
        plotter.base._save_figure(figure_name="Spike rates per neuron")
        # del rates_ts_per_neuron # to free memory

# %% [markdown]
# ### Plot per neuron SpikingNetwork time series

# %%
# Regions in rows
if plot_per_neuron and spikeNet_ts.size:
    row = spikeNet_ts.dims[2] if spikeNet_ts.shape[2] > 1 else None
    if row is None:
        # Populations in rows
        row = spikeNet_ts.dims[3] if spikeNet_ts.shape[3] > 1 else None
        col = None
    else:
        # Populations in cols
         col = spikeNet_ts.dims[3] if spikeNet_ts.shape[3] > 1 else None
    for var in spikeNet_ts.coords[spikeNet_ts.dims[1]]:
        this_var_ts = spikeNet_ts.loc[:, var, :, :, :]
        this_var_ts.name = var.item()
        pyplot.figure()
        this_var_ts.plot(y=spikeNet_ts.dims[4], row=row, col=col, cmap="jet", figsize=FIGSIZE)
        plotter.base._save_figure(
            figure_name="Spiking Network variables' time series per neuron: %s" % this_var_ts.name)
    del spikeNet_ts # to free memory

# %% [markdown]
# # References
#
# 1 Sanz Leon P, Knock SA, Woodman MM, Domide L, <br>
#   Mersmann J, McIntosh AR, Jirsa VK (2013) <br>
#   The Virtual Brain: a simulator of primate brain network dynamics. <br>
#   Frontiers in Neuroinformatics 7:10. doi: 10.3389/fninf.2013.00010 <br>
#   https://www.thevirtualbrain.org/tvb/zwei <br>
#   https://github.com/the-virtual-brain <br>
#
# 2 Ritter P, Schirner M, McIntosh AR, Jirsa VK (2013).  <br>
#   The Virtual Brain integrates computational modeling  <br>
#   and multimodal neuroimaging. Brain Connectivity 3:121–145. <br>
#
# 3 Vitay J, Dinkelbach HÜ and Hamker FH (2015). <br>
#   ANNarchy: a code generation approach to neural simulations on parallel hardware. <br>
#   Frontiers in Neuroinformatics 9:19. doi:10.3389/fninf.2015.00019 <br>
#   For more details see https://annarchy.readthedocs.io/en/latest/ <br>
#
# 4 Baladron, J., Nambu, A., & Hamker, F. H. (2019). <br>
#   The subthalamic nucleus‐external globus pallidus loop biases <br>
#   exploratory decisions towards known alternatives: A neuro‐computational study. <br>
#   European Journal of Neuroscience, 49:754–767. https://doi.org/10.1111/ejn.13666 <br>
#
# 5 Maith O, Villagrasa Escudero F, Ülo Dinkelbach H, Baladron J, <br>
#   Horn, A, Irmen F, Kühn AA, Hamker FH (2020).<br>
#   A computational model‐based analysis of basal ganglia pathway changes <br>
#   in Parkinson’s disease inferred from resting‐state fMRI <br>
#   European Journal of Neuroscience, 00:1–18. https://doi.org/10.1111/ejn.14868

# %%
# ann_model_builder.populations
names = ["GPe", "GPi", "STN", "dSN", "iSN", "Thal", "CtxE"]
for iP, (name, pop) in enumerate(zip(names, ann_network.annarchy_network.get_populations())):
    print("\n%s - %s (size = %d): params =\n%s" % (pop.name, name, pop.size, pop.init) )

# %%
# for reg in ann_network.brain_regions:
#     for pop in reg:
#         conns = pop.GetFromConnections("w")
#         print("%s-%s:" % (reg.label, pop.label))
#         for conn in conns:
#             print("%s" % str(conn))

# %%
print("Configured connections:")

print("\nWithin node's connections:")
ncons = 0
for pop in ann_model_builder.populations_connections:
    ncons += 1
    if hasattr(pop["weight"], "__call__"):
        weight = pop["weight"](pop["nodes"])
    else:
        weight = pop["weight"]
    try:
        p = pop["conn_spec"]["probability"]
    except:
        p = 1.0
    w_conn = assert_loadedParams[np.abs(weight)]
    conn = w_conn.split("_weights")[0]
    p_conn = loadedParams["%s_probs" % conn]
    w_conn = loadedParams[w_conn]
    print("%d. %s -> %s (%s) = %g (p=%g): %s (%g, %g)" 
          % (ncons, pop["source"], pop["target"], pop["receptor_type"], weight, p,
             conn, w_conn, p_conn))
    
print("\nAmong node's connections:")
for pop in ann_model_builder.nodes_connections:
    ncons += 1 
    if hasattr(pop["weight"], "__call__"):
        weight = pop["weight"](pop["source_nodes"], pop["target_nodes"])
    else:
        weight = pop["weight"]
    try:
        p = pop["conn_spec"]["probability"]
    except:
        p = 1.0
    w_conn = assert_loadedParams[np.abs(weight)]
    conn = w_conn.split("_weights")[0]
    p_conn = loadedParams["%s_probs" % conn]
    w_conn = loadedParams[w_conn]
    print("%d. %s -> %s (%s) = %g (p=%g): %s (%g, %g)" 
          % (ncons, pop["source"], pop["target"], pop["receptor_type"], weight, p,
             conn, w_conn, p_conn))
    
print("\nEffective connections:")
conns = ["GPeGPe", "GPiGPi", "dSNdSN", "iSNiSN",
         "dSNGPi" , "iSNGPe", "GPeGPi", "GPiThal", "GPeSTN", "ThaldSN", "ThaliSN", 
         "STNGPe", "STNGPi", "CtxThal", "CtxSTN", "CtxdSN", "CtxiSN"]
for iC, (name, proj) in enumerate(zip(conns, ann_network.annarchy_network.get_projections())):
    meanNconns = np.mean([len(d.pre_ranks) for d in proj.dendrites])
    p = meanNconns / proj.pre.size
    print("%d. %s: %s w = %g (%g) (%s), effective_probability = %g (%g)" % 
          (iC+1, proj.name, name, proj.w, loadedParams["%s_weights" % name], proj.target,
            p, loadedParams["%s_probs" % name]))  # meanNconns = %g,  meanNconns,

# %%
import matplotlib.pyplot as plt

if simulation_mode == "stim":
    dt = ann_network.dt
    data = m1.get() #the dbs stimulus
    t = np.arange(0, simulation_length, dt)
    if stim_mode.find("bi") > -1:
        stim_slice = slice(int(399.0/dt, int(407.0/dt)))
        plt.plot(t[stim_slice] - t[stim_slice][0], data['r'][:][stim_slice, 0], "k")
        plt.xlabel("Time (ms)")
        plt.ylabel("Biphasic stimulus")
        plt.show()
    elif stim_mode.find("mono") > -1:
        stim_slice = slice(int(400.0/dt, int(412.0/dt)))
        plt.plot(t[stim_slice] - t[stim_slice][0], data['r'][:][stim_slice, 0], "k")
        plt.xlabel("Time (ms)")
        plt.ylabel("Monophasic stimulus")
        plt.show()

# %%
from scipy import signal
import matplotlib.pyplot as plt

psd_target = 'STN_Left'
lfp_result = np.array(mean_field_ts._data.loc[:,'v',psd_target,'E_ts'])

n_window = 256 # This can be increased for longer simulations
f1, Pxx_spec1 = signal.welch(lfp_result,1000,'flattop',n_window,scaling='density')

plt.figure()
plt.title(f'{psd_target}, stimulus: {stim_mode}', fontsize=14)
plt.xlabel('Frequency (Hz)', fontsize=10)
plt.ylabel('PSD [a.u./√Hz]', fontsize=10) 

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.semilogy(f1, np.sqrt(Pxx_spec1), color="blue", label=f"{stim_ampl} mA")
plt.axvspan(14, 30, color='grey', alpha=0.5, label = "β")
plt.legend(loc='lower left', fontsize=10)
plt.xlim(0,60)

# %%
psd_target = 'Thal_Left'
lfp_result = np.array(mean_field_ts._data.loc[:,'v',psd_target,'E_ts'])

n_window = 256 # This can be increased for longer simulations
f1, Pxx_spec1 = signal.welch(lfp_result,1000,'flattop',n_window,scaling='density')

plt.figure()
plt.title(f'{psd_target}, stimulus: {stim_mode}', fontsize=14)
plt.xlabel('Frequency (Hz)', fontsize=10)
plt.ylabel('PSD [a.u./√Hz]', fontsize=10) 

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.semilogy(f1, np.sqrt(Pxx_spec1), color="blue", label=f"{stim_ampl} mA")
plt.axvspan(14, 30, color='grey', alpha=0.5, label = "β")
plt.legend(loc='lower left', fontsize=10)
plt.xlim(0,60)

# %%
psd_target = 'Cortex Exc'
mean_rate_result = spikes_res["mean_rate_time_series"][:, "E", 'Cortex'].data.squeeze()

n_window = 256 # This can be increased for longer simulations
f1, Pxx_spec1 = signal.welch(mean_rate_result,1000,'flattop',n_window,scaling='density')

plt.figure()
plt.title(f'{psd_target}, stimulus: {stim_mode}', fontsize=14)
plt.xlabel('Frequency (Hz)', fontsize=10)
plt.ylabel('PSD [a.u./√Hz]', fontsize=10) 

plt.xticks(fontsize=10)
plt.yticks(fontsize=10)
plt.semilogy(f1, np.sqrt(Pxx_spec1), color="blue", label=f"{stim_ampl}")
plt.axvspan(14, 30, color='grey', alpha=0.5, label = "β")
plt.legend(loc='lower left', fontsize=10)
plt.xlim(0,60)

# %%
import matplotlib.pyplot as plt
plt.hist(ann_network.output_devices["E"]["Cortex"].compute_isi(transient=transient), bins=np.linspace(0, 200, 101))
ax = plt.gca()
ax.set_title("Crtx-E ISI")

# %%
plt.hist(ann_network.output_devices["I"]["Cortex"].compute_isi(transient=transient), bins=np.linspace(0, 200, 101))
ax = plt.gca()
ax.set_title("Crtx-I ISI")

# %%
plt.hist(ann_network.output_devices["E"]["STN_Left"].compute_isi(transient=transient), bins=np.linspace(0, 200, 101))
ax = plt.gca()
ax.set_title("STN ISI")

# %%
plt.hist(ann_network.output_devices["IdSN"]["Striatum_Left"].compute_isi(transient=transient), bins=np.linspace(0, 200, 101))
ax = plt.gca()
ax.set_title("dSN ISI")

# %%
plt.hist(ann_network.output_devices["IiSN"]["Striatum_Left"].compute_isi(transient=transient), bins=np.linspace(0, 200, 101))
ax = plt.gca()
ax.set_title("iSN ISI")
