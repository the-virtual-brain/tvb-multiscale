# %%
! pwd
# Out:
# /home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks

# %%
! python ../../../tvb_multiscale/tests/tvb_annarchy/test_spiking_models_builder_properties_methods.py
# Out:
# ANNarchy 4.7 (4.7.2.6) on linux (posix).
# 2023-09-28 13:09:48,705 - INFO - tvb-multiscale - Loading an ANNarchy instance...
# 2023-09-28 13:09:48,705 - INFO - tvb-multiscale - Loading an ANNarchy instance...
# 2023-09-28 13:09:48,705 - INFO - tvb-multiscale - Loading an ANNarchy instance...
# 2023-09-28 13:09:48,706 - INFO - tvb-multiscale - Cleaning ANNarchy compilation directory, if any...
# 2023-09-28 13:09:48,706 - INFO - tvb-multiscale - Cleaning ANNarchy compilation directory, if any...
# 2023-09-28 13:09:48,706 - INFO - tvb-multiscale - Cleaning ANNarchy compilation directory, if any...
# <tvb_multiscale.tvb_annarchy.annarchy_models.models.default.DefaultExcIOBuilder object at 0xffff808f4940>
# annarchy simulator: <module 'ANNarchy' from '/home/docker/.local/lib/python3.10/site-packages/ANNarchy/__init__.py'>
# min_delay:
# 0.05
#
# tvb_dt:
# 0.1
#
# monitor_period:
# 0.1
#
# tvb_model:
# Linear
#
# number_of_regions:
# 68
#
# tvb_weights:
# [[0.0000000e+00 4.8155833e-02 5.5569724e-01 ... 0.0000000e+00
#   9.3632959e-04 1.5197568e-03]
#  [3.4694958e-02 0.0000000e+00 4.0470140e+00 ... 0.0000000e+00
#   0.0000000e+00 6.4991351e-02]
#  [3.3234182e-01 1.6091147e+00 0.0000000e+00 ... 0.0000000e+00
#   1.3227513e-03 2.2254678e-01]
#  ...
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#   4.2837810e-03 6.6117304e+01]
#  [6.8634180e-04 0.0000000e+00 1.8867925e-02 ... 2.7493696e-02
#   0.0000000e+00 2.8296225e+01]
#  [2.8677947e-04 1.3400005e-02 3.4921828e-01 ... 2.5495074e+01
#   1.4883909e+01 0.0000000e+00]]
#
# tvb_delays:
# [[ 0.         39.98974333 34.00171    ...  0.         47.8
#   44.73333333]
#  [39.98974333  0.         14.00699533 ...  0.          0.
#   23.274074  ]
#  [34.00171    14.00699533  0.         ...  0.         58.33333333
#   37.56438333]
#  ...
#  [ 0.          0.          0.         ...  0.         20.76666667
#    6.62544467]
#  [47.8         0.         58.33333333 ... 20.76666667  0.
#    5.83055433]
#  [44.73333333 23.274074   37.56438333 ...  6.62544467  5.83055433
#    0.        ]]
#
# region_labels:
# ['bankssts_L' 'bankssts_R' 'caudalanteriorcingulate_L'
#  'caudalanteriorcingulate_R' 'caudalmiddlefrontal_L'
#  'caudalmiddlefrontal_R' 'cuneus_L' 'cuneus_R' 'entorhinal_L'
#  'entorhinal_R' 'frontalpole_L' 'frontalpole_R' 'fusiform_L' 'fusiform_R'
#  'inferiorparietal_L' 'inferiorparietal_R' 'inferiortemporal_L'
#  'inferiortemporal_R' 'insula_L' 'insula_R' 'isthmuscingulate_L'
#  'isthmuscingulate_R' 'lateraloccipital_L' 'lateraloccipital_R'
#  'lateralorbitofrontal_L' 'lateralorbitofrontal_R' 'lingual_L' 'lingual_R'
#  'medialorbitofrontal_L' 'medialorbitofrontal_R' 'middletemporal_L'
#  'middletemporal_R' 'paracentral_L' 'paracentral_R' 'parahippocampal_L'
#  'parahippocampal_R' 'parsopercularis_L' 'parsopercularis_R'
#  'parsorbitalis_L' 'parsorbitalis_R' 'parstriangularis_L'
#  'parstriangularis_R' 'pericalcarine_L' 'pericalcarine_R' 'postcentral_L'
#  'postcentral_R' 'posteriorcingulate_L' 'posteriorcingulate_R'
#  'precentral_L' 'precentral_R' 'precuneus_L' 'precuneus_R'
#  'rostralanteriorcingulate_L' 'rostralanteriorcingulate_R'
#  'rostralmiddlefrontal_L' 'rostralmiddlefrontal_R' 'superiorfrontal_L'
#  'superiorfrontal_R' 'superiorparietal_L' 'superiorparietal_R'
#  'superiortemporal_L' 'superiortemporal_R' 'supramarginal_L'
#  'supramarginal_R' 'temporalpole_L' 'temporalpole_R'
#  'transversetemporal_L' 'transversetemporal_R']
#
# number_of_populations:
# 0
#
# populations_models:
# OrderedDict()
#
# populations_nodes:
# OrderedDict()
#
# populations_scales:
# OrderedDict()
#
# populations_sizes:
# OrderedDict()
#
# populations_params:
# OrderedDict()
#
# populations_connections_labels:
# []
#
# populations_connections_models:
# OrderedDict()
#
# populations_connections_nodes:
# OrderedDict()
#
# populations_connections_weights:
# OrderedDict()
#
# populations_connections_delays:
# OrderedDict()
#
# populations_connections_receptor_types:
# OrderedDict()
#
# populations_connections_conn_spec:
# OrderedDict()
#
# nodes_connections_labels:
# []
#
# nodes_connections_models:
# OrderedDict()
#
# nodes_connections_source_nodes:
# OrderedDict()
#
# nodes_connections_target_nodes:
# OrderedDict()
#
# nodes_connections_weights:
# OrderedDict()
#
# nodes_connections_delays:
# OrderedDict()
#
# nodes_connections_receptor_types:
# OrderedDict()
#
# nodes_connections_conn_spec:
# OrderedDict()

# %%
! python ../../../tvb_multiscale/tests/tvb_annarchy/test_models.py 0
# Out:
# ANNarchy 4.7 (4.7.2.6) on linux (posix).
#
#
# Testing model 0
# ******************************************************
# ******************************************************
#
# ----------------------------------------------------------------------------------------------------
# Find results in /home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/DefaultExcIO_RATE_bidir/res !
# ----------------------------------------------------------------------------------------------------
#
# Starting App TVBANNarchySerialOrchestrator...
#
# Starting App TVBSerialApp...
#
# Setting TVB LIBRARY_PROFILE...
#
# Starting App ANNarchySerialApp...
# 2023-09-28 13:09:52,332 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Loading an ANNarchy instance...
# 2023-09-28 13:09:52,332 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Loading an ANNarchy instance...
# 2023-09-28 13:09:52,332 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Cleaning ANNarchy compilation directory, if any...
# 2023-09-28 13:09:52,332 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Cleaning ANNarchy compilation directory, if any...
#
#
# Configuring...
#
# Done! in 0.000104 min
#
#
#
# Building...
#
# Building with App TVBANNarchySerialOrchestrator...
# 2023-09-28 13:09:52,339 - INFO - examples.example - Building cosimulators with TVBANNarchySerialOrchestrator...
# 2023-09-28 13:09:52,339 - INFO - examples.example - Building cosimulators with TVBANNarchySerialOrchestrator...
#
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
# 2023-09-28 13:09:52,341 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-28 13:09:52,341 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2023-09-28 13:09:52,341 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2023-09-28 13:09:52,347 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2023-09-28 13:09:52,347 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2023-09-28 13:09:52,348 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-28 13:09:52,348 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
#
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: 973bcc3d-e8c0-4bbd-9a62-c3623984ce13'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: 5dd80905-ac70-4e0a-8a9b-b3dd1ffabebe
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 7f56a09d-a48c-41dc-866b-7488c069b774
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: bef66d2f-e5f3-40e6-9929-50e85084e8ea
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: c9c9f810-2fc0-44e2-b9ae-e705cd6a3073
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('973bcc3d-e8c0-4bbd-9a62-c3623984ce13')
# )
# 2023-09-28 13:09:52,353 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-28 13:09:52,353 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2023-09-28 13:09:52,353 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2023-09-28 13:09:52,359 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2023-09-28 13:09:52,359 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2023-09-28 13:09:52,359 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-28 13:09:52,359 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
#
# Building Spiking Network with builder DefaultExcIOBuilder of App ANNarchySerialApp...
# 2023-09-28 13:09:52,362 - INFO - examples.example - Configuring spiking network builder...
# 2023-09-28 13:09:52,362 - INFO - examples.example - Configuring spiking network builder...
# 2023-09-28 13:09:52,363 - INFO - examples.example - Configuring populations...
# 2023-09-28 13:09:52,363 - INFO - examples.example - Configuring populations...
# 2023-09-28 13:09:52,363 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2023-09-28 13:09:52,363 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2023-09-28 13:09:52,363 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2023-09-28 13:09:52,363 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2023-09-28 13:09:52,363 - INFO - examples.example - Configuring output devices, if any...
# 2023-09-28 13:09:52,363 - INFO - examples.example - Configuring output devices, if any...
# 2023-09-28 13:09:52,364 - INFO - examples.example - Configuring input devices, if any...
# 2023-09-28 13:09:52,364 - INFO - examples.example - Configuring input devices, if any...
# 2023-09-28 13:09:52,364 - INFO - examples.example - Generating spiking brain...
# 2023-09-28 13:09:52,364 - INFO - examples.example - Generating spiking brain...
# 2023-09-28 13:09:52,364 - INFO - examples.example - Generating spiking brain regions...
# 2023-09-28 13:09:52,364 - INFO - examples.example - Generating spiking brain regions...
# 2023-09-28 13:09:52,364 - INFO - examples.example - Generating spiking region node: bankssts_L...
# 2023-09-28 13:09:52,364 - INFO - examples.example - Generating spiking region node: bankssts_L...
# 2023-09-28 13:09:52,366 - INFO - examples.example - Generating population: E...
# 2023-09-28 13:09:52,366 - INFO - examples.example - Generating population: E...
# 2023-09-28 13:09:52,443 - INFO - examples.example - Generating spiking region node: bankssts_R...
# 2023-09-28 13:09:52,443 - INFO - examples.example - Generating spiking region node: bankssts_R...
# 2023-09-28 13:09:52,444 - INFO - examples.example - Generating population: E...
# 2023-09-28 13:09:52,444 - INFO - examples.example - Generating population: E...
# 2023-09-28 13:09:52,481 - INFO - examples.example - Connecting populations within spiking brain regions...
# 2023-09-28 13:09:52,481 - INFO - examples.example - Connecting populations within spiking brain regions...
# 2023-09-28 13:09:52,482 - INFO - examples.example - Connecting E -> E populations
# for spiking region nodes
# [0 1]...
# 2023-09-28 13:09:52,482 - INFO - examples.example - Connecting E -> E populations
# for spiking region nodes
# [0 1]...
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2023-09-28 13:09:52,484 - INFO - examples.example - Connecting populations among spiking brain regions...
# 2023
#   interfaces[0].transformer .............. ElephantSpikesHistogramRate gid: ae9bfdd6-2b0e-4541-b0f5-bb6988b4ab57
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (2,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: values ....... [[0, 1]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].dt ....................... 0.1
#   interfaces[0].times .................... --------------------
#   interfaces[0].times: shape ............. (2,)
#   interfaces[0].times: dtype ............. int64
#   interfaces[0].times: values ............ [[0, 1]]
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'SpikeMonitor'
#   interfaces[0].gid ...................... UUID('be9f6102-a56a-412c-90cf-bb2ddca1971d')
#   interfaces[0].number_of_proxy_nodes .... 2
#   interfaces[0].number_of_proxy_gids ..... 0
#   interfaces[0].proxy_gids ............... --------------------
#   shape .................................. (0,)
#   dtype .................................. float64
#   is empty ............................... True
#   interfaces[0].n_voi .................... 1
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('365284a4-9509-4356-9499-86186fc3bead')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[0, 1]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 2
# )
#
# Built in 0.423076 secs!
#
# Failed to summarize:
# tvb_app.cosimulator_builder.monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# Failed to summarize:
# tvb_app.cosimulator.monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# TVBANNarchySerialOrchestrator (
#   title ............................................................................ 'TVBANNarchySerialOrchestrator gid: a9127a0f-9589-4459-b2fb-a1ff80ff3fac'
#   Type ............................................................................. 'TVBANNarchySerialOrchestrator'
#   config ........................................................................... '--------------------'
#   config.title ..................................................................... 'Config gid: 0696cecf-7978-4133-ba29-0216fd02b284'
#   config.Type ...................................................................... 'Config'
#   config.gid ....................................................................... UUID('0696cecf-7978-4133-ba29-0216fd02b284')
#   tvb_app .......................................................................... '--------------------'
#   tvb_app.title .................................................................... 'TVBSerialApp gid: 92cbbac6-ac2a-4623-9f18-13fb28be63f6'
#   tvb_app.Type ..................................................................... 'TVBSerialApp'
#   tvb_app.config ................................................................... '--------------------'
#   tvb_app.config.title ............................................................. 'Config gid: 0696cecf-7978-4133-ba29-0216fd02b284'
#   tvb_app.config.Type .............................................................. 'Config'
#   tvb_app.config.gid ............................................................... UUID('0696cecf-7978-4133-ba29-0216fd02b284')
#   tvb_app.interfaces_builder ....................................................... '--------------------'
#   tvb_app.interfaces_builder.title ................................................. 'DefaultTVBANNarchyInterfaceBuilder gid: f892ad4c-c6a8-48cd-a636-1a00c1fb3c0d'
#   tvb_app.interfaces_builder.Type .................................................. 'DefaultTVBANNarchyInterfaceBuilder'
#   tvb_app.interfaces_builder.spiking_network ....................................... 'ANNarchyNetwork gid: 9b7d9bec-c12b-44a4-8083-aaec409aad08'
#   tvb_app.interfaces_builder.N_E ................................................... 10
#   tvb_app.interfaces_builder.model ................................................. "'RATE'"
#   tvb_app.interfaces_builder.config ................................................ Config gid: 0696cecf-7978-4133-ba29-0216fd02b284
#   tvb_app.interfaces_builder.logger ................................................ <Logger examples.example (DEBUG)>
#   tvb_app.interfaces_builder.tvb_cosimulator ....................................... CoSimulatorSerial gid: 973bcc3d-e8c0-4bbd-9a62-c3623984ce13
#   tvb_app.interfaces_builder.exclusive_nodes ....................................... True
#   tvb_app.interfaces_builder.output_flag ........................................... True
#   tvb_app.interfaces_builder.input_flag ............................................ True
#   tvb_app.interfaces_builder.proxy_inds ............................................ --------------------
#   tvb_app.interfaces_builder.proxy_inds: shape ..................................... --------------------
#   tvb_app.interfaces_builder.proxy_inds: dtype ..................................... dtype('int64')
#   tvb_app.interfaces_builder.proxy_inds: values .................................... --------------------
#   tvb_app.interfaces_builder.output_interfaces ..................................... 'properties:'
#   tvb_app.interfaces_builder.input_interfaces ...................................... 'properties:'
#   tvb_app.interfaces_builder.default_coupling_mode ................................. 'spikeNet'
#   tvb_app.interfaces_builder.global_coupling_scaling ............................... --------------------
#   tvb_app.interfaces_builder.global_coupling_scaling: shape ........................ (68,)
#   tvb_app.interfaces_builder.global_coupling_scaling: dtype ........................ float64
#   tvb_app.interfaces_builder.global_coupling_scaling: unique_values ................ 0.00390625
#   tvb_app.interfaces_builder.dt .................................................... '0.1'
#   tvb_app.interfaces_builder.gid ................................................... UUID('f892ad4c-c6a8-48cd-a636-1a00c1fb3c0d')
#   tvb_app.interfaces_builder.voi: shape ............................................ --------------------
#   tvb_app.interfaces_builder.voi: shape: shape ..................................... (1,)
#   tvb_app.interfaces_builder.voi: shape: dtype ..................................... int64
#   tvb_app.interfaces_builder.voi: shape: values .................................... 1
#   tvb_app.interfaces_builder.voi: dtype ............................................ dtype('int64')
#   tvb_app.interfaces_builder.voi: values ........................................... 0
#   tvb_app.interfaces_builder.populations: shape .................................... --------------------
#   shape ............................................................................ (0,)
#   dtype ............................................................................ float64
#   is empty ......................................................................... True
#   tvb_app.interfaces_builder.populations: dtype .................................... dtype('<U1')
#   tvb_app.interfaces_builder.populations: values ................................... 'E'
#   tvb_app.interfaces_builder.proxy_inds: shape: shape .............................. (1,)
#   tvb_app.interfaces_builder.proxy_inds: shape: dtype .............................. int64
#   tvb_app.interfaces_builder.proxy_inds: shape: values ............................. 66
#   tvb_app.interfaces_builder.proxy_inds: values: shape ............................. (1, 2)
#   tvb_app.interfaces_builder.proxy_inds: values: dtype ............................. int64
#   tvb_app.interfaces_builder.proxy_inds: values: values ............................ [0 1]
#   tvb_app.interfaces_builder.voi_labels: shape ..................................... --------------------
#   tvb_app.interfaces_builder.voi_labels: shape: shape .............................. (1,)
#   tvb_app.interfaces_builder.voi_labels: shape: dtype .............................. int64
#   tvb_app.interfaces_builder.voi_labels: shape: values ............................. 1
#   tvb_app.interfaces_builder.voi_labels: dtype ..................................... dtype('<U1')
#   tvb_app.interfaces_builder.voi_labels: values .................................... 'R'
#   tvb_app.interfaces_builder.proxy ................................................. 'ANNarchyTimedPoissonPopulationSet gid: 1482ea6a-1847-48cb-92f7-9f436bb6fd46'
#   tvb_app.interfaces_builder.transformer ........................................... 'LinearRate gid: 80c6e90c-8d55-4ec5-b77f-6f2cd3f90a9f'
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape ............................. --------------------
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: shape ...................... (1,)
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: dtype ...................... int64
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: values ..................... 2
#   tvb_app.interfaces_builder.spiking_proxy_inds: dtype ............................. dtype('int64')
#   tvb_app.interfaces_builder.spiking_proxy_inds: values ............................ --------------------
#   tvb_app.interfaces_builder.spiking_proxy_inds: values: shape ..................... (1, 2)
#   tvb_app.interfaces_builder.spiking_proxy_inds: values: dtype ..................... int64
#   tvb_app.interfaces_builder.spiking_proxy_inds: values: values .................... [0 1]
#   tvb_app.interfaces_builder.coupling_mode ......................................... "'spikeNet'"
#   tvb_app.interfaces_builder.proxy_inds: unique_values ............................. --------------------
#   tvb_app.interfaces_builder.proxy_inds: unique_values: shape ...................... (1, 2)
#   tvb_app.interfaces_builder.proxy_inds: unique_values: dtype ...................... int64
#   tvb_app.interfaces_builder.proxy_inds: unique_values: values ..................... [ 2 67]
#   tvb_app.interfaces_builder.monitor_ind ........................................... '0'
#   tvb_app.spiking_network .......................................................... '--------------------'
#   tvb_app.spiking_network.title .................................................... 'ANNarchyNetwork gid: 9b7d9bec-c12b-44a4-8083-aaec409aad08'
#   tvb_app.spiking_network.Type ..................................................... 'ANNarchyNetwork'
#   tvb_app.spiking_network.config ................................................... Config gid: 0696cecf-7978-4133-ba29-0216fd02b284
#   tvb_app.spiking_network.brain_regions ............................................ ANNarchyBrain gid: 27e5ffe2-998c-4e83-bc97-4c060d795a96
#   tvb_app.spiking_network.network_path ............................................. ''
#   tvb_app.spiking_network.logger ................................................... <Logger tvb-multiscale (DEBUG)>
#   tvb_app.spiking_network.output_devices ........................................... DeviceSets gid: 11178125-bd12-44b3-935e-871a385885ff
#   tvb_app.spiking_network.input_devices ............................................ DeviceSets gid: 7117370d-7397-48ef-a7ee-d95c7e736486
#   tvb_app.spiking_network.output_proxies ........................................... DeviceSets gid: a5f714ca-27c2-479d-a25b-b918fd8b0610
#   tvb_app.spiking_network.input_proxies ............................................ DeviceSets gid: f7f7484f-b1ab-4510-90e8-8e1872698a0a
#   tvb_app.spiking_network.gid ...................................................... UUID('9b7d9bec-c12b-44a4-8083-aaec409aad08')
#   tvb_app.cosimulator_builder ...................................................... '--------------------'
#   tvb_app.cosimulator_builder.title ................................................ 'CoSimulatorSerialBuilder gid: 4b164d5a-d03e-4c9b-a4fe-acdbe150ea22'
#   tvb_app.cosimulator_builder.Type ................................................. 'CoSimulatorSerialBuilder'
#   tvb_app.cosimulator_builder.config ............................................... Config gid: 0696cecf-7978-4133-ba29-0216fd02b284
#   tvb_app.cosimulator_builder.logger ............................................... <Logger examples.example (DEBUG)>
#   tvb_app.cosimulator_builder.model ................................................ Linear gid: 5dd80905-ac70-4e0a-8a9b-b3dd1ffabebe
#   tvb_app.cosimulator_builder.model_params[r_e] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[r_e]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[r_e]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[r_e]: values ............................ 0
#   tvb_app.cosimulator_builder.model_params[r_i] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[r_i]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[r_i]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[r_i]: values ............................ 0
#   tvb_app.cosimulator_builder.model_params[k_e] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[k_e]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[k_e]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[k_e]: values ............................ 1
#   tvb_app.cosimulator_builder.model_params[k_i] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[k_i]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[k_i]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[k_i]: values ............................ 1
#   tvb_app.cosimulator_builder.model_params[tau_e] .................................. --------------------
#   tvb_app.cosimulator_builder.model_params[tau_e]: shape ........................... (1,)
#   tvb_app.cosimulator_builder.model_params[tau_e]: dtype ........................... float64
#   tvb_app.cosimulator_builder.model_params[tau_e]: values .......................... 10
#   tvb_app.cosimulator_builder.model_params[tau_i] .................................. --------------------
#   tvb_app.cosimulator_builder.model_params[tau_i]: shape ........................... (1,)
#   tvb_app.cosimulator_builder.model_params[tau_i]: dtype ........................... float64
#   tvb_app.cosimulator_builder.model_params[tau_i]: values .......................... 10
#   tvb_app.cosimulator_builder.model_params[c_ee] ................................... --------------------
#   tvb_app.cosimulator_builder.model_params[c_ee]: shape ............................ (1,)
#   tvb_app.cosimulator_builder.model_params[c_ee]: dtype ............................ float64
#   tvb_app.cosimulator_builder.model_params[c_ee]: values ........................... 10
#   tvb_app.cosimulator_builder.model_params[c_ei] ................................... --------------------
#   tvb_app.cosimulator_builder.model_params[c_ei]: shape ............................ (1,)
#   tvb_app.cosimulator_builder.model_params[c_ei]: dtype ............................ float64
#   tvb_app.cosimulator_builder.model_params[c_ei]: values ........................... 6
#   tvb_app.cosimulator_builder.model_params[c_ie] ................................... --------------------
#   tvb_app.cosimulator_builder.model_params[c_ie]: shape ............................ (1,)
#   tvb_app.cosimulator_builder.model_params[c_ie]: dtype ............................ float64
#   tvb_app.cosimulator_builder.model_params[c_ie]: values ........................... 10
#   tvb_app.cosimulator_builder.model_params[c_ii] ................................... --------------------
#   tvb_app.cosimulator_builder.model_params[c_ii]: shape ............................ (1,)
#   tvb_app.cosimulator_builder.model_params[c_ii]: dtype ............................ float64
#   tvb_app.cosimulator_builder.model_params[c_ii]: values ........................... 1
#   tvb_app.cosimulator_builder.model_params[alpha_e] ................................ --------------------
#   tvb_app.cosimulator_builder.model_params[alpha_e]: shape ......................... (1,)
#   tvb_app.cosimulator_builder.model_params[alpha_e]: dtype ......................... float64
#   tvb_app.cosimulator_builder.model_params[alpha_e]: values ........................ 1.2
#   tvb_app.cosimulator_builder.model_params[alpha_i] ................................ --------------------
#   tvb_app.cosimulator_builder.model_params[alpha_i]: shape ......................... (1,)
#   tvb_app.cosimulator_builder.model_params[alpha_i]: dtype ......................... float64
#   tvb_app.cosimulator_builder.model_params[alpha_i]: values ........................ 2
#   tvb_app.cosimulator_builder.model_params[a_e] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[a_e]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[a_e]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[a_e]: values ............................ 1
#   tvb_app.cosimulator_builder.model_params[a_i] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[a_i]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[a_i]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[a_i]: values ............................ 1
#   tvb_app.cosimulator_builder.model_params[b_e] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[b_e]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[b_e]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[b_e]: values ............................ 0
# ...
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.cortical]: dtype ............ bool
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.cortical]: unique_values .... 1
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres] ................ --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: shape ......... (68,)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: dtype ......... bool
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: =False ........ {0...33}
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: =True ......... {34...67}
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations] ............... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations]: shape ........ (68, 3)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations]: dtype ........ float64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations]: values ....... [-0.38261669 -0.60546974 -0.69786163  0.65982329 -0.3692104  -0.65445925
#   0.92603708  0.22476123  0.30321232 -0.75417582  0.4576563   0.47092414
#  -0.50299289  0.05509325  0.86253283  0.899222    0.06479787  0.43266734
#   0.40962978  0.3030412   0.86044725 -0.71762975  0.19590929  0.66830165
#   0.65151989 -0.30294387 -0.69551912 -0.8720307  -0.10976373 -0.47698467
#  -0.00596095  0.82174661 -0.56982188 -0.12180604  0.81564435 -0.56558606
#   0.40682931  0.054199   -0.91189494 -0.41228273 -0.03266817 -0.91047007
#  -0.80006394 -0.49775     0.33487704  0.83300378 -0.52883519  0.16259782
#  -0.25474036 -0.29356364 -0.92137275  0.20335288 -0.08556166 -0.97535984
#  -0.97482388  0.20036282 -0.09784246  0.96436493  0.25302228 -0.07733052
#   0.93018948 -0.35218341 -0.10351031 -0.75968686 -0.25980467 -0.5961354
#  -0.49661151 -0.72092729 -0.4833641   0.70221386 -0.68505051 -0.19391104
#  -0.23475324  0.09820225 -0.96708181  0.1829861   0.03111709 -0.98262293
#   0.86369223  0.13933983 -0.48437604 -0.56179383  0.02038304 -0.82702614
#   0.88075419 -0.10750546 -0.46120996 -0.98248087 -0.07928951 -0.16865499
#  -0.95037587  0.18198158  0.252326    0.90738399  0.29899871  0.29538799
#   0.84287785 -0.21924381 -0.49141538 -0.93942975  0.02652263 -0.34171377
#   0.2119279  -0.58288886 -0.78442791 -0.13402574 -0.56884351 -0.81145189
#  -0.55077346  0.83158287 -0.07154388  0.89696688  0.18764621  0.40029904
#  -0.59633825  0.47078993 -0.65018269  0.63719518  0.19074258 -0.7467259
#  -0.5790787  -0.29505125 -0.7600083   0.77357165 -0.2593268  -0.5782184
#   0.72945509  0.37259806 -0.57364271 -0.85038668 -0.08062112 -0.51994492
#  -0.62004143  0.48159849  0.6193638   0.71211482  0.4534374   0.53599161
#   0.84926834 -0.02662222  0.5272898  -0.8704929   0.03160028  0.49116549
#  -0.85920021  0.04946875  0.50924242  0.82188478  0.0903833   0.56243779
#   0.83202099 -0.15648958 -0.53221432 -0.93909788 -0.08768294 -0.33227531
#   0.95323808  0.30032389 -0.03380406 -0.88853176  0.42340502 -0.17674701
#  -0.59416038  0.73807852  0.31970852  0.44899813  0.79714001  0.40369356
#   0.68409308  0.4363876   0.58445062 -0.78808872  0.30711392  0.53347654
#  -0.50538932 -0.58355453  0.63564593  0.23008214 -0.57162063  0.78759892
#  -0.42941662  0.88199453  0.19413146  0.4440229   0.85956469  0.2529668
#  -0.90286225 -0.30715946  0.30082026  0.65267736 -0.75558871  0.05565929
#   0.73908346  0.67084084 -0.061059   -0.65805472  0.7526894  -0.02055836
#  -0.04366157  0.3210788   0.94604549 -0.38115902  0.48848431  0.78492094]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas] ...................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas]: shape ............... (68,)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas]: dtype ............... float64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas]: unique_values ....... [ 71.  76.  59.  65. 226. 158. 162.  44.  30.  21.  27. 305. 298. 348.
#  428. 274. 244. 178. 200. 117. 101. 415. 403. 210. 213. 290. 280. 127.
#  164. 237. 261. 125.  69.  72. 165. 159.  63.  64. 112. 146.  95. 122.
#  295. 316. 133. 147. 405. 384. 281.  78. 433. 410. 582. 539. 446. 422.
#  346. 330. 318.  47.  48.  50.  35.]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays] .................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays]: shape ............. (68, 68)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays]: dtype ............. int64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays]: unique_values ..... [[1], [36, 37], [40, 41], [44, 93], [96, 99], [101, 113], [115, 119], [122, 123], [125, 141], [143, 162], [164, 166], [168, 170], [172, 174], [176, 179], [181, 189], [191, 222], [224, 253], [255, 274], [277, 348], [350, 362], [364, 384], [386, 431], [433, 461], [463, 466], [468, 471], [473, 474], [476, 529], [531, 543], [546, 558], [560, 570], [572, 573], [576, 581], [583, 593], [595, 602], [604, 605], [607], [609, 615], [617], [619, 620], [622], [624, 625], [628], [630, 631], [633, 634], [636], [639, 645], [648, 649], [652, 656], [658], [660], [662, 665], [667, 671], [673], [675], [677], [680, 684], [688], [690, 693], [699, 700], [703, 705], [707], [710, 714], [718, 722], [724, 729], [731], [734, 735], [739], [744], [747], [749], [751, 754], [758, 759], [761], [763, 764], [770], [781], [784, 786], [792, 793], [795], [799], [801], [804], [812, 814], [820], [827], [841], [862], [879]]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays] ..................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays]: shape .............. (68, 68)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays]: dtype .............. float64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays]: unique_values ...... [ 0.1        39.98974333 34.00171    ... 20.76666667  6.62544467
#   5.83055433]
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a] .............................. --------------------
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a]: shape ....................... (1,)
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a]: dtype ....................... float64
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a]: values ...................... 0.00390625
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b] .............................. --------------------
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b]: shape ....................... (1,)
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b]: dtype ....................... float64
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b]: values ...................... 0
#   spikeNet_app.interfaces_builder .................................................. None
#   spikeNet_app.logger .............................................................. <Logger examples.example (DEBUG)>
#   spikeNet_app.default_tvb_serial_cosim_path ....................................... '/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/DefaultExcIO_RATE_bidir/config/tvb_serial_cosimulator.pkl'
#   spikeNet_app.gid ................................................................. UUID('e6b25cfc-e8a7-4897-8f06-2bb42d7bbf29')
#   spikeNet_app.spiking_cosimulator ................................................. <module 'ANNarchy' from '/home/docker/.local/lib/python3.10/site-packages/ANNarchy/__init__.py'>
#   logger ........................................................................... <Logger examples.example (DEBUG)>
#   default_tvb_serial_cosim_path .................................................... '/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/DefaultExcIO_RATE_bidir/config/tvb_serial_cosimulator.pkl'
#   gid .............................................................................. UUID('a9127a0f-9589-4459-b2fb-a1ff80ff3fac')
# )
# None
#
#
# Simulating...
#
# Simulating for 36ms with App TVBANNarchySerialOrchestrator...
#
# Configuring simulation with App TVBANNarchySerialOrchestrator...
#
# Configuring simulation with App TVBSerialApp...
# 2023-09-28 13:09:52,783 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-28 13:09:52,783 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2023-09-28 13:09:52,783 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2023-09-28 13:09:52,789 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2023-09-28 13:09:52,789 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2023-09-28 13:09:52,790 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-28 13:09:52,790 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
#
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: 973bcc3d-e8c0-4bbd-9a62-c3623984ce13'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: 5dd80905-ac70-4e0a-8a9b-b3dd1ffabebe
#   output_interfaces ................... TVBtoANNarchyInterfaces gid: 74dbc1f1-c6ae-4138-8fe4-69fae8ebc6a4
#   input_interfaces .................... ANNarchyToTVBInterfaces gid: 365284a4-9509-4356-9499-86186fc3bead
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (66,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: unique_values ....... [[2, 67]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (1,)
#   voi: dtype .......................... int64
#   voi: values ......................... 0
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[0, 1]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. RawCosim(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 7f56a09d-a48c-41dc-866b-7488c069b774
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: bef66d2f-e5f3-40e6-9929-50e85084e8ea
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: c9c9f810-2fc0-44e2-b9ae-e705cd6a3073
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('973bcc3d-e8c0-4bbd-9a62-c3623984ce13')
# )
#
# Configuring simulation with App ANNarchySerialApp...
# Simulating for 36ms with App TVBSerialApp...
# 2023-09-28 13:09:53,252 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - No or all NaN valued cosimulator updates at time step 0!
# 2023-09-28 13:09:53,252 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.016 seconds
# 2023-09-28 13:09:53,252 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2023-09-28 13:09:53,252 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 22031
# 2023-09-28 13:09:53,257 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-28 13:09:53,263 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...9.091% completed in 0.0121357 sec!
# ...9.091% completed in 0.0121357 sec!2023-09-28 13:09:53,271 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-28 13:09:53,278 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...18.182% completed in 0.0264037 sec!
# ...18.182% completed in 0.0264037 sec!2023-09-28 13:09:53,285 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-28 13:09:53,292 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...27.273% completed in 0.0402768 sec!
# ...27.273% completed in 0.0402768 sec!2023-09-28 13:09:53,299 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-28 13:09:53,306 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...36.364% completed in 0.0551238 sec!
# ...36.364% completed in 0.0551238 sec!2023-09-28 13:09:53,314 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-28 13:09:53

#   Type ................................... 'ANNarchyToTVBInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'ANNarchyToTVBInterface gid: f269b5b2-e0a7-40c7-ae48-f64f3bf66e92'
#   interfaces[0].Type ..................... 'ANNarchyToTVBInterface'
#   interfaces[0].proxy .................... ANNarchySpikeMonitorTotalSet gid: cee0e4e1-509c-41df-8f59-60ad25aed157
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: c697bf68-356c-45ef-ba23-dc068721e9bb
#   interfaces[0].transformer .............. ElephantSpikesHistogramRate gid: 72d9fb77-0d54-4dfa-9291-f1635749dd8f
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (2,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: values ....... [[0, 1]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].dt ....................... 0.1
#   interfaces[0].times .................... --------------------
#   interfaces[0].times: shape ............. (2,)
#   interfaces[0].times: dtype ............. int64
#   interfaces[0].times: values ............ [[0, 1]]
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'SpikeMonitor'
#   interfaces[0].gid ...................... UUID('f269b5b2-e0a7-40c7-ae48-f64f3bf66e92')
#   interfaces[0].number_of_proxy_nodes .... 2
#   interfaces[0].number_of_proxy_gids ..... 0
#   interfaces[0].proxy_gids ............... --------------------
#   shape .................................. (0,)
#   dtype .................................. float64
#   is empty ............................... True
#   interfaces[0].n_voi .................... 1
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('edbdcd90-1e4a-4689-a910-8145f77c62d4')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[0, 1]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 2
# )
#
# Built in 0.397846 secs!
#
# Failed to summarize:
# tvb_app.cosimulator_builder.monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# Failed to summarize:
# tvb_app.cosimulator.monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# TVBANNarchySerialOrchestrator (
#   title ............................................................................ 'TVBANNarchySerialOrchestrator gid: df37bb0c-4813-4bc8-893f-e9b2e6ad6c14'
#   Type ............................................................................. 'TVBANNarchySerialOrchestrator'
#   config ........................................................................... '--------------------'
#   config.title ..................................................................... 'Config gid: be606157-5470-4cf2-ac73-6ce3f92e9e5a'
#   config.Type ...................................................................... 'Config'
#   config.gid ....................................................................... UUID('be606157-5470-4cf2-ac73-6ce3f92e9e5a')
#   tvb_app .......................................................................... '--------------------'
#   tvb_app.title .................................................................... 'TVBSerialApp gid: 6b733e9d-0a71-4eff-83af-0b817295f9bc'
#   tvb_app.Type ..................................................................... 'TVBSerialApp'
#   tvb_app.config ................................................................... '--------------------'
#   tvb_app.config.title ............................................................. 'Config gid: be606157-5470-4cf2-ac73-6ce3f92e9e5a'
#   tvb_app.config.Type .............................................................. 'Config'
#   tvb_app.config.gid ............................................................... UUID('be606157-5470-4cf2-ac73-6ce3f92e9e5a')
#   tvb_app.interfaces_builder ....................................................... '--------------------'
#   tvb_app.interfaces_builder.title ................................................. 'DefaultTVBANNarchyInterfaceBuilder gid: 8697b3bc-a281-4059-ba7c-5bfaf1ec89f5'
#   tvb_app.interfaces_builder.Type .................................................. 'DefaultTVBANNarchyInterfaceBuilder'
#   tvb_app.interfaces_builder.spiking_network ....................................... 'ANNarchyNetwork gid: c697bf68-356c-45ef-ba23-dc068721e9bb'
#   tvb_app.interfaces_builder.N_E ................................................... 10
#   tvb_app.interfaces_builder.model ................................................. "'SPIKES'"
#   tvb_app.interfaces_builder.config ................................................ Config gid: be606157-5470-4cf2-ac73-6ce3f92e9e5a
#   tvb_app.interfaces_builder.logger ................................................ <Logger examples.example (DEBUG)>
#   tvb_app.interfaces_builder.tvb_cosimulator ....................................... CoSimulatorSerial gid: 07e607e1-b868-449f-b6bc-33efe78d8df5
#   tvb_app.interfaces_builder.exclusive_nodes ....................................... True
#   tvb_app.interfaces_builder.output_flag ........................................... True
#   tvb_app.interfaces_builder.input_flag ............................................ True
#   tvb_app.interfaces_builder.proxy_inds ............................................ --------------------
#   tvb_app.interfaces_builder.proxy_inds: shape ..................................... --------------------
#   tvb_app.interfaces_builder.proxy_inds: dtype ..................................... dtype('int64')
#   tvb_app.interfaces_builder.proxy_inds: values .................................... --------------------
#   tvb_app.interfaces_builder.output_interfaces ..................................... 'properties:'
#   tvb_app.interfaces_builder.input_interfaces ...................................... 'properties:'
#   tvb_app.interfaces_builder.default_coupling_mode ................................. 'spikeNet'
#   tvb_app.interfaces_builder.global_coupling_scaling ............................... --------------------
#   tvb_app.interfaces_builder.global_coupling_scaling: shape ........................ (68,)
#   tvb_app.interfaces_builder.global_coupling_scaling: dtype ........................ float64
#   tvb_app.interfaces_builder.global_coupling_scaling: unique_values ................ 0.00390625
#   tvb_app.interfaces_builder.dt .................................................... '0.1'
#   tvb_app.interfaces_builder.gid ................................................... UUID('8697b3bc-a281-4059-ba7c-5bfaf1ec89f5')
#   tvb_app.interfaces_builder.voi: shape ............................................ --------------------
#   tvb_app.interfaces_builder.voi: shape: shape ..................................... (1,)
#   tvb_app.interfaces_builder.voi: shape: dtype ..................................... int64
#   tvb_app.interfaces_builder.voi: shape: values .................................... 1
#   tvb_app.interfaces_builder.voi: dtype ............................................ dtype('int64')
#   tvb_app.interfaces_builder.voi: values ........................................... 0
#   tvb_app.interfaces_builder.populations: shape .................................... --------------------
#   shape ............................................................................ (0,)
#   dtype ............................................................................ float64
#   is empty ......................................................................... True
#   tvb_app.interfaces_builder.populations: dtype .................................... dtype('<U1')
#   tvb_app.interfaces_builder.populations: values ................................... 'E'
#   tvb_app.interfaces_builder.proxy_inds: shape: shape .............................. (1,)
#   tvb_app.interfaces_builder.proxy_inds: shape: dtype .............................. int64
#   tvb_app.interfaces_builder.proxy_inds: shape: values ............................. 66
#   tvb_app.interfaces_builder.proxy_inds: values: shape ............................. (1, 2)
#   tvb_app.interfaces_builder.proxy_inds: values: dtype ............................. int64
#   tvb_app.interfaces_builder.proxy_inds: values: values ............................ [0 1]
#   tvb_app.interfaces_builder.voi_labels: shape ..................................... --------------------
#   tvb_app.interfaces_builder.voi_labels: shape: shape .............................. (1,)
#   tvb_app.interfaces_builder.voi_labels: shape: dtype .............................. int64
#   tvb_app.interfaces_builder.voi_labels: shape: values ............................. 1
#   tvb_app.interfaces_builder.voi_labels: dtype ..................................... dtype('<U1')
#   tvb_app.interfaces_builder.voi_labels: values .................................... 'R'
#   tvb_app.interfaces_builder.proxy ................................................. 'ANNarchySpikeSourceArraySet gid: fa440a5a-9d38-4b95-b1bf-d7c4f47ac404'
#   tvb_app.interfaces_builder.transformer ........................................... 'RatesToSpikesElephantPoisson gid: 65f3b263-7bf7-4302-bf97-ca12874ba0a6'
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape ............................. --------------------
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: shape ...................... (1,)
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: dtype ...................... int64
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: values ..................... 2
#   tvb_app.interfaces_builder.spiking_proxy_inds: dtype ............................. dtype('int64')
#   tvb_app.interfaces_builder.spiking_proxy_inds: values ............................ --------------------
#   tvb_app.interfaces_builder.spiking_proxy_inds: values: shape ..................... (1, 2)
#   tvb_app.interfaces_builder.spiking_proxy_inds: values: dtype ..................... int64
#   tvb_app.interfaces_builder.spiking_proxy_inds: values: values .................... [0 1]
#   tvb_app.interfaces_builder.coupling_mode ......................................... "'spikeNet'"
#   tvb_app.interfaces_builder.proxy_inds: unique_values ............................. --------------------
#   tvb_app.interfaces_builder.proxy_inds: unique_values: shape ...................... (1, 2)
#   tvb_app.interfaces_builder.proxy_inds: unique_values: dtype ...................... int64
#   tvb_app.interfaces_builder.proxy_inds: unique_values: values ..................... [ 2 67]
#   tvb_app.interfaces_builder.monitor_ind ........................................... '0'
#   tvb_app.spiking_network .......................................................... '--------------------'
#   tvb_app.spiking_network.title .................................................... 'ANNarchyNetwork gid: c697bf68-356c-45ef-ba23-dc068721e9bb'
#   tvb_app.spiking_network.Type ..................................................... 'ANNarchyNetwork'
#   tvb_app.spiking_network.config ................................................... Config gid: be606157-5470-4cf2-ac73-6ce3f92e9e5a
#   tvb_app.spiking_network.brain_regions ............................................ ANNarchyBrain gid: 66eb8376-836d-4add-bbf1-80b7d083c025
#   tvb_app.spiking_network.network_path ............................................. ''
#   tvb_app.spiking_network.logger ................................................... <Logger tvb-multiscale (DEBUG)>
#   tvb_app.spiking_network.output_devices ........................................... DeviceSets gid: 5343f07a-f5d8-4fb6-9ffe-72304bc4fd3f
#   tvb_app.spiking_network.input_devices ............................................ DeviceSets gid: 91dd7da4-e0f3-4ce8-97b4-957a8175e89f
#   tvb_app.spiking_network.output_proxies ........................................... DeviceSets gid: 475f2c5f-3e29-462d-be4b-b99054e7d28e
#   tvb_app.spiking_network.input_proxies ............................................ DeviceSets gid: bf98c757-ea1a-4b25-a6f1-6b66fb4148ea
#   tvb_app.spiking_network.gid ...................................................... UUID('c697bf68-356c-45ef-ba23-dc068721e9bb')
#   tvb_app.cosimulator_builder ...................................................... '--------------------'
#   tvb_app.cosimulator_builder.title ................................................ 'CoSimulatorSerialBuilder gid: 09560d92-dd08-4924-923c-6c353335a175'
#   tvb_app.cosimulator_builder.Type ................................................. 'CoSimulatorSerialBuilder'
#   tvb_app.cosimulator_builder.config ............................................... Config gid: be606157-5470-4cf2-ac73-6ce3f92e9e5a
#   tvb_app.cosimulator_builder.logger ............................................... <Logger examples.example (DEBUG)>
#   tvb_app.cosimulator_builder.model ................................................ Linear gid: f1453f15-f4cf-4baf-8460-49d901e8d00c
#   tvb_app.cosimulator_builder.model_params[r_e] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[r_e]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[r_e]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[r_e]: values ............................ 0
#   tvb_app.cosimulator_builder.model_params[r_i] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[r_i]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[r_i]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[r_i]: values ............................ 0
#   tvb_app.cosimulator_builder.model_params[k_e] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[k_e]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[k_e]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[k_e]: values ............................ 1
#   tvb_app.cosimulator_builder.model_params[k_i] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[k_i]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[k_i]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[k_i]: values ............................ 1
#   tvb_app.cosimulator_builder.model_params[tau_e] .................................. --------------------
#   tvb_app.cosimulator_builder.model_params[tau_e]: shape ........................... (1,)
#   tvb_app.cosimulator_builder.model_params[tau_e]: dtype ........................... float64
#   tvb_app.cosimulator_builder.model_params[tau_e]: values .......................... 10
#   tvb_app.cosimulator_builder.model_params[tau_i] .................................. --------------------
#   tvb_app.cosimulator_builder.model_params[tau_i]: shape ........................... (1,)
#   tvb_app.cosimulator_builder.model_params[tau_i]: dtype ........................... float64
#   tvb_app.cosimulator_builder.model_params[tau_i]: values .......................... 10
#   tvb_app.cosimulator_builder.model_params[c_ee] ................................... --------------------
#   tvb_app.cosimulator_builder.model_params[c_ee]: shape ............................ (1,)
#   tvb_app.cosimulator_builder.model_params[c_ee]: dtype ............................ float64
#   tvb_app.cosimulator_builder.model_params[c_ee]: values ........................... 10
#   tvb_app.cosimulator_builder.model_params[c_ei] ................................... --------------------
#   tvb_app.cosimulator_builder.model_params[c_ei]: shape ............................ (1,)
#   tvb_app.cosimulator_builder.model_params[c_ei]: dtype ............................ float64
#   tvb_app.cosimulator_builder.model_params[c_ei]: values ........................... 6
#   tvb_app.cosimulator_builder.model_params[c_ie] ................................... --------------------
#   tvb_app.cosimulator_builder.model_params[c_ie]: shape ............................ (1,)
#   tvb_app.cosimulator_builder.model_params[c_ie]: dtype ............................ float64
#   tvb_app.cosimulator_builder.model_params[c_ie]: values ........................... 10
#   tvb_app.cosimulator_builder.model_params[c_ii] ................................... --------------------
#   tvb_app.cosimulator_builder.model_params[c_ii]: shape ............................ (1,)
#   tvb_app.cosimulator_builder.model_params[c_ii]: dtype ............................ float64
#   tvb_app.cosimulator_builder.model_params[c_ii]: values ........................... 1
#   tvb_app.cosimulator_builder.model_params[alpha_e] ................................ --------------------
#   tvb_app.cosimulator_builder.model_params[alpha_e]: shape ......................... (1,)
#   tvb_app.cosimulator_builder.model_params[alpha_e]: dtype ......................... float64
#   tvb_app.cosimulator_builder.model_params[alpha_e]: values ........................ 1.2
#   tvb_app.cosimulator_builder.model_params[alpha_i] ................................ --------------------
#   tvb_app.cosimulator_builder.model_params[alpha_i]: shape ......................... (1,)
#   tvb_app.cosimulator_builder.model_params[alpha_i]: dtype ......................... float64
#   tvb_app.cosimulator_builder.model_params[alpha_i]: values ........................ 2
#   tvb_app.cosimulator_builder.model_params[a_e] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[a_e]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[a_e]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[a_e]: values ............................ 1
#   tvb_app.cosimulator_builder.model_params[a_i] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[a_i]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[a_i]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[a_i]: values ............................ 1
#   tvb_app.cosimulator_builder.model_params[b_e] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[b_e]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[b_e]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[b_e]: values ............................ 0
# ...
#   -0.27065  62.4632   62.4399   12.6364   64.7371   58.6815  -18.7497
#  -29.4435   60.5999   26.9971  -25.4143   62.4196  -48.4458   27.201
#   22.3661   52.096    28.9998   19.2317  -49.9418    0.41451  54.069
#   56.9432    2.3815   54.4009  -21.09     51.9872  -10.1052   28.0673
#   53.8073   -7.9653  -44.5804   17.7626   32.336    48.1555   17.8577
#   33.199  ]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.cortical] ................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.cortical]: shape ............ (68,)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.cortical]: dtype ............ bool
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.cortical]: unique_values .... 1
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres] ................ --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: shape ......... (68,)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: dtype ......... bool
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: =False ........ {0...33}
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: =True ......... {34...67}
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations] ............... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations]: shape ........ (68, 3)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations]: dtype ........ float64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations]: values ....... [-0.38261669 -0.60546974 -0.69786163  0.65982329 -0.3692104  -0.65445925
#   0.92603708  0.22476123  0.30321232 -0.75417582  0.4576563   0.47092414
#  -0.50299289  0.05509325  0.86253283  0.899222    0.06479787  0.43266734
#   0.40962978  0.3030412   0.86044725 -0.71762975  0.19590929  0.66830165
#   0.65151989 -0.30294387 -0.69551912 -0.8720307  -0.10976373 -0.47698467
#  -0.00596095  0.82174661 -0.56982188 -0.12180604  0.81564435 -0.56558606
#   0.40682931  0.054199   -0.91189494 -0.41228273 -0.03266817 -0.91047007
#  -0.80006394 -0.49775     0.33487704  0.83300378 -0.52883519  0.16259782
#  -0.25474036 -0.29356364 -0.92137275  0.20335288 -0.08556166 -0.97535984
#  -0.97482388  0.20036282 -0.09784246  0.96436493  0.25302228 -0.07733052
#   0.93018948 -0.35218341 -0.10351031 -0.75968686 -0.25980467 -0.5961354
#  -0.49661151 -0.72092729 -0.4833641   0.70221386 -0.68505051 -0.19391104
#  -0.23475324  0.09820225 -0.96708181  0.1829861   0.03111709 -0.98262293
#   0.86369223  0.13933983 -0.48437604 -0.56179383  0.02038304 -0.82702614
#   0.88075419 -0.10750546 -0.46120996 -0.98248087 -0.07928951 -0.16865499
#  -0.95037587  0.18198158  0.252326    0.90738399  0.29899871  0.29538799
#   0.84287785 -0.21924381 -0.49141538 -0.93942975  0.02652263 -0.34171377
#   0.2119279  -0.58288886 -0.78442791 -0.13402574 -0.56884351 -0.81145189
#  -0.55077346  0.83158287 -0.07154388  0.89696688  0.18764621  0.40029904
#  -0.59633825  0.47078993 -0.65018269  0.63719518  0.19074258 -0.7467259
#  -0.5790787  -0.29505125 -0.7600083   0.77357165 -0.2593268  -0.5782184
#   0.72945509  0.37259806 -0.57364271 -0.85038668 -0.08062112 -0.51994492
#  -0.62004143  0.48159849  0.6193638   0.71211482  0.4534374   0.53599161
#   0.84926834 -0.02662222  0.5272898  -0.8704929   0.03160028  0.49116549
#  -0.85920021  0.04946875  0.50924242  0.82188478  0.0903833   0.56243779
#   0.83202099 -0.15648958 -0.53221432 -0.93909788 -0.08768294 -0.33227531
#   0.95323808  0.30032389 -0.03380406 -0.88853176  0.42340502 -0.17674701
#  -0.59416038  0.73807852  0.31970852  0.44899813  0.79714001  0.40369356
#   0.68409308  0.4363876   0.58445062 -0.78808872  0.30711392  0.53347654
#  -0.50538932 -0.58355453  0.63564593  0.23008214 -0.57162063  0.78759892
#  -0.42941662  0.88199453  0.19413146  0.4440229   0.85956469  0.2529668
#  -0.90286225 -0.30715946  0.30082026  0.65267736 -0.75558871  0.05565929
#   0.73908346  0.67084084 -0.061059   -0.65805472  0.7526894  -0.02055836
#  -0.04366157  0.3210788   0.94604549 -0.38115902  0.48848431  0.78492094]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas] ...................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas]: shape ............... (68,)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas]: dtype ............... float64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas]: unique_values ....... [ 71.  76.  59.  65. 226. 158. 162.  44.  30.  21.  27. 305. 298. 348.
#  428. 274. 244. 178. 200. 117. 101. 415. 403. 210. 213. 290. 280. 127.
#  164. 237. 261. 125.  69.  72. 165. 159.  63.  64. 112. 146.  95. 122.
#  295. 316. 133. 147. 405. 384. 281.  78. 433. 410. 582. 539. 446. 422.
#  346. 330. 318.  47.  48.  50.  35.]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays] .................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays]: shape ............. (68, 68)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays]: dtype ............. int64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays]: unique_values ..... [[1], [36, 37], [40, 41], [44, 93], [96, 99], [101, 113], [115, 119], [122, 123], [125, 141], [143, 162], [164, 166], [168, 170], [172, 174], [176, 179], [181, 189], [191, 222], [224, 253], [255, 274], [277, 348], [350, 362], [364, 384], [386, 431], [433, 461], [463, 466], [468, 471], [473, 474], [476, 529], [531, 543], [546, 558], [560, 570], [572, 573], [576, 581], [583, 593], [595, 602], [604, 605], [607], [609, 615], [617], [619, 620], [622], [624, 625], [628], [630, 631], [633, 634], [636], [639, 645], [648, 649], [652, 656], [658], [660], [662, 665], [667, 671], [673], [675], [677], [680, 684], [688], [690, 693], [699, 700], [703, 705], [707], [710, 714], [718, 722], [724, 729], [731], [734, 735], [739], [744], [747], [749], [751, 754], [758, 759], [761], [763, 764], [770], [781], [784, 786], [792, 793], [795], [799], [801], [804], [812, 814], [820], [827], [841], [862], [879]]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays] ..................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays]: shape .............. (68, 68)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays]: dtype .............. float64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays]: unique_values ...... [ 0.1        39.98974333 34.00171    ... 20.76666667  6.62544467
#   5.83055433]
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a] .............................. --------------------
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a]: shape ....................... (1,)
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a]: dtype ....................... float64
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a]: values ...................... 0.00390625
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b] .............................. --------------------
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b]: shape ....................... (1,)
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b]: dtype ....................... float64
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b]: values ...................... 0
#   spikeNet_app.interfaces_builder .................................................. None
#   spikeNet_app.logger .............................................................. <Logger examples.example (DEBUG)>
#   spikeNet_app.default_tvb_serial_cosim_path ....................................... '/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/DefaultExcIO_SPIKES_bidir/config/tvb_serial_cosimulator.pkl'
#   spikeNet_app.gid ................................................................. UUID('9297d101-c818-4712-9180-a6a0297a73c1')
#   spikeNet_app.spiking_cosimulator ................................................. <module 'ANNarchy' from '/home/docker/.local/lib/python3.10/site-packages/ANNarchy/__init__.py'>
#   logger ........................................................................... <Logger examples.example (DEBUG)>
#   default_tvb_serial_cosim_path .................................................... '/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/DefaultExcIO_SPIKES_bidir/config/tvb_serial_cosimulator.pkl'
#   gid .............................................................................. UUID('df37bb0c-4813-4bc8-893f-e9b2e6ad6c14')
# )
# None
#
#
# Simulating...
#
# Simulating for 36ms with App TVBANNarchySerialOrchestrator...
#
# Configuring simulation with App TVBANNarchySerialOrchestrator...
#
# Configuring simulation with App TVBSerialApp...
# 2023-09-28 13:09:58,775 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-28 13:09:58,776 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2023-09-28 13:09:58,776 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2023-09-28 13:09:58,782 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2023-09-28 13:09:58,782 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2023-09-28 13:09:58,782 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-28 13:09:58,783 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
#
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: 07e607e1-b868-449f-b6bc-33efe78d8df5'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: f1453f15-f4cf-4baf-8460-49d901e8d00c
#   output_interfaces ................... TVBtoANNarchyInterfaces gid: 250a3efa-7014-4d36-9143-0c90608d3240
#   input_interfaces .................... ANNarchyToTVBInterfaces gid: edbdcd90-1e4a-4689-a910-8145f77c62d4
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (66,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: unique_values ....... [[2, 67]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (1,)
#   voi: dtype .......................... int64
#   voi: values ......................... 0
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[0, 1]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. RawCosim(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 8fbe75f2-b978-4b15-bac5-946e4aab8ff7
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: a8f6344b-ed98-49ed-a2c2-163f8b9e8bc4
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 306d0ce5-9374-4450-b41b-089bd399901c
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('07e607e1-b868-449f-b6bc-33efe78d8df5')
# )
#
# Configuring simulation with App ANNarchySerialApp...
# Simulating for 36ms with App TVBSerialApp...
# Traceback (most recent call last):
#   File "/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/../../../tvb_multiscale/tests/tvb_annarchy/test_models.py", line 154, in <module>
#     test_models(models_to_test_ANNarchy, iM=iM)
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/tests/core/test_models.py", line 205, in test_models
#     print(run_test(models_to_test[iM]))
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/tests/core/test_models.py", line 166, in run_test
#     raise e
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/tests/core/test_models.py", line 162, in run_test
#     test_model.test()
#   File "/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/../../../tvb_multiscale/tests/tvb_annarchy/test_models.py", line 62, in test
#     self.run()
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/tests/core/test_spikeNet_models.py", line 37, in run
#     return self.run_fun()
#   File "/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/../../../tvb_multiscale/tests/tvb_annarchy/test_models.py", line 42, in run_fun
#     default_example(model=self.tvb_to_spikeNet_mode,
#   File "/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/example.py", line 20, in default_example
#     return main_example(default_example_base, DefaultExcIOBuilder(), DefaultTVBANNarchyInterfaceBuilder(), **kwargs)
#   File "/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/example.py", line 15, in main_example
#     return model_fun_to_run(ann_model_builder, tvb_ann_model_builder, TVBANNarchySerialOrchestrator,
#   File "/home/docker/packages/tvb-multiscale/examples/example.py", line 202, in default_example
#     return main_example(orchestrator_app,
#   File "/home/docker/packages/tvb-multiscale/examples/example.py", line 126, in main_example
#     orchestrator.simulate(simulation_length)
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/core/orchestrators/serial_orchestrator.py", line 86, in simulate
#     self.tvb_app.simulate()
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/core/orchestrators/tvb_app.py", line 199, in simulate
#     self._results = self._cosimulator.run()
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/core/tvb/cosimulator/cosimulator_serial.py", line 100, in run
#     self.run_cosimulation(ts, xs, wall_time_start,
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/core/tvb/cosimulator/cosimulator_serial.py", line 78, in run_cosimulation
#     self.send_cosim_coupling(True)
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/core/tvb/cosimulator/cosimulator.py", line 481, in send_cosim_coupling
#     self.output_interfaces(self.loop_cosim_monitor_output(self.n_tvb_steps_ran_since_last_synch,
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/core/interfaces/tvb/interfaces.py", line 421, in __call__
#     outputs.append(interface([self._compute_interface_times(interface, data),
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/core/interfaces/tvb/interfaces.py", line 258, in __call__
#     self.transform_data(
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/core/interfaces/tvb/interfaces.py", line 248, in transform_data
#     self.transformer()
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/core/interfaces/base/transformers/models/base.py", line 76, in __call__
#     self.compute()
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/core/interfaces/base/transformers/models/base.py", line 68, in compute
#     self.output_buffer = np.array(self._compute(self.input_buffer, *args, **kwargs))
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (66, 10) + inhomogeneous part.

# %%
! python ../../../tvb_multiscale/tests/tvb_annarchy/test_models.py 2
# Out:
# ANNarchy 4.7 (4.7.2.6) on linux (posix).
#
#
# Testing model 2
# ******************************************************
# ******************************************************
#
# ----------------------------------------------------------------------------------------------------
# Find results in /home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/WilsonCowan_RATE_bidir/res !
# ----------------------------------------------------------------------------------------------------
#
# Starting App TVBANNarchySerialOrchestrator...
#
# Starting App TVBSerialApp...
#
# Setting TVB LIBRARY_PROFILE...
#
# Starting App ANNarchySerialApp...
# 2023-09-28 13:10:03,682 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Loading an ANNarchy instance...
# 2023-09-28 13:10:03,682 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Loading an ANNarchy instance...
# 2023-09-28 13:10:03,682 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Cleaning ANNarchy compilation directory, if any...
# 2023-09-28 13:10:03,682 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Cleaning ANNarchy compilation directory, if any...
#
#
# Configuring...
#
# Done! in 0.000115 min
#
#
#
# Building...
#
# Building with App TVBANNarchySerialOrchestrator...
# 2023-09-28 13:10:03,689 - INFO - examples.example - Building cosimulators with TVBANNarchySerialOrchestrator...
# 2023-09-28 13:10:03,689 - INFO - examples.example - Building cosimulators with TVBANNarchySerialOrchestrator...
#
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
# 2023-09-28 13:10:03,691 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-28 13:10:03,691 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-09-28 13:10:03,692 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2023-09-28 13:10:03,702 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-09-28 13:10:03,702 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-09-28 13:10:03,702 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-28 13:10:03,702 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
#
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: d4d069b9-eafa-41b0-812c-13df17cbb437'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... WilsonCowan gid: 7fe2049d-09c0-4c4b-a2ef-725fa2bb54b8
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 209d5ab7-5180-465b-a052-1092c5b94c25
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 23edf284-a254-4ab0-ae68-e2ba23371cc8
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: c9601948-39cd-4e0e-b079-af1536712ff9
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('d4d069b9-eafa-41b0-812c-13df17cbb437')
# )
# 2023-09-28 13:10:03,708 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-28 13:10:03,708 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-09-28 13:10:03,708 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-09-28 13:10:03,708 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2023-09-28 13:10:03,718 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-09-28 13:10:03,718 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-09-28 13:10:03,719 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-28 13:10:03,719 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
#
# Building Spiking Network with buil
Type ..................... 'ANNarchyToTVBInterface'
#   interfaces[1].proxy .................... ANNarchySpikeMonitorTotalSet gid: 4402eb66-d80e-4605-a581-d327cf321fc1
#   interfaces[1].spiking_network .......... ANNarchyNetwork gid: ff3c3ca4-6170-41df-80a5-94dfd27b1621
#   interfaces[1].transformer .............. ElephantSpikesHistogramRate gid: c457ffdb-1c26-4d4d-a239-4787c9ec75ab
#   interfaces[1].proxy_inds ............... --------------------
#   interfaces[1].proxy_inds: shape ........ (2,)
#   interfaces[1].proxy_inds: dtype ........ int64
#   interfaces[1].proxy_inds: values ....... [[0, 1]]
#   interfaces[1].voi ...................... --------------------
#   interfaces[1].voi: shape ............... (1,)
#   interfaces[1].voi: dtype ............... int64
#   interfaces[1].voi: values .............. 1
#   interfaces[1].voi_labels ............... --------------------
#   interfaces[1].voi_labels: shape ........ (1,)
#   interfaces[1].voi_labels: dtype ........ <U128
#   interfaces[1].voi_labels: values ....... I
#   interfaces[1].dt ....................... 0.1
#   interfaces[1].times .................... --------------------
#   interfaces[1].times: shape ............. (2,)
#   interfaces[1].times: dtype ............. int64
#   interfaces[1].times: values ............ [[0, 1]]
#   interfaces[1].spiking_proxy_inds ....... --------------------
#   interfaces[1].spiking_proxy_inds: shape  (2,)
#   interfaces[1].spiking_proxy_inds: dtype  int64
#   interfaces[1].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[1].populations .............. --------------------
#   interfaces[1].populations: shape ....... ()
#   interfaces[1].populations: dtype ....... <U128
#   interfaces[1].populations: values ...... I
#   interfaces[1].model .................... 'SpikeMonitor'
#   interfaces[1].gid ...................... UUID('a79babc5-d022-4246-924e-870f900cc784')
#   interfaces[1].number_of_proxy_nodes .... 2
#   interfaces[1].number_of_proxy_gids ..... 0
#   interfaces[1].proxy_gids ............... --------------------
#   interfaces[1].n_voi .................... 1
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('f427728f-9242-4f6b-b835-626877e64b75')
#   number_of_interfaces ................... 2
#   number_of_populations .................. 2
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (2,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. ['E' 'I']
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (4,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: =0 ................. {0, 2}
#   spiking_proxy_inds: =1 ................. {1, 3}
#   n_vois ................................. 2
#   voi .................................... --------------------
#   voi: shape ............................. (2,)
#   voi: dtype ............................. int64
#   voi: values ............................ [[0, 1]]
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (2,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... ['E' 'I']
#   number_of_proxy_nodes .................. 2
# )
#
# Built in 0.277505 secs!
#
# Failed to summarize:
# tvb_app.cosimulator_builder.monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# Failed to summarize:
# tvb_app.cosimulator.monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# TVBANNarchySerialOrchestrator (
#   title ............................................................................ 'TVBANNarchySerialOrchestrator gid: e414d065-9645-4933-a9f4-16357b41b1c7'
#   Type ............................................................................. 'TVBANNarchySerialOrchestrator'
#   config ........................................................................... '--------------------'
#   config.title ..................................................................... 'Config gid: 8f48b5cd-d58e-4401-92d3-253e8f9455d0'
#   config.Type ...................................................................... 'Config'
#   config.gid ....................................................................... UUID('8f48b5cd-d58e-4401-92d3-253e8f9455d0')
#   tvb_app .......................................................................... '--------------------'
#   tvb_app.title .................................................................... 'TVBSerialApp gid: 5ba42137-6fdc-4b74-ad99-7140459b854e'
#   tvb_app.Type ..................................................................... 'TVBSerialApp'
#   tvb_app.config ................................................................... '--------------------'
#   tvb_app.config.title ............................................................. 'Config gid: 8f48b5cd-d58e-4401-92d3-253e8f9455d0'
#   tvb_app.config.Type .............................................................. 'Config'
#   tvb_app.config.gid ............................................................... UUID('8f48b5cd-d58e-4401-92d3-253e8f9455d0')
#   tvb_app.interfaces_builder ....................................................... '--------------------'
#   tvb_app.interfaces_builder.title ................................................. 'WilsonCowanTVBANNarchyInterfaceBuilder gid: e2ca48cf-a6a5-444b-83e5-b06ac361a542'
#   tvb_app.interfaces_builder.Type .................................................. 'WilsonCowanTVBANNarchyInterfaceBuilder'
#   tvb_app.interfaces_builder.spiking_network ....................................... 'ANNarchyNetwork gid: ff3c3ca4-6170-41df-80a5-94dfd27b1621'
#   tvb_app.interfaces_builder.N_E ................................................... 10
#   tvb_app.interfaces_builder.N_I ................................................... 10
#   tvb_app.interfaces_builder.model ................................................. "'RATE'"
#   tvb_app.interfaces_builder.config ................................................ Config gid: 8f48b5cd-d58e-4401-92d3-253e8f9455d0
#   tvb_app.interfaces_builder.logger ................................................ <Logger examples.example (DEBUG)>
#   tvb_app.interfaces_builder.tvb_cosimulator ....................................... CoSimulatorSerial gid: d4d069b9-eafa-41b0-812c-13df17cbb437
#   tvb_app.interfaces_builder.exclusive_nodes ....................................... True
#   tvb_app.interfaces_builder.output_flag ........................................... True
#   tvb_app.interfaces_builder.input_flag ............................................ True
#   tvb_app.interfaces_builder.proxy_inds ............................................ --------------------
#   tvb_app.interfaces_builder.proxy_inds: shape ..................................... --------------------
#   tvb_app.interfaces_builder.proxy_inds: dtype ..................................... dtype('int64')
#   tvb_app.interfaces_builder.proxy_inds: values .................................... --------------------
#   tvb_app.interfaces_builder.output_interfaces ..................................... 'properties:'
#   tvb_app.interfaces_builder.input_interfaces ...................................... 'properties:'
#   tvb_app.interfaces_builder.default_coupling_mode ................................. 'TVB'
#   tvb_app.interfaces_builder.global_coupling_scaling ............................... --------------------
#   tvb_app.interfaces_builder.global_coupling_scaling: shape ........................ (68,)
#   tvb_app.interfaces_builder.global_coupling_scaling: dtype ........................ float64
#   tvb_app.interfaces_builder.global_coupling_scaling: unique_values ................ 0.00390625
#   tvb_app.interfaces_builder.dt .................................................... '0.1'
#   tvb_app.interfaces_builder.gid ................................................... UUID('e2ca48cf-a6a5-444b-83e5-b06ac361a542')
#   tvb_app.interfaces_builder.voi: shape ............................................ --------------------
#   tvb_app.interfaces_builder.voi: shape: shape ..................................... (1,)
#   tvb_app.interfaces_builder.voi: shape: dtype ..................................... int64
#   tvb_app.interfaces_builder.voi: shape: values .................................... 1
#   tvb_app.interfaces_builder.voi: dtype ............................................ dtype('int64')
#   tvb_app.interfaces_builder.voi: values ........................................... 0
#   tvb_app.interfaces_builder.populations: shape .................................... --------------------
#   shape ............................................................................ (0,)
#   dtype ............................................................................ float64
#   is empty ......................................................................... True
#   tvb_app.interfaces_builder.populations: dtype .................................... dtype('<U1')
#   tvb_app.interfaces_builder.populations: values ................................... 'E'
#   tvb_app.interfaces_builder.proxy_inds: shape: shape .............................. (1,)
#   tvb_app.interfaces_builder.proxy_inds: shape: dtype .............................. int64
#   tvb_app.interfaces_builder.proxy_inds: shape: values ............................. 2
#   tvb_app.interfaces_builder.proxy_inds: values: shape ............................. (1, 2)
#   tvb_app.interfaces_builder.proxy_inds: values: dtype ............................. int64
#   tvb_app.interfaces_builder.proxy_inds: values: values ............................ [0 1]
#   tvb_app.interfaces_builder.voi_labels: shape ..................................... --------------------
#   tvb_app.interfaces_builder.voi_labels: shape: shape .............................. (1,)
#   tvb_app.interfaces_builder.voi_labels: shape: dtype .............................. int64
#   tvb_app.interfaces_builder.voi_labels: shape: values ............................. 1
#   tvb_app.interfaces_builder.voi_labels: dtype ..................................... dtype('<U1')
#   tvb_app.interfaces_builder.voi_labels: values .................................... 'E'
#   tvb_app.interfaces_builder.proxy ................................................. 'ANNarchyTimedPoissonPopulationSet gid: 4932e549-5d77-4a38-a03f-dbdb857120af'
#   tvb_app.interfaces_builder.transformer ........................................... 'LinearRate gid: 34c0001d-1413-48c6-b0c7-d3d74f59f39e'
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape ............................. --------------------
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: shape ...................... (1,)
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: dtype ...................... int64
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: values ..................... 2
#   tvb_app.interfaces_builder.spiking_proxy_inds: dtype ............................. dtype('int64')
#   tvb_app.interfaces_builder.spiking_proxy_inds: values ............................ --------------------
#   tvb_app.interfaces_builder.spiking_proxy_inds: values: shape ..................... (1, 2)
#   tvb_app.interfaces_builder.spiking_proxy_inds: values: dtype ..................... int64
#   tvb_app.interfaces_builder.spiking_proxy_inds: values: values .................... [0 1]
#   tvb_app.interfaces_builder.coupling_mode ......................................... "'TVB'"
#   tvb_app.interfaces_builder.cvoi: shape ........................................... --------------------
#   tvb_app.interfaces_builder.cvoi: shape: shape .................................... (1,)
#   tvb_app.interfaces_builder.cvoi: shape: dtype .................................... int64
#   tvb_app.interfaces_builder.cvoi: shape: values ................................... 1
#   tvb_app.interfaces_builder.cvoi: dtype ........................................... dtype('int64')
#   tvb_app.interfaces_builder.cvoi: values .......................................... 0
#   tvb_app.interfaces_builder.monitor_ind ........................................... '0'
#   tvb_app.spiking_network .......................................................... '--------------------'
#   tvb_app.spiking_network.title .................................................... 'ANNarchyNetwork gid: ff3c3ca4-6170-41df-80a5-94dfd27b1621'
#   tvb_app.spiking_network.Type ..................................................... 'ANNarchyNetwork'
#   tvb_app.spiking_network.config ................................................... Config gid: 8f48b5cd-d58e-4401-92d3-253e8f9455d0
#   tvb_app.spiking_network.brain_regions ............................................ ANNarchyBrain gid: ac9df212-800a-4145-87ae-ddac4506266e
# ...
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.cortical]: unique_values .... 1
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres] ................ --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: shape ......... (68,)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: dtype ......... bool
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: =False ........ {0...33}
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: =True ......... {34...67}
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations] ............... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations]: shape ........ (68, 3)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations]: dtype ........ float64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations]: values ....... [-0.38261669 -0.60546974 -0.69786163  0.65982329 -0.3692104  -0.65445925
#   0.92603708  0.22476123  0.30321232 -0.75417582  0.4576563   0.47092414
#  -0.50299289  0.05509325  0.86253283  0.899222    0.06479787  0.43266734
#   0.40962978  0.3030412   0.86044725 -0.71762975  0.19590929  0.66830165
#   0.65151989 -0.30294387 -0.69551912 -0.8720307  -0.10976373 -0.47698467
#  -0.00596095  0.82174661 -0.56982188 -0.12180604  0.81564435 -0.56558606
#   0.40682931  0.054199   -0.91189494 -0.41228273 -0.03266817 -0.91047007
#  -0.80006394 -0.49775     0.33487704  0.83300378 -0.52883519  0.16259782
#  -0.25474036 -0.29356364 -0.92137275  0.20335288 -0.08556166 -0.97535984
#  -0.97482388  0.20036282 -0.09784246  0.96436493  0.25302228 -0.07733052
#   0.93018948 -0.35218341 -0.10351031 -0.75968686 -0.25980467 -0.5961354
#  -0.49661151 -0.72092729 -0.4833641   0.70221386 -0.68505051 -0.19391104
#  -0.23475324  0.09820225 -0.96708181  0.1829861   0.03111709 -0.98262293
#   0.86369223  0.13933983 -0.48437604 -0.56179383  0.02038304 -0.82702614
#   0.88075419 -0.10750546 -0.46120996 -0.98248087 -0.07928951 -0.16865499
#  -0.95037587  0.18198158  0.252326    0.90738399  0.29899871  0.29538799
#   0.84287785 -0.21924381 -0.49141538 -0.93942975  0.02652263 -0.34171377
#   0.2119279  -0.58288886 -0.78442791 -0.13402574 -0.56884351 -0.81145189
#  -0.55077346  0.83158287 -0.07154388  0.89696688  0.18764621  0.40029904
#  -0.59633825  0.47078993 -0.65018269  0.63719518  0.19074258 -0.7467259
#  -0.5790787  -0.29505125 -0.7600083   0.77357165 -0.2593268  -0.5782184
#   0.72945509  0.37259806 -0.57364271 -0.85038668 -0.08062112 -0.51994492
#  -0.62004143  0.48159849  0.6193638   0.71211482  0.4534374   0.53599161
#   0.84926834 -0.02662222  0.5272898  -0.8704929   0.03160028  0.49116549
#  -0.85920021  0.04946875  0.50924242  0.82188478  0.0903833   0.56243779
#   0.83202099 -0.15648958 -0.53221432 -0.93909788 -0.08768294 -0.33227531
#   0.95323808  0.30032389 -0.03380406 -0.88853176  0.42340502 -0.17674701
#  -0.59416038  0.73807852  0.31970852  0.44899813  0.79714001  0.40369356
#   0.68409308  0.4363876   0.58445062 -0.78808872  0.30711392  0.53347654
#  -0.50538932 -0.58355453  0.63564593  0.23008214 -0.57162063  0.78759892
#  -0.42941662  0.88199453  0.19413146  0.4440229   0.85956469  0.2529668
#  -0.90286225 -0.30715946  0.30082026  0.65267736 -0.75558871  0.05565929
#   0.73908346  0.67084084 -0.061059   -0.65805472  0.7526894  -0.02055836
#  -0.04366157  0.3210788   0.94604549 -0.38115902  0.48848431  0.78492094]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas] ...................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas]: shape ............... (68,)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas]: dtype ............... float64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas]: unique_values ....... [ 71.  76.  59.  65. 226. 158. 162.  44.  30.  21.  27. 305. 298. 348.
#  428. 274. 244. 178. 200. 117. 101. 415. 403. 210. 213. 290. 280. 127.
#  164. 237. 261. 125.  69.  72. 165. 159.  63.  64. 112. 146.  95. 122.
#  295. 316. 133. 147. 405. 384. 281.  78. 433. 410. 582. 539. 446. 422.
#  346. 330. 318.  47.  48.  50.  35.]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays] .................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays]: shape ............. (68, 68)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays]: dtype ............. int64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays]: unique_values ..... [[1], [36, 37], [40, 41], [44, 93], [96, 99], [101, 113], [115, 119], [122, 123], [125, 141], [143, 162], [164, 166], [168, 170], [172, 174], [176, 179], [181, 189], [191, 222], [224, 253], [255, 274], [277, 348], [350, 362], [364, 384], [386, 431], [433, 461], [463, 466], [468, 471], [473, 474], [476, 529], [531, 543], [546, 558], [560, 570], [572, 573], [576, 581], [583, 593], [595, 602], [604, 605], [607], [609, 615], [617], [619, 620], [622], [624, 625], [628], [630, 631], [633, 634], [636], [639, 645], [648, 649], [652, 656], [658], [660], [662, 665], [667, 671], [673], [675], [677], [680, 684], [688], [690, 693], [699, 700], [703, 705], [707], [710, 714], [718, 722], [724, 729], [731], [734, 735], [739], [744], [747], [749], [751, 754], [758, 759], [761], [763, 764], [770], [781], [784, 786], [792, 793], [795], [799], [801], [804], [812, 814], [820], [827], [841], [862], [879]]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays] ..................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays]: shape .............. (68, 68)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays]: dtype .............. float64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays]: unique_values ...... [ 0.1        39.98974333 34.00171    ... 20.76666667  6.62544467
#   5.83055433]
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a] .............................. --------------------
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a]: shape ....................... (1,)
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a]: dtype ....................... float64
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a]: values ...................... 0.00390625
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b] .............................. --------------------
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b]: shape ....................... (1,)
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b]: dtype ....................... float64
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b]: values ...................... 0
#   spikeNet_app.interfaces_builder .................................................. None
#   spikeNet_app.logger .............................................................. <Logger examples.example (DEBUG)>
#   spikeNet_app.default_tvb_serial_cosim_path ....................................... '/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/WilsonCowan_RATE_bidir/config/tvb_serial_cosimulator.pkl'
#   spikeNet_app.gid ................................................................. UUID
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 225b3c05-5d52-4915-b2c1-48c20b86b772
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('31ad0753-3080-4f29-9e2d-2eee55801a3c')
# )
# 2023-09-28 13:10:09,376 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-28 13:10:09,376 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-09-28 13:10:09,376 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-09-28 13:10:09,376 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2023-09-28 13:10:09,386 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-09-28 13:10:09,386 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-09-28 13:10:09,387 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-28 13:10:09,387 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
#
# Building Spiking Network with builder WilsonCowanBuilder of App ANNarchySerialApp...
# 2023-09-28 13:10:09,391 - INFO - examples.example - Configuring spiking network builder...
# 2023-09-28 13:10:09,391 - INFO - examples.example - Configuring spiking network builder...
# 2023-09-28 13:10:09,391 - INFO - examples.example - Configuring populations...
# 2023-09-28 13:10:09,391 - INFO - examples.example - Configuring populations...
# 2023-09-28 13:10:09,391 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2023-09-28 13:10:09,391 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2023-09-28 13:10:09,391 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2023-09-28 13:10:09,391 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2023-09-28 13:10:09,392 - INFO - examples.example - Configuring output devices, if any...
# 2023-09-28 13:10:09,392 - INFO - examples.example - Configuring output devices, if any...
# 2023-09-28 13:10:09,392 - INFO - examples.example - Configuring input devices, if any...
# 2023-09-28 13:10:09,392 - INFO - examples.example - Configuring input devices, if any...
# 2023-09-28 13:10:09,392 - INFO - examples.example - Generating spiking brain...
# 2023-09-28 13:10:09,392 - INFO - examples.example - Generating spiking brain...
# 2023-09-28 13:10:09,392 - INFO - examples.example - Generating spiking brain regions...
# 2023-09-28 13:10:09,392 - INFO - examples.example - Generating spiking brain regions...
# 2023-09-28 13:10:09,393 - INFO - examples.example - Generating spiking region node: bankssts_L...
# 2023-09-28 13:10:09,393 - INFO - examples.example - Generating spiking region node: bankssts_L...
# 2023-09-28 13:10:09,394 - INFO - examples.example - Generating population: E...
# 2023-09-28 13:10:09,394 - INFO - examples.example - Generating population: E...
# 2023-09-28 13:10:09,472 - INFO - examples.example - Generating population: I...
# 2023-09-28 13:10:09,472 - INFO - examples.example - Generating population: I...
# 2023-09-28 13:10:09,510 - INFO - examples.example - Generating spiking region node: bankssts_R...
# 2023-09-28 13:10:09,510 - INFO - examples.example - Generating spiking region node: bankssts_R...
# 2023-09-28 13:10:09,511 - INFO - examples.example - Generating population: E...
# 2023-09-28 13:10:09,511 - INFO - examples.example - Generating population: E...
# 2023-09-28 13:10:09,547 - INFO - examples.example - Generating population: I...
# 2023-09-28 13:10:09,547 - INFO - examples.example - Generating population: I...
# 2023-09-28 13:10:09,584 - INFO - examples.example - Connecting populations within spiking brain regions...
# 2023-09-28 13:10:09,584 - INFO - examples.example - Connecting populations within spiking brain regions...
# 2023-09-28 13:10:09,584 - INFO - examples.example - Connecting E -> E populations
# for spiking region nodes
# [0 1]...
# 2023-09-28 13:10:09,584 - INFO - examples.example - Connecting E -> E populations
# for spiking region nodes
# [0 1]...
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2023-09-28 13:10:09,587 - INFO - examples.example - Connecting E -> I populations
# for spiking region nodes
# [0 1]...
# 2023-09-28 13:10:09,587 - INFO - examples.example - Connecting E -> I populations
# for spiking region nodes
# [0 1]...
# 2023-09-28 13:10:09,588 - INFO - examples.example - Connecting I -> E populations
# for spiking region nodes
# [0 1]...
# 2023-09-28 13:10:09,588 - INFO - examples.example - Connecting I -> E populations
# for spiking region nodes
# [0 1]...
# 2023-09-28 13:10:09,590 - INFO - examples.example - Connecting I -> I populations
# for spiking region nodes
# [0 1]...
# 2023-09-28 13:10:09,590 - INFO - examples.example - Connecting I -> I populations
# for spiking region nodes
# [0 1]...
# 2023-09-28 13:10:09,591 - INFO - examples.example - Connecting populations among spiking brain regions...
# 2023-09-28 13:10:09,591 - INFO - examples.example - Connecting populations among spiking brain regions...
# 2023-09-28 13:10:09,592 - INFO - examples.example - Connecting for 0 -> 1 spiking region nodes ...
# 2023-09-28 13:10:09,592 - INFO - examples.example - Connecting for 0 -> 1 spiking region nodes ...
# 2023-09-28 13:10:09,592 - INFO - examples.example - E -> E populations ...
# 2023-09-28 13:10:09,592 - INFO - examples.example - E -> E populations ...
# 2023-09-28 13:10:09,593 - INFO - examples.example - E -> I populations ...
# 2023-09-28 13:10:09,593 - INFO - examples.example - E -> I populations ...
# 2023-09-28 13:10:09,593 - INFO - examples.example - Connecting for 1 -> 0 spiking region nodes ...
# 2023-09-28 13:10:09,593 - INFO - examples.example - Connecting for 1 -> 0 spiking region nodes ...
# 2023-09-28 13:10:09,594 - INFO - examples.example - E -> E populations ...
# 2023-09-28 13:10:09,594 - INFO - examples.example - E -> E populations ...
# 2023-09-28 13:10:09,594 - INFO - examples.example - E -> I populations ...
# 2023-09-28 13:10:09,594 - INFO - examples.example - E -> I populations ...
# 2023-09-28 13:10:09,595 - INFO - examples.example - Generating and connecting output devices, if any...
# 2023-09-28 13:10:09,595 - INFO - examples.example - Generating and connecting output devices, if any...
# 2023-09-28 13:10:09,595 - INFO - examples.example - Generating and connecting ['E', 'I'] -> ['E', 'I'] device set of model SpikeMonitor
# for nodes [0, 1]...
# 2023-09-28 13:10:09,595 - INFO - examples.example - Generating and connecting ['E', 'I'] -> ['E', 'I'] device set of model SpikeMonitor
# for nodes [0, 1]...
# 2023-09-28 13:10:09,596 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E created!
# 2023-09-28 13:10:09,596 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E created!
# 2023-09-28 13:10:09,598 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for I created!
# 2023-09-28 13:10:09,598 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for I created!
# 2023-09-28 13:10:09,599 - INFO - examples.example - Generating and connecting ['Excitatory', 'Inhibitory'] -> ['E', 'I'] device set of model Monitor
# for nodes [0, 1]...
# 2023-09-28 13:10:09,599 - INFO - examples.example - Generating and connecting ['Excitatory', 'Inhibitory'] -> ['E', 'I'] device set of model Monitor
# for nodes [0, 1]...
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2023-09-28 13:10:09,600 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Excitatory created!
# 2023-09-28 13:10:09,600 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Excitatory created!
# 2023-09-28 13:10:09,601 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Inhibitory created!
# 2023-09-28 13:10:09,601 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Inhibitory created!
# 2023-09-28 13:10:09,603 - INFO - examples.example - Generating and connecting input devices, if any...
# 2023-09-28 13:10:09,603 - INFO - examples.example - Generating and connecting input devices, if any...
# 2023
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: 1ca237c9-2639-4025-9994-e1a8577be6f9
#   interfaces[0].transformer .............. ElephantSpikesHistogramRate gid: a9966b75-643a-4e7d-b4f2-06117741de79
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (2,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: values ....... [[0, 1]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... E
#   interfaces[0].dt ....................... 0.1
#   interfaces[0].times .................... --------------------
#   interfaces[0].times: shape ............. (2,)
#   interfaces[0].times: dtype ............. int64
#   interfaces[0].times: values ............ [[0, 1]]
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'SpikeMonitor'
#   interfaces[0].gid ...................... UUID('be50f81f-5c65-4434-be59-2031890c26ea')
#   interfaces[0].number_of_proxy_nodes .... 2
#   interfaces[0].number_of_proxy_gids ..... 0
#   interfaces[0].proxy_gids ............... --------------------
#   shape .................................. (0,)
#   dtype .................................. float64
#   is empty ............................... True
#   interfaces[0].n_voi .................... 1
#   interfaces[1] .......................... '--------------------'
#   interfaces[1].title .................... 'ANNarchyToTVBInterface gid: b81ac306-6fa2-4ab8-9236-f36da732b635'
#   interfaces[1].Type ..................... 'ANNarchyToTVBInterface'
#   interfaces[1].proxy .................... ANNarchySpikeMonitorTotalSet gid: 65013436-beb9-402c-a4ad-e9548b6f6bb1
#   interfaces[1].spiking_network .......... ANNarchyNetwork gid: 1ca237c9-2639-4025-9994-e1a8577be6f9
#   interfaces[1].transformer .............. ElephantSpikesHistogramRate gid: 5a304397-5cf0-42c9-a681-0ca8fdd46d0e
#   interfaces[1].proxy_inds ............... --------------------
#   interfaces[1].proxy_inds: shape ........ (2,)
#   interfaces[1].proxy_inds: dtype ........ int64
#   interfaces[1].proxy_inds: values ....... [[0, 1]]
#   interfaces[1].voi ...................... --------------------
#   interfaces[1].voi: shape ............... (1,)
#   interfaces[1].voi: dtype ............... int64
#   interfaces[1].voi: values .............. 1
#   interfaces[1].voi_labels ............... --------------------
#   interfaces[1].voi_labels: shape ........ (1,)
#   interfaces[1].voi_labels: dtype ........ <U128
#   interfaces[1].voi_labels: values ....... I
#   interfaces[1].dt ....................... 0.1
#   interfaces[1].times .................... --------------------
#   interfaces[1].times: shape ............. (2,)
#   interfaces[1].times: dtype ............. int64
#   interfaces[1].times: values ............ [[0, 1]]
#   interfaces[1].spiking_proxy_inds ....... --------------------
#   interfaces[1].spiking_proxy_inds: shape  (2,)
#   interfaces[1].spiking_proxy_inds: dtype  int64
#   interfaces[1].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[1].populations .............. --------------------
#   interfaces[1].populations: shape ....... ()
#   interfaces[1].populations: dtype ....... <U128
#   interfaces[1].populations: values ...... I
#   interfaces[1].model .................... 'SpikeMonitor'
#   interfaces[1].gid ...................... UUID('b81ac306-6fa2-4ab8-9236-f36da732b635')
#   interfaces[1].number_of_proxy_nodes .... 2
#   interfaces[1].number_of_proxy_gids ..... 0
#   interfaces[1].proxy_gids ............... --------------------
#   interfaces[1].n_voi .................... 1
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('e102643e-4b78-4790-ac72-a59f9d998eca')
#   number_of_interfaces ................... 2
#   number_of_populations .................. 2
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (2,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. ['E' 'I']
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (4,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: =0 ................. {0, 2}
#   spiking_proxy_inds: =1 ................. {1, 3}
#   n_vois ................................. 2
#   voi .................................... --------------------
#   voi: shape ............................. (2,)
#   voi: dtype ............................. int64
#   voi: values ............................ [[0, 1]]
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (2,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... ['E' 'I']
#   number_of_proxy_nodes .................. 2
# )
#
# Built in 0.280852 secs!
#
# Failed to summarize:
# tvb_app.cosimulator_builder.monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# Failed to summarize:
# tvb_app.cosimulator.monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# TVBANNarchySerialOrchestrator (
#   title ............................................................................ 'TVBANNarchySerialOrchestrator gid: d84713e6-db67-4fdc-b383-32b7c641aba0'
#   Type ............................................................................. 'TVBANNarchySerialOrchestrator'
#   config ........................................................................... '--------------------'
#   config.title ..................................................................... 'Config gid: eb6f9e86-f2d4-4c33-b081-15d95fd74ff3'
#   config.Type ...................................................................... 'Config'
#   config.gid ....................................................................... UUID('eb6f9e86-f2d4-4c33-b081-15d95fd74ff3')
#   tvb_app .......................................................................... '--------------------'
#   tvb_app.title .................................................................... 'TVBSerialApp gid: 784eeb94-3437-4328-88f4-c2d3c7d99d3f'
#   tvb_app.Type ..................................................................... 'TVBSerialApp'
#   tvb_app.config ................................................................... '--------------------'
#   tvb_app.config.title ............................................................. 'Config gid: eb6f9e86-f2d4-4c33-b081-15d95fd74ff3'
#   tvb_app.config.Type .............................................................. 'Config'
#   tvb_app.config.gid ............................................................... UUID('eb6f9e86-f2d4-4c33-b081-15d95fd74ff3')
#   tvb_app.interfaces_builder ....................................................... '--------------------'
#   tvb_app.interfaces_builder.title ................................................. 'WilsonCowanTVBANNarchyInterfaceBuilder gid: 52ea88d4-3629-4b77-b057-3abea578f256'
#   tvb_app.interfaces_builder.Type .................................................. 'WilsonCowanTVBANNarchyInterfaceBuilder'
#   tvb_app.interfaces_builder.spiking_network ....................................... 'ANNarchyNetwork gid: 1ca237c9-2639-4025-9994-e1a8577be6f9'
#   tvb_app.interfaces_builder.N_E ................................................... 10
#   tvb_app.interfaces_builder.N_I ................................................... 10
#   tvb_app.interfaces_builder.model ................................................. "'SPIKES'"
#   tvb_app.interfaces_builder.config ................................................ Config gid: eb6f9e86-f2d4-4c33-b081-15d95fd74ff3
#   tvb_app.interfaces_builder.logger ................................................ <Logger examples.example (DEBUG)>
#   tvb_app.interfaces_builder.tvb_cosimulator ....................................... CoSimulatorSerial gid: 31ad0753-3080-4f29-9e2d-2eee55801a3c
#   tvb_app.interfaces_builder.exclusive_nodes ....................................... True
#   tvb_app.interfaces_builder.output_flag ........................................... True
#   tvb_app.interfaces_builder.input_flag ............................................ True
#   tvb_app.interfaces_builder.proxy_inds ............................................ --------------------
#   tvb_app.interfaces_builder.proxy_inds: shape ..................................... --------------------
#   tvb_app.interfaces_builder.proxy_inds: dtype ..................................... dtype('int64')
#   tvb_app.interfaces_builder.proxy_inds: values .................................... --------------------
#   tvb_app.interfaces_builder.output_interfaces ..................................... 'properties:'
#   tvb_app.interfaces_builder.input_interfaces ...................................... 'properties:'
#   tvb_app.interfaces_builder.default_coupling_mode ................................. 'TVB'
#   tvb_app.interfaces_builder.global_coupling_scaling ............................... --------------------
#   tvb_app.interfaces_builder.global_coupling_scaling: shape ........................ (68,)
#   tvb_app.interfaces_builder.global_coupling_scaling: dtype ........................ float64
#   tvb_app.interfaces_builder.global_coupling_scaling: unique_values ................ 0.00390625
#   tvb_app.interfaces_builder.dt .................................................... '0.1'
#   tvb_app.interfaces_builder.gid ................................................... UUID('52ea88d4-3629-4b77-b057-3abea578f256')
#   tvb_app.interfaces_builder.voi: shape ............................................ --------------------
#   tvb_app.interfaces_builder.voi: shape: shape ..................................... (1,)
#   tvb_app.interfaces_builder.voi: shape: dtype ..................................... int64
#   tvb_app.interfaces_builder.voi: shape: values .................................... 1
#   tvb_app.interfaces_builder.voi: dtype ............................................ dtype('int64')
#   tvb_app.interfaces_builder.voi: values ........................................... 0
#   tvb_app.interfaces_builder.populations: shape .................................... --------------------
#   shape ............................................................................ (0,)
#   dtype ............................................................................ float64
#   is empty ......................................................................... True
#   tvb_app.interfaces_builder.populations: dtype .................................... dtype('<U1')
#   tvb_app.interfaces_builder.populations: values ................................... 'E'
#   tvb_app.interfaces_builder.proxy_inds: shape: shape .............................. (1,)
#   tvb_app.interfaces_builder.proxy_inds: shape: dtype .............................. int64
#   tvb_app.interfaces_builder.proxy_inds: shape: values ............................. 2
#   tvb_app.interfaces_builder.proxy_inds: values: shape ............................. (1, 2)
#   tvb_app.interfaces_builder.proxy_inds: values: dtype ............................. int64
#   tvb_app.interfaces_builder.proxy_inds: values: values ............................ [0 1]
#   tvb_app.interfaces_builder.voi_labels: shape ..................................... --------------------
#   tvb_app.interfaces_builder.voi_labels: shape: shape .............................. (1,)
#   tvb_app.interfaces_builder.voi_labels: shape: dtype .............................. int64
#   tvb_app.interfaces_builder.voi_labels: shape: values ............................. 1
#   tvb_app.interfaces_builder.voi_labels: dtype ..................................... dtype('<U1')
#   tvb_app.interfaces_builder.voi_labels: values .................................... 'E'
#   tvb_app.interfaces_builder.proxy ................................................. 'ANNarchySpikeSourceArraySet gid: 93f41b3b-def2-4381-b276-25983650f53b'
#   tvb_app.interfaces_builder.transformer ........................................... 'RatesToSpikesElephantPoisson gid: 86d926bf-c561-4fb6-8a0f-5be4afbe956c'
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape ............................. --------------------
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: shape ...................... (1,)
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: dtype ...................... int64
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: values ..................... 2
#   tvb_app.interfaces_builder.spiking_proxy_inds: dtype ............................. dtype('int64')
#   tvb_app.interfaces_builder.spiking_proxy_inds: values ............................ --------------------
#   tvb_app.interfaces_builder.spiking_proxy_inds: values: shape ..................... (1, 2)
#   tvb_app.interfaces_builder.spiking_proxy_inds: values: dtype ..................... int64
#   tvb_app.interfaces_builder.spiking_proxy_inds: values: values .................... [0 1]
#   tvb_app.interfaces_builder.coupling_mode ......................................... "'TVB'"
#   tvb_app.interfaces_builder.cvoi: shape ........................................... --------------------
#   tvb_app.interfaces_builder.cvoi: shape: shape .................................... (1,)
#   tvb_app.interfaces_builder.cvoi: shape: dtype .................................... int64
#   tvb_app.interfaces_builder.cvoi: shape: values ................................... 1
#   tvb_app.interfaces_builder.cvoi: dtype ........................................... dtype('int64')
#   tvb_app.interfaces_builder.cvoi: values .......................................... 0
#   tvb_app.interfaces_builder.monitor_ind ........................................... '0'
#   tvb_app.spiking_network .......................................................... '--------------------'
#   tvb_app.spiking_network.title .................................................... 'ANNarchyNetwork gid: 1ca237c9-2639-4025-9994-e1a8577be6f9'
#   tvb_app.spiking_network.Type ..................................................... 'ANNarchyNetwork'
#   tvb_app.spiking_network.config ................................................... Config gid: eb6f9e86-f2d4-4c33-b081-15d95fd74ff3
# ...
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.cortical]: unique_values .... 1
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres] ................ --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: shape ......... (68,)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: dtype ......... bool
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: =False ........ {0...33}
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: =True ......... {34...67}
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations] ............... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations]: shape ........ (68, 3)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations]: dtype ........ float64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations]: values ....... [-0.38261669 -0.60546974 -0.69786163  0.65982329 -0.3692104  -0.65445925
#   0.92603708  0.22476123  0.30321232 -0.75417582  0.4576563   0.47092414
#  -0.50299289  0.05509325  0.86253283  0.899222    0.06479787  0.43266734
#   0.40962978  0.3030412   0.86044725 -0.71762975  0.19590929  0.66830165
#   0.65151989 -0.30294387 -0.69551912 -0.8720307  -0.10976373 -0.47698467
#  -0.00596095  0.82174661 -0.56982188 -0.12180604  0.81564435 -0.56558606
#   0.40682931  0.054199   -0.91189494 -0.41228273 -0.03266817 -0.91047007
#  -0.80006394 -0.49775     0.33487704  0.83300378 -0.52883519  0.16259782
#  -0.25474036 -0.29356364 -0.92137275  0.20335288 -0.08556166 -0.97535984
#  -0.97482388  0.20036282 -0.09784246  0.96436493  0.25302228 -0.07733052
#   0.93018948 -0.35218341 -0.10351031 -0.75968686 -0.25980467 -0.5961354
#  -0.49661151 -0.72092729 -0.4833641   0.70221386 -0.68505051 -0.19391104
#  -0.23475324  0.09820225 -0.96708181  0.1829861   0.03111709 -0.98262293
#   0.86369223  0.13933983 -0.48437604 -0.56179383  0.02038304 -0.82702614
#   0.88075419 -0.10750546 -0.46120996 -0.98248087 -0.07928951 -0.16865499
#  -0.95037587  0.18198158  0.252326    0.90738399  0.29899871  0.29538799
#   0.84287785 -0.21924381 -0.49141538 -0.93942975  0.02652263 -0.34171377
#   0.2119279  -0.58288886 -0.78442791 -0.13402574 -0.56884351 -0.81145189
#  -0.55077346  0.83158287 -0.07154388  0.89696688  0.18764621  0.40029904
#  -0.59633825  0.47078993 -0.65018269  0.63719518  0.19074258 -0.7467259
#  -0.5790787  -0.29505125 -0.7600083   0.77357165 -0.2593268  -0.5782184
#   0.72945509  0.37259806 -0.57364271 -0.85038668 -0.08062112 -0.51994492
#  -0.62004143  0.48159849  0.6193638   0.71211482  0.4534374   0.53599161
#   0.84926834 -0.02662222  0.5272898  -0.8704929   0.03160028  0.49116549
#  -0.85920021  0.04946875  0.50924242  0.82188478  0.0903833   0.56243779
#   0.83202099 -0.15648958 -0.53221432 -0.93909788 -0.08768294 -0.33227531
#   0.95323808  0.30032389 -0.03380406 -0.88853176  0.42340502 -0.17674701
#  -0.59416038  0.73807852  0.31970852  0.44899813  0.79714001  0.40369356
#   0.68409308  0.4363876   0.58445062 -0.78808872  0.30711392  0.53347654
#  -0.50538932 -0.58355453  0.63564593  0.23008214 -0.57162063  0.78759892
#  -0.42941662  0.88199453  0.19413146  0.4440229   0.85956469  0.2529668
#  -0.90286225 -0.30715946  0.30082026  0.65267736 -0.75558871  0.05565929
#   0.73908346  0.67084084 -0.061059   -0.65805472  0.7526894  -0.02055836
#  -0.04366157  0.3210788   0.94604549 -0.38115902  0.48848431  0.78492094]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas] ...................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas]: shape ............... (68,)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas]: dtype ............... float64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas]: unique_values ....... [ 71.  76.  59.  65. 226. 158. 162.  44.  30.  21.  27. 305. 298. 348.
#  428. 274. 244. 178. 200. 117. 101. 415. 403. 210. 213. 290. 280. 127.
#  164. 237. 261. 125.  69.  72. 165. 159.  63.  64. 112. 146.  95. 122.
#  295. 316. 133. 147. 405. 384. 281.  78. 433. 410. 582. 539. 446. 422.
#  346. 330. 318.  47.  48.  50.  35.]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays] .................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays]: shape ............. (68, 68)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays]: dtype ............. int64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays]: unique_values ..... [[1], [36, 37], [40, 41], [44, 93], [96, 99], [101, 113], [115, 119], [122, 123], [125, 141], [143, 162], [164, 166], [168, 170], [172, 174], [176, 179], [181, 189], [191, 222], [224, 253], [255, 274], [277, 348], [350, 362], [364, 384], [386, 431], [433, 461], [463, 466], [468, 471], [473, 474], [476, 529], [531, 543], [546, 558], [560, 570], [572, 573], [576, 581], [583, 593], [595, 602], [604, 605], [607], [609, 615], [617], [619, 620], [622], [624, 625], [628], [630, 631], [633, 634], [636], [639, 645], [648, 649], [652, 656], [658], [660], [662, 665], [667, 671], [673], [675], [677], [680, 684], [688], [690, 693], [699, 700], [703, 705], [707], [710, 714], [718, 722], [724, 729], [731], [734, 735], [739], [744], [747], [749], [751, 754], [758, 759], [761], [763, 764], [770], [781], [784, 786], [792, 793], [795], [799], [801], [804], [812, 814], [820], [827], [841], [862], [879]]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays] ..................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays]: shape .............. (68, 68)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays]: dtype .............. float64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays]: unique_values ...... [ 0.1        39.98974333 34.00171    ... 20.76666667  6.62544467
#   5.83055433]
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a] .............................. --------------------
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a]: shape ....................... (1,)
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a]: dtype ....................... float64
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a]: values ...................... 0.00390625
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b] .............................. --------------------
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b]: shape ....................... (1,)
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b]: dtype ....................... float64
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b]: values ...................... 0
#   spikeNet_app.interfaces_builder .................................................. None
#   spikeNet_app.logger .............................................................. <Logger examples.example (DEBUG)>
#   spikeNet_app.default_tvb_serial_cosim_path ....................................... '/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/WilsonCowan_SPIKES_bidir/config/tvb_serial_cosimulator.pkl'
#   spikeNet_app.gid ................................................................. UUID('8ae50252-e86b-4a22-85c7-ee00cadf2e50')
#   spikeNet_app.spiking_cosimulator ................................................. <module 'ANNarchy' from '/home/docker/.local/lib/python3.10/site-packages/ANNarchy/__init__.py'>
#   logger ........................................................................... <Logger examples.example (DEBUG)>
#   default_tvb_serial_cosim_path .................................................... '/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/WilsonCowan_SPIKES_bidir/config/tvb_serial_cosimulator.pkl'
#   gid .............................................................................. UUID('d84713e6-db67-4fdc-b383-32b7c641aba0')
# )
# None
#
#
# Simulating...
#
# Simulating for 36ms with App TVBANNarchySerialOrchestrator...
#
# Configuring simulation with App TVBANNarchySerialOrchestrator...
#
# Configuring simulation with App TVBSerialApp...
# 2023-09-28 13:10:09,659 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-28 13:10:09,659 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-09-28 13:10:09,660 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-09-28 13:10:09,660 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2023-09-28 13:10:09,669 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-09-28 13:10:09,670 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-09-28 13:10:09,670 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-28 13:10:09,670 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
#
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: 31ad0753-3080-4f29-9e2d-2eee55801a3c'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... WilsonCowan gid: 7b6c7962-3921-41b2-981a-0e624884de8e
#   output_interfaces ................... TVBtoANNarchyInterfaces gid: 559fa9ab-67ad-442e-a1c4-e093bcacc01f
#   input_interfaces .................... ANNarchyToTVBInterfaces gid: e102643e-4b78-4790-ac72-a59f9d998eca
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (2,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: values .............. [[0, 1]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (2,)
#   voi: dtype .......................... int64
#   voi: values ......................... [[0, 1]]
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[0, 1]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. CosimCoupling(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: e3cfe527-58d3-48ef-8216-4efe12b3b33e
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: aeef3f33-99fd-4489-b6f1-dcd9f29f5b50
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 225b3c05-5d52-4915-b2c1-48c20b86b772
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('31ad0753-3080-4f29-9e2d-2eee55801a3c')
# )
#
# Configuring simulation with App ANNarchySerialApp...
# Simulating for 36ms with App TVBSerialApp...
# 2023-09-28 13:10:09,876 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - No or all NaN valued cosimulator updates at time step 0!
# 2023-09-28 13:10:09,876 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.032 seconds
# 2023-09-28 13:10:09,876 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2023-09-28 13:10:09,876 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 44063
# 2023-09-28 13:10:09,882 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-28 13:10:09,904 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...9.091% completed in 0.0286171 sec!
# ...9.091% completed in 0.0286171 sec!2023-09-28 13:10:09,917 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-28 13:10:10,017 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...18.182% completed in 0.14119 sec!
# ...18.182% completed in 0.14119 sec!2023-09-28 13:10:10,030 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-28 13:10:10,053 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...27.273% completed in 0.177178 sec!
# ...27.273% completed in 0.177178 sec!2023-09-28 13:10:10,066 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-28 13:10:10,088 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...36.364% completed in 0.212419 sec!
# ...36.364% completed in 0.212419 sec!2023-09-28 13:10:10,102 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-28 13:10:10,124 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...45.455% completed in 0.248191 sec!
# ...45.455% completed in 0.248191 sec!2023-09-28 13:10:10,137 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-28 13:10:10,159 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...54.545% completed in 0.283812 sec!
# ...54.545% completed in 0.283812 sec!2023-09-28 13:10:10,173 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-28 13:10:10,194 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...63.636% completed in 0.319089 sec!
# ...63.636% completed in 0.319089 sec!2023-09-28 13:10:10,208 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-28 13:10:10,230 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...72.727% completed in 0.35485 sec!
# ...72.727% completed in 0.35485 sec!2023-09-28 13:10:10,244 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-28 13:10:10,265 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...81.818% completed in 0.390099 sec!
# ...81.818% completed in 0.390099 sec!2023-09-28 13:10:10,279 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-28 13:10:10,301 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...90.909% completed in 0.42555 sec!
# ...90.909% completed in 0.42555 sec!2023-09-28 13:10:10,315 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-28 13:10:10,338 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...100.000% completed in 0.462155 sec!
# ...100.000% completed in 0.462155 sec!
# Simulated in 0.679065 secs!
#
#
# Cleaning up App TVBANNarchySerialOrchestrator...
#
# Cleaning up App TVBSerialApp...
#
# Cleaning up App ANNarchySerialApp...
#
# Stopping App TVBANNarchySerialOrchestrator...
#
# Stopping App TVBSerialApp...
#
# Success in 0.990944 sec!
# ******************************************************
#
# {'TestWilsonCowanSPIKES': True}
