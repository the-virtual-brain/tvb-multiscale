# %%
! pwd
# Out:
# /home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks

# %%
! python ../../../tvb_multiscale/tests/tvb_annarchy/test_spiking_models_builder_properties_methods.py
# Out:
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
# /home/docker/venv/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# ANNarchy 5.0 (5.0.3) on linux (posix).
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/tvb/cosimulator/models/linear.py:104: SyntaxWarning: invalid escape sequence '\g'
#   """
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
# 2026-08-04 13:16:00,414 - INFO - tvb-multiscale - Loading an ANNarchy instance...
# 2026-08-04 13:16:00,414 - INFO - tvb-multiscale - Loading an ANNarchy instance...
# 2026-08-04 13:16:00,414 - INFO - tvb-multiscale - Loading an ANNarchy instance...
# 2026-08-04 13:16:00,421 - INFO - tvb-multiscale - Cleaning ANNarchy compilation directory, if any...
# 2026-08-04 13:16:00,421 - INFO - tvb-multiscale - Cleaning ANNarchy compilation directory, if any...
# 2026-08-04 13:16:00,421 - INFO - tvb-multiscale - Cleaning ANNarchy compilation directory, if any...
# <tvb_multiscale.tvb_annarchy.annarchy_models.models.default.DefaultExcIOBuilder object at 0xffff436920f0>
# annarchy simulator: <module 'ANNarchy' from '/home/docker/venv/lib/python3.12/site-packages/ANNarchy/__init__.py'>
# min_delay:
# 0.05
#
# tvb_dt:
# 0.1
#
# monitor_period:
# 0.1
#
# tvb_model:
# Linear
#
# number_of_regions:
# 68
#
# tvb_weights:
# [[0.0000000e+00 4.8155833e-02 5.5569724e-01 ... 0.0000000e+00
#   9.3632959e-04 1.5197568e-03]
#  [3.4694958e-02 0.0000000e+00 4.0470140e+00 ... 0.0000000e+00
#   0.0000000e+00 6.4991351e-02]
#  [3.3234182e-01 1.6091147e+00 0.0000000e+00 ... 0.0000000e+00
#   1.3227513e-03 2.2254678e-01]
#  ...
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#   4.2837810e-03 6.6117304e+01]
#  [6.8634180e-04 0.0000000e+00 1.8867925e-02 ... 2.7493696e-02
#   0.0000000e+00 2.8296225e+01]
#  [2.8677947e-04 1.3400005e-02 3.4921828e-01 ... 2.5495074e+01
#   1.4883909e+01 0.0000000e+00]]
#
# tvb_delays:
# [[ 0.         39.98974333 34.00171    ...  0.         47.8
#   44.73333333]
#  [39.98974333  0.         14.00699533 ...  0.          0.
#   23.274074  ]
#  [34.00171    14.00699533  0.         ...  0.         58.33333333
#   37.56438333]
#  ...
#  [ 0.          0.          0.         ...  0.         20.76666667
#    6.62544467]
#  [47.8         0.         58.33333333 ... 20.76666667  0.
#    5.83055433]
#  [44.73333333 23.274074   37.56438333 ...  6.62544467  5.83055433
#    0.        ]]
#
# region_labels:
# ['bankssts_L' 'bankssts_R' 'caudalanteriorcingulate_L'
#  'caudalanteriorcingulate_R' 'caudalmiddlefrontal_L'
#  'caudalmiddlefrontal_R' 'cuneus_L' 'cuneus_R' 'entorhinal_L'
#  'entorhinal_R' 'frontalpole_L' 'frontalpole_R' 'fusiform_L' 'fusiform_R'
#  'inferiorparietal_L' 'inferiorparietal_R' 'inferiortemporal_L'
#  'inferiortemporal_R' 'insula_L' 'insula_R' 'isthmuscingulate_L'
#  'isthmuscingulate_R' 'lateraloccipital_L' 'lateraloccipital_R'
#  'lateralorbitofrontal_L' 'lateralorbitofrontal_R' 'lingual_L' 'lingual_R'
#  'medialorbitofrontal_L' 'medialorbitofrontal_R' 'middletemporal_L'
#  'middletemporal_R' 'paracentral_L' 'paracentral_R' 'parahippocampal_L'
#  'parahippocampal_R' 'parsopercularis_L' 'parsopercularis_R'
#  'parsorbitalis_L' 'parsorbitalis_R' 'parstriangularis_L'
#  'parstriangularis_R' 'pericalcarine_L' 'pericalcarine_R' 'postcentral_L'
#  'postcentral_R' 'posteriorcingulate_L' 'posteriorcingulate_R'
#  'precentral_L' 'precentral_R' 'precuneus_L' 'precuneus_R'
#  'rostralanteriorcingulate_L' 'rostralanteriorcingulate_R'
#  'rostralmiddlefrontal_L' 'rostralmiddlefrontal_R' 'superiorfrontal_L'
#  'superiorfrontal_R' 'superiorparietal_L' 'superiorparietal_R'
#  'superiortemporal_L' 'superiortemporal_R' 'supramarginal_L'
#  'supramarginal_R' 'temporalpole_L' 'temporalpole_R'
#  'transversetemporal_L' 'transversetemporal_R']
#
# number_of_populations:
# 0
#
# populations_models:
# OrderedDict()
#
# populations_nodes:
# OrderedDict()
#
# populations_scales:
# OrderedDict()
#
# populations_sizes:
# OrderedDict()
#
# populations_params:
# OrderedDict()
#
# populations_connections_labels:
# []
#
# populations_connections_models:
# OrderedDict()
#
# populations_connections_nodes:
# OrderedDict()
#
# populations_connections_weights:
# OrderedDict()
#
# populations_connections_delays:
# OrderedDict()
#
# populations_connections_receptor_types:
# OrderedDict()
#
# populations_connections_conn_spec:
# OrderedDict()
#
# nodes_connections_labels:
# []
#
# nodes_connections_models:
# OrderedDict()
#
# nodes_connections_source_nodes:
# OrderedDict()
#
# nodes_connections_target_nodes:
# OrderedDict()
#
# nodes_connections_weights:
# OrderedDict()
#
# nodes_connections_delays:
# OrderedDict()
#
# nodes_connections_receptor_types:
# OrderedDict()
#
# nodes_connections_conn_spec:
# OrderedDict()

# %%
# ! python ../../../tvb_multiscale/tests/tvb_annarchy/test_models.py

# %%
! python ../../../tvb_multiscale/tests/tvb_annarchy/test_models.py 0
# Out:
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
# /home/docker/venv/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# ANNarchy 5.0 (5.0.3) on linux (posix).
# 2026-08-04 13:16:04,822 - WARNING - tvb.simulator.plot.tools - You need mpl_toolkits for some axe related features
#
#
# Testing model 0
# ******************************************************
# ******************************************************
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
#
# ----------------------------------------------------------------------------------------------------
# Find results in /home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/DefaultExcIO_RATE_bidir/res !
# ----------------------------------------------------------------------------------------------------
# 2026-08-04 13:16:05,903 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:16:05,903 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
#
# Starting App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:16:05,905 - INFO - examples.example -
# Starting App TVBSerialApp...
# 2026-08-04 13:16:05,905 - INFO - examples.example -
# Starting App TVBSerialApp...
#
# Starting App TVBSerialApp...
# 2026-08-04 13:16:05,905 - INFO - examples.example -
# Setting TVB LIBRARY_PROFILE...
# 2026-08-04 13:16:05,905 - INFO - examples.example -
# Setting TVB LIBRARY_PROFILE...
#
# Setting TVB LIBRARY_PROFILE...
# 2026-08-04 13:16:05,946 - INFO - examples.example -
# Starting App ANNarchySerialApp...
# 2026-08-04 13:16:05,946 - INFO - examples.example -
# Starting App ANNarchySerialApp...
#
# Starting App ANNarchySerialApp...
# 2026-08-04 13:16:05,946 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Loading an ANNarchy instance...
# 2026-08-04 13:16:05,946 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Loading an ANNarchy instance...
# 2026-08-04 13:16:05,946 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Cleaning ANNarchy compilation directory, if any...
# 2026-08-04 13:16:05,946 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Cleaning ANNarchy compilation directory, if any...
#
#
# Configuring...
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
#
# Done! in 0.000099 min
#
#
#
# Building...
# 2026-08-04 13:16:05,953 - INFO - examples.example -
# Building with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:16:05,953 - INFO - examples.example -
# Building with App TVBANNarchySerialOrchestrator...
#
# Building with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:16:05,953 - INFO - examples.example -
# Building cosimulators with TVBANNarchySerialOrchestrator...
# 2026-08-04 13:16:05,953 - INFO - examples.example -
# Building cosimulators with TVBANNarchySerialOrchestrator...
#
# Building cosimulators with TVBANNarchySerialOrchestrator...
# 2026-08-04 13:16:05,953 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
# 2026-08-04 13:16:05,953 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
#
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
# 2026-08-04 13:16:05,954 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-04 13:16:05,955 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2026-08-04 13:16:05,955 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2026-08-04 13:16:05,961 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2026-08-04 13:16:05,961 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2026-08-04 13:16:05,961 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# 2026-08-04 13:16:05,966 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: 74339a2e-acd0-4813-aad3-0b45bf35a4b9'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: 5db250d2-e799-496d-a35c-ec0a1970f590
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 000701e6-8527-46d1-9457-40d147fc2850
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: ea865738-1327-4e68-a798-c3ccd9861e71
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 9bae19b4-f0b6-425a-9e12-949e1e6c0536
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('74339a2e-acd0-4813-aad3-0b45bf35a4b9')
# )
# 2026-08-04 13:16:05,966 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: 74339a2e-acd0-4813-aad3-0b45bf35a4b9'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: 5db250d2-e799-496d-a35c-ec0a1970f590
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 000701e6-8527-46d1-9457-40d147fc2850
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: ea865738-1327-4e68-a798-c3ccd9861e71
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 9bae19b4-f0b6-425a-9e12-949e1e6c0536
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('74339a2e-acd0-4813-aad3-0b45bf35a4b9')
# )
#
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: 74339a2e-acd0-4813-aad3-0b45bf35a4b9'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: 5db250d2-e799-496d-a35c-ec0a1970f590
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 000701e6-8527-46d1-9457-40d147fc2850
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: ea865738-1327-4e68-a798-c3ccd9861e71
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 9bae19b4-f0b6-425a-9e12-949e1e6c0536
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('74339a2e-acd0-4813-aad3-0b45bf35a4b9')
# )
# 2026-08-04 13:16:05,966 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-04 13:16:05,966 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2026-08-04 13:16:05,966 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2026-08-04 13:16:05,972 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2026-08-04 13:16:05,972 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2026-08-04 13:16:05,973 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2026-08-04 13:16:05,976 - INFO - examples.example -
# Building Spiking Network with builder DefaultExcIOBuilder of App ANNarchySerialApp...
# 2026-08-04 13:16:05,976 - INFO - examples.example -
# Building Spiking Network with builder DefaultExcIOBuilder of App ANNarchySerialApp...
#
# Building Spiking Network with builder DefaultExcIOBuilder of App ANNarchySerialApp...
# 2026-08-04 13:16:05,976 - INFO - examples.example - Loading an ANNarchy instance...
# 2026-08-04 13:16:05,976 - INFO - examples.example - Loading an ANNarchy instance...
# 2026-08-04 13:16:05,977 - INFO - examples.example - Cleaning ANNarchy compilation directory, if any...
# 2026-08-04 13:16:05,977 - INFO - examples.example - Cleaning ANNarchy compilation directory, if any...
# 2026-08-04 13:16:05,977 - INFO - examples.example - Configuring spiking network builder...
# 2026-08-04 13:16:05,977 - INFO - examples.example - Configuring spiking network builder...
# 2026-08-04 13:16:05,977 - INFO - examples.example - Configuring populations...
# 2026-08-04 13:16:05,977 - INFO - examples.example - Configuring populations...
# 2026-08-04 13:16:05,977 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2026-08-04 13:16:05,977 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2026-08-04 13:16:05,977 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2026-08-04 13:16:05,977 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2026-08-04 13:16:05,977 - INFO - examples.example - Configuring output devices, if any...
# 2026-08-04 13:16:05,977 - INFO - examples.example - Configuring output devices, if any...
# 2026-08-04 13:16:05,978 - INFO - examples.example - Configuring input devices, if any...
# 2026-08-04 13:16:05,978 - INFO - examples.example - Configuring input devices, if any...
# 2026-08-04 13:16:05,978 - INFO - examples.example - Generating spiking brain...
# 2026-08-04 13:16:05,978 - INFO - examples.example - Generating spiking brain...
# 2026-08-04 13:16:05,978 - INFO - examples.example - Generating spiking brain regions...
# 2026-08-04 13:16:05,978 - INFO - examples.example - Generating spiking brain regions...
# 2026-08-04 13:16:05,978 - INFO - examples.example - Generating spiking region node: bankssts_L...
# 2026-08-04 13:16:05,978 - INFO - examples.example - Generating spiking region node: bankssts_L...
# 2026-08-04 13:16:05,979 - INFO - examples.example - Generating population: E...
# 2026-08-04 13:16:05,979 - INFO - examples.example - Generating population: E...
# 2026-08-04 13:16:06,128 - INFO - examples.example - Generating spiking region node: bankssts_R...
# 2026-08-04 13:16:06,128 - INFO - examples.example - Generating spiking region node: bankssts_R...
# 2026-08-04 13:16:06,129 - INFO - examples.example - Generating population: E...
# 2026-08-04 13:16:06,129 - INFO - examples.example - Generating population: E...
# 2026-08-04 13:16:06,164 - INFO - examples.example - Connecting populations within spiking brain regions...
# 2026-08-04 13:16:06,164 - INFO - examples.example - Connecting populations within spiking brain regions...
# 2026-08-04 13:16:06,165 - INFO - examples.example - Connecting E -> E populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:16:06,165 - INFO - examples.example - Connecting E -> E populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:16:06,166 - INFO - examples.example - Connecting populations among spiking brain regions...
# 2026-08-04 13:16:06,166 - INFO - examples.example - Connecting populations among spiking brain regions...
# 2026-08-04 13:16:06,167 - INFO - examples.example - Connecting for 0 -> 1 spiking region nodes ...
# 2026-08-04 13:16:06,167 - INFO - examples.example - Connecting for 0 -> 1 spiking region nodes ...
# 2026-08-04 13:16:06,167 - INFO - examples.example - E -> E populations ...
# 2026-08-04 13:16:06,167 - INFO - examples.example - E -> E populations ...
# 2026-08-04 13:16:06,167 - INFO - examples.example - Connecting for 1 -> 0 spiking region nodes ...
# 2026-08-04 13:16:06,167 - INFO - examples.example - Connecting for 1 -> 0 spiking region nodes ...
# 2026-08-04 13:16:06,167 - INFO - examples.example - E -> E populations ...
# 2026-08-04 13:16:06,167 - INFO - examples.example - E -> E populations ...
# 2026-08-04 13:16:06,167 - INFO - examples.example - Generating and connecting output devices, if any...
# 2026-08-04 13:16:06,167 - INFO - examples.example - Generating and connecting output devices, if any...
# 2026-08-04 13:16:06,167 - INFO - examples.example - Generating and connecting ['E'] -> ['E'] device set of model SpikeMonitor
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:16:06,167 - INFO - examples.example - Generating and connecting ['E'] -> ['E'] device set of model SpikeMonitor
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:16:06,168 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E created!
# 2026-08-04 13:16:06,168 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E created!
# 2026-08-04 13:16:06,170 - INFO - examples.example - Generating and connecting ['Excitatory'] -> ['E'] device set of model Monitor
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:16:06,170 - INFO - examples.example - Generating and connecting ['Excitatory'] -> ['E'] device set of model Monitor
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:16:06,170 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Excitatory created!
# 2026-08-04 13:16:06,170 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Excitatory created!
# 2026-08-04 13:16:06,172 - INFO - examples.example - Generating and connecting input devices, if any...
# 2026-08-04 13:16:06,172 - INFO - examples.example - Generating and connecting input devices, if any...
# 2026-08-04 13:16:06,172 - INFO - examples.example - Generating and connecting ['Stimulus'] -> [['E']] device set of model PoissonPopulation
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:16:06,172 - INFO - examples.example - Generating and connecting ['Stimulus'] -> [['E']] device set of model PoissonPopulation
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:16:06,173 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model PoissonPopulation for Stimulus created!
# 2026-08-04 13:16:06,173 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model PoissonPopulation for Stimulus created!
# 2026-08-04 13:16:06,182 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:16:06,182 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:16:06,182 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:16:06,182 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:16:06,182 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:16:06,182 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:16:06,182 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:16:06,182 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:16:06,182 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# ANNarchyNetwork (
#   title ....................................... 'ANNarchyNetwork gid: a208d00c-e182-4c4c-9691-d2514c072a5a'
#   Type ........................................ 'ANNarchyNetwork'
#   annarchy_network ............................ <ANNarchy.core.Network.Network object at 0xffff42ae4920>
#   config ...................................... '--------------------'
#   config.title ................................ 'Config gid: 9df2b456-3950-4fa4-92b3-5fbfa3784fa9'
#   config.Type ................................. 'Config'
#   config.gid .................................. UUID('9df2b456-3950-4fa4-92b3-5fbfa3784fa9')
#   brain_regions ............................... '--------------------'
#   brain_regions.title ......................... 'ANNarchyBrain gid: aea74327-f301-42ed-9fc8-61b9a841c399'
#   brain_regions.Type .......................... 'ANNarchyBrain'
#   brain_regions.gid ........................... UUID('aea74327-f301-42ed-9fc8-61b9a841c399')
#   brain_regions.label ......................... ''
#   brain_regions.size .......................... 2
#   brain_regions.Regions ....................... --------------------
#   brain_regions.Regions: shape ................ (2,)
#   brain_regions.Regions: dtype ................ <U10
#   brain_regions.Regions: values ............... ['bankssts_L' 'bankssts_R']
#   brain_regions.bankssts_L .................... '--------------------'
#   brain_regions[bankssts_L].title ............. 'ANNarchyRegionNode gid: 146a26fc-919c-4870-a479-c5c6eb6ffedd'
#   brain_regions[bankssts_L].Type .............. 'ANNarchyRegionNode'
#   brain_regions[bankssts_L].gid ............... UUID('146a26fc-919c-4870-a479-c5c6eb6ffedd')
#   brain_regions[bankssts_L].label ............. 'bankssts_L'
#   brain_regions[bankssts_L].size .............. 1
#   brain_regions[bankssts_L].Populations ....... --------------------
#   brain_regions[bankssts_L].Populations: shape  (1,)
#   brain_regions[bankssts_L].Populations: dtype  <U1
#   brain_regions[bankssts_L].Populations: values  E
#   brain_regions.bankssts_R .................... '--------------------'
#   brain_regions[bankssts_R].title ............. 'ANNarchyRegionNode gid: 22d9473c-155a-4481-8f8f-179ca8cf175c'
#   brain_regions[bankssts_R].Type .............. 'ANNarchyRegionNode'
#   brain_regions[bankssts_R].gid ............... UUID('22d9473c-155a-4481-8f8f-179ca8cf175c')
#   brain_regions[bankssts_R].label ............. 'bankssts_R'
#   brain_regions[bankssts_R].size .............. 1
#   brain_regions[bankssts_R].Populations ....... --------------------
#   brain_regions[bankssts_R].Populations: shape  (1,)
#   brain_regions[bankssts_R].Populations: dtype  <U1
#   brain_regions[bankssts_R].Populations: values  E
#   network_path ................................ ''
#   logger ...................................... <Logger tvb-multiscale (DEBUG)>
#   output_devices .............................. '--------------------'
#   output_devices.title ........................ 'DeviceSets gid: 84b6d673-7c84-4480-820d-913f6597ccb8'
#   output_devices.Type ......................... 'DeviceSets'
#   output_devices.gid .......................... UUID('84b6d673-7c84-4480-820d-913f6597ccb8')
#   output_devices.label ........................ 'output_devices'
#   output_devices.size ......................... 2
#   output_devices.DeviceSets ................... --------------------
#   output_devices.DeviceSets: shape ............ (2,)
#   output_devices.DeviceSets: dtype ............ <U10
#   output_devices.DeviceSets: values ........... ['E' 'Excitatory']
#   output_devices.E ............................ '--------------------'
#   output_devices[E].title ..................... 'DeviceSet gid: 0cd58ab9-3a2c-48a4-86ea-185320ba7f02'
#   output_devices[E].Type ...................... 'DeviceSet'
#   output_devices[E].model ..................... 'SpikeMonitor'
#   output_devices[E].gid ....................... UUID('0cd58ab9-3a2c-48a4-86ea-185320ba7f02')
#   output_devices[E].label ..................... 'E'
#   output_devices[E].size ...................... 2
#   output_devices[E].Devices ................... --------------------
#   output_devices[E].Devices: shape ............ (2,)
#   output_devices[E].Devices: dtype ............ <U10
#   output_devices[E].Devices: values ........... ['bankssts_L' 'bankssts_R']
#   output_devices.Excitatory ................... '--------------------'
#   output_devices[Excitatory].title ............ 'DeviceSet gid: 55e6a529-3e58-43f8-9b97-8058b8b64bbe'
#   output_devices[Excitatory].Type ............. 'DeviceSet'
#   output_devices[Excitatory].model ............ 'Monitor'
#   output_devices[Excitatory].gid .............. UUID('55e6a529-3e58-43f8-9b97-8058b8b64bbe')
#   output_devices[Excitatory].label ............ 'Excitatory'
#   output_devices[Excitatory].size ............. 2
#   output_devices[Excitatory].Devices .......... --------------------
#   output_devices[Excitatory].Devices: shape ... (2,)
#   output_devices[Excitatory].Devices: dtype ... <U10
#   output_devices[Excitatory].Devices: values .. ['bankssts_L' 'bankssts_R']
#   input_devices ............................... '--------------------'
#   input_devices.title ......................... 'DeviceSets gid: 2b04760c-7131-4072-afe1-cfc1caa6f744'
#   input_devices.Type .......................... 'DeviceSets'
#   input_devices.gid ........................... UUID('2b04760c-7131-4072-afe1-cfc1caa6f744')
#   input_devices.label ......................... 'input_devices'
#   input_devices.size .......................... 1
#   input_devices.DeviceSets .................... --------------------
#   input_devices.DeviceSets: shape ............. (1,)
#   input_devices.DeviceSets: dtype ............. <U8
#   input_devices.DeviceSets: values ............ Stimulus
#   input_devices.Stimulus ...................... '--------------------'
#   input_devices[Stimulus].title ............... 'DeviceSet gid: fef37204-c7fd-4bcb-9b47-9de9ce4fec32'
#   input_devices[Stimulus].Type ................ 'DeviceSet'
#   input_devices[Stimulus].model ............... 'PoissonPopulation'
#   input_devices[Stimulus].gid ................. UUID('fef37204-c7fd-4bcb-9b47-9de9ce4fec32')
#   input_devices[Stimulus].label ............... 'Stimulus'
#   input_devices[Stimulus].size ................ 2
#   input_devices[Stimulus].Devices ............. --------------------
#   input_devices[Stimulus].Devices: shape ...... (2,)
#   input_devices[Stimulus].Devices: dtype ...... <U10
#   input_devices[Stimulus].Devices: values ..... ['bankssts_L' 'bankssts_R']
#   output_proxies .............................. '--------------------'
#   output_proxies.title ........................ 'DeviceSets gid: aa3f55d9-3e51-4fd7-a92b-982487715363'
#   output_proxies.Type ......................... 'DeviceSets'
#   output_proxies.gid .......................... UUID('aa3f55d9-3e51-4fd7-a92b-982487715363')
#   output_proxies.label ........................ 'output_proxies'
#   output_proxies.size ......................... 0
#   output_proxies.DeviceSets ................... --------------------
#   shape ....................................... (0,)
#   dtype ....................................... float64
#   is empty .................................... True
#   input_proxies ............................... '--------------------'
#   input_proxies.title ......................... 'DeviceSets gid: d364267d-9ebc-4ea6-8abc-5d2d088800bd'
#   input_proxies.Type .......................... 'DeviceSets'
#   input_proxies.gid ........................... UUID('d364267d-9ebc-4ea6-8abc-5d2d088800bd')
#   input_proxies.label ......................... ''
#   input_proxies.size .......................... 0
#   input_proxies.DeviceSets .................... --------------------
#   gid ......................................... UUID('a208d00c-e182-4c4c-9691-d2514c072a5a')
# )
# 2026-08-04 13:16:06,185 - INFO - examples.example -
# Building interfaces with Orchestrator TVBANNarchySerialOrchestrator...
# 2026-08-04 13:16:06,185 - INFO - examples.example -
# Building interfaces with Orchestrator TVBANNarchySerialOrchestrator...
#
# Building interfaces with Orchestrator TVBANNarchySerialOrchestrator...
# 2026-08-04 13:16:06,185 - INFO - examples.example -
# Building interfaces' with builder TVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2026-08-04 13:16:06,185 - INFO - examples.example -
# Building interfaces' with builder TVBANNarchyInterfaceBuilder of App TVBSerialApp...
#
# Building interfaces' with builder TVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2026-08-04 13:16:06,185 - INFO - examples.example -
# Configuring interfaces' builder DefaultTVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2026-08-04 13:16:06,185 - INFO - examples.example -
# Configuring interfaces' builder DefaultTVBANNarchyInterfaceBuilder of App TVBSerialApp...
#
# Configuring interfaces' builder DefaultTVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2026-08-04 13:16:06,185 - INFO - examples.example -
# Configuring default interfaces...
# 2026-08-04 13:16:06,185 - INFO - examples.example -
# Configuring default interfaces...
#
# Configuring default interfaces...
# 2026-08-04 13:16:06,188 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model TimedPoissonPopulation for ['R']->E created!
# 2026-08-04 13:16:06,188 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model TimedPoissonPopulation for ['R']->E created!
# 2026-08-04 13:16:06,433 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E->['R'] created!
# 2026-08-04 13:16:06,433 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E->['R'] created!
# 2026-08-04 13:16:06,435 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-04 13:16:06,435 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2026-08-04 13:16:06,435 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2026-08-04 13:16:06,440 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2026-08-04 13:16:06,440 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2026-08-04 13:16:06,441 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2026-08-04 13:16:06,449 - INFO - examples.example -
# TVBtoANNarchyInterfaces (
#   title .................................. 'TVBtoANNarchyInterfaces gid: 82dcf886-fde2-49ff-aff4-0d82d19b6482'
#   Type ................................... 'TVBtoANNarchyInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoANNarchyInterface gid: ad97420a-e910-4183-9197-d54ab740d779'
#   interfaces[0].Type ..................... 'TVBtoANNarchyInterface'
#   interfaces[0].proxy .................... ANNarchyTimedPoissonPopulationSet gid: 8ae86e39-74e2-45b1-85e0-64ba79c62884
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: a208d00c-e182-4c4c-9691-d2514c072a5a
#   interfaces[0].transformer .............. LinearRate gid: fb81f153-28ee-4582-8941-a199211dd63c
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[np.int64(2), np.int64(67)]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[np.int64(0), np.int64(1)]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('ad97420a-e910-4183-9197-d54ab740d779')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int32
#   interfaces[0].proxy_gids: unique_values  0
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('82dcf886-fde2-49ff-aff4-0d82d19b6482')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[np.int64(0), np.int64(1)]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 66
# )
# 2026-08-04 13:16:06,449 - INFO - examples.example -
# TVBtoANNarchyInterfaces (
#   title .................................. 'TVBtoANNarchyInterfaces gid: 82dcf886-fde2-49ff-aff4-0d82d19b6482'
#   Type ................................... 'TVBtoANNarchyInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoANNarchyInterface gid: ad97420a-e910-4183-9197-d54ab740d779'
#   interfaces[0].Type ..................... 'TVBtoANNarchyInterface'
#   interfaces[0].proxy .................... ANNarchyTimedPoissonPopulationSet gid: 8ae86e39-74e2-45b1-85e0-64ba79c62884
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: a208d00c-e182-4c4c-9691-d2514c072a5a
#   interfaces[0].transformer .............. LinearRate gid: fb81f153-28ee-4582-8941-a199211dd63c
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[np.int64(2), np.int64(67)]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[np.int64(0), np.int64(1)]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('ad97420a-e910-4183-9197-d54ab740d779')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int32
#   interfaces[0].proxy_gids: unique_values  0
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('82dcf886-fde2-49ff-aff4-0d82d19b6482')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[np.int64(0), np.int64(1)]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 66
# )
#
# TVBtoANNarchyInterfaces (
#   title .................................. 'TVBtoANNarchyInterfaces gid: 82dcf886-fde2-49ff-aff4-0d82d19b6482'
#   Type ................................... 'TVBtoANNarchyInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoANNarchyInterface gid: ad97420a-e910-4183-9197-d54ab740d779'
#   interfaces[0].Type ..................... 'TVBtoANNarchyInterface'
#   interfaces[0].proxy .................... ANNarchyTimedPoissonPopulationSet gid: 8ae86e39-74e2-45b1-85e0-64ba79c62884
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: a208d00c-e182-4c4c-9691-d2514c072a5a
#   interfaces[0].transformer .............. LinearRate gid: fb81f153-28ee-4582-8941-a199211dd63c
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[np.int64(2), np.int64(67)]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[np.int64(0), np.int64(1)]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('ad97420a-e910-4183-9197-d54ab740d779')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int32
#   interfaces[0].proxy_gids: unique_values  0
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('82dcf886-fde2-49ff-aff4-0d82d19b6482')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[np.int64(0), np.int64(1)]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 66
# )
# 2026-08-04 13:16:06,451 - INFO - examples.example -
# ANNarchyToTVBInterfaces (
#   title .................................. 'ANNarchyToTVBInterfaces gid: f2afe15f-d29d-4e19-8d52-bbdc856ab653'
#   Type ................................... 'ANNarchyToTVBInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'ANNarchyToTVBInterface gid: 6250978e-bb6f-4406-8801-82289617b1be'
#   interfaces[0].Type ..................... 'ANNarchyToTVBInterface'
#   interfaces[0].proxy .................... ANNarchySpikeMonitorSet gid: 1e59b051-b846-4d4a-8226-60f94cd923d3
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: a208d00c-e182-4c4c-9691-d2514c072a5a
#   interfaces[0].transformer .............. ElephantSpikesHistogramRate gid: 9d0727e8-9b39-4c00-ae74-fd20550af7c0
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (2,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: values ....... [[np.int64(0), np.int64(1)]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].dt ....................... 0.1
#   interfaces[0].times .................... --------------------
#   interfaces[0].times: shape ............. (2,)
#   interfaces[0].times: dtype ............. int64
#   interfaces[0].times: values ............ [[np.int64(0), np.int64(1)]]
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[np.int64(0), np.int64(1)]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'SpikeMonitor'
#   interfaces[0].gid ...................... UUID('6250978e-bb6f-4406-8801-82289617b1be')
#   interfaces[0].number_of_proxy_nodes .... 2
#   interfaces[0].number_of_proxy_gids ..... 0
#   interfaces[0].proxy_gids ............... --------------------
#   shape .................................. (0,)
#   dtype .................................. float64
#   is empty ............................... True
#   interfaces[0].n_voi .................... 1
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('f2afe15f-d29d-4e19-8d52-bbdc856ab653')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[np.int64(0), np.int64(1)]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 2
# )
# 2026-08-04 13:16:06,451 - INFO - examples.example -
# ANNarchyToTVBInterfaces (
#   title .................................. 'ANNarchyToTVBInterfaces gid: f2afe15f-d29d-4e19-8d52-bbdc856ab653'
#   Type ................................... 'ANNarchyToTVBInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'ANNarchyToTVBInterface gid: 6250978e-bb6f-4406-8801-82289617b1be'
#   interfaces[0].Type ..................... 'ANNarchyToTVBInterface'
#   interfaces[0].proxy .................... ANNarchySpikeMonitorSet gid: 1e59b051-b846-4d4a-8226-60f94cd923d3
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: a208d00c-e182-4c4c-9691-d2514c072a5a
#   interfaces[0].transformer .............. ElephantSpikesHistogramRate gid: 9d0727e8-9b39-4c00-ae74-fd20550af7c0
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (2,)
#   interfaces[0].proxy_inds: dtype ........ int64
# ...
#   spikeNet_app.tvb_cosimulator_serialized[coupling.gid]: values .................... ea865738-1327-4e68-a798-c3ccd9861e71
#   spikeNet_app.interfaces_builder .................................................. None
#   spikeNet_app.logger .............................................................. <Logger examples.example (DEBUG)>
#   spikeNet_app.default_tvb_serial_cosim_path ....................................... '/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/DefaultExcIO_RATE_bidir/config/tvb_serial_cosimulator.pkl'
#   spikeNet_app.gid ................................................................. UUID('d21c98ad-0bd0-4683-af92-310fc6bce6e1')
#   spikeNet_app.spiking_cosimulator ................................................. <module 'ANNarchy' from '/home/docker/venv/lib/python3.12/site-packages/ANNarchy/__init__.py'>
#   logger ........................................................................... <Logger examples.example (DEBUG)>
#   default_tvb_serial_cosim_path .................................................... '/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/DefaultExcIO_RATE_bidir/config/tvb_serial_cosimulator.pkl'
#   gid .............................................................................. UUID('b5e0f837-39a2-4f9f-ac9d-53d8aafcdba5')
# )
# None
#
#
# Simulating...
# 2026-08-04 13:16:06,470 - INFO - examples.example -
# Simulating for 36ms with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:16:06,470 - INFO - examples.example -
# Simulating for 36ms with App TVBANNarchySerialOrchestrator...
#
# Simulating for 36ms with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:16:06,470 - INFO - examples.example -
# Configuring simulation with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:16:06,470 - INFO - examples.example -
# Configuring simulation with App TVBANNarchySerialOrchestrator...
#
# Configuring simulation with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:16:06,470 - INFO - examples.example -
# Configuring simulation with App TVBSerialApp...
# 2026-08-04 13:16:06,470 - INFO - examples.example -
# Configuring simulation with App TVBSerialApp...
#
# Configuring simulation with App TVBSerialApp...
# 2026-08-04 13:16:06,471 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-04 13:16:06,471 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2026-08-04 13:16:06,471 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2026-08-04 13:16:06,477 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2026-08-04 13:16:06,477 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2026-08-04 13:16:06,478 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# 2026-08-04 13:16:06,483 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: 74339a2e-acd0-4813-aad3-0b45bf35a4b9'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: 5db250d2-e799-496d-a35c-ec0a1970f590
#   output_interfaces ................... TVBtoANNarchyInterfaces gid: 82dcf886-fde2-49ff-aff4-0d82d19b6482
#   input_interfaces .................... ANNarchyToTVBInterfaces gid: f2afe15f-d29d-4e19-8d52-bbdc856ab653
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (66,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: unique_values ....... [[np.int64(2), np.int64(67)]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (1,)
#   voi: dtype .......................... int64
#   voi: values ......................... 0
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[np.int64(0), np.int64(1)]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. RawCosim(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 000701e6-8527-46d1-9457-40d147fc2850
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: ea865738-1327-4e68-a798-c3ccd9861e71
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 9bae19b4-f0b6-425a-9e12-949e1e6c0536
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('74339a2e-acd0-4813-aad3-0b45bf35a4b9')
# )
# 2026-08-04 13:16:06,483 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: 74339a2e-acd0-4813-aad3-0b45bf35a4b9'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: 5db250d2-e799-496d-a35c-ec0a1970f590
#   output_interfaces ................... TVBtoANNarchyInterfaces gid: 82dcf886-fde2-49ff-aff4-0d82d19b6482
#   input_interfaces .................... ANNarchyToTVBInterfaces gid: f2afe15f-d29d-4e19-8d52-bbdc856ab653
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (66,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: unique_values ....... [[np.int64(2), np.int64(67)]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (1,)
#   voi: dtype .......................... int64
#   voi: values ......................... 0
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[np.int64(0), np.int64(1)]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. RawCosim(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 000701e6-8527-46d1-9457-40d147fc2850
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: ea865738-1327-4e68-a798-c3ccd9861e71
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 9bae19b4-f0b6-425a-9e12-949e1e6c0536
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('74339a2e-acd0-4813-aad3-0b45bf35a4b9')
# )
#
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: 74339a2e-acd0-4813-aad3-0b45bf35a4b9'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: 5db250d2-e799-496d-a35c-ec0a1970f590
#   output_interfaces ................... TVBtoANNarchyInterfaces gid: 82dcf886-fde2-49ff-aff4-0d82d19b6482
#   input_interfaces .................... ANNarchyToTVBInterfaces gid: f2afe15f-d29d-4e19-8d52-bbdc856ab653
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (66,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: unique_values ....... [[np.int64(2), np.int64(67)]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (1,)
#   voi: dtype .......................... int64
#   voi: values ......................... 0
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[np.int64(0), np.int64(1)]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. RawCosim(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 000701e6-8527-46d1-9457-40d147fc2850
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: ea865738-1327-4e68-a798-c3ccd9861e71
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 9bae19b4-f0b6-425a-9e12-949e1e6c0536
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('74339a2e-acd0-4813-aad3-0b45bf35a4b9')
# )
# 2026-08-04 13:16:06,483 - INFO - examples.example -
# Configuring simulation with App ANNarchySerialApp...
# 2026-08-04 13:16:06,483 - INFO - examples.example -
# Configuring simulation with App ANNarchySerialApp...
#
# Configuring simulation with App ANNarchySerialApp...
# Compiling network 1... OK
# 2026-08-04 13:19:52,685 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-04 13:19:52,685 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
#
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-04 13:19:52,694 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - No or all NaN valued cosimulator updates at time step 0!
# 2026-08-04 13:19:52,694 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.016 seconds
# 2026-08-04 13:19:52,694 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2026-08-04 13:19:52,694 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 22031
# 2026-08-04 13:19:52,702 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:19:52,706 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...9.091% completed in 0.0136645 sec!
# ...9.091% completed in 0.0136645 sec!2026-08-04 13:19:52,770 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:19:52,775 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...18.182% completed in 0.0821996 sec!
# ...18.182% completed in 0.0821996 sec!2026-08-04 13:19:52,783 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:19:52,787 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...27.273% completed in 0.0942521 sec!
# ...27.273% completed in 0.0942521 sec!2026-08-04 13:19:52,799 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:19:52,804 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...36.364% completed in 0.111317 sec!
# ...36.364% completed in 0.111317 sec!2026-08-04 13:19:52,815 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:19:52,818 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...45.455% completed in 0.125597 sec!
# ...45.455% completed in 0.125597 sec!2026-08-04 13:19:52,826 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:19:52,830 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...54.545% completed in 0.137513 sec!
# ...54.545% completed in 0.137513 sec!2026-08-04 13:19:52,839 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:19:52,843 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...63.636% completed in 0.150234 sec!
# ...63.636% completed in 0.150234 sec!2026-08-04 13:19:52,851 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:19:52,855 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...72.727% completed in 0.162637 sec!
# ...72.727% completed in 0.162637 sec!2026-08-04 13:19:52,864 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:19:52,869 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...81.818% completed in 0.176095 sec!
# ...81.818% completed in 0.176095 sec!2026-08-04 13:19:52,876 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:19:52,880 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...90.909% completed in 0.187684 sec!
# ...90.909% completed in 0.187684 sec!2026-08-04 13:19:52,889 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:19:52,893 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...100.000% completed in 0.200289 sec!
# ...100.000% completed in 0.200289 sec!
# Simulated in 226.423433 secs!
#
# 2026-08-04 13:19:52,893 - INFO - examples.example -
# Cleaning up App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:19:52,893 - INFO - examples.example -
# Cleaning up App TVBANNarchySerialOrchestrator...
#
# Cleaning up App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:19:52,894 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-04 13:19:52,894 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
#
# Cleaning up App TVBSerialApp...
# 2026-08-04 13:19:52,894 - INFO - examples.example -
# Cleaning up App ANNarchySerialApp...
# 2026-08-04 13:19:52,894 - INFO - examples.example -
# Cleaning up App ANNarchySerialApp...
#
# Cleaning up App ANNarchySerialApp...
# 2026-08-04 13:19:52,894 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-04 13:19:52,894 - INFO - examples.example -
# Stopping App TVBSerialApp...
#
# Stopping App TVBSerialApp...
# 2026-08-04 13:19:52,894 - INFO - examples.example -
# Stopping App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:19:52,894 - INFO - examples.example -
# Stopping App TVBANNarchySerialOrchestrator...
#
# Stopping App TVBANNarchySerialOrchestrator...
#
# Success in 227.056 sec!
# ******************************************************
#
# {'TestDefaultRATE': True}

# %%
! python ../../../tvb_multiscale/tests/tvb_annarchy/test_models.py 1
# Out:
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
# /home/docker/venv/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# ANNarchy 5.0 (5.0.3) on linux (posix).
# 2026-08-04 13:19:59,252 - WARNING - tvb.simulator.plot.tools - You need mpl_toolkits for some axe related features
#
#
# Testing model 1
# ******************************************************
# ******************************************************
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
#
# ----------------------------------------------------------------------------------------------------
# Find results in /home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/DefaultExcIO_RATE_bidir/res !
# ----------------------------------------------------------------------------------------------------
# 2026-08-04 13:20:00,401 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:00,401 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
#
# Starting App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:00,401 - INFO - examples.example -
# Starting App TVBSerialApp...
# 2026-08-04 13:20:00,401 - INFO - examples.example -
# Starting App TVBSerialApp...
#
# Starting App TVBSerialApp...
# 2026-08-04 13:20:00,401 - INFO - examples.example -
# Setting TVB LIBRARY_PROFILE...
# 2026-08-04 13:20:00,401 - INFO - examples.example -
# Setting TVB LIBRARY_PROFILE...
#
# Setting TVB LIBRARY_PROFILE...
# 2026-08-04 13:20:00,439 - INFO - examples.example -
# Starting App ANNarchySerialApp...
# 2026-08-04 13:20:00,439 - INFO - examples.example -
# Starting App ANNarchySerialApp...
#
# Starting App ANNarchySerialApp...
# 2026-08-04 13:20:00,439 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Loading an ANNarchy instance...
# 2026-08-04 13:20:00,439 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Loading an ANNarchy instance...
# 2026-08-04 13:20:00,439 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Cleaning ANNarchy compilation directory, if any...
# 2026-08-04 13:20:00,439 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Cleaning ANNarchy compilation directory, if any...
#
#
# Configuring...
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
#
# Done! in 0.000093 min
#
#
#
# Building...
# 2026-08-04 13:20:00,445 - INFO - examples.example -
# Building with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:00,445 - INFO - examples.example -
# Building with App TVBANNarchySerialOrchestrator...
#
# Building with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:00,445 - INFO - examples.example -
# Building cosimulators with TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:00,445 - INFO - examples.example -
# Building cosimulators with TVBANNarchySerialOrchestrator...
#
# Building cosimulators with TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:00,445 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
# 2026-08-04 13:20:00,445 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
#
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
# 2026-08-04 13:20:00,447 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-04 13:20:00,447 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2026-08-04 13:20:00,447 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2026-08-04 13:20:00,453 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2026-08-04 13:20:00,453 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2026-08-04 13:20:00,454 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# 2026-08-04 13:20:00,459 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: fbc4d251-1c20-4fef-a4d6-e4e3741703ae'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: 18e5b40d-ae8c-46c2-a7b7-2e63a2585c43
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 028a438e-0396-47e4-9605-f9d9cd2e6175
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 23506261-31a2-40e7-81b7-35c32751f791
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: bcc113c0-e343-43bd-8012-0abdcec44ef5
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('fbc4d251-1c20-4fef-a4d6-e4e3741703ae')
# )
# 2026-08-04 13:20:00,459 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: fbc4d251-1c20-4fef-a4d6-e4e3741703ae'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: 18e5b40d-ae8c-46c2-a7b7-2e63a2585c43
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 028a438e-0396-47e4-9605-f9d9cd2e6175
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 23506261-31a2-40e7-81b7-35c32751f791
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: bcc113c0-e343-43bd-8012-0abdcec44ef5
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('fbc4d251-1c20-4fef-a4d6-e4e3741703ae')
# )
#
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: fbc4d251-1c20-4fef-a4d6-e4e3741703ae'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: 18e5b40d-ae8c-46c2-a7b7-2e63a2585c43
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 028a438e-0396-47e4-9605-f9d9cd2e6175
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 23506261-31a2-40e7-81b7-35c32751f791
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: bcc113c0-e343-43bd-8012-0abdcec44ef5
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('fbc4d251-1c20-4fef-a4d6-e4e3741703ae')
# )
# 2026-08-04 13:20:00,460 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-04 13:20:00,460 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2026-08-04 13:20:00,460 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2026-08-04 13:20:00,465 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2026-08-04 13:20:00,465 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2026-08-04 13:20:00,466 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2026-08-04 13:20:00,469 - INFO - examples.example -
# Building Spiking Network with builder DefaultExcIOBuilder of App ANNarchySerialApp...
# 2026-08-04 13:20:00,469 - INFO - examples.example -
# Building Spiking Network with builder DefaultExcIOBuilder of App ANNarchySerialApp...
#
# Building Spiking Network with builder DefaultExcIOBuilder of App ANNarchySerialApp...
# 2026-08-04 13:20:00,469 - INFO - examples.example - Loading an ANNarchy instance...
# 2026-08-04 13:20:00,469 - INFO - examples.example - Loading an ANNarchy instance...
# 2026-08-04 13:20:00,469 - INFO - examples.example - Cleaning ANNarchy compilation directory, if any...
# 2026-08-04 13:20:00,469 - INFO - examples.example - Cleaning ANNarchy compilation directory, if any...
# 2026-08-04 13:20:00,470 - INFO - examples.example - Configuring spiking network builder...
# 2026-08-04 13:20:00,470 - INFO - examples.example - Configuring spiking network builder...
# 2026-08-04 13:20:00,470 - INFO - examples.example - Configuring populations...
# 2026-08-04 13:20:00,470 - INFO - examples.example - Configuring populations...
# 2026-08-04 13:20:00,470 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2026-08-04 13:20:00,470 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2026-08-04 13:20:00,470 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2026-08-04 13:20:00,470 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2026-08-04 13:20:00,470 - INFO - examples.example - Configuring output devices, if any...
# 2026-08-04 13:20:00,470 - INFO - examples.example - Configuring output devices, if any...
# 2026-08-04 13:20:00,470 - INFO - examples.example - Configuring input devices, if any...
# 2026-08-04 13:20:00,470 - INFO - examples.example - Configuring input devices, if any...
# 2026-08-04 13:20:00,470 - INFO - examples.example - Generating spiking brain...
# 2026-08-04 13:20:00,470 - INFO - examples.example - Generating spiking brain...
# 2026-08-04 13:20:00,471 - INFO - examples.example - Generating spiking brain regions...
# 2026-08-04 13:20:00,471 - INFO - examples.example - Generating spiking brain regions...
# 2026-08-04 13:20:00,471 - INFO - examples.example - Generating spiking region node: bankssts_L...
# 2026-08-04 13:20:00,471 - INFO - examples.example - Generating spiking region node: bankssts_L...
# 2026-08-04 13:20:00,472 - INFO - examples.example - Generating population: E...
# 2026-08-04 13:20:00,472 - INFO - examples.example - Generating population: E...
# 2026-08-04 13:20:00,618 - INFO - examples.example - Generating spiking region node: bankssts_R...
# 2026-08-04 13:20:00,618 - INFO - examples.example - Generating spiking region node: bankssts_R...
# 2026-08-04 13:20:00,619 - INFO - examples.example - Generating population: E...
# 2026-08-04 13:20:00,619 - INFO - examples.example - Generating population: E...
# 2026-08-04 13:20:00,653 - INFO - examples.example - Connecting populations within spiking brain regions...
# 2026-08-04 13:20:00,653 - INFO - examples.example - Connecting populations within spiking brain regions...
# 2026-08-04 13:20:00,653 - INFO - examples.example - Connecting E -> E populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:20:00,653 - INFO - examples.example - Connecting E -> E populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:20:00,653 - INFO - examples.example - Connecting populations among spiking brain regions...
# 2026-08-04 13:20:00,653 - INFO - examples.example - Connecting populations among spiking brain regions...
# 2026-08-04 13:20:00,654 - INFO - examples.example - Connecting for 0 -> 1 spiking region nodes ...
# 2026-08-04 13:20:00,654 - INFO - examples.example - Connecting for 0 -> 1 spiking region nodes ...
# 2026-08-04 13:20:00,654 - INFO - examples.example - E -> E populations ...
# 2026-08-04 13:20:00,654 - INFO - examples.example - E -> E populations ...
# 2026-08-04 13:20:00,654 - INFO - examples.example - Connecting for 1 -> 0 spiking region nodes ...
# 2026-08-04 13:20:00,654 - INFO - examples.example - Connecting for 1 -> 0 spiking region nodes ...
# 2026-08-04 13:20:00,654 - INFO - examples.example - E -> E populations ...
# 2026-08-04 13:20:00,654 - INFO - examples.example - E -> E populations ...
# 2026-08-04 13:20:00,654 - INFO - examples.example - Generating and connecting output devices, if any...
# 2026-08-04 13:20:00,654 - INFO - examples.example - Generating and connecting output devices, if any...
# 2026-08-04 13:20:00,654 - INFO - examples.example - Generating and connecting ['E'] -> ['E'] device set of model SpikeMonitor
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:20:00,654 - INFO - examples.example - Generating and connecting ['E'] -> ['E'] device set of model SpikeMonitor
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:20:00,655 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E created!
# 2026-08-04 13:20:00,655 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E created!
# 2026-08-04 13:20:00,656 - INFO - examples.example - Generating and connecting ['Excitatory'] -> ['E'] device set of model Monitor
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:20:00,656 - INFO - examples.example - Generating and connecting ['Excitatory'] -> ['E'] device set of model Monitor
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:20:00,657 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Excitatory created!
# 2026-08-04 13:20:00,657 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Excitatory created!
# 2026-08-04 13:20:00,658 - INFO - examples.example - Generating and connecting input devices, if any...
# 2026-08-04 13:20:00,658 - INFO - examples.example - Generating and connecting input devices, if any...
# 2026-08-04 13:20:00,658 - INFO - examples.example - Generating and connecting ['Stimulus'] -> [['E']] device set of model PoissonPopulation
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:20:00,658 - INFO - examples.example - Generating and connecting ['Stimulus'] -> [['E']] device set of model PoissonPopulation
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:20:00,659 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model PoissonPopulation for Stimulus created!
# 2026-08-04 13:20:00,659 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model PoissonPopulation for Stimulus created!
# 2026-08-04 13:20:00,667 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:20:00,667 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:20:00,667 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:20:00,667 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:20:00,667 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:20:00,667 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:20:00,667 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:20:00,667 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:20:00,667 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# ANNarchyNetwork (
#   title ....................................... 'ANNarchyNetwork gid: 0f3f3760-c68f-42bc-a640-94fe01eb2d0f'
#   Type ........................................ 'ANNarchyNetwork'
#   annarchy_network ............................ <ANNarchy.core.Network.Network object at 0xffff3d9f1f40>
#   config ...................................... '--------------------'
#   config.title ................................ 'Config gid: 1d1eac83-f14d-4714-9d9a-dd674d459e0a'
#   config.Type ................................. 'Config'
#   config.gid .................................. UUID('1d1eac83-f14d-4714-9d9a-dd674d459e0a')
#   brain_regions ............................... '--------------------'
#   brain_regions.title ......................... 'ANNarchyBrain gid: 31b0a5ec-3130-4551-98f4-9608f484f0dc'
#   brain_regions.Type .......................... 'ANNarchyBrain'
#   brain_regions.gid ........................... UUID('31b0a5ec-3130-4551-98f4-9608f484f0dc')
#   brain_regions.label ......................... ''
#   brain_regions.size .......................... 2
#   brain_regions.Regions ....................... --------------------
#   brain_regions.Regions: shape ................ (2,)
#   brain_regions.Regions: dtype ................ <U10
#   brain_regions.Regions: values ............... ['bankssts_L' 'bankssts_R']
#   brain_regions.bankssts_L .................... '--------------------'
#   brain_regions[bankssts_L].title ............. 'ANNarchyRegionNode gid: 51a7bc45-e05a-4375-9d03-bdc74be004fa'
#   brain_regions[bankssts_L].Type .............. 'ANNarchyRegionNode'
#   brain_regions[bankssts_L].gid ............... UUID('51a7bc45-e05a-4375-9d03-bdc74be004fa')
#   brain_regions[bankssts_L].label ............. 'bankssts_L'
#   brain_regions[bankssts_L].size .............. 1
#   brain_regions[bankssts_L].Populations ....... --------------------
#   brain_regions[bankssts_L].Populations: shape  (1,)
#   brain_regions[bankssts_L].Populations: dtype  <U1
#   brain_regions[bankssts_L].Populations: values  E
#   brain_regions.bankssts_R .................... '--------------------'
#   brain_regions[bankssts_R].title ............. 'ANNarchyRegionNode gid: e25e5b14-4687-4970-b46b-dd40e7874cf1'
#   brain_regions[bankssts_R].Type .............. 'ANNarchyRegionNode'
#   brain_regions[bankssts_R].gid ............... UUID('e25e5b14-4687-4970-b46b-dd40e7874cf1')
#   brain_regions[bankssts_R].label ............. 'bankssts_R'
#   brain_regions[bankssts_R].size .............. 1
#   brain_regions[bankssts_R].Populations ....... --------------------
#   brain_regions[bankssts_R].Populations: shape  (1,)
#   brain_regions[bankssts_R].Populations: dtype  <U1
#   brain_regions[bankssts_R].Populations: values  E
#   network_path ................................ ''
#   logger ...................................... <Logger tvb-multiscale (DEBUG)>
#   output_devices .............................. '--------------------'
#   output_devices.title ........................ 'DeviceSets gid: b9be123d-2ecf-4111-815c-3da4355be27a'
#   output_devices.Type ......................... 'DeviceSets'
#   output_devices.gid .......................... UUID('b9be123d-2ecf-4111-815c-3da4355be27a')
#   output_devices.label ........................ 'output_devices'
#   output_devices.size ......................... 2
#   output_devices.DeviceSets ................... --------------------
#   output_devices.DeviceSets: shape ............ (2,)
#   output_devices.DeviceSets: dtype ............ <U10
#   output_devices.DeviceSets: values ........... ['E' 'Excitatory']
#   output_devices.E ............................ '--------------------'
#   output_devices[E].title ..................... 'DeviceSet gid: 5d69df78-f53f-4f07-9491-6ba395616ef1'
#   output_devices[E].Type ...................... 'DeviceSet'
#   output_devices[E].model ..................... 'SpikeMonitor'
#   output_devices[E].gid ....................... UUID('5d69df78-f53f-4f07-9491-6ba395616ef1')
#   output_devices[E].label ..................... 'E'
#   output_devices[E].size ...................... 2
#   output_devices[E].Devices ................... --------------------
#   output_devices[E].Devices: shape ............ (2,)
#   output_devices[E].Devices: dtype ............ <U10
#   output_devices[E].Devices: values ........... ['bankssts_L' 'bankssts_R']
#   output_devices.Excitatory ................... '--------------------'
#   output_devices[Excitatory].title ............ 'DeviceSet gid: 6559da85-91d1-463a-ae3f-d24a3a921ec7'
#   output_devices[Excitatory].Type ............. 'DeviceSet'
#   output_devices[Excitatory].model ............ 'Monitor'
#   output_devices[Excitatory].gid .............. UUID('6559da85-91d1-463a-ae3f-d24a3a921ec7')
#   output_devices[Excitatory].label ............ 'Excitatory'
#   output_devices[Excitatory].size ............. 2
#   output_devices[Excitatory].Devices .......... --------------------
#   output_devices[Excitatory].Devices: shape ... (2,)
#   output_devices[Excitatory].Devices: dtype ... <U10
#   output_devices[Excitatory].Devices: values .. ['bankssts_L' 'bankssts_R']
#   input_devices ............................... '--------------------'
#   input_devices.title ......................... 'DeviceSets gid: 0131d9c8-176f-4bfe-b4a5-e0936f171443'
#   input_devices.Type .......................... 'DeviceSets'
#   input_devices.gid ........................... UUID('0131d9c8-176f-4bfe-b4a5-e0936f171443')
#   input_devices.label ......................... 'input_devices'
#   input_devices.size .......................... 1
#   input_devices.DeviceSets .................... --------------------
#   input_devices.DeviceSets: shape ............. (1,)
#   input_devices.DeviceSets: dtype ............. <U8
#   input_devices.DeviceSets: values ............ Stimulus
#   input_devices.Stimulus ...................... '--------------------'
#   input_devices[Stimulus].title ............... 'DeviceSet gid: c14bdae2-0eda-4182-8a96-ceedbb242da7'
#   input_devices[Stimulus].Type ................ 'DeviceSet'
#   input_devices[Stimulus].model ............... 'PoissonPopulation'
#   input_devices[Stimulus].gid ................. UUID('c14bdae2-0eda-4182-8a96-ceedbb242da7')
#   input_devices[Stimulus].label ............... 'Stimulus'
#   input_devices[Stimulus].size ................ 2
#   input_devices[Stimulus].Devices ............. --------------------
#   input_devices[Stimulus].Devices: shape ...... (2,)
#   input_devices[Stimulus].Devices: dtype ...... <U10
#   input_devices[Stimulus].Devices: values ..... ['bankssts_L' 'bankssts_R']
#   output_proxies .............................. '--------------------'
#   output_proxies.title ........................ 'DeviceSets gid: 0f34b81c-7cf2-4d1f-a390-a5e1dabc84bd'
#   output_proxies.Type ......................... 'DeviceSets'
#   output_proxies.gid .......................... UUID('0f34b81c-7cf2-4d1f-a390-a5e1dabc84bd')
#   output_proxies.label ........................ 'output_proxies'
#   output_proxies.size ......................... 0
#   output_proxies.DeviceSets ................... --------------------
#   shape ....................................... (0,)
#   dtype ....................................... float64
#   is empty .................................... True
#   input_proxies ............................... '--------------------'
#   input_proxies.title ......................... 'DeviceSets gid: 9abbb958-b31e-4316-a6b2-69bbbcdac411'
#   input_proxies.Type .......................... 'DeviceSets'
#   input_proxies.gid ........................... UUID('9abbb958-b31e-4316-a6b2-69bbbcdac411')
#   input_proxies.label ......................... ''
#   input_proxies.size .......................... 0
#   input_proxies.DeviceSets .................... --------------------
#   gid ......................................... UUID('0f3f3760-c68f-42bc-a640-94fe01eb2d0f')
# )
# 2026-08-04 13:20:00,670 - INFO - examples.example -
# Building interfaces with Orchestrator TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:00,670 - INFO - examples.example -
# Building interfaces with Orchestrator TVBANNarchySerialOrchestrator...
#
# Building interfaces with Orchestrator TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:00,670 - INFO - examples.example -
# Building interfaces' with builder TVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2026-08-04 13:20:00,670 - INFO - examples.example -
# Building interfaces' with builder TVBANNarchyInterfaceBuilder of App TVBSerialApp...
#
# Building interfaces' with builder TVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2026-08-04 13:20:00,670 - INFO - examples.example -
# Configuring interfaces' builder DefaultTVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2026-08-04 13:20:00,670 - INFO - examples.example -
# Configuring interfaces' builder DefaultTVBANNarchyInterfaceBuilder of App TVBSerialApp...
#
# Configuring interfaces' builder DefaultTVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2026-08-04 13:20:00,670 - INFO - examples.example -
# Configuring default interfaces...
# 2026-08-04 13:20:00,670 - INFO - examples.example -
# Configuring default interfaces...
#
# Configuring default interfaces...
# 2026-08-04 13:20:00,672 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model TimedPoissonPopulation for ['R']->E created!
# 2026-08-04 13:20:00,672 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model TimedPoissonPopulation for ['R']->E created!
# 2026-08-04 13:20:00,989 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E->['R'] created!
# 2026-08-04 13:20:00,989 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E->['R'] created!
# 2026-08-04 13:20:00,991 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-04 13:20:00,991 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2026-08-04 13:20:00,991 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2026-08-04 13:20:00,997 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2026-08-04 13:20:00,997 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2026-08-04 13:20:00,998 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2026-08-04 13:20:01,007 - INFO - examples.example -
# TVBtoANNarchyInterfaces (
#   title .................................. 'TVBtoANNarchyInterfaces gid: cf2c5845-42ca-4497-ab09-b1d0da0a55ad'
#   Type ................................... 'TVBtoANNarchyInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoANNarchyInterface gid: 3879ff63-1034-4b6d-ae93-24c5d45e7da8'
#   interfaces[0].Type ..................... 'TVBtoANNarchyInterface'
#   interfaces[0].proxy .................... ANNarchyTimedPoissonPopulationSet gid: 88e8c66d-52e4-4be1-b8c4-79b9e368f6fc
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: 0f3f3760-c68f-42bc-a640-94fe01eb2d0f
#   interfaces[0].transformer .............. LinearRate gid: d130b0b7-e724-4d77-9bc4-3352d5f7158f
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[np.int64(2), np.int64(67)]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[np.int64(0), np.int64(1)]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('3879ff63-1034-4b6d-ae93-24c5d45e7da8')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int32
#   interfaces[0].proxy_gids: unique_values  0
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('cf2c5845-42ca-4497-ab09-b1d0da0a55ad')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[np.int64(0), np.int64(1)]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 66
# )
# 2026-08-04 13:20:01,007 - INFO - examples.example -
# TVBtoANNarchyInterfaces (
#   title .................................. 'TVBtoANNarchyInterfaces gid: cf2c5845-42ca-4497-ab09-b1d0da0a55ad'
#   Type ................................... 'TVBtoANNarchyInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoANNarchyInterface gid: 3879ff63-1034-4b6d-ae93-24c5d45e7da8'
#   interfaces[0].Type ..................... 'TVBtoANNarchyInterface'
#   interfaces[0].proxy .................... ANNarchyTimedPoissonPopulationSet gid: 88e8c66d-52e4-4be1-b8c4-79b9e368f6fc
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: 0f3f3760-c68f-42bc-a640-94fe01eb2d0f
#   interfaces[0].transformer .............. LinearRate gid: d130b0b7-e724-4d77-9bc4-3352d5f7158f
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[np.int64(2), np.int64(67)]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[np.int64(0), np.int64(1)]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('3879ff63-1034-4b6d-ae93-24c5d45e7da8')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int32
#   interfaces[0].proxy_gids: unique_values  0
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('cf2c5845-42ca-4497-ab09-b1d0da0a55ad')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[np.int64(0), np.int64(1)]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 66
# )
#
# TVBtoANNarchyInterfaces (
#   title .................................. 'TVBtoANNarchyInterfaces gid: cf2c5845-42ca-4497-ab09-b1d0da0a55ad'
#   Type ................................... 'TVBtoANNarchyInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoANNarchyInterface gid: 3879ff63-1034-4b6d-ae93-24c5d45e7da8'
#   interfaces[0].Type ..................... 'TVBtoANNarchyInterface'
#   interfaces[0].proxy .................... ANNarchyTimedPoissonPopulationSet gid: 88e8c66d-52e4-4be1-b8c4-79b9e368f6fc
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: 0f3f3760-c68f-42bc-a640-94fe01eb2d0f
#   interfaces[0].transformer .............. LinearRate gid: d130b0b7-e724-4d77-9bc4-3352d5f7158f
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[np.int64(2), np.int64(67)]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[np.int64(0), np.int64(1)]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('3879ff63-1034-4b6d-ae93-24c5d45e7da8')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int32
#   interfaces[0].proxy_gids: unique_values  0
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('cf2c5845-42ca-4497-ab09-b1d0da0a55ad')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[np.int64(0), np.int64(1)]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 66
# )
# 2026-08-04 13:20:01,008 - INFO - examples.example -
# ANNarchyToTVBInterfaces (
#   title .................................. 'ANNarchyToTVBInterfaces gid: f51baed0-d182-4757-9058-89cd7053b487'
#   Type ................................... 'ANNarchyToTVBInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'ANNarchyToTVBInterface gid: 42c72a32-01bf-401f-a775-9e847b161063'
#   interfaces[0].Type ..................... 'ANNarchyToTVBInterface'
#   interfaces[0].proxy .................... ANNarchySpikeMonitorSet gid: bbbd6dbc-a047-490a-95c4-d2ccc2c6e43d
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: 0f3f3760-c68f-42bc-a640-94fe01eb2d0f
#   interfaces[0].transformer .............. ElephantSpikesHistogramRate gid: 9728d1b0-a07b-4236-afc2-a012a5a08197
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (2,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: values ....... [[np.int64(0), np.int64(1)]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].dt ....................... 0.1
#   interfaces[0].times .................... --------------------
#   interfaces[0].times: shape ............. (2,)
#   interfaces[0].times: dtype ............. int64
#   interfaces[0].times: values ............ [[np.int64(0), np.int64(1)]]
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[np.int64(0), np.int64(1)]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'SpikeMonitor'
#   interfaces[0].gid ...................... UUID('42c72a32-01bf-401f-a775-9e847b161063')
#   interfaces[0].number_of_proxy_nodes .... 2
#   interfaces[0].number_of_proxy_gids ..... 0
#   interfaces[0].proxy_gids ............... --------------------
#   shape .................................. (0,)
#   dtype .................................. float64
#   is empty ............................... True
#   interfaces[0].n_voi .................... 1
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('f51baed0-d182-4757-9058-89cd7053b487')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[np.int64(0), np.int64(1)]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 2
# )
# 2026-08-04 13:20:01,008 - INFO - examples.example -
# ANNarchyToTVBInterfaces (
#   title .................................. 'ANNarchyToTVBInterfaces gid: f51baed0-d182-4757-9058-89cd7053b487'
#   Type ................................... 'ANNarchyToTVBInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'ANNarchyToTVBInterface gid: 42c72a32-01bf-401f-a775-9e847b161063'
#   interfaces[0].Type ..................... 'ANNarchyToTVBInterface'
#   interfaces[0].proxy .................... ANNarchySpikeMonitorSet gid: bbbd6dbc-a047-490a-95c4-d2ccc2c6e43d
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: 0f3f3760-c68f-42bc-a640-94fe01eb2d0f
#   interfaces[0].transformer .............. ElephantSpikesHistogramRate gid: 9728d1b0-a07b-4236-afc2-a012a5a08197
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (2,)
#   interfaces[0].proxy_inds: dtype ........ int64
# ...
#   spikeNet_app.tvb_cosimulator_serialized[coupling.gid]: dtype ..................... object
#   spikeNet_app.tvb_cosimulator_serialized[coupling.gid]: values .................... 23506261-31a2-40e7-81b7-35c32751f791
#   spikeNet_app.interfaces_builder .................................................. None
#   spikeNet_app.logger .............................................................. <Logger examples.example (DEBUG)>
#   spikeNet_app.default_tvb_serial_cosim_path ....................................... '/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/DefaultExcIO_RATE_bidir/config/tvb_serial_cosimulator.pkl'
#   spikeNet_app.gid ................................................................. UUID('29a1364f-0391-4fac-99db-82f351f3da27')
#   spikeNet_app.spiking_cosimulator ................................................. <module 'ANNarchy' from '/home/docker/venv/lib/python3.12/site-packages/ANNarchy/__init__.py'>
#   logger ........................................................................... <Logger examples.example (DEBUG)>
#   default_tvb_serial_cosim_path .................................................... '/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/DefaultExcIO_RATE_bidir/config/tvb_serial_cosimulator.pkl'
#   gid .............................................................................. UUID('a626b8b0-e949-4097-a32b-e080233ba6d4')
# )
# None
#
#
# Simulating...
# 2026-08-04 13:20:01,030 - INFO - examples.example -
# Simulating for 36ms with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:01,030 - INFO - examples.example -
# Simulating for 36ms with App TVBANNarchySerialOrchestrator...
#
# Simulating for 36ms with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:01,030 - INFO - examples.example -
# Configuring simulation with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:01,030 - INFO - examples.example -
# Configuring simulation with App TVBANNarchySerialOrchestrator...
#
# Configuring simulation with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:01,030 - INFO - examples.example -
# Configuring simulation with App TVBSerialApp...
# 2026-08-04 13:20:01,030 - INFO - examples.example -
# Configuring simulation with App TVBSerialApp...
#
# Configuring simulation with App TVBSerialApp...
# 2026-08-04 13:20:01,031 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-04 13:20:01,031 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2026-08-04 13:20:01,031 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2026-08-04 13:20:01,037 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2026-08-04 13:20:01,037 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2026-08-04 13:20:01,037 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# 2026-08-04 13:20:01,043 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: fbc4d251-1c20-4fef-a4d6-e4e3741703ae'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: 18e5b40d-ae8c-46c2-a7b7-2e63a2585c43
#   output_interfaces ................... TVBtoANNarchyInterfaces gid: cf2c5845-42ca-4497-ab09-b1d0da0a55ad
#   input_interfaces .................... ANNarchyToTVBInterfaces gid: f51baed0-d182-4757-9058-89cd7053b487
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (66,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: unique_values ....... [[np.int64(2), np.int64(67)]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (1,)
#   voi: dtype .......................... int64
#   voi: values ......................... 0
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[np.int64(0), np.int64(1)]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. RawCosim(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 028a438e-0396-47e4-9605-f9d9cd2e6175
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 23506261-31a2-40e7-81b7-35c32751f791
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: bcc113c0-e343-43bd-8012-0abdcec44ef5
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('fbc4d251-1c20-4fef-a4d6-e4e3741703ae')
# )
# 2026-08-04 13:20:01,043 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: fbc4d251-1c20-4fef-a4d6-e4e3741703ae'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: 18e5b40d-ae8c-46c2-a7b7-2e63a2585c43
#   output_interfaces ................... TVBtoANNarchyInterfaces gid: cf2c5845-42ca-4497-ab09-b1d0da0a55ad
#   input_interfaces .................... ANNarchyToTVBInterfaces gid: f51baed0-d182-4757-9058-89cd7053b487
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (66,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: unique_values ....... [[np.int64(2), np.int64(67)]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (1,)
#   voi: dtype .......................... int64
#   voi: values ......................... 0
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[np.int64(0), np.int64(1)]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. RawCosim(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 028a438e-0396-47e4-9605-f9d9cd2e6175
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 23506261-31a2-40e7-81b7-35c32751f791
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: bcc113c0-e343-43bd-8012-0abdcec44ef5
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('fbc4d251-1c20-4fef-a4d6-e4e3741703ae')
# )
#
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: fbc4d251-1c20-4fef-a4d6-e4e3741703ae'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: 18e5b40d-ae8c-46c2-a7b7-2e63a2585c43
#   output_interfaces ................... TVBtoANNarchyInterfaces gid: cf2c5845-42ca-4497-ab09-b1d0da0a55ad
#   input_interfaces .................... ANNarchyToTVBInterfaces gid: f51baed0-d182-4757-9058-89cd7053b487
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (66,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: unique_values ....... [[np.int64(2), np.int64(67)]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (1,)
#   voi: dtype .......................... int64
#   voi: values ......................... 0
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[np.int64(0), np.int64(1)]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. RawCosim(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 028a438e-0396-47e4-9605-f9d9cd2e6175
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 23506261-31a2-40e7-81b7-35c32751f791
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: bcc113c0-e343-43bd-8012-0abdcec44ef5
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('fbc4d251-1c20-4fef-a4d6-e4e3741703ae')
# )
# 2026-08-04 13:20:01,043 - INFO - examples.example -
# Configuring simulation with App ANNarchySerialApp...
# 2026-08-04 13:20:01,043 - INFO - examples.example -
# Configuring simulation with App ANNarchySerialApp...
#
# Configuring simulation with App ANNarchySerialApp...
# 2026-08-04 13:20:01,297 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-04 13:20:01,297 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
#
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-04 13:20:01,301 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - No or all NaN valued cosimulator updates at time step 0!
# 2026-08-04 13:20:01,301 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.016 seconds
# 2026-08-04 13:20:01,301 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2026-08-04 13:20:01,301 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 22031
# 2026-08-04 13:20:01,306 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:20:01,309 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...9.091% completed in 0.00859308 sec!
# ...9.091% completed in 0.00859308 sec!2026-08-04 13:20:01,316 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:20:01,319 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...18.182% completed in 0.0186727 sec!
# ...18.182% completed in 0.0186727 sec!2026-08-04 13:20:01,327 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:20:01,330 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...27.273% completed in 0.0293558 sec!
# ...27.273% completed in 0.0293558 sec!2026-08-04 13:20:01,337 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:20:01,340 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...36.364% completed in 0.039331 sec!
# ...36.364% completed in 0.039331 sec!2026-08-04 13:20:01,346 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:20:01,350 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...45.455% completed in 0.0491228 sec!
# ...45.455% completed in 0.0491228 sec!2026-08-04 13:20:01,357 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:20:01,361 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...54.545% completed in 0.0598905 sec!
# ...54.545% completed in 0.0598905 sec!2026-08-04 13:20:01,367 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:20:01,371 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...63.636% completed in 0.0698261 sec!
# ...63.636% completed in 0.0698261 sec!2026-08-04 13:20:01,378 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:20:01,381 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...72.727% completed in 0.080554 sec!
# ...72.727% completed in 0.080554 sec!2026-08-04 13:20:01,388 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:20:01,391 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...81.818% completed in 0.0904016 sec!
# ...81.818% completed in 0.0904016 sec!2026-08-04 13:20:01,398 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:20:01,402 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...90.909% completed in 0.101053 sec!
# ...90.909% completed in 0.101053 sec!2026-08-04 13:20:01,409 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:20:01,411 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...100.000% completed in 0.110648 sec!
# ...100.000% completed in 0.110648 sec!
# Simulated in 0.381686 secs!
#
# 2026-08-04 13:20:01,412 - INFO - examples.example -
# Cleaning up App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:01,412 - INFO - examples.example -
# Cleaning up App TVBANNarchySerialOrchestrator...
#
# Cleaning up App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:01,412 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-04 13:20:01,412 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
#
# Cleaning up App TVBSerialApp...
# 2026-08-04 13:20:01,412 - INFO - examples.example -
# Cleaning up App ANNarchySerialApp...
# 2026-08-04 13:20:01,412 - INFO - examples.example -
# Cleaning up App ANNarchySerialApp...
#
# Cleaning up App ANNarchySerialApp...
# 2026-08-04 13:20:01,412 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-04 13:20:01,412 - INFO - examples.example -
# Stopping App TVBSerialApp...
#
# Stopping App TVBSerialApp...
# 2026-08-04 13:20:01,412 - INFO - examples.example -
# Stopping App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:01,412 - INFO - examples.example -
# Stopping App TVBANNarchySerialOrchestrator...
#
# Stopping App TVBANNarchySerialOrchestrator...
#
# Success in 1.07496 sec!
# ******************************************************
#
# {'TestDefaultSPIKES': True}

# %%
! python ../../../tvb_multiscale/tests/tvb_annarchy/test_models.py 2
# Out:
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
# /home/docker/venv/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# ANNarchy 5.0 (5.0.3) on linux (posix).
# 2026-08-04 13:20:06,963 - WARNING - tvb.simulator.plot.tools - You need mpl_toolkits for some axe related features
#
#
# Testing model 2
# ******************************************************
# ******************************************************
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
#
# ----------------------------------------------------------------------------------------------------
# Find results in /home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/WilsonCowan_RATE_bidir/res !
# ----------------------------------------------------------------------------------------------------
# 2026-08-04 13:20:07,985 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:07,985 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
#
# Starting App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:07,987 - INFO - examples.example -
# Starting App TVBSerialApp...
# 2026-08-04 13:20:07,987 - INFO - examples.example -
# Starting App TVBSerialApp...
#
# Starting App TVBSerialApp...
# 2026-08-04 13:20:07,988 - INFO - examples.example -
# Setting TVB LIBRARY_PROFILE...
# 2026-08-04 13:20:07,988 - INFO - examples.example -
# Setting TVB LIBRARY_PROFILE...
#
# Setting TVB LIBRARY_PROFILE...
# 2026-08-04 13:20:08,028 - INFO - examples.example -
# Starting App ANNarchySerialApp...
# 2026-08-04 13:20:08,028 - INFO - examples.example -
# Starting App ANNarchySerialApp...
#
# Starting App ANNarchySerialApp...
# 2026-08-04 13:20:08,028 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Loading an ANNarchy instance...
# 2026-08-04 13:20:08,028 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Loading an ANNarchy instance...
# 2026-08-04 13:20:08,028 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Cleaning ANNarchy compilation directory, if any...
# 2026-08-04 13:20:08,028 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Cleaning ANNarchy compilation directory, if any...
#
#
# Configuring...
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
#
# Done! in 0.000107 min
#
#
#
# Building...
# 2026-08-04 13:20:08,035 - INFO - examples.example -
# Building with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:08,035 - INFO - examples.example -
# Building with App TVBANNarchySerialOrchestrator...
#
# Building with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:08,035 - INFO - examples.example -
# Building cosimulators with TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:08,035 - INFO - examples.example -
# Building cosimulators with TVBANNarchySerialOrchestrator...
#
# Building cosimulators with TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:08,035 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
# 2026-08-04 13:20:08,035 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
#
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
# 2026-08-04 13:20:08,037 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-04 13:20:08,037 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2026-08-04 13:20:08,037 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2026-08-04 13:20:08,047 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2026-08-04 13:20:08,047 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2026-08-04 13:20:08,048 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# 2026-08-04 13:20:08,053 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: ff1f2e8d-c970-49cb-99f5-9cd0a21a2e3d'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... WilsonCowan gid: b3d09d0c-13fa-4987-a08a-a37ded77d6ac
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: d4ea6dc1-c186-4349-b99b-9ecf5a1197c5
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 1f8a11f4-2f8e-4a07-ba4f-4a2bb3c1bd82
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: cf3e414d-dec7-477b-86ad-97ef8a3308d7
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('ff1f2e8d-c970-49cb-99f5-9cd0a21a2e3d')
# )
# 2026-08-04 13:20:08,053 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: ff1f2e8d-c970-49cb-99f5-9cd0a21a2e3d'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... WilsonCowan gid: b3d09d0c-13fa-4987-a08a-a37ded77d6ac
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: d4ea6dc1-c186-4349-b99b-9ecf5a1197c5
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 1f8a11f4-2f8e-4a07-ba4f-4a2bb3c1bd82
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: cf3e414d-dec7-477b-86ad-97ef8a3308d7
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('ff1f2e8d-c970-49cb-99f5-9cd0a21a2e3d')
# )
#
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: ff1f2e8d-c970-49cb-99f5-9cd0a21a2e3d'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... WilsonCowan gid: b3d09d0c-13fa-4987-a08a-a37ded77d6ac
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: d4ea6dc1-c186-4349-b99b-9ecf5a1197c5
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 1f8a11f4-2f8e-4a07-ba4f-4a2bb3c1bd82
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: cf3e414d-dec7-477b-86ad-97ef8a3308d7
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('ff1f2e8d-c970-49cb-99f5-9cd0a21a2e3d')
# )
# 2026-08-04 13:20:08,054 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-04 13:20:08,054 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2026-08-04 13:20:08,054 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2026-08-04 13:20:08,054 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2026-08-04 13:20:08,063 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2026-08-04 13:20:08,063 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2026-08-04 13:20:08,064 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2026-08-04 13:20:08,070 - INFO - examples.example -
# Building Spiking Network with builder WilsonCowanBuilder of App ANNarchySerialApp...
# 2026-08-04 13:20:08,070 - INFO - examples.example -
# Building Spiking Network with builder WilsonCowanBuilder of App ANNarchySerialApp...
#
# Building Spiking Network with builder WilsonCowanBuilder of App ANNarchySerialApp...
# 2026-08-04 13:20:08,070 - INFO - examples.example - Loading an ANNarchy instance...
# 2026-08-04 13:20:08,070 - INFO - examples.example - Loading an ANNarchy instance...
# 2026-08-04 13:20:08,070 - INFO - examples.example - Cleaning ANNarchy compilation directory, if any...
# 2026-08-04 13:20:08,070 - INFO - examples.example - Cleaning ANNarchy compilation directory, if any...
# 2026-08-04 13:20:08,071 - INFO - examples.example - Configuring spiking network builder...
# 2026-08-04 13:20:08,071 - INFO - examples.example - Configuring spiking network builder...
# 2026-08-04 13:20:08,071 - INFO - examples.example - Configuring populations...
# 2026-08-04 13:20:08,071 - INFO - examples.example - Configuring populations...
# 2026-08-04 13:20:08,071 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2026-08-04 13:20:08,071 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2026-08-04 13:20:08,071 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2026-08-04 13:20:08,071 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2026-08-04 13:20:08,071 - INFO - examples.example - Configuring output devices, if any...
# 2026-08-04 13:20:08,071 - INFO - examples.example - Configuring output devices, if any...
# 2026-08-04 13:20:08,072 - INFO - examples.example - Configuring input devices, if any...
# 2026-08-04 13:20:08,072 - INFO - examples.example - Configuring input devices, if any...
# 2026-08-04 13:20:08,072 - INFO - examples.example - Generating spiking brain...
# 2026-08-04 13:20:08,072 - INFO - examples.example - Generating spiking brain...
# 2026-08-04 13:20:08,072 - INFO - examples.example - Generating spiking brain regions...
# 2026-08-04 13:20:08,072 - INFO - examples.example - Generating spiking brain regions...
# 2026-08-04 13:20:08,072 - INFO - examples.example - Generating spiking region node: bankssts_L...
# 2026-08-04 13:20:08,072 - INFO - examples.example - Generating spiking region node: bankssts_L...
# 2026-08-04 13:20:08,073 - INFO - examples.example - Generating population: E...
# 2026-08-04 13:20:08,073 - INFO - examples.example - Generating population: E...
# 2026-08-04 13:20:08,218 - INFO - examples.example - Generating population: I...
# 2026-08-04 13:20:08,218 - INFO - examples.example - Generating population: I...
# 2026-08-04 13:20:08,255 - INFO - examples.example - Generating spiking region node: bankssts_R...
# 2026-08-04 13:20:08,255 - INFO - examples.example - Generating spiking region node: bankssts_R...
# 2026-08-04 13:20:08,255 - INFO - examples.example - Generating population: E...
# 2026-08-04 13:20:08,255 - INFO - examples.example - Generating population: E...
# 2026-08-04 13:20:08,291 - INFO - examples.example - Generating population: I...
# 2026-08-04 13:20:08,291 - INFO - examples.example - Generating population: I...
# 2026-08-04 13:20:08,327 - INFO - examples.example - Connecting populations within spiking brain regions...
# 2026-08-04 13:20:08,327 - INFO - examples.example - Connecting populations within spiking brain regions...
# 2026-08-04 13:20:08,328 - INFO - examples.example - Connecting E -> E populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:20:08,328 - INFO - examples.example - Connecting E -> E populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:20:08,328 - INFO - examples.example - Connecting E -> I populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:20:08,328 - INFO - examples.example - Connecting E -> I populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:20:08,329 - INFO - examples.example - Connecting I -> E populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:20:08,329 - INFO - examples.example - Connecting I -> E populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:20:08,329 - INFO - examples.example - Connecting I -> I populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:20:08,329 - INFO - examples.example - Connecting I -> I populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:20:08,329 - INFO - examples.example - Connecting populations among spiking brain regions...
# 2026-08-04 13:20:08,329 - INFO - examples.example - Connecting populations among spiking brain regions...
# 2026-08-04 13:20:08,329 - INFO - examples.example - Connecting for 0 -> 1 spiking region nodes ...
# 2026-08-04 13:20:08,329 - INFO - examples.example - Connecting for 0 -> 1 spiking region nodes ...
# 2026-08-04 13:20:08,330 - INFO - examples.example - E -> E populations ...
# 2026-08-04 13:20:08,330 - INFO - examples.example - E -> E populations ...
# 2026-08-04 13:20:08,330 - INFO - examples.example - E -> I populations ...
# 2026-08-04 13:20:08,330 - INFO - examples.example - E -> I populations ...
# 2026-08-04 13:20:08,330 - INFO - examples.example - Connecting for 1 -> 0 spiking region nodes ...
# 2026-08-04 13:20:08,330 - INFO - examples.example - Connecting for 1 -> 0 spiking region nodes ...
# 2026-08-04 13:20:08,330 - INFO - examples.example - E -> E populations ...
# 2026-08-04 13:20:08,330 - INFO - examples.example - E -> E populations ...
# 2026-08-04 13:20:08,330 - INFO - examples.example - E -> I populations ...
# 2026-08-04 13:20:08,330 - INFO - examples.example - E -> I populations ...
# 2026-08-04 13:20:08,331 - INFO - examples.example - Generating and connecting output devices, if any...
# 2026-08-04 13:20:08,331 - INFO - examples.example - Generating and connecting output devices, if any...
# 2026-08-04 13:20:08,331 - INFO - examples.example - Generating and connecting ['E', 'I'] -> ['E', 'I'] device set of model SpikeMonitor
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:20:08,331 - INFO - examples.example - Generating and connecting ['E', 'I'] -> ['E', 'I'] device set of model SpikeMonitor
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:20:08,332 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E created!
# 2026-08-04 13:20:08,332 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E created!
# 2026-08-04 13:20:08,333 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for I created!
# 2026-08-04 13:20:08,333 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for I created!
# 2026-08-04 13:20:08,334 - INFO - examples.example - Generating and connecting ['Excitatory', 'Inhibitory'] -> ['E', 'I'] device set of model Monitor
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:20:08,334 - INFO - examples.example - Generating and connecting ['Excitatory', 'Inhibitory'] -> ['E', 'I'] device set of model Monitor
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:20:08,334 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Excitatory created!
# 2026-08-04 13:20:08,334 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Excitatory created!
# 2026-08-04 13:20:08,336 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Inhibitory created!
# 2026-08-04 13:20:08,336 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Inhibitory created!
# 2026-08-04 13:20:08,338 - INFO - examples.example - Generating and connecting input devices, if any...
# 2026-08-04 13:20:08,338 - INFO - examples.example - Generating and connecting input devices, if any...
# 2026-08-04 13:20:08,338 - INFO - examples.example - Generating and connecting ['Stimulus'] -> [['E']] device set of model PoissonPopulation
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:20:08,338 - INFO - examples.example - Generating and connecting ['Stimulus'] -> [['E']] device set of model PoissonPopulation
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:20:08,339 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model PoissonPopulation for Stimulus created!
# 2026-08-04 13:20:08,339 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model PoissonPopulation for Stimulus created!
# 2026-08-04 13:20:08,348 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:20:08,348 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:20:08,348 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:20:08,348 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:20:08,348 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:20:08,348 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:20:08,348 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:20:08,348 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:20:08,348 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# ANNarchyNetwork (
#   title ....................................... 'ANNarchyNetwork gid: c32b591d-660b-456d-916d-99f34cafed36'
#   Type ........................................ 'ANNarchyNetwork'
#   annarchy_network ............................ <ANNarchy.core.Network.Network object at 0xffff65102330>
#   config ...................................... '--------------------'
#   config.title ................................ 'Config gid: d36f6fe3-2dae-48b9-875e-be9780755dad'
#   config.Type ................................. 'Config'
#   config.gid .................................. UUID('d36f6fe3-2dae-48b9-875e-be9780755dad')
#   brain_regions ............................... '--------------------'
#   brain_regions.title ......................... 'ANNarchyBrain gid: bbe3ffa4-bcd2-4c5b-81f9-09c9f9d404b6'
#   brain_regions.Type .......................... 'ANNarchyBrain'
#   brain_regions.gid ........................... UUID('bbe3ffa4-bcd2-4c5b-81f9-09c9f9d404b6')
#   brain_regions.label ......................... ''
#   brain_regions.size .......................... 2
#   brain_regions.Regions ....................... --------------------
#   brain_regions.Regions: shape ................ (2,)
#   brain_regions.Regions: dtype ................ <U10
#   brain_regions.Regions: values ............... ['bankssts_L' 'bankssts_R']
#   brain_regions.bankssts_L .................... '--------------------'
#   brain_regions[bankssts_L].title ............. 'ANNarchyRegionNode gid: 7f8eb105-5ad2-436d-90f8-b57c8abd0e55'
#   brain_regions[bankssts_L].Type .............. 'ANNarchyRegionNode'
#   brain_regions[bankssts_L].gid ............... UUID('7f8eb105-5ad2-436d-90f8-b57c8abd0e55')
#   brain_regions[bankssts_L].label ............. 'bankssts_L'
#   brain_regions[bankssts_L].size .............. 2
#   brain_regions[bankssts_L].Populations ....... --------------------
#   brain_regions[bankssts_L].Populations: shape  (2,)
#   brain_regions[bankssts_L].Populations: dtype  <U1
#   brain_regions[bankssts_L].Populations: values  ['E' 'I']
#   brain_regions.bankssts_R .................... '--------------------'
#   brain_regions[bankssts_R].title ............. 'ANNarchyRegionNode gid: 6faa74d1-24e7-4c60-8f1b-d73e98778bad'
#   brain_regions[bankssts_R].Type .............. 'ANNarchyRegionNode'
#   brain_regions[bankssts_R].gid ............... UUID('6faa74d1-24e7-4c60-8f1b-d73e98778bad')
#   brain_regions[bankssts_R].label ............. 'bankssts_R'
#   brain_regions[bankssts_R].size .............. 2
#   brain_regions[bankssts_R].Populations ....... --------------------
#   brain_regions[bankssts_R].Populations: shape  (2,)
#   brain_regions[bankssts_R].Populations: dtype  <U1
#   brain_regions[bankssts_R].Populations: values  ['E' 'I']
#   network_path ................................ ''
#   logger ...................................... <Logger tvb-multiscale (DEBUG)>
#   output_devices .............................. '--------------------'
#   output_devices.title ........................ 'DeviceSets gid: 2daed495-a818-4920-afba-8e58f9c96102'
#   output_devices.Type ......................... 'DeviceSets'
#   output_devices.gid .......................... UUID('2daed495-a818-4920-afba-8e58f9c96102')
#   output_devices.label ........................ 'output_devices'
#   output_devices.size ......................... 4
#   output_devices.DeviceSets ................... --------------------
#   output_devices.DeviceSets: shape ............ (4,)
#   output_devices.DeviceSets: dtype ............ <U10
#   output_devices.DeviceSets: values ........... ['E' 'I' 'Excitatory' 'Inhibitory']
#   output_devices.E ............................ '--------------------'
#   output_devices[E].title ..................... 'DeviceSet gid: bfbdb167-976e-4939-97b8-c859824eca30'
#   output_devices[E].Type ...................... 'DeviceSet'
#   output_devices[E].model ..................... 'SpikeMonitor'
#   output_devices[E].gid ....................... UUID('bfbdb167-976e-4939-97b8-c859824eca30')
#   output_devices[E].label ..................... 'E'
#   output_devices[E].size ...................... 2
#   output_devices[E].Devices ................... --------------------
#   output_devices[E].Devices: shape ............ (2,)
#   output_devices[E].Devices: dtype ............ <U10
#   output_devices[E].Devices: values ........... ['bankssts_L' 'bankssts_R']
#   output_devices.I ............................ '--------------------'
#   output_devices[I].title ..................... 'DeviceSet gid: 5335d0ce-8bb3-4232-b852-03a0415dadf3'
#   output_devices[I].Type ...................... 'DeviceSet'
#   output_devices[I].model ..................... 'SpikeMonitor'
#   output_devices[I].gid ....................... UUID('5335d0ce-8bb3-4232-b852-03a0415dadf3')
#   output_devices[I].label ..................... 'I'
#   output_devices[I].size ...................... 2
#   output_devices[I].Devices ................... --------------------
#   output_devices[I].Devices: shape ............ (2,)
#   output_devices[I].Devices: dtype ............ <U10
#   output_devices[I].Devices: values ........... ['bankssts_L' 'bankssts_R']
#   output_devices.Excitatory ................... '--------------------'
#   output_devices[Excitatory].title ............ 'DeviceSet gid: 05ceee8d-df19-455e-af59-a793ca906d2b'
#   output_devices[Excitatory].Type ............. 'DeviceSet'
#   output_devices[Excitatory].model ............ 'Monitor'
#   output_devices[Excitatory].gid .............. UUID('05ceee8d-df19-455e-af59-a793ca906d2b')
#   output_devices[Excitatory].label ............ 'Excitatory'
#   output_devices[Excitatory].size ............. 2
#   output_devices[Excitatory].Devices .......... --------------------
#   output_devices[Excitatory].Devices: shape ... (2,)
#   output_devices[Excitatory].Devices: dtype ... <U10
#   output_devices[Excitatory].Devices: values .. ['bankssts_L' 'bankssts_R']
#   output_devices.Inhibitory ................... '--------------------'
#   output_devices[Inhibitory].title ............ 'DeviceSet gid: 409c7f07-4de0-43e1-9c95-2627f0d8b5d2'
#   output_devices[Inhibitory].Type ............. 'DeviceSet'
#   output_devices[Inhibitory].model ............ 'Monitor'
#   output_devices[Inhibitory].gid .............. UUID('409c7f07-4de0-43e1-9c95-2627f0d8b5d2')
#   output_devices[Inhibitory].label ............ 'Inhibitory'
#   output_devices[Inhibitory].size ............. 2
#   output_devices[Inhibitory].Devices .......... --------------------
#   output_devices[Inhibitory].Devices: shape ... (2,)
#   output_devices[Inhibitory].Devices: dtype ... <U10
#   output_devices[Inhibitory].Devices: values .. ['bankssts_L' 'bankssts_R']
#   input_devices ............................... '--------------------'
#   input_devices.title ......................... 'DeviceSets gid: b6df40bf-95c6-4322-8b6f-485dd9ded7cd'
#   input_devices.Type .......................... 'DeviceSets'
#   input_devices.gid ........................... UUID('b6df40bf-95c6-4322-8b6f-485dd9ded7cd')
#   input_devices.label ......................... 'input_devices'
#   input_devices.size .......................... 1
#   input_devices.DeviceSets .................... --------------------
#   input_devices.DeviceSets: shape ............. (1,)
#   input_devices.DeviceSets: dtype ............. <U8
#   input_devices.DeviceSets: values ............ Stimulus
#   input_devices.Stimulus ...................... '--------------------'
#   input_devices[Stimulus].title ............... 'DeviceSet gid: 5696b7ea-a88f-48b5-b16b-f739c8de8db4'
#   input_devices[Stimulus].Type ................ 'DeviceSet'
#   input_devices[Stimulus].model ............... 'PoissonPopulation'
#   input_devices[Stimulus].gid ................. UUID('5696b7ea-a88f-48b5-b16b-f739c8de8db4')
#   input_devices[Stimulus].label ............... 'Stimulus'
#   input_devices[Stimulus].size ................ 2
#   input_devices[Stimulus].Devices ............. --------------------
#   input_devices[Stimulus].Devices: shape ...... (2,)
#   input_devices[Stimulus].Devices: dtype ...... <U10
#   input_devices[Stimulus].Devices: values ..... ['bankssts_L' 'bankssts_R']
#   output_proxies .............................. '--------------------'
#   output_proxies.title ........................ 'DeviceSets gid: 2c802cff-14f6-425c-adb0-64cab59aea77'
#   output_proxies.Type ......................... 'DeviceSets'
#   output_proxies.gid .......................... UUID('2c802cff-14f6-425c-adb0-64cab59aea77')
#   output_proxies.label ........................ 'output_proxies'
#   output_proxies.size ......................... 0
#   output_proxies.DeviceSets ................... --------------------
#   shape ....................................... (0,)
#   dtype ....................................... float64
#   is empty .................................... True
#   input_proxies ............................... '--------------------'
#   input_proxies.title ......................... 'DeviceSets gid: a84b8f56-9e67-4aed-9f9d-c3125afe19ec'
#   input_proxies.Type .......................... 'DeviceSets'
#   input_proxies.gid ........................... UUID('a84b8f56-9e67-4aed-9f9d-c3125afe19ec')
#   input_proxies.label ......................... ''
#   input_proxies.size .......................... 0
#   input_proxies.DeviceSets .................... --------------------
#   gid ......................................... UUID('c32b591d-660b-456d-916d-99f34cafed36')
# )
# 2026-08-04 13:20:08,350 - INFO - examples.example -
# Building interfaces with Orchestrator TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:08,350 - INFO - examples.example -
# Building interfaces with Orchestrator TVBANNarchySerialOrchestrator...
#
# Building interfaces with Orchestrator TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:08,351 - INFO - examples.example -
# Building interfaces' with builder TVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2026-08-04 13:20:08,351 - INFO - examples.example -
# Building interfaces' with builder TVBANNarchyInterfaceBuilder of App TVBSerialApp...
#
# Building interfaces' with builder TVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2026-08-04 13:20:08,351 - INFO - examples.example -
# Configuring interfaces' builder WilsonCowanTVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2026-08-04 13:20:08,351 - INFO - examples.example -
# Configuring interfaces' builder WilsonCowanTVBANNarchyInterfaceBuilder of App TVBSerialApp...
#
# Configuring interfaces' builder WilsonCowanTVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2026-08-04 13:20:08,351 - INFO - examples.example -
# Configuring default interfaces...
# 2026-08-04 13:20:08,351 - INFO - examples.example -
# Configuring default interfaces...
#
# Configuring default interfaces...
# 2026-08-04 13:20:08,353 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model TimedPoissonPopulation for ['E']->E created!
# 2026-08-04 13:20:08,353 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model TimedPoissonPopulation for ['E']->E created!
# 2026-08-04 13:20:08,617 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E->['E'] created!
# 2026-08-04 13:20:08,617 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E->['E'] created!
# 2026-08-04 13:20:08,620 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for I->['I'] created!
# 2026-08-04 13:20:08,620 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for I->['I'] created!
# 2026-08-04 13:20:08,621 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-04 13:20:08,622 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2026-08-04 13:20:08,622 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2026-08-04 13:20:08,622 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2026-08-04 13:20:08,631 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2026-08-04 13:20:08,631 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2026-08-04 13:20:08,632 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2026-08-04 13:20:08,641 - INFO - examples.example -
# TVBtoANNarchyInterfaces (
#   title .................................. 'TVBtoANNarchyInterfaces gid: 6c13c506-830c-4b75-9edb-a91f336c62d5'
#   Type ................................... 'TVBtoANNarchyInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoANNarchyInterface gid: 490c11d5-6e29-4ab5-bf6e-9840f30e924b'
#   interfaces[0].Type ..................... 'TVBtoANNarchyInterface'
#   interfaces[0].proxy .................... ANNarchyTimedPoissonPopulationSet gid: d3f4f308-8832-4ffc-9e71-97caf8b53c2f
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: c32b591d-660b-456d-916d-99f34cafed36
#   interfaces[0].transformer .............. LinearRate gid: b9c294a4-70fb-42d3-9388-ddb382832094
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[np.int64(2), np.int64(67)]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... E
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[np.int64(0), np.int64(1)]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('490c11d5-6e29-4ab5-bf6e-9840f30e924b')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int32
#   interfaces[0].proxy_gids: unique_values  0
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('6c13c506-830c-4b75-9edb-a91f336c62d5')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[np.int64(0), np.int64(1)]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... E
#   number_of_proxy_nodes .................. 66
# )
# 2026-08-04 13:20:08,641 - INFO - examples.example -
# TVBtoANNarchyInterfaces (
#   title .................................. 'TVBtoANNarchyInterfaces gid: 6c13c506-830c-4b75-9edb-a91f336c62d5'
#   Type ................................... 'TVBtoANNarchyInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoANNarchyInterface gid: 490c11d5-6e29-4ab5-bf6e-9840f30e924b'
#   interfaces[0].Type ..................... 'TVBtoANNarchyInterface'
#   interfaces[0].proxy .................... ANNarchyTimedPoissonPopulationSet gid: d3f4f308-8832-4ffc-9e71-97caf8b53c2f
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: c32b591d-660b-456d-916d-99f34cafed36
#   interfaces[0].transformer .............. LinearRate gid: b9c294a4-70fb-42d3-9388-ddb382832094
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[np.int64(2), np.int64(67)]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... E
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[np.int64(0), np.int64(1)]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('490c11d5-6e29-4ab5-bf6e-9840f30e924b')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int32
#   interfaces[0].proxy_gids: unique_values  0
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('6c13c506-830c-4b75-9edb-a91f336c62d5')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[np.int64(0), np.int64(1)]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... E
#   number_of_proxy_nodes .................. 66
# )
#
# TVBtoANNarchyInterfaces (
#   title .................................. 'TVBtoANNarchyInterfaces gid: 6c13c506-830c-4b75-9edb-a91f336c62d5'
#   Type ................................... 'TVBtoANNarchyInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoANNarchyInterface gid: 490c11d5-6e29-4ab5-bf6e-9840f30e924b'
#   interfaces[0].Type ..................... 'TVBtoANNarchyInterface'
#   interfaces[0].proxy .................... ANNarchyTimedPoissonPopulationSet gid: d3f4f308-8832-4ffc-9e71-97caf8b53c2f
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: c32b591d-660b-456d-916d-99f34cafed36
#   interfaces[0].transformer .............. LinearRate gid: b9c294a4-70fb-42d3-9388-ddb382832094
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[np.int64(2), np.int64(67)]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... E
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[np.int64(0), np.int64(1)]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('490c11d5-6e29-4ab5-bf6e-9840f30e924b')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int32
#   interfaces[0].proxy_gids: unique_values  0
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('6c13c506-830c-4b75-9edb-a91f336c62d5')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[np.int64(0), np.int64(1)]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... E
#   number_of_proxy_nodes .................. 66
# )
# 2026-08-04 13:20:08,642 - INFO - examples.example -
# ANNarchyToTVBInterfaces (
#   title .................................. 'ANNarchyToTVBInterfaces gid: 62c0e052-3989-4fc9-b4f6-e0a846f6f6a5'
#   Type ................................... 'ANNarchyToTVBInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'ANNarchyToTVBInterface gid: 76eada9a-83e8-4e57-a632-b0b5e44b6b1c'
#   interfaces[0].Type ..................... 'ANNarchyToTVBInterface'
# ...
#   spikeNet_app.logger .............................................................. <Logger examples.example (DEBUG)>
#   spikeNet_app.default_tvb_serial_cosim_path ....................................... '/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/WilsonCowan_RATE_bidir/config/tvb_serial_cosimulator.pkl'
#   spikeNet_app.gid ................................................................. UUID('4492a52c-35ce-4dcf-af2e-f8958e3c693d')
#   spikeNet_app.spiking_cosimulator ................................................. <module 'ANNarchy' from '/home/docker/venv/lib/python3.12/site-packages/ANNarchy/__init__.py'>
#   logger ........................................................................... <Logger examples.example (DEBUG)>
#   default_tvb_serial_cosim_path .................................................... '/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/WilsonCowan_RATE_bidir/config/tvb_serial_cosimulator.pkl'
#   gid .............................................................................. UUID('f4fbab65-9699-4ce9-a65d-5f9f26b5c4f1')
# )
# None
#
#
# Simulating...
# 2026-08-04 13:20:08,665 - INFO - examples.example -
# Simulating for 36ms with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:08,665 - INFO - examples.example -
# Simulating for 36ms with App TVBANNarchySerialOrchestrator...
#
# Simulating for 36ms with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:08,665 - INFO - examples.example -
# Configuring simulation with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:08,665 - INFO - examples.example -
# Configuring simulation with App TVBANNarchySerialOrchestrator...
#
# Configuring simulation with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:20:08,665 - INFO - examples.example -
# Configuring simulation with App TVBSerialApp...
# 2026-08-04 13:20:08,665 - INFO - examples.example -
# Configuring simulation with App TVBSerialApp...
#
# Configuring simulation with App TVBSerialApp...
# 2026-08-04 13:20:08,666 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-04 13:20:08,666 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2026-08-04 13:20:08,666 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2026-08-04 13:20:08,666 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2026-08-04 13:20:08,675 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2026-08-04 13:20:08,675 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2026-08-04 13:20:08,677 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# 2026-08-04 13:20:08,683 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: ff1f2e8d-c970-49cb-99f5-9cd0a21a2e3d'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... WilsonCowan gid: b3d09d0c-13fa-4987-a08a-a37ded77d6ac
#   output_interfaces ................... TVBtoANNarchyInterfaces gid: 6c13c506-830c-4b75-9edb-a91f336c62d5
#   input_interfaces .................... ANNarchyToTVBInterfaces gid: 62c0e052-3989-4fc9-b4f6-e0a846f6f6a5
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (66,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: unique_values ....... [[np.int64(2), np.int64(67)]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (2,)
#   voi: dtype .......................... int64
#   voi: values ......................... [[np.int64(0), np.int64(1)]]
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[np.int64(0), np.int64(1)]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. RawCosim(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: d4ea6dc1-c186-4349-b99b-9ecf5a1197c5
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 1f8a11f4-2f8e-4a07-ba4f-4a2bb3c1bd82
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: cf3e414d-dec7-477b-86ad-97ef8a3308d7
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('ff1f2e8d-c970-49cb-99f5-9cd0a21a2e3d')
# )
# 2026-08-04 13:20:08,683 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: ff1f2e8d-c970-49cb-99f5-9cd0a21a2e3d'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... WilsonCowan gid: b3d09d0c-13fa-4987-a08a-a37ded77d6ac
#   output_interfaces ................... TVBtoANNarchyInterfaces gid: 6c13c506-830c-4b75-9edb-a91f336c62d5
#   input_interfaces .................... ANNarchyToTVBInterfaces gid: 62c0e052-3989-4fc9-b4f6-e0a846f6f6a5
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (66,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: unique_values ....... [[np.int64(2), np.int64(67)]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (2,)
#   voi: dtype .......................... int64
#   voi: values ......................... [[np.int64(0), np.int64(1)]]
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[np.int64(0), np.int64(1)]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. RawCosim(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: d4ea6dc1-c186-4349-b99b-9ecf5a1197c5
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 1f8a11f4-2f8e-4a07-ba4f-4a2bb3c1bd82
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: cf3e414d-dec7-477b-86ad-97ef8a3308d7
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('ff1f2e8d-c970-49cb-99f5-9cd0a21a2e3d')
# )
#
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: ff1f2e8d-c970-49cb-99f5-9cd0a21a2e3d'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... WilsonCowan gid: b3d09d0c-13fa-4987-a08a-a37ded77d6ac
#   output_interfaces ................... TVBtoANNarchyInterfaces gid: 6c13c506-830c-4b75-9edb-a91f336c62d5
#   input_interfaces .................... ANNarchyToTVBInterfaces gid: 62c0e052-3989-4fc9-b4f6-e0a846f6f6a5
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (66,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: unique_values ....... [[np.int64(2), np.int64(67)]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (2,)
#   voi: dtype .......................... int64
#   voi: values ......................... [[np.int64(0), np.int64(1)]]
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[np.int64(0), np.int64(1)]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. RawCosim(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: d4ea6dc1-c186-4349-b99b-9ecf5a1197c5
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 1f8a11f4-2f8e-4a07-ba4f-4a2bb3c1bd82
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: cf3e414d-dec7-477b-86ad-97ef8a3308d7
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('ff1f2e8d-c970-49cb-99f5-9cd0a21a2e3d')
# )
# 2026-08-04 13:20:08,683 - INFO - examples.example -
# Configuring simulation with App ANNarchySerialApp...
# 2026-08-04 13:20:08,683 - INFO - examples.example -
# Configuring simulation with App ANNarchySerialApp...
#
# Configuring simulation with App ANNarchySerialApp...
# Compiling network 1... OK
# 2026-08-04 13:24:12,584 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-04 13:24:12,584 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
#
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-04 13:24:12,589 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - No or all NaN valued cosimulator updates at time step 0!
# 2026-08-04 13:24:12,589 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.032 seconds
# 2026-08-04 13:24:12,589 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2026-08-04 13:24:12,589 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 44063
# 2026-08-04 13:24:12,597 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:12,600 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...9.091% completed in 0.0118518 sec!
# ...9.091% completed in 0.0118518 sec!2026-08-04 13:24:12,613 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:12,617 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...18.182% completed in 0.0285742 sec!
# ...18.182% completed in 0.0285742 sec!2026-08-04 13:24:12,777 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:12,781 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...27.273% completed in 0.192419 sec!
# ...27.273% completed in 0.192419 sec!2026-08-04 13:24:12,795 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:12,799 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...36.364% completed in 0.210485 sec!
# ...36.364% completed in 0.210485 sec!2026-08-04 13:24:12,812 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:12,816 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...45.455% completed in 0.227474 sec!
# ...45.455% completed in 0.227474 sec!2026-08-04 13:24:12,829 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:12,833 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...54.545% completed in 0.244899 sec!
# ...54.545% completed in 0.244899 sec!2026-08-04 13:24:12,859 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:12,863 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...63.636% completed in 0.274499 sec!
# ...63.636% completed in 0.274499 sec!2026-08-04 13:24:12,877 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:12,881 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...72.727% completed in 0.292147 sec!
# ...72.727% completed in 0.292147 sec!2026-08-04 13:24:12,895 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:12,899 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...81.818% completed in 0.310104 sec!
# ...81.818% completed in 0.310104 sec!2026-08-04 13:24:12,914 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:12,918 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...90.909% completed in 0.329553 sec!
# ...90.909% completed in 0.329553 sec!2026-08-04 13:24:12,932 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:12,935 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...100.000% completed in 0.346899 sec!
# ...100.000% completed in 0.346899 sec!
# Simulated in 244.270989 secs!
#
# 2026-08-04 13:24:12,936 - INFO - examples.example -
# Cleaning up App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:24:12,936 - INFO - examples.example -
# Cleaning up App TVBANNarchySerialOrchestrator...
#
# Cleaning up App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:24:12,936 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-04 13:24:12,936 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
#
# Cleaning up App TVBSerialApp...
# 2026-08-04 13:24:12,936 - INFO - examples.example -
# Cleaning up App ANNarchySerialApp...
# 2026-08-04 13:24:12,936 - INFO - examples.example -
# Cleaning up App ANNarchySerialApp...
#
# Cleaning up App ANNarchySerialApp...
# 2026-08-04 13:24:12,936 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-04 13:24:12,936 - INFO - examples.example -
# Stopping App TVBSerialApp...
#
# Stopping App TVBSerialApp...
# 2026-08-04 13:24:12,936 - INFO - examples.example -
# Stopping App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:24:12,936 - INFO - examples.example -
# Stopping App TVBANNarchySerialOrchestrator...
#
# Stopping App TVBANNarchySerialOrchestrator...
#
# Success in 245.016 sec!
# ******************************************************
#
# {'TestWilsonCowanRATE': True}

# %%
! python ../../../tvb_multiscale/tests/tvb_annarchy/test_models.py 3
# Out:
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
# /home/docker/venv/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# ANNarchy 5.0 (5.0.3) on linux (posix).
# 2026-08-04 13:24:18,511 - WARNING - tvb.simulator.plot.tools - You need mpl_toolkits for some axe related features
#
#
# Testing model 3
# ******************************************************
# ******************************************************
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
#
# ----------------------------------------------------------------------------------------------------
# Find results in /home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/WilsonCowan_RATE_bidir/res !
# ----------------------------------------------------------------------------------------------------
# 2026-08-04 13:24:19,584 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:24:19,584 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
#
# Starting App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:24:19,584 - INFO - examples.example -
# Starting App TVBSerialApp...
# 2026-08-04 13:24:19,584 - INFO - examples.example -
# Starting App TVBSerialApp...
#
# Starting App TVBSerialApp...
# 2026-08-04 13:24:19,584 - INFO - examples.example -
# Setting TVB LIBRARY_PROFILE...
# 2026-08-04 13:24:19,584 - INFO - examples.example -
# Setting TVB LIBRARY_PROFILE...
#
# Setting TVB LIBRARY_PROFILE...
# 2026-08-04 13:24:19,621 - INFO - examples.example -
# Starting App ANNarchySerialApp...
# 2026-08-04 13:24:19,621 - INFO - examples.example -
# Starting App ANNarchySerialApp...
#
# Starting App ANNarchySerialApp...
# 2026-08-04 13:24:19,621 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Loading an ANNarchy instance...
# 2026-08-04 13:24:19,621 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Loading an ANNarchy instance...
# 2026-08-04 13:24:19,622 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Cleaning ANNarchy compilation directory, if any...
# 2026-08-04 13:24:19,622 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Cleaning ANNarchy compilation directory, if any...
#
#
# Configuring...
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
#
# Done! in 0.000105 min
#
#
#
# Building...
# 2026-08-04 13:24:19,629 - INFO - examples.example -
# Building with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:24:19,629 - INFO - examples.example -
# Building with App TVBANNarchySerialOrchestrator...
#
# Building with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:24:19,629 - INFO - examples.example -
# Building cosimulators with TVBANNarchySerialOrchestrator...
# 2026-08-04 13:24:19,629 - INFO - examples.example -
# Building cosimulators with TVBANNarchySerialOrchestrator...
#
# Building cosimulators with TVBANNarchySerialOrchestrator...
# 2026-08-04 13:24:19,629 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
# 2026-08-04 13:24:19,629 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
#
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
# 2026-08-04 13:24:19,630 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-04 13:24:19,631 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2026-08-04 13:24:19,631 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2026-08-04 13:24:19,640 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2026-08-04 13:24:19,640 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2026-08-04 13:24:19,641 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# 2026-08-04 13:24:19,648 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: df7ca6fe-767f-464c-8b16-46a197c89ea7'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... WilsonCowan gid: 0741940d-916f-474e-87c1-c6fd10aec468
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 76c251fc-aa6b-4bab-8eb7-ac7c5b86ee13
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 89c0e7ff-e854-47e8-a42d-1457e0ed76cd
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 7c29e063-f011-41d8-ae4e-1015ea00e434
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('df7ca6fe-767f-464c-8b16-46a197c89ea7')
# )
# 2026-08-04 13:24:19,648 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: df7ca6fe-767f-464c-8b16-46a197c89ea7'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... WilsonCowan gid: 0741940d-916f-474e-87c1-c6fd10aec468
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 76c251fc-aa6b-4bab-8eb7-ac7c5b86ee13
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 89c0e7ff-e854-47e8-a42d-1457e0ed76cd
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 7c29e063-f011-41d8-ae4e-1015ea00e434
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('df7ca6fe-767f-464c-8b16-46a197c89ea7')
# )
#
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: df7ca6fe-767f-464c-8b16-46a197c89ea7'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... WilsonCowan gid: 0741940d-916f-474e-87c1-c6fd10aec468
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 76c251fc-aa6b-4bab-8eb7-ac7c5b86ee13
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 89c0e7ff-e854-47e8-a42d-1457e0ed76cd
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 7c29e063-f011-41d8-ae4e-1015ea00e434
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('df7ca6fe-767f-464c-8b16-46a197c89ea7')
# )
# 2026-08-04 13:24:19,648 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-04 13:24:19,648 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2026-08-04 13:24:19,649 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2026-08-04 13:24:19,649 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2026-08-04 13:24:19,657 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2026-08-04 13:24:19,657 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2026-08-04 13:24:19,658 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2026-08-04 13:24:19,663 - INFO - examples.example -
# Building Spiking Network with builder WilsonCowanBuilder of App ANNarchySerialApp...
# 2026-08-04 13:24:19,663 - INFO - examples.example -
# Building Spiking Network with builder WilsonCowanBuilder of App ANNarchySerialApp...
#
# Building Spiking Network with builder WilsonCowanBuilder of App ANNarchySerialApp...
# 2026-08-04 13:24:19,663 - INFO - examples.example - Loading an ANNarchy instance...
# 2026-08-04 13:24:19,663 - INFO - examples.example - Loading an ANNarchy instance...
# 2026-08-04 13:24:19,663 - INFO - examples.example - Cleaning ANNarchy compilation directory, if any...
# 2026-08-04 13:24:19,663 - INFO - examples.example - Cleaning ANNarchy compilation directory, if any...
# 2026-08-04 13:24:19,664 - INFO - examples.example - Configuring spiking network builder...
# 2026-08-04 13:24:19,664 - INFO - examples.example - Configuring spiking network builder...
# 2026-08-04 13:24:19,664 - INFO - examples.example - Configuring populations...
# 2026-08-04 13:24:19,664 - INFO - examples.example - Configuring populations...
# 2026-08-04 13:24:19,664 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2026-08-04 13:24:19,664 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2026-08-04 13:24:19,664 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2026-08-04 13:24:19,664 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2026-08-04 13:24:19,664 - INFO - examples.example - Configuring output devices, if any...
# 2026-08-04 13:24:19,664 - INFO - examples.example - Configuring output devices, if any...
# 2026-08-04 13:24:19,665 - INFO - examples.example - Configuring input devices, if any...
# 2026-08-04 13:24:19,665 - INFO - examples.example - Configuring input devices, if any...
# 2026-08-04 13:24:19,665 - INFO - examples.example - Generating spiking brain...
# 2026-08-04 13:24:19,665 - INFO - examples.example - Generating spiking brain...
# 2026-08-04 13:24:19,665 - INFO - examples.example - Generating spiking brain regions...
# 2026-08-04 13:24:19,665 - INFO - examples.example - Generating spiking brain regions...
# 2026-08-04 13:24:19,665 - INFO - examples.example - Generating spiking region node: bankssts_L...
# 2026-08-04 13:24:19,665 - INFO - examples.example - Generating spiking region node: bankssts_L...
# 2026-08-04 13:24:19,666 - INFO - examples.example - Generating population: E...
# 2026-08-04 13:24:19,666 - INFO - examples.example - Generating population: E...
# 2026-08-04 13:24:19,812 - INFO - examples.example - Generating population: I...
# 2026-08-04 13:24:19,812 - INFO - examples.example - Generating population: I...
# 2026-08-04 13:24:19,852 - INFO - examples.example - Generating spiking region node: bankssts_R...
# 2026-08-04 13:24:19,852 - INFO - examples.example - Generating spiking region node: bankssts_R...
# 2026-08-04 13:24:19,853 - INFO - examples.example - Generating population: E...
# 2026-08-04 13:24:19,853 - INFO - examples.example - Generating population: E...
# 2026-08-04 13:24:19,892 - INFO - examples.example - Generating population: I...
# 2026-08-04 13:24:19,892 - INFO - examples.example - Generating population: I...
# 2026-08-04 13:24:19,932 - INFO - examples.example - Connecting populations within spiking brain regions...
# 2026-08-04 13:24:19,932 - INFO - examples.example - Connecting populations within spiking brain regions...
# 2026-08-04 13:24:19,932 - INFO - examples.example - Connecting E -> E populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:24:19,932 - INFO - examples.example - Connecting E -> E populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:24:19,933 - INFO - examples.example - Connecting E -> I populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:24:19,933 - INFO - examples.example - Connecting E -> I populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:24:19,933 - INFO - examples.example - Connecting I -> E populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:24:19,933 - INFO - examples.example - Connecting I -> E populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:24:19,934 - INFO - examples.example - Connecting I -> I populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:24:19,934 - INFO - examples.example - Connecting I -> I populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:24:19,935 - INFO - examples.example - Connecting populations among spiking brain regions...
# 2026-08-04 13:24:19,935 - INFO - examples.example - Connecting populations among spiking brain regions...
# 2026-08-04 13:24:19,935 - INFO - examples.example - Connecting for 0 -> 1 spiking region nodes ...
# 2026-08-04 13:24:19,935 - INFO - examples.example - Connecting for 0 -> 1 spiking region nodes ...
# 2026-08-04 13:24:19,935 - INFO - examples.example - E -> E populations ...
# 2026-08-04 13:24:19,935 - INFO - examples.example - E -> E populations ...
# 2026-08-04 13:24:19,936 - INFO - examples.example - E -> I populations ...
# 2026-08-04 13:24:19,936 - INFO - examples.example - E -> I populations ...
# 2026-08-04 13:24:19,936 - INFO - examples.example - Connecting for 1 -> 0 spiking region nodes ...
# 2026-08-04 13:24:19,936 - INFO - examples.example - Connecting for 1 -> 0 spiking region nodes ...
# 2026-08-04 13:24:19,936 - INFO - examples.example - E -> E populations ...
# 2026-08-04 13:24:19,936 - INFO - examples.example - E -> E populations ...
# 2026-08-04 13:24:19,936 - INFO - examples.example - E -> I populations ...
# 2026-08-04 13:24:19,936 - INFO - examples.example - E -> I populations ...
# 2026-08-04 13:24:19,936 - INFO - examples.example - Generating and connecting output devices, if any...
# 2026-08-04 13:24:19,936 - INFO - examples.example - Generating and connecting output devices, if any...
# 2026-08-04 13:24:19,937 - INFO - examples.example - Generating and connecting ['E', 'I'] -> ['E', 'I'] device set of model SpikeMonitor
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:24:19,937 - INFO - examples.example - Generating and connecting ['E', 'I'] -> ['E', 'I'] device set of model SpikeMonitor
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:24:19,938 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E created!
# 2026-08-04 13:24:19,938 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E created!
# 2026-08-04 13:24:19,940 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for I created!
# 2026-08-04 13:24:19,940 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for I created!
# 2026-08-04 13:24:19,941 - INFO - examples.example - Generating and connecting ['Excitatory', 'Inhibitory'] -> ['E', 'I'] device set of model Monitor
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:24:19,941 - INFO - examples.example - Generating and connecting ['Excitatory', 'Inhibitory'] -> ['E', 'I'] device set of model Monitor
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:24:19,942 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Excitatory created!
# 2026-08-04 13:24:19,942 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Excitatory created!
# 2026-08-04 13:24:19,944 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Inhibitory created!
# 2026-08-04 13:24:19,944 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Inhibitory created!
# 2026-08-04 13:24:19,946 - INFO - examples.example - Generating and connecting input devices, if any...
# 2026-08-04 13:24:19,946 - INFO - examples.example - Generating and connecting input devices, if any...
# 2026-08-04 13:24:19,946 - INFO - examples.example - Generating and connecting ['Stimulus'] -> [['E']] device set of model PoissonPopulation
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:24:19,946 - INFO - examples.example - Generating and connecting ['Stimulus'] -> [['E']] device set of model PoissonPopulation
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:24:19,947 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model PoissonPopulation for Stimulus created!
# 2026-08-04 13:24:19,947 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model PoissonPopulation for Stimulus created!
# 2026-08-04 13:24:19,958 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:24:19,958 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:24:19,958 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:24:19,958 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:24:19,958 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:24:19,958 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:24:19,958 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:24:19,958 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2026-08-04 13:24:19,958 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# ANNarchyNetwork (
#   title ....................................... 'ANNarchyNetwork gid: 2c09a2a8-8218-414a-ae64-37795f728746'
#   Type ........................................ 'ANNarchyNetwork'
#   annarchy_network ............................ <ANNarchy.core.Network.Network object at 0xffff6fe06f60>
#   config ...................................... '--------------------'
#   config.title ................................ 'Config gid: fa100f2f-f6fe-4df6-aef5-14f10571c2a5'
#   config.Type ................................. 'Config'
#   config.gid .................................. UUID('fa100f2f-f6fe-4df6-aef5-14f10571c2a5')
#   brain_regions ............................... '--------------------'
#   brain_regions.title ......................... 'ANNarchyBrain gid: 07c96479-18e1-44bb-93e2-a5f0344d986a'
#   brain_regions.Type .......................... 'ANNarchyBrain'
#   brain_regions.gid ........................... UUID('07c96479-18e1-44bb-93e2-a5f0344d986a')
#   brain_regions.label ......................... ''
#   brain_regions.size .......................... 2
#   brain_regions.Regions ....................... --------------------
#   brain_regions.Regions: shape ................ (2,)
#   brain_regions.Regions: dtype ................ <U10
#   brain_regions.Regions: values ............... ['bankssts_L' 'bankssts_R']
#   brain_regions.bankssts_L .................... '--------------------'
#   brain_regions[bankssts_L].title ............. 'ANNarchyRegionNode gid: 1798841d-a764-4c76-8b95-930125906ff1'
#   brain_regions[bankssts_L].Type .............. 'ANNarchyRegionNode'
#   brain_regions[bankssts_L].gid ............... UUID('1798841d-a764-4c76-8b95-930125906ff1')
#   brain_regions[bankssts_L].label ............. 'bankssts_L'
#   brain_regions[bankssts_L].size .............. 2
#   brain_regions[bankssts_L].Populations ....... --------------------
#   brain_regions[bankssts_L].Populations: shape  (2,)
#   brain_regions[bankssts_L].Populations: dtype  <U1
#   brain_regions[bankssts_L].Populations: values  ['E' 'I']
#   brain_regions.bankssts_R .................... '--------------------'
#   brain_regions[bankssts_R].title ............. 'ANNarchyRegionNode gid: 18c09230-33c2-41ac-9bd2-59a861b3a225'
#   brain_regions[bankssts_R].Type .............. 'ANNarchyRegionNode'
#   brain_regions[bankssts_R].gid ............... UUID('18c09230-33c2-41ac-9bd2-59a861b3a225')
#   brain_regions[bankssts_R].label ............. 'bankssts_R'
#   brain_regions[bankssts_R].size .............. 2
#   brain_regions[bankssts_R].Populations ....... --------------------
#   brain_regions[bankssts_R].Populations: shape  (2,)
#   brain_regions[bankssts_R].Populations: dtype  <U1
#   brain_regions[bankssts_R].Populations: values  ['E' 'I']
#   network_path ................................ ''
#   logger ...................................... <Logger tvb-multiscale (DEBUG)>
#   output_devices .............................. '--------------------'
#   output_devices.title ........................ 'DeviceSets gid: d4be8220-ede9-44f3-bead-c7084ed6e10e'
#   output_devices.Type ......................... 'DeviceSets'
#   output_devices.gid .......................... UUID('d4be8220-ede9-44f3-bead-c7084ed6e10e')
#   output_devices.label ........................ 'output_devices'
#   output_devices.size ......................... 4
#   output_devices.DeviceSets ................... --------------------
#   output_devices.DeviceSets: shape ............ (4,)
#   output_devices.DeviceSets: dtype ............ <U10
#   output_devices.DeviceSets: values ........... ['E' 'I' 'Excitatory' 'Inhibitory']
#   output_devices.E ............................ '--------------------'
#   output_devices[E].title ..................... 'DeviceSet gid: 5fc276d0-a4c8-4a4b-8aad-09ec6771584f'
#   output_devices[E].Type ...................... 'DeviceSet'
#   output_devices[E].model ..................... 'SpikeMonitor'
#   output_devices[E].gid ....................... UUID('5fc276d0-a4c8-4a4b-8aad-09ec6771584f')
#   output_devices[E].label ..................... 'E'
#   output_devices[E].size ...................... 2
#   output_devices[E].Devices ................... --------------------
#   output_devices[E].Devices: shape ............ (2,)
#   output_devices[E].Devices: dtype ............ <U10
#   output_devices[E].Devices: values ........... ['bankssts_L' 'bankssts_R']
#   output_devices.I ............................ '--------------------'
#   output_devices[I].title ..................... 'DeviceSet gid: d8cdc614-ec1f-4530-88c0-7f87ec2924c0'
#   output_devices[I].Type ...................... 'DeviceSet'
#   output_devices[I].model ..................... 'SpikeMonitor'
#   output_devices[I].gid ....................... UUID('d8cdc614-ec1f-4530-88c0-7f87ec2924c0')
#   output_devices[I].label ..................... 'I'
#   output_devices[I].size ...................... 2
#   output_devices[I].Devices ................... --------------------
#   output_devices[I].Devices: shape ............ (2,)
#   output_devices[I].Devices: dtype ............ <U10
#   output_devices[I].Devices: values ........... ['bankssts_L' 'bankssts_R']
#   output_devices.Excitatory ................... '--------------------'
#   output_devices[Excitatory].title ............ 'DeviceSet gid: b679ac4e-0ee0-401b-a029-3e8e7b68f1df'
#   output_devices[Excitatory].Type ............. 'DeviceSet'
#   output_devices[Excitatory].model ............ 'Monitor'
#   output_devices[Excitatory].gid .............. UUID('b679ac4e-0ee0-401b-a029-3e8e7b68f1df')
#   output_devices[Excitatory].label ............ 'Excitatory'
#   output_devices[Excitatory].size ............. 2
#   output_devices[Excitatory].Devices .......... --------------------
#   output_devices[Excitatory].Devices: shape ... (2,)
#   output_devices[Excitatory].Devices: dtype ... <U10
#   output_devices[Excitatory].Devices: values .. ['bankssts_L' 'bankssts_R']
#   output_devices.Inhibitory ................... '--------------------'
#   output_devices[Inhibitory].title ............ 'DeviceSet gid: 5d1cf1b0-c6f4-4590-93a2-a52cf1c37ec9'
#   output_devices[Inhibitory].Type ............. 'DeviceSet'
#   output_devices[Inhibitory].model ............ 'Monitor'
#   output_devices[Inhibitory].gid .............. UUID('5d1cf1b0-c6f4-4590-93a2-a52cf1c37ec9')
#   output_devices[Inhibitory].label ............ 'Inhibitory'
#   output_devices[Inhibitory].size ............. 2
#   output_devices[Inhibitory].Devices .......... --------------------
#   output_devices[Inhibitory].Devices: shape ... (2,)
#   output_devices[Inhibitory].Devices: dtype ... <U10
#   output_devices[Inhibitory].Devices: values .. ['bankssts_L' 'bankssts_R']
#   input_devices ............................... '--------------------'
#   input_devices.title ......................... 'DeviceSets gid: ab3f77f2-804c-49d8-9ca1-c08dcee2e4a6'
#   input_devices.Type .......................... 'DeviceSets'
#   input_devices.gid ........................... UUID('ab3f77f2-804c-49d8-9ca1-c08dcee2e4a6')
#   input_devices.label ......................... 'input_devices'
#   input_devices.size .......................... 1
#   input_devices.DeviceSets .................... --------------------
#   input_devices.DeviceSets: shape ............. (1,)
#   input_devices.DeviceSets: dtype ............. <U8
#   input_devices.DeviceSets: values ............ Stimulus
#   input_devices.Stimulus ...................... '--------------------'
#   input_devices[Stimulus].title ............... 'DeviceSet gid: 36cb4da9-a015-4ec1-b6db-2e5a9c8e624e'
#   input_devices[Stimulus].Type ................ 'DeviceSet'
#   input_devices[Stimulus].model ............... 'PoissonPopulation'
#   input_devices[Stimulus].gid ................. UUID('36cb4da9-a015-4ec1-b6db-2e5a9c8e624e')
#   input_devices[Stimulus].label ............... 'Stimulus'
#   input_devices[Stimulus].size ................ 2
#   input_devices[Stimulus].Devices ............. --------------------
#   input_devices[Stimulus].Devices: shape ...... (2,)
#   input_devices[Stimulus].Devices: dtype ...... <U10
#   input_devices[Stimulus].Devices: values ..... ['bankssts_L' 'bankssts_R']
#   output_proxies .............................. '--------------------'
#   output_proxies.title ........................ 'DeviceSets gid: 3e8bb1da-d7c2-4a5b-832e-8a30a47dd512'
#   output_proxies.Type ......................... 'DeviceSets'
#   output_proxies.gid .......................... UUID('3e8bb1da-d7c2-4a5b-832e-8a30a47dd512')
#   output_proxies.label ........................ 'output_proxies'
#   output_proxies.size ......................... 0
#   output_proxies.DeviceSets ................... --------------------
#   shape ....................................... (0,)
#   dtype ....................................... float64
#   is empty .................................... True
#   input_proxies ............................... '--------------------'
#   input_proxies.title ......................... 'DeviceSets gid: 17430ef5-f215-4e44-a36d-2658b509423f'
#   input_proxies.Type .......................... 'DeviceSets'
#   input_proxies.gid ........................... UUID('17430ef5-f215-4e44-a36d-2658b509423f')
#   input_proxies.label ......................... ''
#   input_proxies.size .......................... 0
#   input_proxies.DeviceSets .................... --------------------
#   gid ......................................... UUID('2c09a2a8-8218-414a-ae64-37795f728746')
# )
# 2026-08-04 13:24:19,962 - INFO - examples.example -
# Building interfaces with Orchestrator TVBANNarchySerialOrchestrator...
# 2026-08-04 13:24:19,962 - INFO - examples.example -
# Building interfaces with Orchestrator TVBANNarchySerialOrchestrator...
#
# Building interfaces with Orchestrator TVBANNarchySerialOrchestrator...
# 2026-08-04 13:24:19,962 - INFO - examples.example -
# Building interfaces' with builder TVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2026-08-04 13:24:19,962 - INFO - examples.example -
# Building interfaces' with builder TVBANNarchyInterfaceBuilder of App TVBSerialApp...
#
# Building interfaces' with builder TVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2026-08-04 13:24:19,962 - INFO - examples.example -
# Configuring interfaces' builder WilsonCowanTVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2026-08-04 13:24:19,962 - INFO - examples.example -
# Configuring interfaces' builder WilsonCowanTVBANNarchyInterfaceBuilder of App TVBSerialApp...
#
# Configuring interfaces' builder WilsonCowanTVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2026-08-04 13:24:19,962 - INFO - examples.example -
# Configuring default interfaces...
# 2026-08-04 13:24:19,962 - INFO - examples.example -
# Configuring default interfaces...
#
# Configuring default interfaces...
# 2026-08-04 13:24:19,965 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model TimedPoissonPopulation for ['E']->E created!
# 2026-08-04 13:24:19,965 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model TimedPoissonPopulation for ['E']->E created!
# 2026-08-04 13:24:20,247 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E->['E'] created!
# 2026-08-04 13:24:20,247 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E->['E'] created!
# 2026-08-04 13:24:20,249 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for I->['I'] created!
# 2026-08-04 13:24:20,249 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for I->['I'] created!
# 2026-08-04 13:24:20,251 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-04 13:24:20,251 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2026-08-04 13:24:20,252 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2026-08-04 13:24:20,252 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2026-08-04 13:24:20,261 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2026-08-04 13:24:20,261 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2026-08-04 13:24:20,262 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2026-08-04 13:24:20,271 - INFO - examples.example -
# TVBtoANNarchyInterfaces (
#   title .................................. 'TVBtoANNarchyInterfaces gid: 5a3ccede-fe37-4048-844f-fe06926951f0'
#   Type ................................... 'TVBtoANNarchyInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoANNarchyInterface gid: 73d357c8-0d74-4bf0-80b4-b2625be945d3'
#   interfaces[0].Type ..................... 'TVBtoANNarchyInterface'
#   interfaces[0].proxy .................... ANNarchyTimedPoissonPopulationSet gid: 48ede731-5b7c-47f0-bd4a-e33f3cf96adc
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: 2c09a2a8-8218-414a-ae64-37795f728746
#   interfaces[0].transformer .............. LinearRate gid: 48178acd-0aca-4ea2-9667-7a689553cd57
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[np.int64(2), np.int64(67)]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... E
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[np.int64(0), np.int64(1)]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('73d357c8-0d74-4bf0-80b4-b2625be945d3')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int32
#   interfaces[0].proxy_gids: unique_values  0
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('5a3ccede-fe37-4048-844f-fe06926951f0')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[np.int64(0), np.int64(1)]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... E
#   number_of_proxy_nodes .................. 66
# )
# 2026-08-04 13:24:20,271 - INFO - examples.example -
# TVBtoANNarchyInterfaces (
#   title .................................. 'TVBtoANNarchyInterfaces gid: 5a3ccede-fe37-4048-844f-fe06926951f0'
#   Type ................................... 'TVBtoANNarchyInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoANNarchyInterface gid: 73d357c8-0d74-4bf0-80b4-b2625be945d3'
#   interfaces[0].Type ..................... 'TVBtoANNarchyInterface'
#   interfaces[0].proxy .................... ANNarchyTimedPoissonPopulationSet gid: 48ede731-5b7c-47f0-bd4a-e33f3cf96adc
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: 2c09a2a8-8218-414a-ae64-37795f728746
#   interfaces[0].transformer .............. LinearRate gid: 48178acd-0aca-4ea2-9667-7a689553cd57
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[np.int64(2), np.int64(67)]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... E
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[np.int64(0), np.int64(1)]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('73d357c8-0d74-4bf0-80b4-b2625be945d3')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int32
#   interfaces[0].proxy_gids: unique_values  0
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('5a3ccede-fe37-4048-844f-fe06926951f0')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[np.int64(0), np.int64(1)]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... E
#   number_of_proxy_nodes .................. 66
# )
#
# TVBtoANNarchyInterfaces (
#   title .................................. 'TVBtoANNarchyInterfaces gid: 5a3ccede-fe37-4048-844f-fe06926951f0'
#   Type ................................... 'TVBtoANNarchyInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoANNarchyInterface gid: 73d357c8-0d74-4bf0-80b4-b2625be945d3'
#   interfaces[0].Type ..................... 'TVBtoANNarchyInterface'
#   interfaces[0].proxy .................... ANNarchyTimedPoissonPopulationSet gid: 48ede731-5b7c-47f0-bd4a-e33f3cf96adc
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: 2c09a2a8-8218-414a-ae64-37795f728746
#   interfaces[0].transformer .............. LinearRate gid: 48178acd-0aca-4ea2-9667-7a689553cd57
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[np.int64(2), np.int64(67)]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... E
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[np.int64(0), np.int64(1)]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('73d357c8-0d74-4bf0-80b4-b2625be945d3')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int32
#   interfaces[0].proxy_gids: unique_values  0
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('5a3ccede-fe37-4048-844f-fe06926951f0')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[np.int64(0), np.int64(1)]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... E
#   number_of_proxy_nodes .................. 66
# )
# 2026-08-04 13:24:20,274 - INFO - examples.example -
# ANNarchyToTVBInterfaces (
#   title .................................. 'ANNarchyToTVBInterfaces gid: 74e2077c-ba93-46a9-bfba-9adf70d737bf'
#   Type ................................... 'ANNarchyToTVBInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'ANNarchyToTVBInterface gid: bc6cce89-f7f8-4088-9613-ec748ee9adab'
#   interfaces[0].Type ..................... 'ANNarchyToTVBInterface'
# ...
#   spikeNet_app.logger .............................................................. <Logger examples.example (DEBUG)>
#   spikeNet_app.default_tvb_serial_cosim_path ....................................... '/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/WilsonCowan_RATE_bidir/config/tvb_serial_cosimulator.pkl'
#   spikeNet_app.gid ................................................................. UUID('b79f4d11-f5db-4080-9547-5873b85ae728')
#   spikeNet_app.spiking_cosimulator ................................................. <module 'ANNarchy' from '/home/docker/venv/lib/python3.12/site-packages/ANNarchy/__init__.py'>
#   logger ........................................................................... <Logger examples.example (DEBUG)>
#   default_tvb_serial_cosim_path .................................................... '/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/WilsonCowan_RATE_bidir/config/tvb_serial_cosimulator.pkl'
#   gid .............................................................................. UUID('05e33a1d-4bd3-4472-9561-504e71a850a1')
# )
# None
#
#
# Simulating...
# 2026-08-04 13:24:20,298 - INFO - examples.example -
# Simulating for 36ms with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:24:20,298 - INFO - examples.example -
# Simulating for 36ms with App TVBANNarchySerialOrchestrator...
#
# Simulating for 36ms with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:24:20,298 - INFO - examples.example -
# Configuring simulation with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:24:20,298 - INFO - examples.example -
# Configuring simulation with App TVBANNarchySerialOrchestrator...
#
# Configuring simulation with App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:24:20,298 - INFO - examples.example -
# Configuring simulation with App TVBSerialApp...
# 2026-08-04 13:24:20,298 - INFO - examples.example -
# Configuring simulation with App TVBSerialApp...
#
# Configuring simulation with App TVBSerialApp...
# 2026-08-04 13:24:20,299 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-04 13:24:20,299 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2026-08-04 13:24:20,299 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2026-08-04 13:24:20,299 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2026-08-04 13:24:20,309 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2026-08-04 13:24:20,309 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2026-08-04 13:24:20,311 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# 2026-08-04 13:24:20,318 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: df7ca6fe-767f-464c-8b16-46a197c89ea7'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... WilsonCowan gid: 0741940d-916f-474e-87c1-c6fd10aec468
#   output_interfaces ................... TVBtoANNarchyInterfaces gid: 5a3ccede-fe37-4048-844f-fe06926951f0
#   input_interfaces .................... ANNarchyToTVBInterfaces gid: 74e2077c-ba93-46a9-bfba-9adf70d737bf
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (66,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: unique_values ....... [[np.int64(2), np.int64(67)]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (2,)
#   voi: dtype .......................... int64
#   voi: values ......................... [[np.int64(0), np.int64(1)]]
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[np.int64(0), np.int64(1)]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. RawCosim(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 76c251fc-aa6b-4bab-8eb7-ac7c5b86ee13
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 89c0e7ff-e854-47e8-a42d-1457e0ed76cd
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 7c29e063-f011-41d8-ae4e-1015ea00e434
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('df7ca6fe-767f-464c-8b16-46a197c89ea7')
# )
# 2026-08-04 13:24:20,318 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: df7ca6fe-767f-464c-8b16-46a197c89ea7'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... WilsonCowan gid: 0741940d-916f-474e-87c1-c6fd10aec468
#   output_interfaces ................... TVBtoANNarchyInterfaces gid: 5a3ccede-fe37-4048-844f-fe06926951f0
#   input_interfaces .................... ANNarchyToTVBInterfaces gid: 74e2077c-ba93-46a9-bfba-9adf70d737bf
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (66,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: unique_values ....... [[np.int64(2), np.int64(67)]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (2,)
#   voi: dtype .......................... int64
#   voi: values ......................... [[np.int64(0), np.int64(1)]]
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[np.int64(0), np.int64(1)]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. RawCosim(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 76c251fc-aa6b-4bab-8eb7-ac7c5b86ee13
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 89c0e7ff-e854-47e8-a42d-1457e0ed76cd
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 7c29e063-f011-41d8-ae4e-1015ea00e434
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('df7ca6fe-767f-464c-8b16-46a197c89ea7')
# )
#
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: df7ca6fe-767f-464c-8b16-46a197c89ea7'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... WilsonCowan gid: 0741940d-916f-474e-87c1-c6fd10aec468
#   output_interfaces ................... TVBtoANNarchyInterfaces gid: 5a3ccede-fe37-4048-844f-fe06926951f0
#   input_interfaces .................... ANNarchyToTVBInterfaces gid: 74e2077c-ba93-46a9-bfba-9adf70d737bf
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (66,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: unique_values ....... [[np.int64(2), np.int64(67)]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (2,)
#   voi: dtype .......................... int64
#   voi: values ......................... [[np.int64(0), np.int64(1)]]
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[np.int64(0), np.int64(1)]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. RawCosim(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 76c251fc-aa6b-4bab-8eb7-ac7c5b86ee13
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 89c0e7ff-e854-47e8-a42d-1457e0ed76cd
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 7c29e063-f011-41d8-ae4e-1015ea00e434
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('df7ca6fe-767f-464c-8b16-46a197c89ea7')
# )
# 2026-08-04 13:24:20,318 - INFO - examples.example -
# Configuring simulation with App ANNarchySerialApp...
# 2026-08-04 13:24:20,318 - INFO - examples.example -
# Configuring simulation with App ANNarchySerialApp...
#
# Configuring simulation with App ANNarchySerialApp...
# 2026-08-04 13:24:20,623 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-04 13:24:20,623 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
#
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-04 13:24:20,626 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - No or all NaN valued cosimulator updates at time step 0!
# 2026-08-04 13:24:20,626 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.032 seconds
# 2026-08-04 13:24:20,627 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2026-08-04 13:24:20,627 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 44063
# 2026-08-04 13:24:20,633 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:20,637 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...9.091% completed in 0.0108888 sec!
# ...9.091% completed in 0.0108888 sec!2026-08-04 13:24:20,648 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:20,653 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...18.182% completed in 0.0273397 sec!
# ...18.182% completed in 0.0273397 sec!2026-08-04 13:24:20,801 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:20,805 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...27.273% completed in 0.178732 sec!
# ...27.273% completed in 0.178732 sec!2026-08-04 13:24:20,821 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:20,827 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...36.364% completed in 0.200972 sec!
# ...36.364% completed in 0.200972 sec!2026-08-04 13:24:20,840 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:20,843 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...45.455% completed in 0.217302 sec!
# ...45.455% completed in 0.217302 sec!2026-08-04 13:24:20,857 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:20,864 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...54.545% completed in 0.238039 sec!
# ...54.545% completed in 0.238039 sec!2026-08-04 13:24:20,876 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:20,880 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...63.636% completed in 0.253956 sec!
# ...63.636% completed in 0.253956 sec!2026-08-04 13:24:20,893 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:20,896 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...72.727% completed in 0.270452 sec!
# ...72.727% completed in 0.270452 sec!2026-08-04 13:24:20,911 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:20,915 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...81.818% completed in 0.288682 sec!
# ...81.818% completed in 0.288682 sec!2026-08-04 13:24:20,928 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:20,931 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...90.909% completed in 0.305411 sec!
# ...90.909% completed in 0.305411 sec!2026-08-04 13:24:20,945 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:24:20,949 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...100.000% completed in 0.322795 sec!
# ...100.000% completed in 0.322795 sec!
# Simulated in 0.651569 secs!
#
# 2026-08-04 13:24:20,949 - INFO - examples.example -
# Cleaning up App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:24:20,949 - INFO - examples.example -
# Cleaning up App TVBANNarchySerialOrchestrator...
#
# Cleaning up App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:24:20,949 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-04 13:24:20,949 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
#
# Cleaning up App TVBSerialApp...
# 2026-08-04 13:24:20,950 - INFO - examples.example -
# Cleaning up App ANNarchySerialApp...
# 2026-08-04 13:24:20,950 - INFO - examples.example -
# Cleaning up App ANNarchySerialApp...
#
# Cleaning up App ANNarchySerialApp...
# 2026-08-04 13:24:20,950 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-04 13:24:20,950 - INFO - examples.example -
# Stopping App TVBSerialApp...
#
# Stopping App TVBSerialApp...
# 2026-08-04 13:24:20,950 - INFO - examples.example -
# Stopping App TVBANNarchySerialOrchestrator...
# 2026-08-04 13:24:20,950 - INFO - examples.example -
# Stopping App TVBANNarchySerialOrchestrator...
#
# Stopping App TVBANNarchySerialOrchestrator...
#
# Success in 1.43149 sec!
# ******************************************************
#
# {'TestWilsonCowanSPIKES': True}
