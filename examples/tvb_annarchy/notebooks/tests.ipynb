# %%
! pwd
# Out:
# /home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks

# %%
! python ../../../tvb_multiscale/tests/tvb_annarchy/test_spiking_models_builder_properties_methods.py
# Out:
# ANNarchy 4.7 (4.7.2.6) on linux (posix).
# 2023-10-25 17:51:45,332 - INFO - tvb-multiscale - Loading an ANNarchy instance...
# 2023-10-25 17:51:45,332 - INFO - tvb-multiscale - Loading an ANNarchy instance...
# 2023-10-25 17:51:45,332 - INFO - tvb-multiscale - Loading an ANNarchy instance...
# 2023-10-25 17:51:45,332 - INFO - tvb-multiscale - Cleaning ANNarchy compilation directory, if any...
# 2023-10-25 17:51:45,332 - INFO - tvb-multiscale - Cleaning ANNarchy compilation directory, if any...
# 2023-10-25 17:51:45,332 - INFO - tvb-multiscale - Cleaning ANNarchy compilation directory, if any...
# SPIKING_DT TO SET= 0.05
# <tvb_multiscale.tvb_annarchy.annarchy_models.models.default.DefaultExcIOBuilder object at 0xffff6b5b5990>
# annarchy simulator: <module 'ANNarchy' from '/home/docker/.local/lib/python3.10/site-packages/ANNarchy/__init__.py'>
# min_delay:
# 0.05
#
# tvb_dt:
# 0.1
#
# monitor_period:
# 0.1
#
# tvb_model:
# Linear
#
# number_of_regions:
# 68
#
# tvb_weights:
# [[0.0000000e+00 4.8155833e-02 5.5569724e-01 ... 0.0000000e+00
#   9.3632959e-04 1.5197568e-03]
#  [3.4694958e-02 0.0000000e+00 4.0470140e+00 ... 0.0000000e+00
#   0.0000000e+00 6.4991351e-02]
#  [3.3234182e-01 1.6091147e+00 0.0000000e+00 ... 0.0000000e+00
#   1.3227513e-03 2.2254678e-01]
#  ...
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#   4.2837810e-03 6.6117304e+01]
#  [6.8634180e-04 0.0000000e+00 1.8867925e-02 ... 2.7493696e-02
#   0.0000000e+00 2.8296225e+01]
#  [2.8677947e-04 1.3400005e-02 3.4921828e-01 ... 2.5495074e+01
#   1.4883909e+01 0.0000000e+00]]
#
# tvb_delays:
# [[ 0.         39.98974333 34.00171    ...  0.         47.8
#   44.73333333]
#  [39.98974333  0.         14.00699533 ...  0.          0.
#   23.274074  ]
#  [34.00171    14.00699533  0.         ...  0.         58.33333333
#   37.56438333]
#  ...
#  [ 0.          0.          0.         ...  0.         20.76666667
#    6.62544467]
#  [47.8         0.         58.33333333 ... 20.76666667  0.
#    5.83055433]
#  [44.73333333 23.274074   37.56438333 ...  6.62544467  5.83055433
#    0.        ]]
#
# region_labels:
# ['bankssts_L' 'bankssts_R' 'caudalanteriorcingulate_L'
#  'caudalanteriorcingulate_R' 'caudalmiddlefrontal_L'
#  'caudalmiddlefrontal_R' 'cuneus_L' 'cuneus_R' 'entorhinal_L'
#  'entorhinal_R' 'frontalpole_L' 'frontalpole_R' 'fusiform_L' 'fusiform_R'
#  'inferiorparietal_L' 'inferiorparietal_R' 'inferiortemporal_L'
#  'inferiortemporal_R' 'insula_L' 'insula_R' 'isthmuscingulate_L'
#  'isthmuscingulate_R' 'lateraloccipital_L' 'lateraloccipital_R'
#  'lateralorbitofrontal_L' 'lateralorbitofrontal_R' 'lingual_L' 'lingual_R'
#  'medialorbitofrontal_L' 'medialorbitofrontal_R' 'middletemporal_L'
#  'middletemporal_R' 'paracentral_L' 'paracentral_R' 'parahippocampal_L'
#  'parahippocampal_R' 'parsopercularis_L' 'parsopercularis_R'
#  'parsorbitalis_L' 'parsorbitalis_R' 'parstriangularis_L'
#  'parstriangularis_R' 'pericalcarine_L' 'pericalcarine_R' 'postcentral_L'
#  'postcentral_R' 'posteriorcingulate_L' 'posteriorcingulate_R'
#  'precentral_L' 'precentral_R' 'precuneus_L' 'precuneus_R'
#  'rostralanteriorcingulate_L' 'rostralanteriorcingulate_R'
#  'rostralmiddlefrontal_L' 'rostralmiddlefrontal_R' 'superiorfrontal_L'
#  'superiorfrontal_R' 'superiorparietal_L' 'superiorparietal_R'
#  'superiortemporal_L' 'superiortemporal_R' 'supramarginal_L'
#  'supramarginal_R' 'temporalpole_L' 'temporalpole_R'
#  'transversetemporal_L' 'transversetemporal_R']
#
# number_of_populations:
# 0
#
# populations_models:
# OrderedDict()
#
# populations_nodes:
# OrderedDict()
#
# populations_scales:
# OrderedDict()
#
# populations_sizes:
# OrderedDict()
#
# populations_params:
# OrderedDict()
#
# populations_connections_labels:
# []
#
# populations_connections_models:
# OrderedDict()
#
# populations_connections_nodes:
# OrderedDict()
#
# populations_connections_weights:
# OrderedDict()
#
# populations_connections_delays:
# OrderedDict()
#
# populations_connections_receptor_types:
# OrderedDict()
#
# populations_connections_conn_spec:
# OrderedDict()
#
# nodes_connections_labels:
# []
#
# nodes_connections_models:
# OrderedDict()
#
# nodes_connections_source_nodes:
# OrderedDict()
#
# nodes_connections_target_nodes:
# OrderedDict()
#
# nodes_connections_weights:
# OrderedDict()
#
# nodes_connections_delays:
# OrderedDict()
#
# nodes_connections_receptor_types:
# OrderedDict()
#
# nodes_connections_conn_spec:
# OrderedDict()

# %%
! python ../../../tvb_multiscale/tests/tvb_annarchy/test_models.py
# Out:
# ANNarchy 4.7 (4.7.2.6) on linux (posix).
#
# ******************************************************
# ******************************************************
# TestDefaultRATE
# ******************************************************
# ******************************************************
#
# ----------------------------------------------------------------------------------------------------
# Find results in /home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/DefaultExcIO_RATE_bidir/res !
# ----------------------------------------------------------------------------------------------------
# 2023-10-25 17:51:49,340 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
# 2023-10-25 17:51:49,340 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
#
# Starting App TVBANNarchySerialOrchestrator...
# 2023-10-25 17:51:49,340 - INFO - examples.example -
# Starting App TVBSerialApp...
# 2023-10-25 17:51:49,340 - INFO - examples.example -
# Starting App TVBSerialApp...
#
# Starting App TVBSerialApp...
# 2023-10-25 17:51:49,340 - INFO - examples.example -
# Setting TVB LIBRARY_PROFILE...
# 2023-10-25 17:51:49,340 - INFO - examples.example -
# Setting TVB LIBRARY_PROFILE...
#
# Setting TVB LIBRARY_PROFILE...
# 2023-10-25 17:51:49,341 - INFO - examples.example -
# Starting App ANNarchySerialApp...
# 2023-10-25 17:51:49,341 - INFO - examples.example -
# Starting App ANNarchySerialApp...
#
# Starting App ANNarchySerialApp...
# 2023-10-25 17:51:49,342 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Loading an ANNarchy instance...
# 2023-10-25 17:51:49,342 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Loading an ANNarchy instance...
# 2023-10-25 17:51:49,342 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Cleaning ANNarchy compilation directory, if any...
# 2023-10-25 17:51:49,342 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Cleaning ANNarchy compilation directory, if any...
#
#
# Configuring...
#
# Done! in 0.000101 min
#
#
#
# Building...
# 2023-10-25 17:51:49,348 - INFO - examples.example -
# Building with App TVBANNarchySerialOrchestrator...
# 2023-10-25 17:51:49,348 - INFO - examples.example -
# Building with App TVBANNarchySerialOrchestrator...
#
# Building with App TVBANNarchySerialOrchestrator...
# 2023-10-25 17:51:49,348 - INFO - examples.example -
# Building cosimulators with TVBANNarchySerialOrchestrator...
# 2023-10-25 17:51:49,348 - INFO - examples.example -
# Building cosimulators with TVBANNarchySerialOrchestrator...
#
# Building cosimulators with TVBANNarchySerialOrchestrator...
# 2023-10-25 17:51:49,349 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
# 2023-10-25 17:51:49,349 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
#
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
# 2023-10-25 17:51:49,350 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-10-25 17:51:49,350 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2023-10-25 17:51:49,350 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2023-10-25 17:51:49,356 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2023-10-25 17:51:49,356 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2023-10-25 17:51:49,357 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-10-25 17:51:49,357 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# 2023-10-25 17:51:49,362 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: f76684f9-7324-445d-b109-6489e82bf454'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: d8ace129-a326-40a0-9333-157f73f1b7ff
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 213dc761-1dc7-4d6e-95ff-322debca7d45
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: dd25bc7a-a9de-4240-81de-5aeed2aca49e
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 5a27e85b-bf6c-4d05-aacb-711fe4ccbb5d
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID
- INFO - examples.example - Generating and connecting ['E'] -> ['E'] device set of model SpikeMonitor
# for nodes [0, 1]...
# 2023-10-25 17:51:49,488 - INFO - examples.example - Generating and connecting ['E'] -> ['E'] device set of model SpikeMonitor
# for nodes [0, 1]...
# 2023-10-25 17:51:49,489 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E created!
# 2023-10-25 17:51:49,489 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E created!
# 2023-10-25 17:51:49,491 - INFO - examples.example - Generating and connecting ['Excitatory'] -> ['E'] device set of model Monitor
# for nodes [0, 1]...
# 2023-10-25 17:51:49,491 - INFO - examples.example - Generating and connecting ['Excitatory'] -> ['E'] device set of model Monitor
# for nodes [0, 1]...
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2023-10-25 17:51:49,491 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Excitatory created!
# 2023-10-25 17:51:49,491 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Excitatory created!
# 2023-10-25 17:51:49,493 - INFO - examples.example - Generating and connecting input devices, if any...
# 2023-10-25 17:51:49,493 - INFO - examples.example - Generating and connecting input devices, if any...
# 2023-10-25 17:51:49,493 - INFO - examples.example - Generating and connecting ['Stimulus'] -> [['E']] device set of model PoissonPopulation
# for nodes [0, 1]...
# 2023-10-25 17:51:49,493 - INFO - examples.example - Generating and connecting ['Stimulus'] -> [['E']] device set of model PoissonPopulation
# for nodes [0, 1]...
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2023-10-25 17:51:49,494 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model PoissonPopulation for Stimulus created!
# 2023-10-25 17:51:49,494 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model PoissonPopulation for Stimulus created!
# 2023-10-25 17:51:49,500 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2023-10-25 17:51:49,500 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2023-10-25 17:51:49,500 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2023-10-25 17:51:49,500 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2023-10-25 17:51:49,500 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2023-10-25 17:51:49,500 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2023-10-25 17:51:49,500 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2023-10-25 17:51:49,500 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2023-10-25 17:51:49,500 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# ANNarchyNetwork (
#   title ....................................... 'ANNarchyNetwork gid: ca8f9bb4-6e6f-4cdc-b2d0-17514bff2af6'
#   Type ........................................ 'ANNarchyNetwork'
#   config ...................................... '--------------------'
#   config.title ................................ 'Config gid: 363d92bb-f250-4c6c-a514-e00f0e624959'
#   config.Type ................................. 'Config'
#   config.gid .................................. UUID('363d92bb-f250-4c6c-a514-e00f0e624959')
#   brain_regions ............................... '--------------------'
#   brain_regions.title ......................... 'ANNarchyBrain gid: de87acc5-fc93-4997-8889-893490d8fd5e'
#   brain_regions.Type .......................... 'ANNarchyBrain'
#   brain_regions.gid ........................... UUID('de87acc5-fc93-4997-8889-893490d8fd5e')
#   brain_regions.label ......................... ''
#   brain_regions.size .......................... 2
#   brain_regions.Regions ....................... --------------------
#   brain_regions.Regions: shape ................ (2,)
#   brain_regions.Regions: dtype ................ <U10
#   brain_regions.Regions: values ............... ['bankssts_L' 'bankssts_R']
#   brain_regions.bankssts_L .................... '--------------------'
#   brain_regions[bankssts_L].title ............. 'ANNarchyRegionNode gid: 951ad345-0a3b-41b2-a5f0-d000a04a392e'
#   brain_regions[bankssts_L].Type .............. 'ANNarchyRegionNode'
#   brain_regions[bankssts_L].gid ............... UUID('951ad345-0a3b-41b2-a5f0-d000a04a392e')
#   brain_regions[bankssts_L].label ............. 'bankssts_L'
#   brain_regions[bankssts_L].size .............. 1
#   brain_regions[bankssts_L].Populations ....... --------------------
#   brain_regions[bankssts_L].Populations: shape  (1,)
#   brain_regions[bankssts_L].Populations: dtype  <U1
#   brain_regions[bankssts_L].Populations: values  E
#   brain_regions.bankssts_R .................... '--------------------'
#   brain_regions[bankssts_R].title ............. 'ANNarchyRegionNode gid: 4686f141-9aa7-4db8-8e11-01a048ba93b9'
#   brain_regions[bankssts_R].Type .............. 'ANNarchyRegionNode'
#   brain_regions[bankssts_R].gid ............... UUID('4686f141-9aa7-4db8-8e11-01a048ba93b9')
#   brain_regions[bankssts_R].label ............. 'bankssts_R'
#   brain_regions[bankssts_R].size .............. 1
#   brain_regions[bankssts_R].Populations ....... --------------------
#   brain_regions[bankssts_R].Populations: shape  (1,)
#   brain_regions[bankssts_R].Populations: dtype  <U1
#   brain_regions[bankssts_R].Populations: values  E
#   network_path ................................ ''
#   logger ...................................... <Logger tvb-multiscale (DEBUG)>
#   output_devices .............................. '--------------------'
#   output_devices.title ........................ 'DeviceSets gid: dcc68b75-3661-43d6-821f-bdbf8da6460a'
#   output_devices.Type ......................... 'DeviceSets'
#   output_devices.gid .......................... UUID('dcc68b75-3661-43d6-821f-bdbf8da6460a')
#   output_devices.label ........................ 'output_devices'
#   output_devices.size ......................... 2
#   output_devices.DeviceSets ................... --------------------
#   output_devices.DeviceSets: shape ............ (2,)
#   output_devices.DeviceSets: dtype ............ <U10
#   output_devices.DeviceSets: values ........... ['E' 'Excitatory']
#   output_devices.E ............................ '--------------------'
#   output_devices[E].title ..................... 'DeviceSet gid: e836659e-292a-456b-9fec-764949e92a99'
#   output_devices[E].Type ...................... 'DeviceSet'
#   output_devices[E].model ..................... 'SpikeMonitor'
#   output_devices[E].gid ....................... UUID('e836659e-292a-456b-9fec-764949e92a99')
#   output_devices[E].label ..................... 'E'
#   output_devices[E].size ...................... 2
#   output_devices[E].Devices ................... --------------------
#   output_devices[E].Devices: shape ............ (2,)
#   output_devices[E].Devices: dtype ............ <U10
#   output_devices[E].Devices: values ........... ['bankssts_L' 'bankssts_R']
#   output_devices.Excitatory ................... '--------------------'
#   output_devices[Excitatory].title ............ 'DeviceSet gid: 3bdff81c-6782-499f-82e5-ee2746b4a36f'
#   output_devices[Excitatory].Type ............. 'DeviceSet'
#   output_devices[Excitatory].model ............ 'Monitor'
#   output_devices[Excitatory].gid .............. UUID('3bdff81c-6782-499f-82e5-ee2746b4a36f')
#   output_devices[Excitatory].label ............ 'Excitatory'
#   output_devices[Excitatory].size ............. 2
#   output_devices[Excitatory].Devices .......... --------------------
#   output_devices[Excitatory].Devices: shape ... (2,)
#   output_devices[Excitatory].Devices: dtype ... <U10
#   output_devices[Excitatory].Devices: values .. ['bankssts_L' 'bankssts_R']
#   input_devices ............................... '--------------------'
#   input_devices.title ......................... 'DeviceSets gid: c2603ceb-815a-4178-8719-5cdea10d408a'
#   input_devices.Type .......................... 'DeviceSets'
#   input_devices.gid ........................... UUID('c2603ceb-815a-4178-8719-5cdea10d408a')
#   input_devices.label ......................... 'input_devices'
#   input_devices.size .......................... 1
#   input_devices.DeviceSets .................... --------------------
#   input_devices.DeviceSets: shape ............. (1,)
#   input_devices.DeviceSets: dtype ............. <U8
#   input_devices.DeviceSets: values ............ Stimulus
#   input_devices.Stimulus ...................... '--------------------'
#   input_devices[Stimulus].title ............... 'DeviceSet gid: cc396b82-b2d6-4ede-978a-2cbf115f0805'
#   input_devices[Stimulus].Type ................ 'DeviceSet'
#   input_devices[Stimulus].model ............... 'PoissonPopulation'
#   input_devices[Stimulus].gid ................. UUID('cc396b82-b2d6-4ede-978a-2cbf115f0805')
#   input_devices[Stimulus].label ............... 'Stimulus'
#   input_devices[Stimulus].size ................ 2
#   input_devices[Stimulus].Devices ............. --------------------
#   input_devices[Stimulus].Devices: shape ...... (2,)
#   input_devices[Stimulus].Devices: dtype ...... <U10
#   input_devices[Stimulus].Devices: values ..... ['bankssts_L' 'bankssts_R']
#   output_proxies .............................. '--------------------'
#   output_proxies.title ........................ 'DeviceSets gid: e1737f8a-b581-47bd-a5b3-fbaa9bffa63a'
#   output_proxies.Type ......................... 'DeviceSets'
#   output_proxies.gid .......................... UUID('e1737f8a-b581-47bd-a5b3-fbaa9bffa63a')
#   output_proxies.label ........................ 'output_proxies'
#   output_proxies.size ......................... 0
#   output_proxies.DeviceSets ................... --------------------
#   shape ....................................... (0,)
#   dtype ....................................... float64
#   is empty .................................... True
#   input_proxies ............................... '--------------------'
#   input_proxies.title ......................... 'DeviceSets gid: e53152db-4315-4047-bf8f-5cbaf795e3f8'
#   input_proxies.Type .......................... 'DeviceSets'
#   input_proxies.gid ........................... UUID('e53152db-4315-4047-bf8f-5cbaf795e3f8')
#   input_proxies.label ......................... ''
#   input_proxies.size .......................... 0
#   input_proxies.DeviceSets .................... --------------------
#   gid ......................................... UUID('ca8f9bb4-6e6f-4cdc-b2d0-17514bff2af6')
# )
# 2023-10-25 17:51:49,581 - INFO - examples.example -
# Building interfaces with Orchestrator TVBANNarchySerialOrchestrator...
# 2023-10-25 17:51:49,581 - INFO - examples.example -
# Building interfaces with Orchestrator TVBANNarchySerialOrchestrator...
#
# Building interfaces with Orchestrator TVBANNarchySerialOrchestrator...
# 2023-10-25 17:51:49,582 - INFO - examples.example -
# Building interfaces' with builder TVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2023-10-25 17:51:49,582 - INFO - examples.example -
# Building interfaces' with builder TVBANNarchyInterfaceBuilder of App TVBSerialApp...
#
# Building interfaces' with builder TVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2023-10-25 17:51:49,582 - INFO - examples.example -
# Configuring interfaces' builder DefaultTVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2023-10-25 17:51:49,582 - INFO - examples.example -
# Configuring interfaces' builder DefaultTVBANNarchyInterfaceBuilder of App TVBSerialApp...
#
# Configuring interfaces' builder DefaultTVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2023-10-25 17:51:49,582 - INFO - examples.example -
# Configuring default interfaces...
# 2023-10-25 17:51:49,582 - INFO - examples.example -
# Configuring default interfaces...
#
# Configuring default interfaces...
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2023-10-25 17:51:49,585 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model TimedPoissonPopulation for ['R']->E created!
# 2023-10-25 17:51:49,585 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model TimedPoissonPopulation for ['R']->E created!
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2023-10-25 17:51:49,743 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E->['R'] created!
# 2023-10-25 17:51:49,743 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E->['R'] created!
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2023-10-25 17:51:49,745 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-10-25 17:51:49,745 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2023-10-25 17:51:49,745 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2023-10-25 17:51:49,751 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2023-10-25 17:51:49,751 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2023-10-25 17:51:49,752 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-10-25 17:51:49,752 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# 2023-10-25 17:51:49,758 - INFO - examples.example -
# TVBtoANNarchyInterfaces (
#   title .................................. 'TVBtoANNarchyInterfaces gid: 0bf76034-a198-4a67-8d17-722ca631aff1'
#   Type ................................... 'TVBtoANNarchyInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoANNarchyInterface gid: 67940bf9-af6b-420b-9f53-9402006a5315'
#   interfaces[0].Type ..................... 'TVBtoANNarchyInterface'
#   interfaces[0].proxy .................... ANNarchyTimedPoissonPopulationSet gid: 10ed6458-606b-4297-9a60-7772f83cd6aa
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: ca8f9bb4-6e6f-4cdc-b2d0-17514bff2af6
#   interfaces[0].transformer .............. LinearRate gid: 92abd4da-c3f1-4417-82ef-9f098e2c4024
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[2, 67]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('67940bf9-af6b-420b-9f53-9402006a5315')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int32
#   interfaces[0].proxy_gids: unique_values  0
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('0bf76034-a198-4a67-8d17-722ca631aff1')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[0, 1]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 66
# )
# 2023-10-25 17:51:49,758 - INFO - examples.example -
# TVBtoANNarchyInterfaces (
#   title .................................. 'TVBtoANNarchyInterfaces gid: 0bf76034-a198-4a67-8d17-722ca631aff1'
#   Type ................................... 'TVBtoANNarchyInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoANNarchyInterface gid: 67940bf9-af6b-420b-9f53-9402006a5315'
#   interfaces[0].Type ..................... 'TVBtoANNarchyInterface'
#   interfaces[0].proxy .................... ANNarchyTimedPoissonPopulationSet gid: 10ed6458-606b-4297-9a60-7772f83cd6aa
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: ca8f9bb4-6e6f-4cdc-b2d0-17514bff2af6
#   interfaces[0].transformer .............. LinearRate gid: 92abd4da-c3f1-4417-82ef-9f098e2c4024
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[2, 67]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('67940bf9-af6b-420b-9f53-9402006a5315')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int32
#   interfaces[0].proxy_gids: unique_values  0
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('0bf76034-a198-4a67-8d17-722ca631aff1')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[0, 1]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 66
# )
#
# TVBtoANNarchyInterfaces (
#   title .................................. 'TVBtoANNarchyInterfaces gid: 0bf76034-a198-4a67-8d17-722ca631aff1'
#   Type ................................... 'TVBtoANNarchyInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoANNarchyInterface gid: 67940bf9-af6b-420b-9f53-9402006a5315'
#   interfaces[0].Type ..................... 'TVBtoANNarchyInterface'
#   interfaces[0].proxy .................... ANNarchyTimedPoissonPopulationSet gid: 10ed6458-606b-4297-9a60-7772f83cd6aa
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: ca8f9bb4-6e6f-4cdc-b2d0-17514bff2af6
#   interfaces[0].transformer .............. LinearRate gid: 92abd4da-c3f1-4417-82ef-9f098e2c4024
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[2, 67]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('67940bf9-af6b-420b-9f53-9402006a5315')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int32
#   interfaces[0].proxy_gids: unique_values  0
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('0bf76034-a198-4a67-8d17-722ca631aff1')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[0, 1]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 66
# )
# 2023-10-25 17:51:49,760 - INFO - examples.example -
# ANNarchyToTVBInterfaces (
#   title .................................. 'ANNarchyToTVBInterfaces gid: 5fcb5851-5151-4f48-bca0-95427db42075'
#   Type ................................... 'ANNarchyToTVBInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'ANNarchyToTVBInterface gid: 94667e10-8d40-439f-b8c2-5fe8456ed23e'
#   interfaces[0].Type ..................... 'ANNarchyToTVBInterface'
#   interfaces[0].proxy .................... ANNarchySpikeMonitorTotalSet gid: b9384a08-9b71-4956-866e-2e6cd1436fe1
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: ca8f9bb4-6e6f-4cdc-b2d0-17514bff2af6
#   interfaces[0].transformer .............. ElephantSpikesHistogramRate gid: af317733-361f-43c1-9548-77efa390313c
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (2,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: values ....... [[0, 1]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].dt ....................... 0.1
#   interfaces[0].times .................... --------------------
#   interfaces[0].times: shape ............. (2,)
#   interfaces[0].times: dtype ............. int64
#   interfaces[0].times: values ............ [[0, 1]]
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'SpikeMonitor'
#   interfaces[0].gid ...................... UUID('94667e10-8d40-439f-b8c2-5fe8456ed23e')
#   interfaces[0].number_of_proxy_nodes .... 2
#   interfaces[0].number_of_proxy_gids ..... 0
#   interfaces[0].proxy_gids ............... --------------------
#   shape .................................. (0,)
#   dtype .................................. float64
#   is empty ............................... True
#   interfaces[0].n_voi .................... 1
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('5fcb5851-5151-4f48-bca0-95427db42075')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[0, 1]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 2
# )
# 2023-10-25 17:51:49,760 - INFO - examples.example -
# ANNarchyToTVBInterfaces (
#   title .................................. 'ANNarchyToTVBInterfaces gid: 5fcb5851-5151-4f48-bca0-95427db42075'
#   Type ................................... 'ANNarchyToTVBInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'ANNarchyToTVBInterface gid: 94667e10-8d40-439f-b8c2-5fe8456ed23e'
#   interfaces[0].Type ..................... 'ANNarchyToTVBInterface'
#   interfaces[0].proxy .................... ANNarchySpikeMonitorTotalSet gid: b9384a08-9b71-4956-866e-2e6cd1436fe1
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: ca8f9bb4-6e6f-4cdc-b2d0-17514bff2af6
#   interfaces[0].transformer .............. ElephantSpikesHistogramRate gid: af317733-361f-43c1-9548-77efa390313c
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (2,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: values ....... [[0, 1]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].dt ....................... 0.1
#   interfaces[0].times .................... --------------------
#   interfaces[0].times: shape ............. (2,)
#   interfaces[0].times: dtype ............. int64
#   interfaces[0].times: values ............ [[0, 1]]
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
# ...
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. CosimCoupling(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 8d20dee6-f78f-4aa8-8ebf-9b991786e558
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 5ea1e060-34c6-4f6f-becd-76d45a4b77ce
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 00a8d123-7bea-4b8b-88bb-d35a8ba06446
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('c0f65ad4-5671-4c6b-9f7c-f3fe1424fe4f')
# )
# 2023-10-25 17:55:06,386 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: c0f65ad4-5671-4c6b-9f7c-f3fe1424fe4f'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... WilsonCowan gid: 40b13517-99e5-47a7-9dd9-414c0b4d5581
#   output_interfaces ................... TVBtoANNarchyInterfaces gid: ed621c41-9625-4396-9d2b-00b2fe433921
#   input_interfaces .................... ANNarchyToTVBInterfaces gid: 8c824749-1570-4725-89d2-e8eac91c51f1
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (2,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: values .............. [[0, 1]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (2,)
#   voi: dtype .......................... int64
#   voi: values ......................... [[0, 1]]
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[0, 1]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. CosimCoupling(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 8d20dee6-f78f-4aa8-8ebf-9b991786e558
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 5ea1e060-34c6-4f6f-becd-76d45a4b77ce
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 00a8d123-7bea-4b8b-88bb-d35a8ba06446
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('c0f65ad4-5671-4c6b-9f7c-f3fe1424fe4f')
# )
# 2023-10-25 17:55:06,386 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: c0f65ad4-5671-4c6b-9f7c-f3fe1424fe4f'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... WilsonCowan gid: 40b13517-99e5-47a7-9dd9-414c0b4d5581
#   output_interfaces ................... TVBtoANNarchyInterfaces gid: ed621c41-9625-4396-9d2b-00b2fe433921
#   input_interfaces .................... ANNarchyToTVBInterfaces gid: 8c824749-1570-4725-89d2-e8eac91c51f1
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (2,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: values .............. [[0, 1]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (2,)
#   voi: dtype .......................... int64
#   voi: values ......................... [[0, 1]]
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[0, 1]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. CosimCoupling(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 8d20dee6-f78f-4aa8-8ebf-9b991786e558
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 5ea1e060-34c6-4f6f-becd-76d45a4b77ce
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 00a8d123-7bea-4b8b-88bb-d35a8ba06446
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('c0f65ad4-5671-4c6b-9f7c-f3fe1424fe4f')
# )
#
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: c0f65ad4-5671-4c6b-9f7c-f3fe1424fe4f'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... WilsonCowan gid: 40b13517-99e5-47a7-9dd9-414c0b4d5581
#   output_interfaces ................... TVBtoANNarchyInterfaces gid: ed621c41-9625-4396-9d2b-00b2fe433921
#   input_interfaces .................... ANNarchyToTVBInterfaces gid: 8c824749-1570-4725-89d2-e8eac91c51f1
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (2,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: values .............. [[0, 1]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (2,)
#   voi: dtype .......................... int64
#   voi: values ......................... [[0, 1]]
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[0, 1]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. CosimCoupling(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 8d20dee6-f78f-4aa8-8ebf-9b991786e558
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 5ea1e060-34c6-4f6f-becd-76d45a4b77ce
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: