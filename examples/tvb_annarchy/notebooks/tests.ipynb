# %%
! pwd
# Out:
# /home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks

# %%
! python ../../../tvb_multiscale/tests/tvb_annarchy/test_spiking_models_builder_properties_methods.py
# Out:
# ANNarchy 4.7 (4.7.2.6) on linux (posix).
# 2023-10-04 16:21:07,867 - INFO - tvb-multiscale - Loading an ANNarchy instance...
# 2023-10-04 16:21:07,867 - INFO - tvb-multiscale - Loading an ANNarchy instance...
# 2023-10-04 16:21:07,867 - INFO - tvb-multiscale - Loading an ANNarchy instance...
# 2023-10-04 16:21:07,868 - INFO - tvb-multiscale - Cleaning ANNarchy compilation directory, if any...
# 2023-10-04 16:21:07,868 - INFO - tvb-multiscale - Cleaning ANNarchy compilation directory, if any...
# 2023-10-04 16:21:07,868 - INFO - tvb-multiscale - Cleaning ANNarchy compilation directory, if any...
# ...
# annarchy simulator: <module 'ANNarchy' from '/home/docker/.local/lib/python3.10/site-packages/ANNarchy/__init__.py'>
# min_delay:
# 0.05
#
# tvb_dt:
# 0.1
#
# monitor_period:
# 0.1
#
# tvb_model:
# Linear
#
# number_of_regions:
# 68
#
# tvb_weights:
# [[0.0000000e+00 4.8155833e-02 5.5569724e-01 ... 0.0000000e+00
#   9.3632959e-04 1.5197568e-03]
# ...

# %%
! python ../../../tvb_multiscale/tests/tvb_annarchy/test_models.py 0
# Out:
# ANNarchy 4.7 (4.7.2.6) on linux (posix).
#
#
# Testing model 0
# ******************************************************
# ******************************************************
#
# ----------------------------------------------------------------------------------------------------
# Find results in /home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/DefaultExcIO_RATE_bidir/res !
# ----------------------------------------------------------------------------------------------------
# 2023-10-04 16:21:11,349 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
# 2023-10-04 16:21:11,349 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
#
# Starting App TVBANNarchySerialOrchestrator...
#
# Starting App TVBSerialApp...
#
# Setting TVB LIBRARY_PROFILE...
#
# Starting App ANNarchySerialApp...
# ...

# %%
! python ../../../tvb_multiscale/tests/tvb_annarchy/test_models.py 1
# Out:
# ANNarchy 4.7 (4.7.2.6) on linux (posix).
#
#
# Testing model 1
# ******************************************************
# ******************************************************
#
# ----------------------------------------------------------------------------------------------------
# Find results in /home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/DefaultExcIO_SPIKES_bidir/res !
# ----------------------------------------------------------------------------------------------------
# 2023-10-04 16:21:17,124 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
# 2023-10-04 16:21:17,124 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
#
# Starting App TVBANNarchySerialOrchestrator...
#
# Starting App TVBSerialApp...
#
# Setting TVB LIBRARY_PROFILE...
#
# Starting App ANNarchySerialApp...
# ...

# %%
! python ../../../tvb_multiscale/tests/tvb_annarchy/test_models.py 2
# Out:
# ANNarchy 4.7 (4.7.2.6) on linux (posix).
#
#
# Testing model 2
# ******************************************************
# ******************************************************
#
# ----------------------------------------------------------------------------------------------------
# Find results in /home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/WilsonCowan_RATE_bidir/res !
# ----------------------------------------------------------------------------------------------------
# 2023-10-04 16:21:23,282 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
# 2023-10-04 16:21:23,282 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
#
# Starting App TVBANNarchySerialOrchestrator...
#
# Starting App TVBSerialApp...
#
# Setting TVB LIBRARY_PROFILE...
#
# Starting App ANNarchySerialApp...
# ...

# %%
! python ../../../tvb_multiscale/tests/tvb_annarchy/test_models.py 3
# Out:
# ANNarchy 4.7 (4.7.2.6) on linux (posix).
#
#
# Testing model 3
# ******************************************************
# ******************************************************
#
# ----------------------------------------------------------------------------------------------------
# Find results in /home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/WilsonCowan_SPIKES_bidir/res !
# ----------------------------------------------------------------------------------------------------
# 2023-10-04 16:21:28,707 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
# 2023-10-04 16:21:28,707 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
#
# Starting App TVBANNarchySerialOrchestrator...
#
# Starting App TVBSerialApp...
#
# Setting TVB LIBRARY_PROFILE...
#
# Starting App ANNarchySerialApp...
# ...

# %%
! python ../../../tvb_multiscale/tests/tvb_annarchy/test_models.py -1
# Out:
# ANNarchy 4.7 (4.7.2.6) on linux (posix).
#
# ******************************************************
# ******************************************************
# TestDefaultRATE
# ******************************************************
# ******************************************************
#
# ----------------------------------------------------------------------------------------------------
# Find results in /home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/DefaultExcIO_RATE_bidir/res !
# ----------------------------------------------------------------------------------------------------
# 2023-10-04 16:21:34,359 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
# 2023-10-04 16:21:34,359 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
#
# Starting App TVBANNarchySerialOrchestrator...
#
# Starting App TVBSerialApp...
#
# Setting TVB LIBRARY_PROFILE...
#
# Starting App ANNarchySerialApp...
# ...
