# %%
! pwd
# Out:
# /home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks

# %%
! python ../../../tvb_multiscale/tests/tvb_annarchy/test_spiking_models_builder_properties_methods.py
# Out:
# ANNarchy 4.8 (4.8.2.3) on linux (posix).
# 2025-02-19 10:58:51,791 - INFO - tvb-multiscale - Loading an ANNarchy instance...
# 2025-02-19 10:58:51,791 - INFO - tvb-multiscale - Loading an ANNarchy instance...
# 2025-02-19 10:58:51,791 - INFO - tvb-multiscale - Loading an ANNarchy instance...
# 2025-02-19 10:58:51,791 - INFO - tvb-multiscale - Cleaning ANNarchy compilation directory, if any...
# 2025-02-19 10:58:51,791 - INFO - tvb-multiscale - Cleaning ANNarchy compilation directory, if any...
# 2025-02-19 10:58:51,791 - INFO - tvb-multiscale - Cleaning ANNarchy compilation directory, if any...
# <tvb_multiscale.tvb_annarchy.annarchy_models.models.default.DefaultExcIOBuilder object at 0xffff759a0490>
# annarchy simulator: <module 'ANNarchy' from '/home/docker/.local/lib/python3.10/site-packages/ANNarchy/__init__.py'>
# min_delay:
# 0.05
#
# tvb_dt:
# 0.1
#
# monitor_period:
# 0.1
#
# tvb_model:
# Linear
#
# number_of_regions:
# 68
#
# tvb_weights:
# [[0.0000000e+00 4.8155833e-02 5.5569724e-01 ... 0.0000000e+00
#   9.3632959e-04 1.5197568e-03]
#  [3.4694958e-02 0.0000000e+00 4.0470140e+00 ... 0.0000000e+00
#   0.0000000e+00 6.4991351e-02]
#  [3.3234182e-01 1.6091147e+00 0.0000000e+00 ... 0.0000000e+00
#   1.3227513e-03 2.2254678e-01]
#  ...
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#   4.2837810e-03 6.6117304e+01]
#  [6.8634180e-04 0.0000000e+00 1.8867925e-02 ... 2.7493696e-02
#   0.0000000e+00 2.8296225e+01]
#  [2.8677947e-04 1.3400005e-02 3.4921828e-01 ... 2.5495074e+01
#   1.4883909e+01 0.0000000e+00]]
#
# tvb_delays:
# [[ 0.         39.98974333 34.00171    ...  0.         47.8
#   44.73333333]
#  [39.98974333  0.         14.00699533 ...  0.          0.
#   23.274074  ]
#  [34.00171    14.00699533  0.         ...  0.         58.33333333
#   37.56438333]
#  ...
#  [ 0.          0.          0.         ...  0.         20.76666667
#    6.62544467]
#  [47.8         0.         58.33333333 ... 20.76666667  0.
#    5.83055433]
#  [44.73333333 23.274074   37.56438333 ...  6.62544467  5.83055433
#    0.        ]]
#
# region_labels:
# ['bankssts_L' 'bankssts_R' 'caudalanteriorcingulate_L'
#  'caudalanteriorcingulate_R' 'caudalmiddlefrontal_L'
#  'caudalmiddlefrontal_R' 'cuneus_L' 'cuneus_R' 'entorhinal_L'
#  'entorhinal_R' 'frontalpole_L' 'frontalpole_R' 'fusiform_L' 'fusiform_R'
#  'inferiorparietal_L' 'inferiorparietal_R' 'inferiortemporal_L'
#  'inferiortemporal_R' 'insula_L' 'insula_R' 'isthmuscingulate_L'
#  'isthmuscingulate_R' 'lateraloccipital_L' 'lateraloccipital_R'
#  'lateralorbitofrontal_L' 'lateralorbitofrontal_R' 'lingual_L' 'lingual_R'
#  'medialorbitofrontal_L' 'medialorbitofrontal_R' 'middletemporal_L'
#  'middletemporal_R' 'paracentral_L' 'paracentral_R' 'parahippocampal_L'
#  'parahippocampal_R' 'parsopercularis_L' 'parsopercularis_R'
#  'parsorbitalis_L' 'parsorbitalis_R' 'parstriangularis_L'
#  'parstriangularis_R' 'pericalcarine_L' 'pericalcarine_R' 'postcentral_L'
#  'postcentral_R' 'posteriorcingulate_L' 'posteriorcingulate_R'
#  'precentral_L' 'precentral_R' 'precuneus_L' 'precuneus_R'
#  'rostralanteriorcingulate_L' 'rostralanteriorcingulate_R'
#  'rostralmiddlefrontal_L' 'rostralmiddlefrontal_R' 'superiorfrontal_L'
#  'superiorfrontal_R' 'superiorparietal_L' 'superiorparietal_R'
#  'superiortemporal_L' 'superiortemporal_R' 'supramarginal_L'
#  'supramarginal_R' 'temporalpole_L' 'temporalpole_R'
#  'transversetemporal_L' 'transversetemporal_R']
#
# number_of_populations:
# 0
#
# populations_models:
# OrderedDict()
#
# populations_nodes:
# OrderedDict()
#
# populations_scales:
# OrderedDict()
#
# populations_sizes:
# OrderedDict()
#
# populations_params:
# OrderedDict()
#
# populations_connections_labels:
# []
#
# populations_connections_models:
# OrderedDict()
#
# populations_connections_nodes:
# OrderedDict()
#
# populations_connections_weights:
# OrderedDict()
#
# populations_connections_delays:
# OrderedDict()
#
# populations_connections_receptor_types:
# OrderedDict()
#
# populations_connections_conn_spec:
# OrderedDict()
#
# nodes_connections_labels:
# []
#
# nodes_connections_models:
# OrderedDict()
#
# nodes_connections_source_nodes:
# OrderedDict()
#
# nodes_connections_target_nodes:
# OrderedDict()
#
# nodes_connections_weights:
# OrderedDict()
#
# nodes_connections_delays:
# OrderedDict()
#
# nodes_connections_receptor_types:
# OrderedDict()
#
# nodes_connections_conn_spec:
# OrderedDict()

# %%
# ! /usr/bin/pip3 install ANNarchy --upgrade;
! python ../../../tvb_multiscale/tests/tvb_annarchy/test_models.py
# Out:
# ANNarchy 4.8 (4.8.2.3) on linux (posix).
#
# ******************************************************
# ******************************************************
# TestDefaultRATE
# ******************************************************
# ******************************************************
#
# ----------------------------------------------------------------------------------------------------
# Find results in /home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/DefaultExcIO_RATE_bidir/res !
# ----------------------------------------------------------------------------------------------------
# 2025-02-19 10:58:55,394 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
# 2025-02-19 10:58:55,394 - INFO - examples.example -
# Starting App TVBANNarchySerialOrchestrator...
#
# Starting App TVBANNarchySerialOrchestrator...
# 2025-02-19 10:58:55,394 - INFO - examples.example -
# Starting App TVBSerialApp...
# 2025-02-19 10:58:55,394 - INFO - examples.example -
# Starting App TVBSerialApp...
#
# Starting App TVBSerialApp...
# 2025-02-19 10:58:55,395 - INFO - examples.example -
# Setting TVB LIBRARY_PROFILE...
# 2025-02-19 10:58:55,395 - INFO - examples.example -
# Setting TVB LIBRARY_PROFILE...
#
# Setting TVB LIBRARY_PROFILE...
# 2025-02-19 10:58:55,396 - INFO - examples.example -
# Starting App ANNarchySerialApp...
# 2025-02-19 10:58:55,396 - INFO - examples.example -
# Starting App ANNarchySerialApp...
#
# Starting App ANNarchySerialApp...
# 2025-02-19 10:58:55,396 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Loading an ANNarchy instance...
# 2025-02-19 10:58:55,396 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Loading an ANNarchy instance...
# 2025-02-19 10:58:55,396 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Cleaning ANNarchy compilation directory, if any...
# 2025-02-19 10:58:55,396 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Cleaning ANNarchy compilation directory, if any...
#
#
# Configuring...
#
# Done! in 0.000089 min
#
#
#
# Building...
# 2025-02-19 10:58:55,402 - INFO - examples.example -
# Building with App TVBANNarchySerialOrchestrator...
# 2025-02-19 10:58:55,402 - INFO - examples.example -
# Building with App TVBANNarchySerialOrchestrator...
#
# Building with App TVBANNarchySerialOrchestrator...
# 2025-02-19 10:58:55,402 - INFO - examples.example -
# Building cosimulators with TVBANNarchySerialOrchestrator...
# 2025-02-19 10:58:55,402 - INFO - examples.example -
# Building cosimulators with TVBANNarchySerialOrchestrator...
#
# Building cosimulators with TVBANNarchySerialOrchestrator...
# 2025-02-19 10:58:55,402 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
# 2025-02-19 10:58:55,402 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
#
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
# 2025-02-19 10:58:55,403 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2025-02-19 10:58:55,403 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2025-02-19 10:58:55,404 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2025-02-19 10:58:55,410 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2025-02-19 10:58:55,410 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2025-02-19 10:58:55,410 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2025-02-19 10:58:55,411 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# 2025-02-19 10:58:55,494 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: 5644c80c-ae0b-40a5-9c96-653bffb7f76b'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid:
- INFO - examples.example - Generating and connecting ['Excitatory'] -> ['E'] device set of model Monitor
# for nodes [0, 1]...
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2025-02-19 10:58:55,623 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Excitatory created!
# 2025-02-19 10:58:55,623 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Excitatory created!
# 2025-02-19 10:58:55,625 - INFO - examples.example - Generating and connecting input devices, if any...
# 2025-02-19 10:58:55,625 - INFO - examples.example - Generating and connecting input devices, if any...
# 2025-02-19 10:58:55,625 - INFO - examples.example - Generating and connecting ['Stimulus'] -> [['E']] device set of model PoissonPopulation
# for nodes [0, 1]...
# 2025-02-19 10:58:55,625 - INFO - examples.example - Generating and connecting ['Stimulus'] -> [['E']] device set of model PoissonPopulation
# for nodes [0, 1]...
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2025-02-19 10:58:55,626 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model PoissonPopulation for Stimulus created!
# 2025-02-19 10:58:55,626 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model PoissonPopulation for Stimulus created!
# 2025-02-19 10:58:55,632 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2025-02-19 10:58:55,632 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2025-02-19 10:58:55,632 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2025-02-19 10:58:55,632 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2025-02-19 10:58:55,632 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2025-02-19 10:58:55,632 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2025-02-19 10:58:55,632 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2025-02-19 10:58:55,632 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2025-02-19 10:58:55,632 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# ANNarchyNetwork (
#   title ....................................... 'ANNarchyNetwork gid: e698a40c-6b95-4ee0-be0b-0f7806818e44'
#   Type ........................................ 'ANNarchyNetwork'
#   config ...................................... '--------------------'
#   config.title ................................ 'Config gid: 2c671282-718b-41bb-a1b3-004b124a6077'
#   config.Type ................................. 'Config'
#   config.gid .................................. UUID('2c671282-718b-41bb-a1b3-004b124a6077')
#   brain_regions ............................... '--------------------'
#   brain_regions.title ......................... 'ANNarchyBrain gid: 13c7666c-347b-440f-a560-a4f57fa50ef6'
#   brain_regions.Type .......................... 'ANNarchyBrain'
#   brain_regions.gid ........................... UUID('13c7666c-347b-440f-a560-a4f57fa50ef6')
#   brain_regions.label ......................... ''
#   brain_regions.size .......................... 2
#   brain_regions.Regions ....................... --------------------
#   brain_regions.Regions: shape ................ (2,)
#   brain_regions.Regions: dtype ................ <U10
#   brain_regions.Regions: values ............... ['bankssts_L' 'bankssts_R']
#   brain_regions.bankssts_L .................... '--------------------'
#   brain_regions[bankssts_L].title ............. 'ANNarchyRegionNode gid: dd1827f4-4dd7-4b6b-889e-7ed6592fe001'
#   brain_regions[bankssts_L].Type .............. 'ANNarchyRegionNode'
#   brain_regions[bankssts_L].gid ............... UUID('dd1827f4-4dd7-4b6b-889e-7ed6592fe001')
#   brain_regions[bankssts_L].label ............. 'bankssts_L'
#   brain_regions[bankssts_L].size .............. 1
#   brain_regions[bankssts_L].Populations ....... --------------------
#   brain_regions[bankssts_L].Populations: shape  (1,)
#   brain_regions[bankssts_L].Populations: dtype  <U1
#   brain_regions[bankssts_L].Populations: values  E
#   brain_regions.bankssts_R .................... '--------------------'
#   brain_regions[bankssts_R].title ............. 'ANNarchyRegionNode gid: ccd72b98-d4b6-4b4f-993b-db84494c545e'
#   brain_regions[bankssts_R].Type .............. 'ANNarchyRegionNode'
#   brain_regions[bankssts_R].gid ............... UUID('ccd72b98-d4b6-4b4f-993b-db84494c545e')
#   brain_regions[bankssts_R].label ............. 'bankssts_R'
#   brain_regions[bankssts_R].size .............. 1
#   brain_regions[bankssts_R].Populations ....... --------------------
#   brain_regions[bankssts_R].Populations: shape  (1,)
#   brain_regions[bankssts_R].Populations: dtype  <U1
#   brain_regions[bankssts_R].Populations: values  E
#   network_path ................................ ''
#   logger ...................................... <Logger tvb-multiscale (DEBUG)>
#   output_devices .............................. '--------------------'
#   output_devices.title ........................ 'DeviceSets gid: 39878f9b-5a23-4e39-82a1-7fa692ec808d'
#   output_devices.Type ......................... 'DeviceSets'
#   output_devices.gid .......................... UUID('39878f9b-5a23-4e39-82a1-7fa692ec808d')
#   output_devices.label ........................ 'output_devices'
#   output_devices.size ......................... 2
#   output_devices.DeviceSets ................... --------------------
#   output_devices.DeviceSets: shape ............ (2,)
#   output_devices.DeviceSets: dtype ............ <U10
#   output_devices.DeviceSets: values ........... ['E' 'Excitatory']
#   output_devices.E ............................ '--------------------'
#   output_devices[E].title ..................... 'DeviceSet gid: 048bce2e-7e81-420a-b1ac-ec52ff46436d'
#   output_devices[E].Type ...................... 'DeviceSet'
#   output_devices[E].model ..................... 'SpikeMonitor'
#   output_devices[E].gid ....................... UUID('048bce2e-7e81-420a-b1ac-ec52ff46436d')
#   output_devices[E].label ..................... 'E'
#   output_devices[E].size ...................... 2
#   output_devices[E].Devices ................... --------------------
#   output_devices[E].Devices: shape ............ (2,)
#   output_devices[E].Devices: dtype ............ <U10
#   output_devices[E].Devices: values ........... ['bankssts_L' 'bankssts_R']
#   output_devices.Excitatory ................... '--------------------'
#   output_devices[Excitatory].title ............ 'DeviceSet gid: 57639d96-c17e-4b00-8801-1f3ed2ca1231'
#   output_devices[Excitatory].Type ............. 'DeviceSet'
#   output_devices[Excitatory].model ............ 'Monitor'
#   output_devices[Excitatory].gid .............. UUID('57639d96-c17e-4b00-8801-1f3ed2ca1231')
#   output_devices[Excitatory].label ............ 'Excitatory'
#   output_devices[Excitatory].size ............. 2
#   output_devices[Excitatory].Devices .......... --------------------
#   output_devices[Excitatory].Devices: shape ... (2,)
#   output_devices[Excitatory].Devices: dtype ... <U10
#   output_devices[Excitatory].Devices: values .. ['bankssts_L' 'bankssts_R']
#   input_devices ............................... '--------------------'
#   input_devices.title ......................... 'DeviceSets gid: 47dd7c3e-78f6-4c2b-abf3-bee0ac074407'
#   input_devices.Type .......................... 'DeviceSets'
#   input_devices.gid ........................... UUID('47dd7c3e-78f6-4c2b-abf3-bee0ac074407')
#   input_devices.label ......................... 'input_devices'
#   input_devices.size .......................... 1
#   input_devices.DeviceSets .................... --------------------
#   input_devices.DeviceSets: shape ............. (1,)
#   input_devices.DeviceSets: dtype ............. <U8
#   input_devices.DeviceSets: values ............ Stimulus
#   input_devices.Stimulus ...................... '--------------------'
#   input_devices[Stimulus].title ............... 'DeviceSet gid: 6ec88835-8cea-44f6-ba37-fef20361e9bb'
#   input_devices[Stimulus].Type ................ 'DeviceSet'
#   input_devices[Stimulus].model ............... 'PoissonPopulation'
#   input_devices[Stimulus].gid ................. UUID('6ec88835-8cea-44f6-ba37-fef20361e9bb')
#   input_devices[Stimulus].label ............... 'Stimulus'
#   input_devices[Stimulus].size ................ 2
#   input_devices[Stimulus].Devices ............. --------------------
#   input_devices[Stimulus].Devices: shape ...... (2,)
#   input_devices[Stimulus].Devices: dtype ...... <U10
#   input_devices[Stimulus].Devices: values ..... ['bankssts_L' 'bankssts_R']
#   output_proxies .............................. '--------------------'
#   output_proxies.title ........................ 'DeviceSets gid: 19216235-4c96-448b-8308-a5e0dc7dff9d'
#   output_proxies.Type ......................... 'DeviceSets'
#   output_proxies.gid .......................... UUID('19216235-4c96-448b-8308-a5e0dc7dff9d')
#   output_proxies.label ........................ 'output_proxies'
#   output_proxies.size ......................... 0
#   output_proxies.DeviceSets ................... --------------------
#   shape ....................................... (0,)
#   dtype ....................................... float64
#   is empty .................................... True
#   input_proxies ............................... '--------------------'
#   input_proxies.title ......................... 'DeviceSets gid: df5db4a7-1320-48dc-894c-696d7968ffc4'
#   input_proxies.Type .......................... 'DeviceSets'
#   input_proxies.gid ........................... UUID('df5db4a7-1320-48dc-894c-696d7968ffc4')
#   input_proxies.label ......................... ''
#   input_proxies.size .......................... 0
#   input_proxies.DeviceSets .................... --------------------
#   gid ......................................... UUID('e698a40c-6b95-4ee0-be0b-0f7806818e44')
# )
# 2025-02-19 10:58:55,634 - INFO - examples.example -
# Building interfaces with Orchestrator TVBANNarchySerialOrchestrator...
# 2025-02-19 10:58:55,634 - INFO - examples.example -
# Building interfaces with Orchestrator TVBANNarchySerialOrchestrator...
#
# Building interfaces with Orchestrator TVBANNarchySerialOrchestrator...
# 2025-02-19 10:58:55,635 - INFO - examples.example -
# Building interfaces' with builder TVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2025-02-19 10:58:55,635 - INFO - examples.example -
# Building interfaces' with builder TVBANNarchyInterfaceBuilder of App TVBSerialApp...
#
# Building interfaces' with builder TVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2025-02-19 10:58:55,635 - INFO - examples.example -
# Configuring interfaces' builder DefaultTVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2025-02-19 10:58:55,635 - INFO - examples.example -
# Configuring interfaces' builder DefaultTVBANNarchyInterfaceBuilder of App TVBSerialApp...
#
# Configuring interfaces' builder DefaultTVBANNarchyInterfaceBuilder of App TVBSerialApp...
# 2025-02-19 10:58:55,635 - INFO - examples.example -
# Configuring default interfaces...
# 2025-02-19 10:58:55,635 - INFO - examples.example -
# Configuring default interfaces...
#
# Configuring default interfaces...
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2025-02-19 10:58:55,638 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model TimedPoissonPopulation for ['R']->E created!
# 2025-02-19 10:58:55,638 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model TimedPoissonPopulation for ['R']->E created!
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2025-02-19 10:58:55,816 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E->['R'] created!
# 2025-02-19 10:58:55,816 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E->['R'] created!
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:77: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2025-02-19 10:58:55,818 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2025-02-19 10:58:55,818 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2025-02-19 10:58:55,819 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2025-02-19 10:58:55,825 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2025-02-19 10:58:55,825 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2025-02-19 10:58:55,826 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2025-02-19 10:58:55,826 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# 2025-02-19 10:58:55,832 - INFO - examples.example -
# TVBtoANNarchyInterfaces (
#   title .................................. 'TVBtoANNarchyInterfaces gid: 4a3b288f-434e-4d91-9925-f9fce627055f'
#   Type ................................... 'TVBtoANNarchyInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoANNarchyInterface gid: 43f40bc7-b8d4-4f9b-886d-4fa78b6344c9'
#   interfaces[0].Type ..................... 'TVBtoANNarchyInterface'
#   interfaces[0].proxy .................... ANNarchyTimedPoissonPopulationSet gid: d2dfc2ea-b6e5-42d1-bcb6-fe8155bf1b4c
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: e698a40c-6b95-4ee0-be0b-0f7806818e44
#   interfaces[0].transformer .............. LinearRate gid: 8501f7ea-51b3-49f9-a375-b4eb71be0328
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[2, 67]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('43f40bc7-b8d4-4f9b-886d-4fa78b6344c9')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int32
#   interfaces[0].proxy_gids: unique_values  0
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('4a3b288f-434e-4d91-9925-f9fce627055f')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[0, 1]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 66
# )
# 2025-02-19 10:58:55,832 - INFO - examples.example -
# TVBtoANNarchyInterfaces (
#   title .................................. 'TVBtoANNarchyInterfaces gid: 4a3b288f-434e-4d91-9925-f9fce627055f'
#   Type ................................... 'TVBtoANNarchyInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoANNarchyInterface gid: 43f40bc7-b8d4-4f9b-886d-4fa78b6344c9'
#   interfaces[0].Type ..................... 'TVBtoANNarchyInterface'
#   interfaces[0].proxy .................... ANNarchyTimedPoissonPopulationSet gid: d2dfc2ea-b6e5-42d1-bcb6-fe8155bf1b4c
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: e698a40c-6b95-4ee0-be0b-0f7806818e44
#   interfaces[0].transformer .............. LinearRate gid: 8501f7ea-51b3-49f9-a375-b4eb71be0328
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[2, 67]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('43f40bc7-b8d4-4f9b-886d-4fa78b6344c9')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int32
#   interfaces[0].proxy_gids: unique_values  0
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('4a3b288f-434e-4d91-9925-f9fce627055f')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[0, 1]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 66
# )
#
# TVBtoANNarchyInterfaces (
#   title .................................. 'TVBtoANNarchyInterfaces gid: 4a3b288f-434e-4d91-9925-f9fce627055f'
#   Type ................................... 'TVBtoANNarchyInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoANNarchyInterface gid: 43f40bc7-b8d4-4f9b-886d-4fa78b6344c9'
#   interfaces[0].Type ..................... 'TVBtoANNarchyInterface'
#   interfaces[0].proxy .................... ANNarchyTimedPoissonPopulationSet gid: d2dfc2ea-b6e5-42d1-bcb6-fe8155bf1b4c
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: e698a40c-6b95-4ee0-be0b-0f7806818e44
#   interfaces[0].transformer .............. LinearRate gid: 8501f7ea-51b3-49f9-a375-b4eb71be0328
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[2, 67]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('43f40bc7-b8d4-4f9b-886d-4fa78b6344c9')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int32
#   interfaces[0].proxy_gids: unique_values  0
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('4a3b288f-434e-4d91-9925-f9fce627055f')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[0, 1]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 66
# )
# 2025-02-19 10:58:55,833 - INFO - examples.example -
# ANNarchyToTVBInterfaces (
#   title .................................. 'ANNarchyToTVBInterfaces gid: d081e36f-098a-45c5-b4af-c09164ffc43d'
#   Type ................................... 'ANNarchyToTVBInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'ANNarchyToTVBInterface gid: 52dba2c6-e78e-4c4f-9a8a-d4f9030a45b1'
#   interfaces[0].Type ..................... 'ANNarchyToTVBInterface'
#   interfaces[0].proxy .................... ANNarchySpikeMonitorTotalSet gid: d74077d7-7485-4aed-acad-84fdd1f981ab
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid