#   tvb_app.interfaces_builder.exclusive_nodes ....................................... True
#   tvb_app.interfaces_builder.output_flag ........................................... True
#   tvb_app.interfaces_builder.input_flag ............................................ True
#   tvb_app.interfaces_builder.proxy_inds ............................................ --------------------
#   tvb_app.interfaces_builder.proxy_inds: shape ..................................... --------------------
#   tvb_app.interfaces_builder.proxy_inds: dtype ..................................... dtype('int64')
#   tvb_app.interfaces_builder.proxy_inds: values .................................... --------------------
#   tvb_app.interfaces_builder.output_interfaces ..................................... 'properties:'
#   tvb_app.interfaces_builder.input_interfaces ...................................... 'properties:'
#   tvb_app.interfaces_builder.default_coupling_mode ................................. 'spikeNet'
#   tvb_app.interfaces_builder.global_coupling_scaling ............................... --------------------
#   tvb_app.interfaces_builder.global_coupling_scaling: shape ........................ (68,)
#   tvb_app.interfaces_builder.global_coupling_scaling: dtype ........................ float64
#   tvb_app.interfaces_builder.global_coupling_scaling: unique_values ................ 0.00390625
#   tvb_app.interfaces_builder.dt .................................................... '0.1'
#   tvb_app.interfaces_builder.gid ................................................... UUID('986df392-2d89-4362-b551-0cca504f3c5e')
#   tvb_app.interfaces_builder.voi: shape ............................................ --------------------
#   tvb_app.interfaces_builder.voi: shape: shape ..................................... (1,)
#   tvb_app.interfaces_builder.voi: shape: dtype ..................................... int64
#   tvb_app.interfaces_builder.voi: shape: values .................................... 1
#   tvb_app.interfaces_builder.voi: dtype ............................................ dtype('int64')
#   tvb_app.interfaces_builder.voi: values ........................................... 0
#   tvb_app.interfaces_builder.populations: shape .................................... --------------------
#   shape ............................................................................ (0,)
#   dtype ............................................................................ float64
#   is empty ......................................................................... True
#   tvb_app.interfaces_builder.populations: dtype .................................... dtype('<U1')
#   tvb_app.interfaces_builder.populations: values ................................... 'E'
#   tvb_app.interfaces_builder.proxy_inds: shape: shape .............................. (1,)
#   tvb_app.interfaces_builder.proxy_inds: shape: dtype .............................. int64
#   tvb_app.interfaces_builder.proxy_inds: shape: values ............................. 66
#   tvb_app.interfaces_builder.proxy_inds: values: shape ............................. (1, 2)
#   tvb_app.interfaces_builder.proxy_inds: values: dtype ............................. int64
#   tvb_app.interfaces_builder.proxy_inds: values: values ............................ [0 1]
#   tvb_app.interfaces_builder.voi_labels: shape ..................................... --------------------
#   tvb_app.interfaces_builder.voi_labels: shape: shape .............................. (1,)
#   tvb_app.interfaces_builder.voi_labels: shape: dtype .............................. int64
#   tvb_app.interfaces_builder.voi_labels: shape: values ............................. 1
#   tvb_app.interfaces_builder.voi_labels: dtype ..................................... dtype('<U1')
#   tvb_app.interfaces_builder.voi_labels: values .................................... 'R'
#   tvb_app.interfaces_builder.proxy ................................................. 'ANNarchyTimedPoissonPopulationSet gid: b8dd1f9d-d716-438d-9e4b-a3e93e002dfb'
#   tvb_app.interfaces_builder.transformer ........................................... 'LinearRate gid: c6b31275-6f00-4005-b1f0-7ca907d46c48'
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape ............................. --------------------
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: shape ...................... (1,)
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: dtype ...................... int64
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: values ..................... 2
#   tvb_app.interfaces_builder.spiking_proxy_inds: dtype ............................. dtype('int64')
#   tvb_app.interfaces_builder.spiking_proxy_inds: values ............................ --------------------
#   tvb_app.interfaces_builder.spiking_proxy_inds: values: shape ..................... (1, 2)
#   tvb_app.interfaces_builder.spiking_proxy_inds: values: dtype ..................... int64
#   tvb_app.interfaces_builder.spiking_proxy_inds: values: values .................... [0 1]
#   tvb_app.interfaces_builder.coupling_mode ......................................... "'spikeNet'"
#   tvb_app.interfaces_builder.proxy_inds: unique_values ............................. --------------------
#   tvb_app.interfaces_builder.proxy_inds: unique_values: shape ...................... (1, 2)
#   tvb_app.interfaces_builder.proxy_inds: unique_values: dtype ...................... int64
#   tvb_app.interfaces_builder.proxy_inds: unique_values: values ..................... [ 2 67]
#   tvb_app.interfaces_builder.monitor_ind ........................................... '0'
#   tvb_app.spiking_network .......................................................... '--------------------'
#   tvb_app.spiking_network.title .................................................... 'ANNarchyNetwork gid: 1f1957c8-e999-4c21-a683-4d6d92d02d19'
#   tvb_app.spiking_network.Type ..................................................... 'ANNarchyNetwork'
#   tvb_app.spiking_network.config ................................................... Config gid: 78faad9b-f759-45ea-8a9b-bad9b55f1907
#   tvb_app.spiking_network.brain_regions ............................................ ANNarchyBrain gid: 46576e9b-1920-4915-ad50-759245aebac6
#   tvb_app.spiking_network.network_path ............................................. ''
#   tvb_app.spiking_network.output_devices ........................................... DeviceSets gid: 72dbd578-49bc-4235-a505-7e69fbaf7892
#   tvb_app.spiking_network.input_devices ............................................ DeviceSets gid: 91e60c64-0c3d-48f8-a045-5fff2b0f3d8c
#   tvb_app.spiking_network.output_proxies ........................................... DeviceSets gid: ca4882ea-fa5c-469f-a24a-09d3aa6c1e38
#   tvb_app.spiking_network.input_proxies ............................................ DeviceSets gid: e9c64df8-5e8e-4a7f-8aab-5b510bf245e0
#   tvb_app.spiking_network.gid ...................................................... UUID('1f1957c8-e999-4c21-a683-4d6d92d02d19')
#   tvb_app.cosimulator_builder ...................................................... '--------------------'
#   tvb_app.cosimulator_builder.title ................................................ 'CoSimulatorSerialBuilder gid: 9d1516bc-f8ff-4f6f-867a-3b5eb8d92ae2'
#   tvb_app.cosimulator_builder.Type ................................................. 'CoSimulatorSerialBuilder'
#   tvb_app.cosimulator_builder.config ............................................... Config gid: 78faad9b-f759-45ea-8a9b-bad9b55f1907
#   tvb_app.cosimulator_builder.logger ............................................... <Logger examples.example (DEBUG)>
#   tvb_app.cosimulator_builder.model ................................................ Linear gid: a24649a8-94da-4e3a-a60d-ace0f8732646
#   tvb_app.cosimulator_builder.model_params[r_e] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[r_e]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[r_e]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[r_e]: values ............................ 0
#   tvb_app.cosimulator_builder.model_params[r_i] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[r_i]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[r_i]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[r_i]: values ............................ 0
#   tvb_app.cosimulator_builder.model_params[k_e] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[k_e]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[k_e]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[k_e]: values ............................ 1
#   tvb_app.cosimulator_builder.model_params[k_i] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[k_i]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[k_i]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[k_i]: values ............................ 1
#   tvb_app.cosimulator_builder.model_params[tau_e] .................................. --------------------
#   tvb_app.cosimulator_builder.model_params[tau_e]: shape ........................... (1,)
#   tvb_app.cosimulator_builder.model_params[tau_e]: dtype ........................... float64
#   tvb_app.cosimulator_builder.model_params[tau_e]: values .......................... 10
#   tvb_app.cosimulator_builder.model_params[tau_i] .................................. --------------------
#   tvb_app.cosimulator_builder.model_params[tau_i]: shape ........................... (1,)
#   tvb_app.cosimulator_builder.model_params[tau_i]: dtype ........................... float64
#   tvb_app.cosimulator_builder.model_params[tau_i]: values .......................... 10
#   tvb_app.cosimulator_builder.model_params[c_ee] ................................... --------------------
#   tvb_app.cosimulator_builder.model_params[c_ee]: shape ............................ (1,)
#   tvb_app.cosimulator_builder.model_params[c_ee]: dtype ............................ float64
#   tvb_app.cosimulator_builder.model_params[c_ee]: values ........................... 10
#   tvb_app.cosimulator_builder.model_params[c_ei] ................................... --------------------
#   tvb_app.cosimulator_builder.model_params[c_ei]: shape ............................ (1,)
#   tvb_app.cosimulator_builder.model_params[c_ei]: dtype ............................ float64
#   tvb_app.cosimulator_builder.model_params[c_ei]: values ........................... 6
#   tvb_app.cosimulator_builder.model_params[c_ie] ................................... --------------------
#   tvb_app.cosimulator_builder.model_params[c_ie]: shape ............................ (1,)
#   tvb_app.cosimulator_builder.model_params[c_ie]: dtype ............................ float64
#   tvb_app.cosimulator_builder.model_params[c_ie]: values ........................... 10
#   tvb_app.cosimulator_builder.model_params[c_ii] ................................... --------------------
#   tvb_app.cosimulator_builder.model_params[c_ii]: shape ............................ (1,)
#   tvb_app.cosimulator_builder.model_params[c_ii]: dtype ............................ float64
#   tvb_app.cosimulator_builder.model_params[c_ii]: values ........................... 1
#   tvb_app.cosimulator_builder.model_params[alpha_e] ................................ --------------------
#   tvb_app.cosimulator_builder.model_params[alpha_e]: shape ......................... (1,)
#   tvb_app.cosimulator_builder.model_params[alpha_e]: dtype ......................... float64
#   tvb_app.cosimulator_builder.model_params[alpha_e]: values ........................ 1.2
#   tvb_app.cosimulator_builder.model_params[alpha_i] ................................ --------------------
#   tvb_app.cosimulator_builder.model_params[alpha_i]: shape ......................... (1,)
#   tvb_app.cosimulator_builder.model_params[alpha_i]: dtype ......................... float64
#   tvb_app.cosimulator_builder.model_params[alpha_i]: values ........................ 2
# ...
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.cortical]
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[2, 67]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'SPIKES'
#   interfaces[0].gid ...................... UUID('eeb66f95-65a2-4820-a7f2-4ce4ebb34f9f')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 660
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (660,)
#   interfaces[0].proxy_gids: dtype ........ int32
#   interfaces[0].proxy_gids: unique_values  [[0, 9]]
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('095d86d9-9d04-4dba-ac50-b57b971160fb')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[0, 1]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 66
# )
#
# ANNarchyToTVBInterfaces (
#   title .................................. 'ANNarchyToTVBInterfaces gid: 304dd407-3ce0-4888-b85e-02bf2c7963f1'
#   Type ................................... 'ANNarchyToTVBInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'ANNarchyToTVBInterface gid: 63492d7e-6391-47ee-ae8d-ef64795f5eb3'
#   interfaces[0].Type ..................... 'ANNarchyToTVBInterface'
#   interfaces[0].proxy .................... ANNarchySpikeMonitorTotalSet gid: c839c6f0-9d10-4536-8b0c-39204bd7bfc6
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: e48216ec-1e07-4808-bfb8-4e026329e678
#   interfaces[0].transformer .............. ElephantSpikesHistogramRate gid: 7e41b3ac-b8ef-4aaf-89ce-fb004878ed12
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (2,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: values ....... [[0, 1]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].dt ....................... 0.1
#   interfaces[0].times .................... --------------------
#   interfaces[0].times: shape ............. (2,)
#   interfaces[0].times: dtype ............. int64
#   interfaces[0].times: values ............ [[0, 1]]
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'SpikeMonitor'
#   interfaces[0].gid ...................... UUID('63492d7e-6391-47ee-ae8d-ef64795f5eb3')
#   interfaces[0].number_of_proxy_nodes .... 2
#   interfaces[0].number_of_proxy_gids ..... 0
#   interfaces[0].proxy_gids ............... --------------------
#   shape .................................. (0,)
#   dtype .................................. float64
#   is empty ............................... True
#   interfaces[0].n_voi .................... 1
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('304dd407-3ce0-4888-b85e-02bf2c7963f1')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[0, 1]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 2
# )
#
# Built in 0.310460 secs!
#
# Failed to summarize:
# tvb_app.cosimulator_builder.monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# Failed to summarize:
# tvb_app.cosimulator.monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# TVBANNarchySerialOrchestrator (
#   title ............................................................................ 'TVBANNarchySerialOrchestrator gid: 6417a37b-119d-48ef-a152-7b9208a1773d'
#   Type ............................................................................. 'TVBANNarchySerialOrchestrator'
#   config ........................................................................... '--------------------'
#   config.title ..................................................................... 'Config gid: 82b0a9ad-6d53-48d6-b51a-750d7670c630'
#   config.Type ...................................................................... 'Config'
#   config.gid ....................................................................... UUID('82b0a9ad-6d53-48d6-b51a-750d7670c630')
#   tvb_app .......................................................................... '--------------------'
#   tvb_app.title .................................................................... 'TVBSerialApp gid: bc134775-fecc-481f-b112-9b03f99c8689'
#   tvb_app.Type ..................................................................... 'TVBSerialApp'
#   tvb_app.config ................................................................... '--------------------'
#   tvb_app.config.title ............................................................. 'Config gid: 82b0a9ad-6d53-48d6-b51a-750d7670c630'
#   tvb_app.config.Type .............................................................. 'Config'
#   tvb_app.config.gid ............................................................... UUID('82b0a9ad-6d53-48d6-b51a-750d7670c630')
#   tvb_app.interfaces_builder ....................................................... '--------------------'
#   tvb_app.interfaces_builder.title ................................................. 'DefaultTVBANNarchyInterfaceBuilder gid: 3915de83-9078-487e-9ce4-47e553927b3c'
#   tvb_app.interfaces_builder.Type .................................................. 'DefaultTVBANNarchyInterfaceBuilder'
#   tvb_app.interfaces_builder.spiking_network ....................................... 'ANNarchyNetwork gid: e48216ec-1e07-4808-bfb8-4e026329e678'
#   tvb_app.interfaces_builder.N_E ................................................... 10
#   tvb_app.interfaces_builder.model ................................................. "'SPIKES'"
#   tvb_app.interfaces_builder.config ................................................ Config gid: 82b0a9ad-6d53-48d6-b51a-750d7670c630
#   tvb_app.interfaces_builder.logger ................................................ <Logger examples.example (DEBUG)>
#   tvb_app.interfaces_builder.tvb_cosimulator ....................................... CoSimulatorSerial gid: 4fd5186c-6c98-4d8b-8a16-673d6cad880c
#   tvb_app.interfaces_builder.exclusive_nodes ....................................... True
#   tvb_app.interfaces_builder.output_flag ........................................... True
#   tvb_app.interfaces_builder.input_flag ............................................ True
#   tvb_app.interfaces_builder.proxy_inds ............................................ --------------------
#   tvb_app.interfaces_builder.proxy_inds: shape ..................................... --------------------
#   tvb_app.interfaces_builder.proxy_inds: dtype ..................................... dtype('int64')
#   tvb_app.interfaces_builder.proxy_inds: values .................................... --------------------
#   tvb_app.interfaces_builder.output_interfaces ..................................... 'properties:'
#   tvb_app.interfaces_builder.input_interfaces ...................................... 'properties:'
#   tvb_app.interfaces_builder.default_coupling_mode ................................. 'spikeNet'
#   tvb_app.interfaces_builder.global_coupling_scaling ............................... --------------------
#   tvb_app.interfaces_builder.global_coupling_scaling: shape ........................ (68,)
#   tvb_app.interfaces_builder.global_coupling_scaling: dtype ........................ float64
#   tvb_app.interfaces_builder.global_coupling_scaling: unique_values ................ 0.00390625
#   tvb_app.interfaces_builder.dt .................................................... '0.1'
#   tvb_app.interfaces_builder.gid ................................................... UUID('3915de83-9078-487e-9ce4-47e553927b3c')
#   tvb_app.interfaces_builder.voi: shape ............................................ --------------------
#   tvb_app.interfaces_builder.voi: shape: shape ..................................... (1,)
#   tvb_app.interfaces_builder.voi: shape: dtype ..................................... int64
#   tvb_app.interfaces_builder.voi: shape: values .................................... 1
#   tvb_app.interfaces_builder.voi: dtype ............................................ dtype('int64')
#   tvb_app.interfaces_builder.voi: values ........................................... 0
#   tvb_app.interfaces_builder.populations: shape .................................... --------------------
#   shape ............................................................................ (0,)
#   dtype ............................................................................ float64
#   is empty ......................................................................... True
#   tvb_app.interfaces_builder.populations: dtype .................................... dtype('<U1')
#   tvb_app.interfaces_builder.populations: values ................................... 'E'
#   tvb_app.interfaces_builder.proxy_inds: shape: shape .............................. (1,)
#   tvb_app.interfaces_builder.proxy_inds: shape: dtype .............................. int64
#   tvb_app.interfaces_builder.proxy_inds: shape: values ............................. 66
#   tvb_app.interfaces_builder.proxy_inds: values: shape ............................. (1, 2)
#   tvb_app.interfaces_builder.proxy_inds: values: dtype ............................. int64
#   tvb_app.interfaces_builder.proxy_inds: values: values ............................ [0 1]
#   tvb_app.interfaces_builder.voi_labels: shape ..................................... --------------------
#   tvb_app.interfaces_builder.voi_labels: shape: shape .............................. (1,)
#   tvb_app.interfaces_builder.voi_labels: shape: dtype .............................. int64
#   tvb_app.interfaces_builder.voi_labels: shape: values ............................. 1
#   tvb_app.interfaces_builder.voi_labels: dtype ..................................... dtype('<U1')
#   tvb_app.interfaces_builder.voi_labels: values .................................... 'R'
#   tvb_app.interfaces_builder.proxy ................................................. 'ANNarchySpikeSourceArraySet gid: 4cb2f9f2-c164-4dbc-ae63-0ab159573a33'
#   tvb_app.interfaces_builder.transformer ........................................... 'RatesToSpikesElephantPoisson gid: 60d44490-d8b3-4c8e-8f1d-009395d5e7d9'
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape ............................. --------------------
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: shape ...................... (1,)
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: dtype ...................... int64
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: values ..................... 2
#   tvb_app.interfaces_builder.spiking_proxy_inds: dtype ............................. dtype('int64')
#   tvb_app.interfaces_builder.spiking_proxy_inds: values ............................ --------------------
#   tvb_app.interfaces_builder.spiking_proxy_inds: values: shape ..................... (1, 2)
#   tvb_app.interfaces_builder.spiking_proxy_inds: values: dtype ..................... int64
#   tvb_app.interfaces_builder.spiking_proxy_inds: values: values .................... [0 1]
#   tvb_app.interfaces_builder.coupling_mode ......................................... "'spikeNet'"
#   tvb_app.interfaces_builder.proxy_inds: unique_values ............................. --------------------
#   tvb_app.interfaces_builder.proxy_inds: unique_values: shape ...................... (1, 2)
#   tvb_app.interfaces_builder.proxy_inds: unique_values: dtype ...................... int64
#   tvb_app.interfaces_builder.proxy_inds: unique_values: values ..................... [ 2 67]
#   tvb_app.interfaces_builder.monitor_ind ........................................... '0'
#   tvb_app.spiking_network .......................................................... '--------------------'
#   tvb_app.spiking_network.title .................................................... 'ANNarchyNetwork gid: e48216ec-1e07-4808-bfb8-4e026329e678'
#   tvb_app.spiking_network.Type ..................................................... 'ANNarchyNetwork'
#   tvb_app.spiking_network.config ................................................... Config gid: 82b0a9ad-6d53-48d6-b51a-750d7670c630
#   tvb_app.spiking_network.brain_regions ............................................ ANNarchyBrain gid: 5181a010-96f6-450a-bab0-dcc9a054060c
#   tvb_app.spiking_network.network_path ............................................. ''
#   tvb_app.spiking_network.output_devices ........................................... DeviceSets gid: 0b77ccd1-9ab0-42b5-b16c-2d4d78e33781
#   tvb_app.spiking_network.input_devices ............................................ DeviceSets gid: 3d844bed-4543-43a0-ace8-89d1152a1910
#   tvb_app.spiking_network.output_proxies ........................................... DeviceSets gid: b5fc6e8e-6d87-4ab2-b168-2b007c945a7d
#   tvb_app.spiking_network.input_proxies ............................................ DeviceSets gid: a7318b19-2b24-402a-ab87-a8308ad0b5e6
#   tvb_app.spiking_network.gid ...................................................... UUID('e48216ec-1e07-4808-bfb8-4e026329e678')
#   tvb_app.cosimulator_builder ...................................................... '--------------------'
#   tvb_app.cosimulator_builder.title ................................................ 'CoSimulatorSerialBuilder gid: 47884fb6-6a29-435d-9bf8-7c80bbbab925'
#   tvb_app.cosimulator_builder.Type ................................................. 'CoSimulatorSerialBuilder'
#   tvb_app.cosimulator_builder.config ............................................... Config gid: 82b0a9ad-6d53-48d6-b51a-750d7670c630
#   tvb_app.cosimulator_builder.logger ............................................... <Logger examples.example (DEBUG)>
#   tvb_app.cosimulator_builder.model ................................................ Linear gid: 68fbe542-e82f-4643-87ed-09a4fecb1ca5
#   tvb_app.cosimulator_builder.model_params[r_e] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[r_e]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[r_e]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[r_e]: values ............................ 0
#   tvb_app.cosimulator_builder.model_params[r_i] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[r_i]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[r_i]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[r_i]: values ............................ 0
#   tvb_app.cosimulator_builder.model_params[k_e] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[k_e]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[k_e]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[k_e]: values ............................ 1
#   tvb_app.cosimulator_builder.model_params[k_i] .................................... --------------------
#   tvb_app.cosimulator_builder.model_params[k_i]: shape ............................. (1,)
#   tvb_app.cosimulator_builder.model_params[k_i]: dtype ............................. float64
#   tvb_app.cosimulator_builder.model_params[k_i]: values ............................ 1
#   tvb_app.cosimulator_builder.model_params[tau_e] .................................. --------------------
#   tvb_app.cosimulator_builder.model_params[tau_e]: shape ........................... (1,)
#   tvb_app.cosimulator_builder.model_params[tau_e]: dtype ........................... float64
#   tvb_app.cosimulator_builder.model_params[tau_e]: values .......................... 10
#   tvb_app.cosimulator_builder.model_params[tau_i] .................................. --------------------
#   tvb_app.cosimulator_builder.model_params[tau_i]: shape ........................... (1,)
#   tvb_app.cosimulator_builder.model_params[tau_i]: dtype ........................... float64
#   tvb_app.cosimulator_builder.model_params[tau_i]: values .......................... 10
#   tvb_app.cosimulator_builder.model_params[c_ee] ................................... --------------------
#   tvb_app.cosimulator_builder.model_params[c_ee]: shape ............................ (1,)
#   tvb_app.cosimulator_builder.model_params[c_ee]: dtype ............................ float64
#   tvb_app.cosimulator_builder.model_params[c_ee]: values ........................... 10
#   tvb_app.cosimulator_builder.model_params[c_ei] ................................... --------------------
#   tvb_app.cosimulator_builder.model_params[c_ei]: shape ............................ (1,)
#   tvb_app.cosimulator_builder.model_params[c_ei]: dtype ............................ float64
#   tvb_app.cosimulator_builder.model_params[c_ei]: values ........................... 6
#   tvb_app.cosimulator_builder.model_params[c_ie] ................................... --------------------
#   tvb_app.cosimulator_builder.model_params[c_ie]: shape ............................ (1,)
#   tvb_app.cosimulator_builder.model_params[c_ie]: dtype ............................ float64
#   tvb_app.cosimulator_builder.model_params[c_ie]: values ........................... 10
#   tvb_app.cosimulator_builder.model_params[c_ii] ................................... --------------------
#   tvb_app.cosimulator_builder.model_params[c_ii]: shape ............................ (1,)
#   tvb_app.cosimulator_builder.model_params[c_ii]: dtype ............................ float64
#   tvb_app.cosimulator_builder.model_params[c_ii]: values ........................... 1
#   tvb_app.cosimulator_builder.model_params[alpha_e] ................................ --------------------
#   tvb_app.cosimulator_builder.model_params[alpha_e]: shape ......................... (1,)
#   tvb_app.cosimulator_builder.model_params[alpha_e]: dtype ......................... float64
#   tvb_app.cosimulator_builder.model_params[alpha_e]: values ........................ 1.2
#   tvb_app.cosimulator_builder.model_params[alpha_i] ................................ --------------------
#   tvb_app.cosimulator_builder.model_params[alpha_i]: shape ......................... (1,)
#   tvb_app.cosimulator_builder.model_params[alpha_i]: dtype ......................... float64
#   tvb_app.cosimulator_builder.model_params[alpha_i]: values ........................ 2
# ...
#   -0.27065  62.4632   62.4399   12.6364   64.7371   58.6815  -18.7497
#  -29.4435   60.5999   26.9971  -25.4143   62.4196  -48.4458   27.201
#   22.3661   52.096    28.9998   19.2317  -49.9418    0.41451  54.069
#   56.9432    2.3815   54.4009  -21.09     51.9872  -10.1052   28.0673
#   53.8073   -7.9653  -44.5804   17.7626   32.336    48.1555   17.8577
#   33.199  ]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.cortical] ................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.cortical]: shape ............ (68,)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.cortical]: dtype ............ bool
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.cortical]: unique_values .... 1
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres] ................ --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: shape ......... (68,)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: dtype ......... bool
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: =False ........ {0...33}
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: =True ......... {34...67}
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations] ............... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations]: shape ........ (68, 3)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations]: dtype ........ float64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations]: values ....... [-0.38261669 -0.60546974 -0.69786163  0.65982329 -0.3692104  -0.65445925
#   0.92603708  0.22476123  0.30321232 -0.75417582  0.4576563   0.47092414
#  -0.50299289  0.05509325  0.86253283  0.899222    0.06479787  0.43266734
#   0.40962978  0.3030412   0.86044725 -0.71762975  0.19590929  0.66830165
#   0.65151989 -0.30294387 -0.69551912 -0.8720307  -0.10976373 -0.47698467
#  -0.00596095  0.82174661 -0.56982188 -0.12180604  0.81564435 -0.56558606
#   0.40682931  0.054199   -0.91189494 -0.41228273 -0.03266817 -0.91047007
#  -0.80006394 -0.49775     0.33487704  0.83300378 -0.52883519  0.16259782
#  -0.25474036 -0.29356364 -0.92137275  0.20335288 -0.08556166 -0.97535984
#  -0.97482388  0.20036282 -0.09784246  0.96436493  0.25302228 -0.07733052
#   0.93018948 -0.35218341 -0.10351031 -0.75968686 -0.25980467 -0.5961354
#  -0.49661151 -0.72092729 -0.4833641   0.70221386 -0.68505051 -0.19391104
#  -0.23475324  0.09820225 -0.96708181  0.1829861   0.03111709 -0.98262293
#   0.86369223  0.13933983 -0.48437604 -0.56179383  0.02038304 -0.82702614
#   0.88075419 -0.10750546 -0.46120996 -0.98248087 -0.07928951 -0.16865499
#  -0.95037587  0.18198158  0.252326    0.90738399  0.29899871  0.29538799
#   0.84287785 -0.21924381 -0.49141538 -0.93942975  0.02652263 -0.34171377
#   0.2119279  -0.58288886 -0.78442791 -0.13402574 -0.56884351 -0.81145189
#  -0.55077346  0.83158287 -0.07154388  0.89696688  0.18764621  0.40029904
#  -0.59633825  0.47078993 -0.65018269  0.63719518  0.19074258 -0.7467259
#  -0.5790787  -0.29505125 -0.7600083   0.77357165 -0.2593268  -0.5782184
#   0.72945509  0.37259806 -0.57364271 -0.85038668 -0.08062112 -0.51994492
#  -0.62004143  0.48159849  0.6193638   0.71211482  0.4534374   0.53599161
#   0.84926834 -0.02662222  0.5272898  -0.8704929   0.03160028  0.49116549
#  -0.85920021  0.04946875  0.50924242  0.82188478  0.0903833   0.56243779
#   0.83202099 -0.15648958 -0.53221432 -0.93909788 -0.08768294 -0.33227531
#   0.95323808  0.30032389 -0.03380406 -0.88853176  0.42340502 -0.17674701
#  -0.59416038  0.73807852  0.31970852  0.44899813  0.79714001  0.40369356
#   0.68409308  0.4363876   0.58445062 -0.78808872  0.30711392  0.53347654
#  -0.50538932 -0.58355453  0.63564593  0.23008214 -0.57162063  0.78759892
#  -0.42941662  0.88199453  0.19413146  0.4440229   0.85956469  0.2529668
#  -0.90286225 -0.30715946  0.30082026  0.65267736 -0.75558871  0.05565929
#   0.73908346  0.67084084 -0.061059   -0.65805472  0.7526894  -0.02055836
#  -0.04366157  0.3210788   0.94604549 -0.38115902  0.48848431  0.78492094]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas] ...................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas]: shape ............... (68,)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas]: dtype ............... float64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas]: unique_values ....... [ 71.  76.  59.  65. 226. 158. 162.  44.  30.  21.  27. 305. 298. 348.
#  428. 274. 244. 178. 200. 117. 101. 415. 403. 210. 213. 290. 280. 127.
#  164. 237. 261. 125.  69.  72. 165. 159.  63.  64. 112. 146.  95. 122.
#  295. 316. 133. 147. 405. 384. 281.  78. 433. 410. 582. 539. 446. 422.
#  346. 330. 318.  47.  48.  50.  35.]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays] .................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays]: shape ............. (68, 68)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays]: dtype ............. int64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays]: unique_values ..... [[1], [36, 37], [40, 41], [44, 93], [96, 99], [101, 113], [115, 119], [122, 123], [125, 141], [143, 162], [164, 166], [168, 170], [172, 174], [176, 179], [181, 189], [191, 222], [224, 253], [255, 274], [277, 348], [350, 362], [364, 384], [386, 431], [433, 461], [463, 466], [468, 471], [473, 474], [476, 529], [531, 543], [546, 558], [560, 570], [572, 573], [576, 581], [583, 593], [595, 602], [604, 605], [607], [609, 615], [617], [619, 620], [622], [624, 625], [628], [630, 631], [633, 634], [636], [639, 645], [648, 649], [652, 656], [658], [660], [662, 665], [667, 671], [673], [675], [677], [680, 684], [688], [690, 693], [699, 700], [703, 705], [707], [710, 714], [718, 722], [724, 729], [731], [734, 735], [739], [744], [747], [749], [751, 754], [758, 759], [761], [763, 764], [770], [781], [784, 786], [792, 793], [795], [799], [801], [804], [812, 814], [820], [827], [841], [862], [879]]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays] ..................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays]: shape .............. (68, 68)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays]: dtype .............. float64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays]: unique_values ...... [ 0.1        39.98974333 34.00171    ... 20.76666667  6.62544467
#   5.83055433]
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a] .............................. --------------------
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a]: shape ....................... (1,)
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a]: dtype ....................... float64
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a]: values ...................... 0.00390625
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b] .............................. --------------------
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b]: shape ....................... (1,)
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b]: dtype ....................... float64
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b]: values ...................... 0
#   spikeNet_app.interfaces_builder .................................................. None
#   spikeNet_app.logger .............................................................. <Logger examples.example (DEBUG)>
#   spikeNet_app.default_tvb_serial_cosim_path ....................................... '/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/DefaultExcIO_SPIKES_bidir/config/tvb_serial_cosimulator.pkl'
#   spikeNet_app.gid ................................................................. UUID('4eecb0a4-ba87-494e-a09e-158f29a162cd')
#   spikeNet_app.spiking_cosimulator ................................................. <module 'ANNarchy' from '/home/docker/.local/lib/python3.10/site-packages/ANNarchy/__init__.py'>
#   logger ........................................................................... <Logger examples.example (DEBUG)>
#   default_tvb_serial_cosim_path .................................................... '/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/DefaultExcIO_SPIKES_bidir/config/tvb_serial_cosimulator.pkl'
#   gid .............................................................................. UUID('6417a37b-119d-48ef-a152-7b9208a1773d')
# )
# None
#
#
# Simulating...
#
# Simulating for 36ms with App TVBANNarchySerialOrchestrator...
#
# Configuring simulation with App TVBANNarchySerialOrchestrator...
#
# Configuring simulation with App TVBSerialApp...
# 2023-09-20 18:28:15,987 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-20 18:28:15,987 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2023-09-20 18:28:15,987 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2023-09-20 18:28:15,993 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2023-09-20 18:28:15,993 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2023-09-20 18:28:15,994 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-20 18:28:15,994 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
#
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: 4fd5186c-6c98-4d8b-8a16-673d6cad880c'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: 68fbe542-e82f-4643-87ed-09a4fecb1ca5
#   output_interfaces ................... TVBtoANNarchyInterfaces gid: 095d86d9-9d04-4dba-ac50-b57b971160fb
#   input_interfaces .................... ANNarchyToTVBInterfaces gid: 304dd407-3ce0-4888-b85e-02bf2c7963f1
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (66,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: unique_values ....... [[2, 67]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (1,)
#   voi: dtype .......................... int64
#   voi: values ......................... 0
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[0, 1]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. RawCosim(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 8149f035-6a47-4d43-a913-3bc6d20a28fa
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 6393004d-0e8c-4f01-99bb-942c4010c40e
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 691033b6-d354-4461-afae-41af2ef1f49d
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('4fd5186c-6c98-4d8b-8a16-673d6cad880c')
# )
#
# Configuring simulation with App ANNarchySerialApp...
# Compiling ...  OK
#
# Simulating for 36ms with App TVBSerialApp...
# Traceback (most recent call last):
#   File "/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/../../../tvb_multiscale/tests/tvb_annarchy/test_models.py", line 154, in <module>
#     test_models(models_to_test_ANNarchy, iM=iM)
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/tests/core/test_models.py", line 205, in test_models
#     print(run_test(models_to_test[iM]))
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/tests/core/test_models.py", line 166, in run_test
#     raise e
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/tests/core/test_models.py", line 162, in run_test
#     test_model.test()
#   File "/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/../../../tvb_multiscale/tests/tvb_annarchy/test_models.py", line 62, in test
#     self.run()
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/tests/core/test_spikeNet_models.py", line 37, in run
#     return self.run_fun()
#   File "/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/../../../tvb_multiscale/tests/tvb_annarchy/test_models.py", line 42, in run_fun
#     default_example(model=self.tvb_to_spikeNet_mode,
#   File "/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/example.py", line 20, in default_example
#     return main_example(default_example_base, DefaultExcIOBuilder(), DefaultTVBANNarchyInterfaceBuilder(), **kwargs)
#   File "/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/example.py", line 15, in main_example
#     return model_fun_to_run(ann_model_builder, tvb_ann_model_builder, TVBANNarchySerialOrchestrator,
#   File "/home/docker/packages/tvb-multiscale/examples/example.py", line 202, in default_example
#     return main_example(orchestrator_app,
#   File "/home/docker/packages/tvb-multiscale/examples/example.py", line 126, in main_example
#     orchestrator.simulate(simulation_length)
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/core/orchestrators/serial_orchestrator.py", line 86, in simulate
#     self.tvb_app.simulate()
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/core/orchestrators/tvb_app.py", line 199, in simulate
#     self._results = self._cosimulator.run()
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/core/tvb/cosimulator/cosimulator_serial.py", line 98, in run
#     self.run_cosimulation(ts, xs, wall_time_start,
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/core/tvb/cosimulator/cosimulator_serial.py", line 76, in run_cosimulation
#     self.send_cosim_coupling(True)
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/core/tvb/cosimulator/cosimulator.py", line 429, in send_cosim_coupling
#     self.output_interfaces(self.loop_cosim_monitor_output(self.n_tvb_steps_ran_since_last_synch,
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/core/interfaces/tvb/interfaces.py", line 421, in __call__
#     outputs.append(interface([self._compute_interface_times(interface, data),
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/core/interfaces/tvb/interfaces.py", line 258, in __call__
#     self.transform_data(
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/core/interfaces/tvb/interfaces.py", line 248, in transform_data
#     self.transformer()
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/core/interfaces/base/transformers/models/base.py", line 76, in __call__
#     self.compute()
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/core/interfaces/base/transformers/models/base.py", line 68, in compute
#     self.output_buffer = np.array(self._compute(self.input_buffer, *args, **kwargs))
# ValueError: setting an array element with a sequence. The requested array has an inhomogeneous shape after 2 dimensions. The detected shape was (66, 10) + inhomogeneous part.

# %%
! python ../../../tvb_multiscale/tests/tvb_annarchy/test_models.py 2
# Out:
# ANNarchy 4.7 (4.7.2.6) on linux (posix).
#
#
# Testing model 2
# ******************************************************
# ******************************************************
#
# ----------------------------------------------------------------------------------------------------
# Find results in /home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/WilsonCowan_RATE_bidir/res !
# ----------------------------------------------------------------------------------------------------
#
# Starting App TVBANNarchySerialOrchestrator...
#
# Starting App TVBSerialApp...
#
# Setting TVB LIBRARY_PROFILE...
#
# Starting App ANNarchySerialApp...
# 2023-09-20 18:31:12,576 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Loading an ANNarchy instance...
# 2023-09-20 18:31:12,576 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Loading an ANNarchy instance...
# 2023-09-20 18:31:12,576 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Cleaning ANNarchy compilation directory, if any...
# 2023-09-20 18:31:12,576 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Cleaning ANNarchy compilation directory, if any...
#
#
# Configuring...
#
# Done! in 0.000063 min
#
#
#
# Building...
#
# Building with App TVBANNarchySerialOrchestrator...
# 2023-09-20 18:31:12,581 - INFO - examples.example - Building cosimulators with TVBANNarchySerialOrchestrator...
# 2023-09-20 18:31:12,581 - INFO - examples.example - Building cosimulators with TVBANNarchySerialOrchestrator...
#
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
# 2023-09-20 18:31:12,582 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-20 18:31:12,582 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-09-20 18:31:12,583 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2023-09-20 18:31:12,592 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-09-20 18:31:12,593 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-09-20 18:31:12,593 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-20 18:31:12,593 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
#
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: 7ec0b7a5-c93a-4331-81e3-d0400dcc1688'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... WilsonCowan gid:

#   output_devices[Inhibitory].label ............ 'Inhibitory'
#   output_devices[Inhibitory].size ............. 2
#   output_devices[Inhibitory].Devices .......... --------------------
#   output_devices[Inhibitory].Devices: shape ... (2,)
#   output_devices[Inhibitory].Devices: dtype ... <U10
#   output_devices[Inhibitory].Devices: values .. ['bankssts_L' 'bankssts_R']
#   input_devices ............................... '--------------------'
#   input_devices.title ......................... 'DeviceSets gid: 65852a28-58d2-4fdc-928d-520fd4d7f61a'
#   input_devices.Type .......................... 'DeviceSets'
#   input_devices.gid ........................... UUID('65852a28-58d2-4fdc-928d-520fd4d7f61a')
#   input_devices.label ......................... 'input_devices'
#   input_devices.size .......................... 1
#   input_devices.DeviceSets .................... --------------------
#   input_devices.DeviceSets: shape ............. (1,)
#   input_devices.DeviceSets: dtype ............. <U8
#   input_devices.DeviceSets: values ............ Stimulus
#   input_devices.Stimulus ...................... '--------------------'
#   input_devices[Stimulus].title ............... 'DeviceSet gid: 4a7a6823-be0b-4134-a16d-1583a821770d'
#   input_devices[Stimulus].Type ................ 'DeviceSet'
#   input_devices[Stimulus].model ............... 'PoissonPopulation'
#   input_devices[Stimulus].gid ................. UUID('4a7a6823-be0b-4134-a16d-1583a821770d')
#   input_devices[Stimulus].label ............... 'Stimulus'
#   input_devices[Stimulus].size ................ 2
#   input_devices[Stimulus].Devices ............. --------------------
#   input_devices[Stimulus].Devices: shape ...... (2,)
#   input_devices[Stimulus].Devices: dtype ...... <U10
#   input_devices[Stimulus].Devices: values ..... ['bankssts_L' 'bankssts_R']
#   output_proxies .............................. '--------------------'
#   output_proxies.title ........................ 'DeviceSets gid: d85cc98c-d28c-4e4b-bc64-3b0e37cfa810'
#   output_proxies.Type ......................... 'DeviceSets'
#   output_proxies.gid .......................... UUID('d85cc98c-d28c-4e4b-bc64-3b0e37cfa810')
#   output_proxies.label ........................ 'output_proxies'
#   output_proxies.size ......................... 0
#   output_proxies.DeviceSets ................... --------------------
#   shape ....................................... (0,)
#   dtype ....................................... float64
#   is empty .................................... True
#   input_proxies ............................... '--------------------'
#   input_proxies.title ......................... 'DeviceSets gid: fd3ba125-ea7e-4567-b9e4-d984f46acd67'
#   input_proxies.Type .......................... 'DeviceSets'
#   input_proxies.gid ........................... UUID('fd3ba125-ea7e-4567-b9e4-d984f46acd67')
#   input_proxies.label ......................... ''
#   input_proxies.size .......................... 0
#   input_proxies.DeviceSets .................... --------------------
#   gid ......................................... UUID('a0349064-cebf-4ac8-aea9-9825d3c62382')
# )
#
# Building interfaces with Orchestrator TVBANNarchySerialOrchestrator...
#
# Building interfaces' with builder TVBANNarchyInterfaceBuilder of App TVBSerialApp...
#
# Configuring interfaces' builder WilsonCowanTVBANNarchyInterfaceBuilder of App TVBSerialApp...
#
# Configuring default interfaces...
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:76: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2023-09-20 18:31:12,841 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model TimedPoissonPopulation for ['E']->E created!
# 2023-09-20 18:31:12,841 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model TimedPoissonPopulation for ['E']->E created!
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:76: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2023-09-20 18:31:12,848 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E->['E'] created!
# 2023-09-20 18:31:12,848 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E->['E'] created!
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:76: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2023-09-20 18:31:12,850 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for I->['I'] created!
# 2023-09-20 18:31:12,850 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for I->['I'] created!
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:76: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2023-09-20 18:31:12,852 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-20 18:31:12,852 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-09-20 18:31:12,853 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-09-20 18:31:12,853 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2023-09-20 18:31:12,861 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-09-20 18:31:12,861 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-09-20 18:31:12,862 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-20 18:31:12,862 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
#
# TVBtoANNarchyInterfaces (
#   title .................................. 'TVBtoANNarchyInterfaces gid: d7788141-68c3-4edc-be2e-a1a1db201f01'
#   Type ................................... 'TVBtoANNarchyInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoANNarchyInterface gid: 76676de7-cb08-403c-8d8f-dd37f284093d'
#   interfaces[0].Type ..................... 'TVBtoANNarchyInterface'
#   interfaces[0].proxy .................... ANNarchyTimedPoissonPopulationSet gid: 1750e7b2-5639-4489-a127-0ec3cedb3e2c
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: a0349064-cebf-4ac8-aea9-9825d3c62382
#   interfaces[0].transformer .............. LinearRate gid: a44ad695-6426-45dc-bd46-b618ee9428ff
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... --------------------
#   interfaces[0].cvoi: shape .............. (1,)
#   interfaces[0].cvoi: dtype .............. int64
#   interfaces[0].cvoi: values ............. 0
#   interfaces[0].coupling_mode ............ 'TVB'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (2,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: values ....... [[0, 1]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... E
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('76676de7-cb08-403c-8d8f-dd37f284093d')
#   interfaces[0].number_of_proxy_nodes .... 2
#   interfaces[0].number_of_proxy_gids ..... 2
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (2,)
#   interfaces[0].proxy_gids: dtype ........ int32
#   interfaces[0].proxy_gids: unique_values  0
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('d7788141-68c3-4edc-be2e-a1a1db201f01')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[0, 1]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... E
#   number_of_proxy_nodes .................. 2
# )
#
# ANNarchyToTVBInterfaces (
#   title .................................. 'ANNarchyToTVBInterfaces gid: 9300f121-0b20-4181-aec0-0f8353df946c'
#   Type ................................... 'ANNarchyToTVBInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'ANNarchyToTVBInterface gid: ba143526-9c86-4525-a695-3ba7f06dd32a'
#   interfaces[0].Type ..................... 'ANNarchyToTVBInterface'
#   interfaces[0].proxy .................... ANNarchySpikeMonitorTotalSet gid: 7ca215ea-0679-4755-894c-4c74cfdaae75
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: a0349064-cebf-4ac8-aea9-9825d3c62382
#   interfaces[0].transformer .............. ElephantSpikesHistogramRate gid: 324e5d47-f681-42a6-bcfe-0b3e68b2e103
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (2,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: values ....... [[0, 1]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... E
#   interfaces[0].dt ....................... 0.1
#   interfaces[0].times .................... --------------------
#   interfaces[0].times: shape ............. (2,)
#   interfaces[0].times: dtype ............. int64
#   interfaces[0].times: values ............ [[0, 1]]
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'SpikeMonitor'
#   interfaces[0].gid ...................... UUID('ba143526-9c86-4525-a695-3ba7f06dd32a')
#   interfaces[0].number_of_proxy_nodes .... 2
#   interfaces[0].number_of_proxy_gids ..... 0
#   interfaces[0].proxy_gids ............... --------------------
#   shape .................................. (0,)
#   dtype .................................. float64
#   is empty ............................... True
#   interfaces[0].n_voi .................... 1
#   interfaces[1] .......................... '--------------------'
#   interfaces[1].title .................... 'ANNarchyToTVBInterface gid: 2a252ed3-af44-4e11-a53b-afce760eeffb'
#   interfaces[1].Type ..................... 'ANNarchyToTVBInterface'
#   interfaces[1].proxy .................... ANNarchySpikeMonitorTotalSet gid: 14c32bfc-688a-448f-bacc-b1b7f91b0691
#   interfaces[1].spiking_network .......... ANNarchyNetwork gid: a0349064-cebf-4ac8-aea9-9825d3c62382
#   interfaces[1].transformer .............. ElephantSpikesHistogramRate gid: 06ec821e-5638-4df6-834a-8f4c6cbbe005
#   interfaces[1].proxy_inds ............... --------------------
#   interfaces[1].proxy_inds: shape ........ (2,)
#   interfaces[1].proxy_inds: dtype ........ int64
#   interfaces[1].proxy_inds: values ....... [[0, 1]]
#   interfaces[1].voi ...................... --------------------
#   interfaces[1].voi: shape ............... (1,)
#   interfaces[1].voi: dtype ............... int64
#   interfaces[1].voi: values .............. 1
#   interfaces[1].voi_labels ............... --------------------
#   interfaces[1].voi_labels: shape ........ (1,)
#   interfaces[1].voi_labels: dtype ........ <U128
#   interfaces[1].voi_labels: values ....... I
#   interfaces[1].dt ....................... 0.1
#   interfaces[1].times .................... --------------------
#   interfaces[1].times: shape ............. (2,)
#   interfaces[1].times: dtype ............. int64
#   interfaces[1].times: values ............ [[0, 1]]
#   interfaces[1].spiking_proxy_inds ....... --------------------
#   interfaces[1].spiking_proxy_inds: shape  (2,)
#   interfaces[1].spiking_proxy_inds: dtype  int64
#   interfaces[1].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[1].populations .............. --------------------
#   interfaces[1].populations: shape ....... ()
#   interfaces[1].populations: dtype ....... <U128
#   interfaces[1].populations: values ...... I
#   interfaces[1].model .................... 'SpikeMonitor'
#   interfaces[1].gid ...................... UUID('2a252ed3-af44-4e11-a53b-afce760eeffb')
#   interfaces[1].number_of_proxy_nodes .... 2
#   interfaces[1].number_of_proxy_gids ..... 0
#   interfaces[1].proxy_gids ............... --------------------
#   interfaces[1].n_voi .................... 1
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('9300f121-0b20-4181-aec0-0f8353df946c')
#   number_of_interfaces ................... 2
#   number_of_populations .................. 2
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (2,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. ['E' 'I']
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (4,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: =0 ................. {0, 2}
#   spiking_proxy_inds: =1 ................. {1, 3}
#   n_vois ................................. 2
#   voi .................................... --------------------
#   voi: shape ............................. (2,)
#   voi: dtype ............................. int64
#   voi: values ............................ [[0, 1]]
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (2,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... ['E' 'I']
#   number_of_proxy_nodes .................. 2
# )
#
# Built in 0.287512 secs!
#
# Failed to summarize:
# tvb_app.cosimulator_builder.monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# Failed to summarize:
# tvb_app.cosimulator.monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# TVBANNarchySerialOrchestrator (
#   title ............................................................................ 'TVBANNarchySerialOrchestrator gid: dc8fec42-5ad4-4ba9-80d7-a09bcd86f093'
#   Type ............................................................................. 'TVBANNarchySerialOrchestrator'
#   config ........................................................................... '--------------------'
#   config.title ..................................................................... 'Config gid: bf297cee-0d15-4734-999a-a73ace7e99e3'
#   config.Type ...................................................................... 'Config'
#   config.gid ....................................................................... UUID('bf297cee-0d15-4734-999a-a73ace7e99e3')
#   tvb_app .......................................................................... '--------------------'
#   tvb_app.title .................................................................... 'TVBSerialApp gid: f8eb65cc-d56e-41c6-8e86-527891d6bcb5'
#   tvb_app.Type ..................................................................... 'TVBSerialApp'
#   tvb_app.config ................................................................... '--------------------'
#   tvb_app.config.title ............................................................. 'Config gid: bf297cee-0d15-4734-999a-a73ace7e99e3'
#   tvb_app.config.Type .............................................................. 'Config'
#   tvb_app.config.gid ............................................................... UUID('bf297cee-0d15-4734-999a-a73ace7e99e3')
#   tvb_app.interfaces_builder ....................................................... '--------------------'
#   tvb_app.interfaces_builder.title ................................................. 'WilsonCowanTVBANNarchyInterfaceBuilder gid: c91fde62-0dfd-4000-a9eb-693292aee762'
#   tvb_app.interfaces_builder.Type .................................................. 'WilsonCowanTVBANNarchyInterfaceBuilder'
#   tvb_app.interfaces_builder.spiking_network ....................................... 'ANNarchyNetwork gid: a0349064-cebf-4ac8-aea9-9825d3c62382'
#   tvb_app.interfaces_builder.N_E ................................................... 10
#   tvb_app.interfaces_builder.N_I ................................................... 10
#   tvb_app.interfaces_builder.model ................................................. "'RATE'"
#   tvb_app.interfaces_builder.config ................................................ Config gid: bf297cee-0d15-4734-999a-a73ace7e99e3
#   tvb_app.interfaces_builder.logger ................................................ <Logger examples.example (DEBUG)>
#   tvb_app.interfaces_builder.tvb_cosimulator ....................................... CoSimulatorSerial gid: 7ec0b7a5-c93a-4331-81e3-d0400dcc1688
#   tvb_app.interfaces_builder.exclusive_nodes ....................................... True
#   tvb_app.interfaces_builder.output_flag ........................................... True
#   tvb_app.interfaces_builder.input_flag ............................................ True
#   tvb_app.interfaces_builder.proxy_inds ............................................ --------------------
#   tvb_app.interfaces_builder.proxy_inds: shape ..................................... --------------------
#   tvb_app.interfaces_builder.proxy_inds: dtype ..................................... dtype('int64')
#   tvb_app.interfaces_builder.proxy_inds: values .................................... --------------------
#   tvb_app.interfaces_builder.output_interfaces ..................................... 'properties:'
#   tvb_app.interfaces_builder.input_interfaces ...................................... 'properties:'
#   tvb_app.interfaces_builder.default_coupling_mode ................................. 'TVB'
#   tvb_app.interfaces_builder.global_coupling_scaling ............................... --------------------
#   tvb_app.interfaces_builder.global_coupling_scaling: shape ........................ (68,)
#   tvb_app.interfaces_builder.global_coupling_scaling: dtype ........................ float64
#   tvb_app.interfaces_builder.global_coupling_scaling: unique_values ................ 0.00390625
#   tvb_app.interfaces_builder.dt .................................................... '0.1'
#   tvb_app.interfaces_builder.gid ................................................... UUID('c91fde62-0dfd-4000-a9eb-693292aee762')
#   tvb_app.interfaces_builder.voi: shape ............................................ --------------------
#   tvb_app.interfaces_builder.voi: shape: shape ..................................... (1,)
#   tvb_app.interfaces_builder.voi: shape: dtype ..................................... int64
#   tvb_app.interfaces_builder.voi: shape: values .................................... 1
#   tvb_app.interfaces_builder.voi: dtype ............................................ dtype('int64')
#   tvb_app.interfaces_builder.voi: values ........................................... 0
#   tvb_app.interfaces_builder.populations: shape .................................... --------------------
#   shape ............................................................................ (0,)
#   dtype ............................................................................ float64
#   is empty ......................................................................... True
#   tvb_app.interfaces_builder.populations: dtype .................................... dtype('<U1')
#   tvb_app.interfaces_builder.populations: values ................................... 'E'
#   tvb_app.interfaces_builder.proxy_inds: shape: shape .............................. (1,)
#   tvb_app.interfaces_builder.proxy_inds: shape: dtype .............................. int64
#   tvb_app.interfaces_builder.proxy_inds: shape: values ............................. 2
#   tvb_app.interfaces_builder.proxy_inds: values: shape ............................. (1, 2)
#   tvb_app.interfaces_builder.proxy_inds: values: dtype ............................. int64
#   tvb_app.interfaces_builder.proxy_inds: values: values ............................ [0 1]
#   tvb_app.interfaces_builder.voi_labels: shape ..................................... --------------------
#   tvb_app.interfaces_builder.voi_labels: shape: shape .............................. (1,)
#   tvb_app.interfaces_builder.voi_labels: shape: dtype .............................. int64
#   tvb_app.interfaces_builder.voi_labels: shape: values ............................. 1
#   tvb_app.interfaces_builder.voi_labels: dtype ..................................... dtype('<U1')
#   tvb_app.interfaces_builder.voi_labels: values .................................... 'E'
#   tvb_app.interfaces_builder.proxy ................................................. 'ANNarchyTimedPoissonPopulationSet gid: 1750e7b2-5639-4489-a127-0ec3cedb3e2c'
#   tvb_app.interfaces_builder.transformer ........................................... 'LinearRate gid: a44ad695-6426-45dc-bd46-b618ee9428ff'
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape ............................. --------------------
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: shape ...................... (1,)
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: dtype ...................... int64
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: values ..................... 2
#   tvb_app.interfaces_builder.spiking_proxy_inds: dtype ............................. dtype('int64')
# ...
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.cortical]: unique_values .... 1
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres] ................ --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: shape ......... (68,)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: dtype ......... bool
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: =False ........ {0...33}
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: =True ......... {34...67}
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations] ............... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations]: shape ........ (68, 3)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations]: dtype ........ float64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations]: values ....... [-0.38261669 -0.60546974 -0.69786163  0.65982329 -0.3692104  -0.65445925
#   0.92603708  0.22476123  0.30321232 -0.75417582  0.4576563   0.47092414
#  -0.50299289  0.05509325  0.86253283  0.899222    0.06479787  0.43266734
#   0.40962978  0.3030412   0.86044725 -0.71762975  0.19590929  0.66830165
#   0.65151989 -0.30294387 -0.69551912 -0.8720307  -0.10976373 -0.47698467
#  -0.00596095  0.82174661 -0.56982188 -0.12180604  0.81564435 -0.56558606
#   0.40682931  0.054199   -0.91189494 -0.41228273 -0.03266817 -0.91047007
#  -0.80006394 -0.49775     0.33487704  0.83300378 -0.52883519  0.16259782
#  -0.25474036 -0.29356364 -0.92137275  0.20335288 -0.08556166 -0.97535984
#  -0.97482388  0.20036282 -0.09784246  0.96436493  0.25302228 -0.07733052
#   0.93018948 -0.35218341 -0.10351031 -0.75968686 -0.25980467 -0.5961354
#  -0.49661151 -0.72092729 -0.4833641   0.70221386 -0.68505051 -0.19391104
#  -0.23475324  0.09820225 -0.96708181  0.1829861   0.03111709 -0.98262293
#   0.86369223  0.13933983 -0.48437604 -0.56179383  0.02038304 -0.82702614
#   0.88075419 -0.10750546 -0.46120996 -0.98248087 -0.07928951 -0.16865499
#  -0.95037587  0.18198158  0.252326    0.90738399  0.29899871  0.29538799
#   0.84287785 -0.21924381 -0.49141538 -0.93942975  0.02652263 -0.34171377
#   0.2119279  -0.58288886 -0.78442791 -0.13402574 -0.56884351 -0.81145189
#  -0.55077346  0.83158287 -0.07154388  0.89696688  0.18764621  0.40029904
#  -0.59633825  0.47078993 -0.65018269  0.63719518  0.19074258 -0.7467259
#  -0.5790787  -0.29505125 -0.7600083   0.77357165 -0.2593268  -0.5782184
#   0.72945509  0.37259806 -0.57364271 -0.85038668 -0.08062112 -0.51994492
#  -0.62004143  0.48159849  0.6193638   0.71211482  0.4534374   0.53599161
#   0.84926834 -0.02662222  0.5272898  -0.8704929   0.03160028  0.49116549
#  -0.85920021  0.04946875  0.50924242  0.82188478  0.0903833   0.56243779
#   0.83202099 -0.15648958 -0.53221432 -0.93909788 -0.08768294 -0.33227531
#   0.95323808  0.30032389 -0.03380406 -0.88853176  0.42340502 -0.17674701
#  -0.59416038  0.73807852  0.31970852  0.44899813  0.79714001  0.40369356
#   0.68409308  0.4363876   0.58445062 -0.78808872  0.30711392  0.53347654
#  -0.50538932 -0.58355453  0.63564593  0.23008214 -0.57162063  0.78759892
#  -0.42941662  0.88199453  0.19413146  0.4440229   0.85956469  0.2529668
#  -0.90286225 -0.30715946  0.30082026  0.65267736 -0.75558871  0.05565929
#   0.73908346  0.67084084 -0.061059   -0.65805472  0.7526894  -0.02055836
#  -0.04366157  0.3210788   0.94604549 -0.38115902  0.48848431  0.78492094]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas] ...................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas]: shape ............... (68,)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas]: dtype ............... float64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas]: unique_values ....... [ 71.  76.  59.  65. 226. 158. 162.  44.  30.  21.  27. 305. 298. 348.
#  428. 274. 244. 178. 200. 117. 101. 415. 403. 210. 213. 290. 280. 127.
#  164. 237. 261. 125.  69.  72. 165. 159.  63.  64. 112. 146.  95. 122.
#  295. 316. 133. 147. 405. 384. 281.  78. 433. 410. 582. 539. 446. 422.
#  346. 330. 318.  47.  48.  50.  35.]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays] .................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays]: shape ............. (68, 68)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays]: dtype ............. int64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays]: unique_values ..... [[1], [36, 37], [40, 41], [44, 93], [96, 99], [101, 113], [115, 119], [122, 123], [125, 141], [143, 162], [164, 166], [168, 170], [172, 174], [176, 179], [181, 189], [191, 222], [224, 253], [255, 274], [277, 348], [350, 362], [364, 384], [386, 431], [433, 461], [463, 466], [468, 471], [473, 474], [476, 529], [531, 543], [546, 558], [560, 570], [572, 573], [576, 581], [583, 593], [595, 602], [604, 605], [607], [609, 615], [617], [619, 620], [622], [624, 625], [628], [630, 631], [633, 634], [636], [639, 645], [648, 649], [652, 656], [658], [660], [662, 665], [667, 671], [673], [675], [677], [680, 684], [688], [690, 693], [699, 700], [703, 705], [707], [710, 714], [718, 722], [724, 729], [731], [734, 735], [739], [744], [747], [749], [751, 754], [758, 759], [761], [763, 764], [770], [781], [784, 786], [792, 793], [795], [799], [801], [804], [812, 814], [820], [827], [841], [862], [879]]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays] ..................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays]: shape .............. (68, 68)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays]: dtype .............. float64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays]: unique_values ...... [ 0.1        39.98974333 34.00171    ... 20.76666667  6.62544467
#   5.83055433]
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a] .............................. --------------------
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a]: shape ....................... (1,)
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a]: dtype ....................... float64
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a]: values ...................... 0.00390625
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b] .............................. --------------------
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b]: shape ....................... (1,)
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b]: dtype ....................... float64
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b]: values ...................... 0
#   spikeNet_app.interfaces_builder .................................................. None
#   spikeNet_app.logger .............................................................. <Logger examples.example (DEBUG)>
#   spikeNet_app.default_tvb_serial_cosim_path ....................................... '/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/WilsonCowan_RATE_bidir/config/tvb_serial_cosimulator.pkl'
#   spikeNet_app.gid ................................................................. UUID('ae1c1cf9-070e-49c3-8103-7aa2c5bb6a48')
#   spikeNet_app.spiking_cosimulator ................................................. <module 'ANNarchy' from '/home/docker/.local/lib/python3.10/site-packages/ANNarchy/__init__.py'>
#   logger ........................................................................... <Logger examples.example (DEBUG)>
#   default_tvb_serial_cosim_path .................................................... '/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/WilsonCowan_RATE_bidir/config/tvb_serial_cosimulator.pkl'
#   gid .............................................................................. UUID('dc8fec42-5ad4-4ba9-80d7-a09bcd86f093')
# )
# None
#
#
# Simulating...
#
# Simulating for 36ms with App TVBANNarchySerialOrchestrator...
#
# Configuring simulation with App TVBANNarchySerialOrchestrator...
#
# Configuring simulation with App TVBSerialApp...
# 2023-09-20 18:31:12,889 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-20 18:31:12,890 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-09-20 18:31:12,890 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-09-20 18:31:12,890 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2023-09-20 18:31:12,899 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-09-20 18:31:12,900 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-09-20 18:31:12,900 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-20 18:31:12,900 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
#
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: 7ec0b7a5-c93a-4331-81e3-d0400dcc1688'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... WilsonCowan gid: 67cad6bf-5588-4ddb-bb84-18e489df4114
#   output_interfaces ................... TVBtoANNarchyInterfaces gid: d7788141-68c3-4edc-be2e-a1a1db201f01
#   input_interfaces .................... ANNarchyToTVBInterfaces gid: 9300f121-0b20-4181-aec0-0f8353df946c
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (2,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: values .............. [[0, 1]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (2,)
#   voi: dtype .......................... int64
#   voi: values ......................... [[0, 1]]
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[0, 1]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. CosimCoupling(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: f13f8e16-4cca-4836-bf92-ab7347fbf2ef
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 3a4cb876-d28c-46cb-83bd-537b90780462
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 9dd7e770-9a2e-4366-83b6-4a5c6fd4d324
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('7ec0b7a5-c93a-4331-81e3-d0400dcc1688')
# )
#
# Configuring simulation with App ANNarchySerialApp...
# Compiling ...  OK
#
# Simulating for 36ms with App TVBSerialApp...
# 2023-09-20 18:31:35,330 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - No or all NaN valued cosimulator updates at time step 0!
# 2023-09-20 18:31:35,330 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.032 seconds
# 2023-09-20 18:31:35,330 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2023-09-20 18:31:35,330 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 44063
# 2023-09-20 18:31:35,337 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:31:35,340 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...9.091% completed in 0.0104353 sec!
# ...9.091% completed in 0.0104353 sec!2023-09-20 18:31:35,353 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:31:35,356 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...18.182% completed in 0.0261362 sec!
# ...18.182% completed in 0.0261362 sec!2023-09-20 18:31:35,370 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:31:35,373 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...27.273% completed in 0.0430751 sec!
# ...27.273% completed in 0.0430751 sec!2023-09-20 18:31:35,387 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:31:35,390 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...36.364% completed in 0.0599537 sec!
# ...36.364% completed in 0.0599537 sec!2023-09-20 18:31:35,404 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:31:35,407 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...45.455% completed in 0.0766504 sec!
# ...45.455% completed in 0.0766504 sec!2023-09-20 18:31:35,503 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:31:35,506 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...54.545% completed in 0.176462 sec!
# ...54.545% completed in 0.176462 sec!2023-09-20 18:31:35,520 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:31:35,523 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...63.636% completed in 0.193284 sec!
# ...63.636% completed in 0.193284 sec!2023-09-20 18:31:35,537 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:31:35,540 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...72.727% completed in 0.209846 sec!
# ...72.727% completed in 0.209846 sec!2023-09-20 18:31:35,554 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:31:35,557 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...81.818% completed in 0.226921 sec!
# ...81.818% completed in 0.226921 sec!2023-09-20 18:31:35,570 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:31:35,573 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...90.909% completed in 0.24343 sec!
# ...90.909% completed in 0.24343 sec!2023-09-20 18:31:35,587 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:31:35,590 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...100.000% completed in 0.260269 sec!
# ...100.000% completed in 0.260269 sec!
# Simulated in 22.701627 secs!
#
#
# Cleaning up App TVBANNarchySerialOrchestrator...
#
# Cleaning up App TVBSerialApp...
#
# Cleaning up App ANNarchySerialApp...
#
# Stopping App TVBANNarchySerialOrchestrator...
#
# Stopping App TVBSerialApp...
#
# Success in 23.0195 sec!
# ******************************************************
#
# {'TestWilsonCowanRATE': True}

# %%
! python ../../../tvb_multiscale/tests/tvb_annarchy/test_models.py 3
# Out:
# ANNarchy 4.7 (4.7.2.6) on linux (posix).
#
#
# Testing model 3
# ******************************************************
# ******************************************************
#
# ----------------------------------------------------------------------------------------------------
# Find results in /home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/WilsonCowan_SPIKES_bidir/res !
# ----------------------------------------------------------------------------------------------------
#
# Starting App TVBANNarchySerialOrchestrator...
#
# Starting App TVBSerialApp...
#
# Setting TVB LIBRARY_PROFILE...
#
# Starting App ANNarchySerialApp...
# 2023-09-20 18:31:40,664 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Loading an ANNarchy instance...
# 2023-09-20 18:31:40,664 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Loading an ANNarchy instance...
# 2023-09-20 18:31:40,664 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Cleaning ANNarchy compilation directory, if any...
# 2023-09-20 18:31:40,664 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.annarchy_factory - Cleaning ANNarchy compilation directory, if any...
#
#
# Configuring...
#
# Done! in 0.000069 min
#
#
#
# Building...
#
# Building with App TVBANNarchySerialOrchestrator...
# 2023-09-20 18:31:40,669 - INFO - examples.example - Building cosimulators with TVBANNarchySerialOrchestrator...
# 2023-09-20 18:31:40,669 - INFO - examples.example - Building cosimulators with TVBANNarchySerialOrchestrator...
#
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
# 2023-09-20 18:31:40,670 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-20 18:31:40,671 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-09-20 18:31:40,671 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2023-09-20 18:31:40,681 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-09-20 18:31:40,681 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-09-20 18:31:40,682 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-20 18:31:40,682 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
#
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: e86ca640-24d0-415a-96c6-06d478c7e5a6'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... WilsonCowan gid: 9fdd6e41-10d6-4087-bc88-f6ff8beb1cf2
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 90616928-3f21-4de3-9c15-57217eeeb444
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: c74f4151-c493-4230-b91f-e2e3264438d5
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: e1d353e6-657e-4e1b-937b-d4a23988680f
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('e86ca640-24d0-415a-96c6-06d478c7e5a6')
# )
# 2023-09-20 18:31:40,688 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-20 18:31:40,688 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-09-20 18:31:40,688 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-09-20 18:31:40,688 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2023-09-20 18:31:40,698 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-09-20 18:31:40,698 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-09-20 18:31:40,698 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-20 18:31:40,698 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
#
# Building Spiking Network with builder WilsonCowanBuilder of App ANNarchySerialApp...
# 2023-09-20 18:31:40,702 - INFO - tvb_multiscale.core.spiking_models.builders.base - Configuring spiking network builder...
# 2023-09-20 18:31:40,702 - INFO - tvb_multiscale.core.spiking_models.builders.base - Configuring spiking network builder...
# 2023-09-20 18:31:40,703 - INFO - tvb_multiscale.core.spiking_models.builders.base - Configuring populations...
# 2023-09-20 18:31:40,703 - INFO - tvb_multiscale.core.spiking_models.builders.base - Configuring populations...
# 2023-09-20 18:31:40,703 - INFO - tvb_multiscale.core.spiking_models.builders.base - Configuring populations' connections within spiking region nodes...
# 2023-09-20 18:31:40,703 - INFO - tvb_multiscale.core.spiking_models.builders.base - Configuring populations' connections within spiking region nodes...
# 2023-09-20 18:31:40,703 - INFO - tvb_multiscale.core.spiking_models.builders.base - Configuring populations' connections among spiking region nodes...
# 2023-09-20 18:31:40,703 - INFO - tvb_multiscale.core.spiking_models.builders.base - Configuring populations' connections among spiking region nodes...
# 2023-09-20 18:31:40,703 - INFO - tvb_multiscale.core.spiking_models.builders.base - Configuring output devices, if any...
# 2023-09-20 18:31:40,703 - INFO - tvb_multiscale.core.spiking_models.builders.base - Configuring output devices, if any...
# 2023-09-20 18:31:40,704 - INFO - tvb_multiscale.core.spiking_models.builders.base - Configuring input devices, if any...
# 2023-09-20 18:31:40,704 - INFO - tvb_multiscale.core.spiking_models.builders.base - Configuring input devices, if any...
# 2023-09-20 18:31:40,704 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating spiking brain...
# 2023-09-20 18:31:40,704 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating spiking brain...
# 2023-09-20 18:31:40,704 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating spiking brain regions...
# 2023-09-20 18:31:40,704 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating spiking brain regions...
# 2023-09-20 18:31:40,705 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating spiking region node: bankssts_L...
# 2023-09-20 18:31:40,705 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating spiking region node: bankssts_L...
# 2023-09-20 18:31:40,706 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating population: E...
# 2023-09-20 18:31:40,706 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating population: E...
# 2023-09-20 18:31:40,784 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating population: I...
# 2023-09-20 18:31:40,784 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating population: I...
# 2023-09-20 18:31:40,821 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating spiking region node: bankssts_R...
# 2023-09-20 18:31:40,821 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating spiking region node: bankssts_R...
# 2023-09-20 18:31:40,822 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating population: E...
# 2023-09-20 18:31:40,822 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating population: E...
# 2023-09-20 18:31:40,859 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating population: I...
# 2023-09-20 18:31:40,859 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating population: I...
# 2023-09-20 18:31:40,895 - INFO - tvb_multiscale.core.spiking_models.builders.base - Connecting populations within spiking brain regions...
# 2023-09-20 18:31:40,895 - INFO - tvb_multiscale.core.spiking_models.builders.base - Connecting populations within spiking brain regions...
# 2023-09-20 18:31:40,895 - INFO - tvb_multiscale.core.spiking_models.builders.base - Connecting E -> E populations
# for spiking region nodes
# [0 1]...
# 2023-09-20 18:31:40,895 - INFO - tvb_multiscale.core.spiking_models.builders.base - Connecting E -> E populations
# for spiking region nodes
# [0 1]...
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:76: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2023-09-20 18:31:40,898 - INFO - tvb_multiscale.core.spiking_models.builders.base - Connecting E -> I populations
# for spiking region nodes
# [0 1]...
# 2023-09-20 18:31:40,898 - INFO - tvb_multiscale.core.spiking_models.builders.base - Connecting E -> I populations
# for spiking region nodes
# [0 1]...
# 2023-09-20 18:31:40,900 - INFO - tvb_multiscale.core.spiking_models.builders.base - Connecting I -> E populations
# for spiking region nodes
# [0 1]...
# 2023-09-20 18:31:40,900 - INFO - tvb_multiscale.core.spiking_models.builders.base - Connecting I -> E populations
# for spiking region nodes
# [0 1]...
# 2023-09-20 18:31:40,901 - INFO - tvb_multiscale.core.spiking_models.builders.base - Connecting I -> I populations
# for spiking region nodes
# [0 1]...
# 2023-09-20 18:31:40,901 - INFO - tvb_multiscale.core.spiking_models.builders.base - Connecting I -> I populations
# for spiking region nodes
# [0 1]...
# 2023-09-20 18:31:40,902 - INFO - tvb_multiscale.core.spiking_models.builders.base - Connecting populations among spiking brain regions...
# 2023-09-20 18:31:40,902 - INFO - tvb_multiscale.core.spiking_models.builders.base - Connecting populations among spiking brain regions...
# 2023-09-20 18:31:40,903 - INFO - tvb_multiscale.core.spiking_models.builders.base - Connecting for 0 -> 1 spiking region nodes ...
# 2023-09-20 18:31:40,903 - INFO - tvb_multiscale.core.spiking_models.builders.base - Connecting for 0 -> 1 spiking region nodes ...
# 2023-09-20 18:31:40,903 - INFO - tvb_multiscale.core.spiking_models.builders.base - E -> E populations ...
# 2023-09-20 18:31:40,903 - INFO - tvb_multiscale.core.spiking_models.builders.base - E -> E populations ...
# 2023-09-20 18:31:40,904 - INFO - tvb_multiscale.core.spiking_models.builders.base - E -> I populations ...
# 2023-09-20 18:31:40,904 - INFO - tvb_multiscale.core.spiking_models.builders.base - E -> I populations ...
# 2023-09-20 18:31:40,905 - INFO - tvb_multiscale.core.spiking_models.builders.base - Connecting for 1 -> 0 spiking region nodes ...
# 2023-09-20 18:31:40,905 - INFO - tvb_multiscale.core.spiking_models.builders.base - Connecting for 1 -> 0 spiking region nodes ...
# 2023-09-20 18:31:40,906 - INFO - tvb_multiscale.core.spiking_models.builders.base - E -> E populations ...
# 2023-09-20 18:31:40,906 - INFO - tvb_multiscale.core.spiking_models.builders.base - E -> E populations ...
# 2023-09-20 18:31:40,907 - INFO - tvb_multiscale.core.spiking_models.builders.base - E -> I populations ...
# 2023-09-20 18:31:40,907 - INFO - tvb_multiscale.core.spiking_models.builders.base - E -> I populations ...
# 2023-09-20 18:31:40,907 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating and connecting output devices, if any...
# 2023-09-20 18:31:40,907 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating and connecting output devices, if any...
# 2023-09-20 18:31:40,908 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating and connecting ['E', 'I'] -> ['E', 'I'] device set of model SpikeMonitor
# for nodes [0, 1]...
# 2023-09-20 18:31:40,908 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating and connecting ['E', 'I'] -> ['E', 'I'] device set of model SpikeMonitor
# for nodes [0, 1]...
# 2023-09-20 18:31:40,909 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E created!
# 2023-09-20 18:31:40,909 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E created!
# 2023-09-20 18:31:40,910 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for I created!
# 2023-09-20 18:31:40,910 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for I created!
# 2023-09-20 18:31:40,912 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating and connecting ['Excitatory', 'Inhibitory'] -> ['E', 'I'] device set of model Monitor
# for nodes [0, 1]...
# 2023-09-20 18:31:40,912 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating and connecting ['Excitatory', 'Inhibitory'] -> ['E', 'I'] device set of model Monitor
# for nodes [0, 1]...
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:76: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2023-09-20 18:31:40,913 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Excitatory created!
# 2023-09-20 18:31:40,913 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Excitatory created!
# 2023-09-20 18:31:40,914 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Inhibitory created!
# 2023-09-20 18:31:40,914 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model Monitor for Inhibitory created!
# 2023-09-20 18:31:40,916 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating and connecting input devices, if any...
# 2023-09-20 18:31:40,916 - INFO - tvb_multiscale.core.spiking_models.builders.base - Generating and connecting input devices, if any...
# 2023-09-20 18:31:40,916 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.base - Generating and connecting ['Stimulus'] -> [['E']] device set of model PoissonPopulation
# for nodes [0, 1]...
# 2023-09-20 18:31:40,916 - INFO - tvb_multiscale.tvb_annarchy.annarchy_models.builders.base - Generating and connecting ['Stimulus'] -> [['E']] device set of model PoissonPopulation
# for nodes [0, 1]...
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:76: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2023-09-20 18:31:40,917 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model PoissonPopulation for Stimulus created!
# 2023-09-20 18:31:40,917 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model PoissonPopulation for Stimulus created!
# 2023-09-20 18:31:40,922 - INFO - tvb_multiscale.core.spiking_models.network - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# 2023-09-20 18:31:40,922 - INFO - tvb_multiscale.core.spiking_models.network - <class 'tvb_multiscale.tvb_annarchy.annarchy_models.network.ANNarchyNetwork'> created!
# ANNarchyNetwork (
#   title ....................................... 'ANNarchyNetwork gid: 7df85f6a-a47f-4726-a077-36e99fe2957c'
#   Type ........................................ 'ANNarchyNetwork'
#   config ...................................... '--------------------'
#   config.title ................................ 'Config gid: c580920f-7265-48a9-b15a-01fce04ef84d'
#   config.Type ................................. 'Config'
#   config.gid .................................. UUID('c580920f-7265-48a9-b15a-01fce04ef84d')
#   brain_regions ............................... '--------------------'
#   brain_regions.title ......................... 'ANNarchyBrain gid: 84f3e7b0-3d9e-4d0f-8fe1-b1a3bf7a40e8'
#   brain_regions.Type .......................... 'ANNarchyBrain'
#   brain_regions.gid ........................... UUID('84f3e7b0-3d9e-4d0f-8fe1-b1a3bf7a40e8')
#   brain_regions.label ......................... ''
#   brain_regions.size .......................... 2
#   brain_regions.Regions ....................... --------------------
#   brain_regions.Regions: shape ................ (2,)
#   brain_regions.Regions: dtype ................ <U10
#   brain_regions.Regions: values ............... ['bankssts_L' 'bankssts_R']
#   brain_regions.bankssts_L .................... '--------------------'
#   brain_regions[bankssts_L].title ............. 'ANNarchyRegionNode gid: 4aa21c32-e264-4932-980c-5245b0eafff3'
#   brain_regions[bankssts_L].Type .............. 'ANNarchyRegionNode'
#   brain_regions[bankssts_L].gid ............... UUID('4aa21c32-e264-4932-980c-5245b0eafff3')
#   brain_regions[bankssts_L].label ............. 'bankssts_L'
#   brain_regions[bankssts_L].size .............. 2
#   brain_regions[bankssts_L].Populations ....... --------------------
#   brain_regions[bankssts_L].Populations: shape  (2,)
#   brain_regions[bankssts_L].Populations: dtype  <U1
#   brain_regions[bankssts_L].Populations: values  ['E' 'I']
#   brain_regions.bankssts_R .................... '--------------------'
#   brain_regions[bankssts_R].title ............. 'ANNarchyRegionNode gid: 85705471-b6ac-47c4-83ab-09194681afe0'
#   brain_regions[bankssts_R].Type .............. 'ANNarchyRegionNode'
#   brain_regions[bankssts_R].gid ............... UUID('85705471-b6ac-47c4-83ab-09194681afe0')
#   brain_regions[bankssts_R].label ............. 'bankssts_R'
#   brain_regions[bankssts_R].size .............. 2
#   brain_regions[bankssts_R].Populations ....... --------------------
#   brain_regions[bankssts_R].Populations: shape  (2,)
#   brain_regions[bankssts_R].Populations: dtype  <U1
#   brain_regions[bankssts_R].Populations: values  ['E' 'I']
#   network_path ................................ ''
#   output_devices .............................. '--------------------'
#   output_devices.title ........................ 'DeviceSets gid: d65fa910-2729-44b6-ab03-f7f68b55203f'
#   output_devices.Type ......................... 'DeviceSets'
#   output_devices.gid .......................... UUID('d65fa910-2729-44b6-ab03-f7f68b55203f')
#   output_devices.label ........................ 'output_devices'
#   output_devices.size ......................... 4
#   output_devices.DeviceSets ................... --------------------
#   output_devices.DeviceSets: shape ............ (4,)
#   output_devices.DeviceSets: dtype ............ <U10
#   output_devices.DeviceSets: values ........... ['E' 'I' 'Excitatory' 'Inhibitory']
#   output_devices.E ............................ '--------------------'
#   output_devices[E].title ..................... 'DeviceSet gid: 075562f6-238b-4436-9349-f209d2b045ff'
#   output_devices[E].Type ...................... 'DeviceSet'
#   output_devices[E].model ..................... 'SpikeMonitor'
#   output_devices[E].gid ....................... UUID('075562f6-238b-4436-9349-f209d2b045ff')
#   output_devices[E].label ..................... 'E'
#   output_devices[E].size ...................... 2
#   output_devices[E].Devices ................... --------------------
#   output_devices[E].Devices: shape ............ (2,)
#   output_devices[E].Devices: dtype ............ <U10
#   output_devices[E].Devices: values ........... ['bankssts_L' 'bankssts_R']
#   output_devices.I ............................ '--------------------'
#   output_devices[I].title ..................... 'DeviceSet gid: a1bad98c-e78a-4edf-a666-0a8af9ac2529'
#   output_devices[I].Type ...................... 'DeviceSet'
#   output_devices[I].model ..................... 'SpikeMonitor'
#   output_devices[I].gid ....................... UUID('a1bad98c-e78a-4edf-a666-0a8af9ac2529')
#   output_devices[I].label ..................... 'I'
#   output_devices[I].size ...................... 2
#   output_devices[I].Devices ................... --------------------
#   output_devices[I].Devices: shape ............ (2,)
#   output_devices[I].Devices: dtype ............ <U10
#   output_devices[I].Devices: values ........... ['bankssts_L' 'bankssts_R']
#   output_devices.Excitatory ................... '--------------------'
#   output_devices[Excitatory].title ............ 'DeviceSet gid: 9625fbb9-4785-4a2d-b343-c2bcc9fb8f77'
#   output_devices[Excitatory].Type ............. 'DeviceSet'
#   output_devices[Excitatory].model ............ 'Monitor'
#   output_devices[Excitatory].gid .............. UUID('9625fbb9-4785-4a2d-b343-c2bcc9fb8f77')
#   output_devices[Excitatory].label ............ 'Excitatory'
#   output_devices[Excitatory].size ............. 2
#   output_devices[Excitatory].Devices .......... --------------------
#   output_devices[Excitatory].Devices: shape ... (2,)
#   output_devices[Excitatory].Devices: dtype ... <U10
#   output_devices[Excitatory].Devices: values .. ['bankssts_L' 'bankssts_R']
#   output_devices.Inhibitory ................... '--------------------'
#   output_devices[Inhibitory].title ............ 'DeviceSet gid: c532f40a-4149-43a1-ac83-506e243ab978'
#   output_devices[Inhibitory].Type ............. 'DeviceSet'
#   output_devices[Inhibitory].model ............ 'Monitor'
#   output_devices[Inhibitory].gid .............. UUID('c532f40a-4149-43a1-ac83-506e243ab978')
#   output_devices[Inhibitory].label ............ 'Inhibitory'
#   output_devices[Inhibitory].size ............. 2
#   output_devices[Inhibitory].Devices .......... --------------------
#   output_devices[Inhibitory].Devices: shape ... (2,)
#   output_devices[Inhibitory].Devices: dtype ... <U10
#   output_devices[Inhibitory].Devices: values .. ['bankssts_L' 'bankssts_R']
#   input_devices ............................... '--------------------'
#   input_devices.title ......................... 'DeviceSets gid: 5e7cf891-2f5f-4513-92cc-b57e1a86e530'
#   input_devices.Type .......................... 'DeviceSets'
#   input_devices.gid ........................... UUID('5e7cf891-2f5f-4513-92cc-b57e1a86e530')
#   input_devices.label ......................... 'input_devices'
#   input_devices.size .......................... 1
#   input_devices.DeviceSets .................... --------------------
#   input_devices.DeviceSets: shape ............. (1,)
#   input_devices.DeviceSets: dtype ............. <U8
#   input_devices.DeviceSets: values ............ Stimulus
#   input_devices.Stimulus ...................... '--------------------'
#   input_devices[Stimulus].title ............... 'DeviceSet gid: d02014d5-5fa8-4002-94f6-4cb49d5d03e9'
#   input_devices[Stimulus].Type ................ 'DeviceSet'
#   input_devices[Stimulus].model ............... 'PoissonPopulation'
#   input_devices[Stimulus].gid ................. UUID('d02014d5-5fa8-4002-94f6-4cb49d5d03e9')
#   input_devices[Stimulus].label ............... 'Stimulus'
#   input_devices[Stimulus].size ................ 2
#   input_devices[Stimulus].Devices ............. --------------------
#   input_devices[Stimulus].Devices: shape ...... (2,)
#   input_devices[Stimulus].Devices: dtype ...... <U10
#   input_devices[Stimulus].Devices: values ..... ['bankssts_L' 'bankssts_R']
#   output_proxies .............................. '--------------------'
#   output_proxies.title ........................ 'DeviceSets gid: 112fb444-dbf0-4f3f-be5f-84f1174071fb'
#   output_proxies.Type ......................... 'DeviceSets'
#   output_proxies.gid .......................... UUID('112fb444-dbf0-4f3f-be5f-84f1174071fb')
#   output_proxies.label ........................ 'output_proxies'
#   output_proxies.size ......................... 0
#   output_proxies.DeviceSets ................... --------------------
#   shape ....................................... (0,)
#   dtype ....................................... float64
#   is empty .................................... True
#   input_proxies ............................... '--------------------'
#   input_proxies.title ......................... 'DeviceSets gid: 37fdbdd6-3608-4809-af79-701cb60548c9'
#   input_proxies.Type .......................... 'DeviceSets'
#   input_proxies.gid ........................... UUID('37fdbdd6-3608-4809-af79-701cb60548c9')
#   input_proxies.label ......................... ''
#   input_proxies.size .......................... 0
#   input_proxies.DeviceSets .................... --------------------
#   gid ......................................... UUID('7df85f6a-a47f-4726-a077-36e99fe2957c')
# )
#
# Building interfaces with Orchestrator TVBANNarchySerialOrchestrator...
#
# Building interfaces' with builder TVBANNarchyInterfaceBuilder of App TVBSerialApp...
#
# Configuring interfaces' builder WilsonCowanTVBANNarchyInterfaceBuilder of App TVBSerialApp...
#
# Configuring default interfaces...
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:76: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2023-09-20 18:31:40,926 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeSourceArray for ['E']->E created!
# 2023-09-20 18:31:40,926 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeSourceArray for ['E']->E created!
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:76: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2023-09-20 18:31:40,932 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E->['E'] created!
# 2023-09-20 18:31:40,932 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for E->['E'] created!
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:76: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2023-09-20 18:31:40,934 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for I->['I'] created!
# 2023-09-20 18:31:40,934 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model SpikeMonitor for I->['I'] created!
# /home/docker/packages/tvb-multiscale/tvb_multiscale/core/spiking_models/node_set.py:76: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   pops = pd.Series.__getitem__(self, items)
# 2023-09-20 18:31:40,936 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-20 18:31:40,936 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-09-20 18:31:40,936 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-09-20 18:31:40,936 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2023-09-20 18:31:40,945 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-09-20 18:31:40,945 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-09-20 18:31:40,946 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-20 18:31:40,946 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
#
# TVBtoANNarchyInterfaces (
#   title .................................. 'TVBtoANNarchyInterfaces gid: 9e9e0e11-8e9d-4fcd-a1f6-1c06b91f7724'
#   Type ................................... 'TVBtoANNarchyInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoANNarchyInterface gid: dce4773d-df82-4034-8c7d-5494b93ae3f1'
#   interfaces[0].Type ..................... 'TVBtoANNarchyInterface'
#   interfaces[0].proxy .................... ANNarchySpikeSourceArraySet gid: 18b31c50-c7b7-4411-8c85-235be452b6f0
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: 7df85f6a-a47f-4726-a077-36e99fe2957c
#   interfaces[0].transformer .............. RatesToSpikesElephantPoisson gid: ad650e17-6179-4e6b-bc53-aeae4cbd9188
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... --------------------
#   interfaces[0].cvoi: shape .............. (1,)
#   interfaces[0].cvoi: dtype .............. int64
#   interfaces[0].cvoi: values ............. 0
#   interfaces[0].coupling_mode ............ 'TVB'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (2,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: values ....... [[0, 1]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... E
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'SPIKES'
#   interfaces[0].gid ...................... UUID('dce4773d-df82-4034-8c7d-5494b93ae3f1')
#   interfaces[0].number_of_proxy_nodes .... 2
#   interfaces[0].number_of_proxy_gids ..... 20
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (20,)
#   interfaces[0].proxy_gids: dtype ........ int32
#   interfaces[0].proxy_gids: unique_values  [[0, 9]]
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('9e9e0e11-8e9d-4fcd-a1f6-1c06b91f7724')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[0, 1]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... E
#   number_of_proxy_nodes .................. 2
# )
#
# ANNarchyToTVBInterfaces (
#   title .................................. 'ANNarchyToTVBInterfaces gid: e3ba2c86-8e20-48fd-8e66-0925e25a9c17'
#   Type ................................... 'ANNarchyToTVBInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'ANNarchyToTVBInterface gid: 1e2d59ac-6764-488c-a5d8-1a3840b3639e'
#   interfaces[0].Type ..................... 'ANNarchyToTVBInterface'
#   interfaces[0].proxy .................... ANNarchySpikeMonitorTotalSet gid: 58fdfd61-40a0-4c77-b347-d56f0fc46b26
#   interfaces[0].spiking_network .......... ANNarchyNetwork gid: 7df85f6a-a47f-4726-a077-36e99fe2957c
#   interfaces[0].transformer .............. ElephantSpikesHistogramRate gid: a7d8500c-2cce-45d3-b4c4-3c37ed31e9b3
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (2,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: values ....... [[0, 1]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... E
#   interfaces[0].dt ....................... 0.1
#   interfaces[0].times .................... --------------------
#   interfaces[0].times: shape ............. (2,)
#   interfaces[0].times: dtype ............. int64
#   interfaces[0].times: values ............ [[0, 1]]
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'SpikeMonitor'
#   interfaces[0].gid ...................... UUID('1e2d59ac-6764-488c-a5d8-1a3840b3639e')
#   interfaces[0].number_of_proxy_nodes .... 2
#   interfaces[0].number_of_proxy_gids ..... 0
#   interfaces[0].proxy_gids ............... --------------------
#   shape .................................. (0,)
#   dtype .................................. float64
#   is empty ............................... True
#   interfaces[0].n_voi .................... 1
#   interfaces[1] .......................... '--------------------'
#   interfaces[1].title .................... 'ANNarchyToTVBInterface gid: 5c6c35c1-1285-42d2-9aa6-2a86da142f26'
#   interfaces[1].Type ..................... 'ANNarchyToTVBInterface'
#   interfaces[1].proxy .................... ANNarchySpikeMonitorTotalSet gid: 2003dbe1-b37f-44a7-91f7-417062bdb325
#   interfaces[1].spiking_network .......... ANNarchyNetwork gid: 7df85f6a-a47f-4726-a077-36e99fe2957c
#   interfaces[1].transformer .............. ElephantSpikesHistogramRate gid: aa2014cc-d22e-41e2-a030-77e692798b63
#   interfaces[1].proxy_inds ............... --------------------
#   interfaces[1].proxy_inds: shape ........ (2,)
#   interfaces[1].proxy_inds: dtype ........ int64
#   interfaces[1].proxy_inds: values ....... [[0, 1]]
#   interfaces[1].voi ...................... --------------------
#   interfaces[1].voi: shape ............... (1,)
#   interfaces[1].voi: dtype ............... int64
#   interfaces[1].voi: values .............. 1
#   interfaces[1].voi_labels ............... --------------------
#   interfaces[1].voi_labels: shape ........ (1,)
#   interfaces[1].voi_labels: dtype ........ <U128
#   interfaces[1].voi_labels: values ....... I
#   interfaces[1].dt ....................... 0.1
#   interfaces[1].times .................... --------------------
#   interfaces[1].times: shape ............. (2,)
#   interfaces[1].times: dtype ............. int64
#   interfaces[1].times: values ............ [[0, 1]]
#   interfaces[1].spiking_proxy_inds ....... --------------------
#   interfaces[1].spiking_proxy_inds: shape  (2,)
#   interfaces[1].spiking_proxy_inds: dtype  int64
#   interfaces[1].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[1].populations .............. --------------------
#   interfaces[1].populations: shape ....... ()
#   interfaces[1].populations: dtype ....... <U128
#   interfaces[1].populations: values ...... I
#   interfaces[1].model .................... 'SpikeMonitor'
#   interfaces[1].gid ...................... UUID('5c6c35c1-1285-42d2-9aa6-2a86da142f26')
#   interfaces[1].number_of_proxy_nodes .... 2
#   interfaces[1].number_of_proxy_gids ..... 0
#   interfaces[1].proxy_gids ............... --------------------
#   interfaces[1].n_voi .................... 1
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('e3ba2c86-8e20-48fd-8e66-0925e25a9c17')
#   number_of_interfaces ................... 2
#   number_of_populations .................. 2
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (2,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. ['E' 'I']
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (4,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: =0 ................. {0, 2}
#   spiking_proxy_inds: =1 ................. {1, 3}
#   n_vois ................................. 2
#   voi .................................... --------------------
#   voi: shape ............................. (2,)
#   voi: dtype ............................. int64
#   voi: values ............................ [[0, 1]]
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (2,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... ['E' 'I']
#   number_of_proxy_nodes .................. 2
# )
#
# Built in 0.283048 secs!
# Failed to summarize:
# tvb_app.cosimulator_builder.monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# Failed to summarize:
# tvb_app.cosimulator.monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# TVBANNarchySerialOrchestrator (
#   title ............................................................................ 'TVBANNarchySerialOrchestrator gid: 54fd5225-e7ab-4f49-bc6c-c794096efd6f'
#   Type ............................................................................. 'TVBANNarchySerialOrchestrator'
#   config ........................................................................... '--------------------'
#   config.title ..................................................................... 'Config gid: c580920f-7265-48a9-b15a-01fce04ef84d'
#   config.Type ...................................................................... 'Config'
#   config.gid ....................................................................... UUID('c580920f-7265-48a9-b15a-01fce04ef84d')
#   tvb_app .......................................................................... '--------------------'
#   tvb_app.title .................................................................... 'TVBSerialApp gid: 21332293-5dd8-45a1-8672-8090b45349be'
#   tvb_app.Type ..................................................................... 'TVBSerialApp'
#   tvb_app.config ................................................................... '--------------------'
#   tvb_app.config.title ............................................................. 'Config gid: c580920f-7265-48a9-b15a-01fce04ef84d'
#   tvb_app.config.Type .............................................................. 'Config'
#   tvb_app.config.gid ............................................................... UUID('c580920f-7265-48a9-b15a-01fce04ef84d')
#   tvb_app.interfaces_builder ....................................................... '--------------------'
#   tvb_app.interfaces_builder.title ................................................. 'WilsonCowanTVBANNarchyInterfaceBuilder gid: 27e71937-80ea-4277-bb80-feefc880086a'
#   tvb_app.interfaces_builder.Type .................................................. 'WilsonCowanTVBANNarchyInterfaceBuilder'
#   tvb_app.interfaces_builder.spiking_network ....................................... 'ANNarchyNetwork gid: 7df85f6a-a47f-4726-a077-36e99fe2957c'
#   tvb_app.interfaces_builder.N_E ................................................... 10
#   tvb_app.interfaces_builder.N_I ................................................... 10
#   tvb_app.interfaces_builder.model ................................................. "'SPIKES'"
#   tvb_app.interfaces_builder.config ................................................ Config gid: c580920f-7265-48a9-b15a-01fce04ef84d
#   tvb_app.interfaces_builder.logger ................................................ <Logger examples.example (DEBUG)>
#   tvb_app.interfaces_builder.tvb_cosimulator ....................................... CoSimulatorSerial gid: e86ca640-24d0-415a-96c6-06d478c7e5a6
#   tvb_app.interfaces_builder.exclusive_nodes ....................................... True
#   tvb_app.interfaces_builder.output_flag ........................................... True
#   tvb_app.interfaces_builder.input_flag ............................................ True
#   tvb_app.interfaces_builder.proxy_inds ............................................ --------------------
#   tvb_app.interfaces_builder.proxy_inds: shape ..................................... --------------------
#   tvb_app.interfaces_builder.proxy_inds: dtype ..................................... dtype('int64')
#   tvb_app.interfaces_builder.proxy_inds: values .................................... --------------------
#   tvb_app.interfaces_builder.output_interfaces ..................................... 'properties:'
#   tvb_app.interfaces_builder.input_interfaces ...................................... 'properties:'
#   tvb_app.interfaces_builder.default_coupling_mode ................................. 'TVB'
#   tvb_app.interfaces_builder.global_coupling_scaling ............................... --------------------
#   tvb_app.interfaces_builder.global_coupling_scaling: shape ........................ (68,)
#   tvb_app.interfaces_builder.global_coupling_scaling: dtype ........................ float64
#   tvb_app.interfaces_builder.global_coupling_scaling: unique_values ................ 0.00390625
#   tvb_app.interfaces_builder.dt .................................................... '0.1'
#   tvb_app.interfaces_builder.gid ................................................... UUID('27e71937-80ea-4277-bb80-feefc880086a')
#   tvb_app.interfaces_builder.voi: shape ............................................ --------------------
#   tvb_app.interfaces_builder.voi: shape: shape ..................................... (1,)
#   tvb_app.interfaces_builder.voi: shape: dtype ..................................... int64
#   tvb_app.interfaces_builder.voi: shape: values .................................... 1
#   tvb_app.interfaces_builder.voi: dtype ............................................ dtype('int64')
#   tvb_app.interfaces_builder.voi: values ........................................... 0
#   tvb_app.interfaces_builder.populations: shape .................................... --------------------
#   shape ............................................................................ (0,)
#   dtype ............................................................................ float64
#   is empty ......................................................................... True
#   tvb_app.interfaces_builder.populations: dtype .................................... dtype('<U1')
#   tvb_app.interfaces_builder.populations: values ................................... 'E'
#   tvb_app.interfaces_builder.proxy_inds: shape: shape .............................. (1,)
#   tvb_app.interfaces_builder.proxy_inds: shape: dtype .............................. int64
#   tvb_app.interfaces_builder.proxy_inds: shape: values ............................. 2
#   tvb_app.interfaces_builder.proxy_inds: values: shape ............................. (1, 2)
#   tvb_app.interfaces_builder.proxy_inds: values: dtype ............................. int64
#   tvb_app.interfaces_builder.proxy_inds: values: values ............................ [0 1]
#   tvb_app.interfaces_builder.voi_labels: shape ..................................... --------------------
#   tvb_app.interfaces_builder.voi_labels: shape: shape .............................. (1,)
#   tvb_app.interfaces_builder.voi_labels: shape: dtype .............................. int64
#   tvb_app.interfaces_builder.voi_labels: shape: values ............................. 1
#   tvb_app.interfaces_builder.voi_labels: dtype ..................................... dtype('<U1')
#   tvb_app.interfaces_builder.voi_labels: values .................................... 'E'
#   tvb_app.interfaces_builder.proxy ................................................. 'ANNarchySpikeSourceArraySet gid: 18b31c50-c7b7-4411-8c85-235be452b6f0'
#   tvb_app.interfaces_builder.transformer ........................................... 'RatesToSpikesElephantPoisson gid: ad650e17-6179-4e6b-bc53-aeae4cbd9188'
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape ............................. --------------------
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: shape ...................... (1,)
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: dtype ...................... int64
#   tvb_app.interfaces_builder.spiking_proxy_inds: shape: values ..................... 2
#   tvb_app.interfaces_builder.spiking_proxy_inds: dtype ............................. dtype('int64')
# ...
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.cortical]: unique_values .... 1
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres] ................ --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: shape ......... (68,)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: dtype ......... bool
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: =False ........ {0...33}
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.hemispheres]: =True ......... {34...67}
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations] ............... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations]: shape ........ (68, 3)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations]: dtype ........ float64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.orientations]: values ....... [-0.38261669 -0.60546974 -0.69786163  0.65982329 -0.3692104  -0.65445925
#   0.92603708  0.22476123  0.30321232 -0.75417582  0.4576563   0.47092414
#  -0.50299289  0.05509325  0.86253283  0.899222    0.06479787  0.43266734
#   0.40962978  0.3030412   0.86044725 -0.71762975  0.19590929  0.66830165
#   0.65151989 -0.30294387 -0.69551912 -0.8720307  -0.10976373 -0.47698467
#  -0.00596095  0.82174661 -0.56982188 -0.12180604  0.81564435 -0.56558606
#   0.40682931  0.054199   -0.91189494 -0.41228273 -0.03266817 -0.91047007
#  -0.80006394 -0.49775     0.33487704  0.83300378 -0.52883519  0.16259782
#  -0.25474036 -0.29356364 -0.92137275  0.20335288 -0.08556166 -0.97535984
#  -0.97482388  0.20036282 -0.09784246  0.96436493  0.25302228 -0.07733052
#   0.93018948 -0.35218341 -0.10351031 -0.75968686 -0.25980467 -0.5961354
#  -0.49661151 -0.72092729 -0.4833641   0.70221386 -0.68505051 -0.19391104
#  -0.23475324  0.09820225 -0.96708181  0.1829861   0.03111709 -0.98262293
#   0.86369223  0.13933983 -0.48437604 -0.56179383  0.02038304 -0.82702614
#   0.88075419 -0.10750546 -0.46120996 -0.98248087 -0.07928951 -0.16865499
#  -0.95037587  0.18198158  0.252326    0.90738399  0.29899871  0.29538799
#   0.84287785 -0.21924381 -0.49141538 -0.93942975  0.02652263 -0.34171377
#   0.2119279  -0.58288886 -0.78442791 -0.13402574 -0.56884351 -0.81145189
#  -0.55077346  0.83158287 -0.07154388  0.89696688  0.18764621  0.40029904
#  -0.59633825  0.47078993 -0.65018269  0.63719518  0.19074258 -0.7467259
#  -0.5790787  -0.29505125 -0.7600083   0.77357165 -0.2593268  -0.5782184
#   0.72945509  0.37259806 -0.57364271 -0.85038668 -0.08062112 -0.51994492
#  -0.62004143  0.48159849  0.6193638   0.71211482  0.4534374   0.53599161
#   0.84926834 -0.02662222  0.5272898  -0.8704929   0.03160028  0.49116549
#  -0.85920021  0.04946875  0.50924242  0.82188478  0.0903833   0.56243779
#   0.83202099 -0.15648958 -0.53221432 -0.93909788 -0.08768294 -0.33227531
#   0.95323808  0.30032389 -0.03380406 -0.88853176  0.42340502 -0.17674701
#  -0.59416038  0.73807852  0.31970852  0.44899813  0.79714001  0.40369356
#   0.68409308  0.4363876   0.58445062 -0.78808872  0.30711392  0.53347654
#  -0.50538932 -0.58355453  0.63564593  0.23008214 -0.57162063  0.78759892
#  -0.42941662  0.88199453  0.19413146  0.4440229   0.85956469  0.2529668
#  -0.90286225 -0.30715946  0.30082026  0.65267736 -0.75558871  0.05565929
#   0.73908346  0.67084084 -0.061059   -0.65805472  0.7526894  -0.02055836
#  -0.04366157  0.3210788   0.94604549 -0.38115902  0.48848431  0.78492094]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas] ...................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas]: shape ............... (68,)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas]: dtype ............... float64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.areas]: unique_values ....... [ 71.  76.  59.  65. 226. 158. 162.  44.  30.  21.  27. 305. 298. 348.
#  428. 274. 244. 178. 200. 117. 101. 415. 403. 210. 213. 290. 280. 127.
#  164. 237. 261. 125.  69.  72. 165. 159.  63.  64. 112. 146.  95. 122.
#  295. 316. 133. 147. 405. 384. 281.  78. 433. 410. 582. 539. 446. 422.
#  346. 330. 318.  47.  48.  50.  35.]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays] .................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays]: shape ............. (68, 68)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays]: dtype ............. int64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.idelays]: unique_values ..... [[1], [36, 37], [40, 41], [44, 93], [96, 99], [101, 113], [115, 119], [122, 123], [125, 141], [143, 162], [164, 166], [168, 170], [172, 174], [176, 179], [181, 189], [191, 222], [224, 253], [255, 274], [277, 348], [350, 362], [364, 384], [386, 431], [433, 461], [463, 466], [468, 471], [473, 474], [476, 529], [531, 543], [546, 558], [560, 570], [572, 573], [576, 581], [583, 593], [595, 602], [604, 605], [607], [609, 615], [617], [619, 620], [622], [624, 625], [628], [630, 631], [633, 634], [636], [639, 645], [648, 649], [652, 656], [658], [660], [662, 665], [667, 671], [673], [675], [677], [680, 684], [688], [690, 693], [699, 700], [703, 705], [707], [710, 714], [718, 722], [724, 729], [731], [734, 735], [739], [744], [747], [749], [751, 754], [758, 759], [761], [763, 764], [770], [781], [784, 786], [792, 793], [795], [799], [801], [804], [812, 814], [820], [827], [841], [862], [879]]
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays] ..................... --------------------
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays]: shape .............. (68, 68)
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays]: dtype .............. float64
#   spikeNet_app.tvb_cosimulator_serialized[connectivity.delays]: unique_values ...... [ 0.1        39.98974333 34.00171    ... 20.76666667  6.62544467
#   5.83055433]
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a] .............................. --------------------
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a]: shape ....................... (1,)
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a]: dtype ....................... float64
#   spikeNet_app.tvb_cosimulator_serialized[coupling.a]: values ...................... 0.00390625
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b] .............................. --------------------
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b]: shape ....................... (1,)
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b]: dtype ....................... float64
#   spikeNet_app.tvb_cosimulator_serialized[coupling.b]: values ...................... 0
#   spikeNet_app.interfaces_builder .................................................. None
#   spikeNet_app.logger .............................................................. <Logger examples.example (DEBUG)>
#   spikeNet_app.default_tvb_serial_cosim_path ....................................... '/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/WilsonCowan_SPIKES_bidir/config/tvb_serial_cosimulator.pkl'
#   spikeNet_app.gid ................................................................. UUID('d55b7d99-c598-48ed-997d-7685e5339360')
#   spikeNet_app.spiking_cosimulator ................................................. <module 'ANNarchy' from '/home/docker/.local/lib/python3.10/site-packages/ANNarchy/__init__.py'>
#   logger ........................................................................... <Logger examples.example (DEBUG)>
#   default_tvb_serial_cosim_path .................................................... '/home/docker/packages/tvb-multiscale/examples/tvb_annarchy/notebooks/outputs/WilsonCowan_SPIKES_bidir/config/tvb_serial_cosimulator.pkl'
#   gid .............................................................................. UUID('54fd5225-e7ab-4f49-bc6c-c794096efd6f')
# )
# None
#
#
# Simulating...
#
# Simulating for 36ms with App TVBANNarchySerialOrchestrator...
#
# Configuring simulation with App TVBANNarchySerialOrchestrator...
#
# Configuring simulation with App TVBSerialApp...
# 2023-09-20 18:31:40,974 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-20 18:31:40,974 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-09-20 18:31:40,974 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-09-20 18:31:40,974 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2023-09-20 18:31:40,984 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-09-20 18:31:40,984 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-09-20 18:31:40,985 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-20 18:31:40,985 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
#
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: e86ca640-24d0-415a-96c6-06d478c7e5a6'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... WilsonCowan gid: 9fdd6e41-10d6-4087-bc88-f6ff8beb1cf2
#   output_interfaces ................... TVBtoANNarchyInterfaces gid: 9e9e0e11-8e9d-4fcd-a1f6-1c06b91f7724
#   input_interfaces .................... ANNarchyToTVBInterfaces gid: e3ba2c86-8e20-48fd-8e66-0925e25a9c17
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (2,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: values .............. [[0, 1]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (2,)
#   voi: dtype .......................... int64
#   voi: values ......................... [[0, 1]]
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[0, 1]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. CosimCoupling(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 90616928-3f21-4de3-9c15-57217eeeb444
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: c74f4151-c493-4230-b91f-e2e3264438d5
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: e1d353e6-657e-4e1b-937b-d4a23988680f
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('e86ca640-24d0-415a-96c6-06d478c7e5a6')
# )
#
# Configuring simulation with App ANNarchySerialApp...
# Compiling ...  OK
#
# Simulating for 36ms with App TVBSerialApp...
# 2023-09-20 18:32:03,176 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - No or all NaN valued cosimulator updates at time step 0!
# 2023-09-20 18:32:03,176 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.032 seconds
# 2023-09-20 18:32:03,176 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2023-09-20 18:32:03,176 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 44063
# 2023-09-20 18:32:03,183 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:32:03,205 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...9.091% completed in 0.0288355 sec!
# ...9.091% completed in 0.0288355 sec!2023-09-20 18:32:03,218 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:32:03,241 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...18.182% completed in 0.0649416 sec!
# ...18.182% completed in 0.0649416 sec!2023-09-20 18:32:03,255 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:32:03,277 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...27.273% completed in 0.100952 sec!
# ...27.273% completed in 0.100952 sec!2023-09-20 18:32:03,291 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:32:03,313 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...36.364% completed in 0.136738 sec!
# ...36.364% completed in 0.136738 sec!2023-09-20 18:32:03,411 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:32:03,435 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...45.455% completed in 0.258955 sec!
# ...45.455% completed in 0.258955 sec!2023-09-20 18:32:03,449 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:32:03,471 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...54.545% completed in 0.2951 sec!
# ...54.545% completed in 0.2951 sec!2023-09-20 18:32:03,485 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:32:03,508 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...63.636% completed in 0.331518 sec!
# ...63.636% completed in 0.331518 sec!2023-09-20 18:32:03,522 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:32:03,546 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...72.727% completed in 0.370069 sec!
# ...72.727% completed in 0.370069 sec!2023-09-20 18:32:03,560 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:32:03,583 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...81.818% completed in 0.406806 sec!
# ...81.818% completed in 0.406806 sec!2023-09-20 18:32:03,597 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:32:03,619 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...90.909% completed in 0.443004 sec!
# ...90.909% completed in 0.443004 sec!2023-09-20 18:32:03,633 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-09-20 18:32:03,656 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...100.000% completed in 0.479437 sec!
# ...100.000% completed in 0.479437 sec!
# Simulated in 22.682318 secs!
#
#
# Cleaning up App TVBANNarchySerialOrchestrator...
#
# Cleaning up App TVBSerialApp...
#
# Cleaning up App ANNarchySerialApp...
#
# Stopping App TVBANNarchySerialOrchestrator...
#
# Stopping App TVBSerialApp...
#
# Success in 22.997 sec!
# ******************************************************
#
# {'TestWilsonCowanSPIKES': True}
