# %%
! pwd
# Out:
# /home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks

# %%
! python ../../../tvb_multiscale/tests/tvb_nest/test_simulator.py
# Out:
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
# 2026-08-04 13:43:43,840 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2026-08-04 13:43:43,840 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2026-08-04 13:43:43,842 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2026-08-04 13:43:43,842 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2026-08-04 13:43:43,842 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2026-08-04 13:43:43,842 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2026-08-04 13:43:43,842 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2026-08-04 13:43:43,842 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2026-08-04 13:43:43,842 - INFO - tvb_multiscale.tvb_nest.config - NEST_MODULE_PATH: /home/docker/build/nest/lib/nest
# 2026-08-04 13:43:43,842 - INFO - tvb_multiscale.tvb_nest.config - NEST_MODULE_PATH: /home/docker/build/nest/lib/nest
# 2026-08-04 13:43:43,842 - INFO - tvb_multiscale.tvb_nest.config - PATH: /home/docker/build/nest/bin:/home/docker/build/nest/bin:/home/docker/venv/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin;;
# 2026-08-04 13:43:43,842 - INFO - tvb_multiscale.tvb_nest.config - PATH: /home/docker/build/nest/bin:/home/docker/build/nest/bin:/home/docker/venv/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin;;
# 2026-08-04 13:43:43,842 - INFO - tvb_multiscale.tvb_nest.config - LD_LIBRARY_PATH: /home/docker/build/nest/lib/nest::/home/docker/build/nest/lib/nest
# 2026-08-04 13:43:43,842 - INFO - tvb_multiscale.tvb_nest.config - LD_LIBRARY_PATH: /home/docker/build/nest/lib/nest::/home/docker/build/nest/lib/nest
# 2026-08-04 13:43:43,842 - INFO - tvb_multiscale.tvb_nest.config - SLI_PATH: /home/docker/build/nest/share/nest/sli
# 2026-08-04 13:43:43,842 - INFO - tvb_multiscale.tvb_nest.config - SLI_PATH: /home/docker/build/nest/share/nest/sli
# 2026-08-04 13:43:43,842 - INFO - tvb_multiscale.tvb_nest.config - NEST_PYTHON_PREFIX: /home/docker/build/nest/lib/python3.12/site-packages
# 2026-08-04 13:43:43,842 - INFO - tvb_multiscale.tvb_nest.config - NEST_PYTHON_PREFIX: /home/docker/build/nest/lib/python3.12/site-packages
# 2026-08-04 13:43:43,842 - INFO - tvb_multiscale.tvb_nest.config - system path: ['/home/docker/build/nest/lib/python3.12/site-packages', '/home/docker/packages/tvb-multiscale/tvb_multiscale/tests/tvb_nest', '/home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks', '/home/docker/venv', '/home/docker/packages/PySpike', '/home/docker/build/nest/lib/python3.12/site-packages', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '/home/docker/venv/lib/python3.12/site-packages', '/home/docker/packages/tvb-root/tvb_bin', '/home/docker/packages/tvb-root/tvb_build', '/home/docker/packages/tvb-root/tvb_contrib', '/home/docker/packages/tvb-root/tvb_framework', '/home/docker/packages/tvb-root/tvb_library', '/home/docker/packages/tvb-root/tvb_storage', '/home/docker/venv/lib/python3.12/site-packages/NEST_Client-0.1-py3.12.egg', '/home/docker/packages/tvb-multiscale', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages']
# 2026-08-04 13:43:43,842 - INFO - tvb_multiscale.tvb_nest.config - system path: ['/home/docker/build/nest/lib/python3.12/site-packages', '/home/docker/packages/tvb-multiscale/tvb_multiscale/tests/tvb_nest', '/home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks', '/home/docker/venv', '/home/docker/packages/PySpike', '/home/docker/build/nest/lib/python3.12/site-packages', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '/home/docker/venv/lib/python3.12/site-packages', '/home/docker/packages/tvb-root/tvb_bin', '/home/docker/packages/tvb-root/tvb_build', '/home/docker/packages/tvb-root/tvb_contrib', '/home/docker/packages/tvb-root/tvb_framework', '/home/docker/packages/tvb-root/tvb_library', '/home/docker/packages/tvb-root/tvb_storage', '/home/docker/venv/lib/python3.12/site-packages/NEST_Client-0.1-py3.12.egg', '/home/docker/packages/tvb-multiscale', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages']

# %%
! python ../../../tvb_multiscale/tests/tvb_nest/test_spiking_models_builder_properties_methods.py
# Out:
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
# 2026-08-04 13:43:45,921 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2026-08-04 13:43:45,921 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2026-08-04 13:43:45,922 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2026-08-04 13:43:45,922 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2026-08-04 13:43:45,922 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2026-08-04 13:43:45,922 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2026-08-04 13:43:45,922 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2026-08-04 13:43:45,922 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2026-08-04 13:43:45,922 - INFO - tvb_multiscale.tvb_nest.config - NEST_MODULE_PATH: /home/docker/build/nest/lib/nest
# 2026-08-04 13:43:45,922 - INFO - tvb_multiscale.tvb_nest.config - NEST_MODULE_PATH: /home/docker/build/nest/lib/nest
# 2026-08-04 13:43:45,922 - INFO - tvb_multiscale.tvb_nest.config - PATH: /home/docker/build/nest/bin:/home/docker/build/nest/bin:/home/docker/venv/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin;;
# 2026-08-04 13:43:45,922 - INFO - tvb_multiscale.tvb_nest.config - PATH: /home/docker/build/nest/bin:/home/docker/build/nest/bin:/home/docker/venv/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin;;
# 2026-08-04 13:43:45,922 - INFO - tvb_multiscale.tvb_nest.config - LD_LIBRARY_PATH: /home/docker/build/nest/lib/nest::/home/docker/build/nest/lib/nest
# 2026-08-04 13:43:45,922 - INFO - tvb_multiscale.tvb_nest.config - LD_LIBRARY_PATH: /home/docker/build/nest/lib/nest::/home/docker/build/nest/lib/nest
# 2026-08-04 13:43:45,922 - INFO - tvb_multiscale.tvb_nest.config - SLI_PATH: /home/docker/build/nest/share/nest/sli
# 2026-08-04 13:43:45,922 - INFO - tvb_multiscale.tvb_nest.config - SLI_PATH: /home/docker/build/nest/share/nest/sli
# 2026-08-04 13:43:45,922 - INFO - tvb_multiscale.tvb_nest.config - NEST_PYTHON_PREFIX: /home/docker/build/nest/lib/python3.12/site-packages
# 2026-08-04 13:43:45,922 - INFO - tvb_multiscale.tvb_nest.config - NEST_PYTHON_PREFIX: /home/docker/build/nest/lib/python3.12/site-packages
# 2026-08-04 13:43:45,922 - INFO - tvb_multiscale.tvb_nest.config - system path: ['/home/docker/build/nest/lib/python3.12/site-packages', '/home/docker/packages/tvb-multiscale/tvb_multiscale/tests/tvb_nest', '/home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks', '/home/docker/venv', '/home/docker/packages/PySpike', '/home/docker/build/nest/lib/python3.12/site-packages', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '/home/docker/venv/lib/python3.12/site-packages', '/home/docker/packages/tvb-root/tvb_bin', '/home/docker/packages/tvb-root/tvb_build', '/home/docker/packages/tvb-root/tvb_contrib', '/home/docker/packages/tvb-root/tvb_framework', '/home/docker/packages/tvb-root/tvb_library', '/home/docker/packages/tvb-root/tvb_storage', '/home/docker/venv/lib/python3.12/site-packages/NEST_Client-0.1-py3.12.egg', '/home/docker/packages/tvb-multiscale', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages']
# 2026-08-04 13:43:45,922 - INFO - tvb_multiscale.tvb_nest.config - system path: ['/home/docker/build/nest/lib/python3.12/site-packages', '/home/docker/packages/tvb-multiscale/tvb_multiscale/tests/tvb_nest', '/home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks', '/home/docker/venv', '/home/docker/packages/PySpike', '/home/docker/build/nest/lib/python3.12/site-packages', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '/home/docker/venv/lib/python3.12/site-packages', '/home/docker/packages/tvb-root/tvb_bin', '/home/docker/packages/tvb-root/tvb_build', '/home/docker/packages/tvb-root/tvb_contrib', '/home/docker/packages/tvb-root/tvb_framework', '/home/docker/packages/tvb-root/tvb_library', '/home/docker/packages/tvb-root/tvb_storage', '/home/docker/venv/lib/python3.12/site-packages/NEST_Client-0.1-py3.12.egg', '/home/docker/packages/tvb-multiscale', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages']
#
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.9.0
#  Built: Aug  4 2026 09:30:46
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.
#
# 2026-08-04 13:43:46,096 - WARNING - tvb_multiscale.core.neotraits - Field seems mutable and has a default value. Consider using a lambda as a value factory
#    attribute tvb_multiscale.tvb_nest.nest_models.node._NESTNodeCollection._nodes = Attr(field_type=(<class 'nest.lib.hl_api_types.NodeCollection'>, <class 'tvb_multiscale.tvb_nest.nest_models.server_client.node_collection.NodeCollection'>), default=NodeCollection(<empty>), required=False)
# 2026-08-04 13:43:46,096 - WARNING - tvb_multiscale.core.neotraits - Field seems mutable and has a default value. Consider using a lambda as a value factory
#    attribute tvb_multiscale.tvb_nest.nest_models.node._NESTNodeCollection._nodes = Attr(field_type=(<class 'nest.lib.hl_api_types.NodeCollection'>, <class 'tvb_multiscale.tvb_nest.nest_models.server_client.node_collection.NodeCollection'>), default=NodeCollection(<empty>), required=False)
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning:Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#
# Aug 04 13:43:46 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.05 ms.
# <tvb_multiscale.tvb_nest.nest_models.models.default.DefaultExcIOBuilder object at 0xffff40d3f8f0>
# nest simulator: <module 'nest' from '/home/docker/build/nest/lib/python3.12/site-packages/nest/__init__.py'>
# min_delay:
# 0.05
#
# tvb_dt:
# 0.1
#
# monitor_period:
# 0.1
#
# tvb_model:
# Linear
#
# number_of_regions:
# 68
#
# tvb_weights:
# [[0.0000000e+00 4.8155833e-02 5.5569724e-01 ... 0.0000000e+00
#   9.3632959e-04 1.5197568e-03]
#  [3.4694958e-02 0.0000000e+00 4.0470140e+00 ... 0.0000000e+00
#   0.0000000e+00 6.4991351e-02]
#  [3.3234182e-01 1.6091147e+00 0.0000000e+00 ... 0.0000000e+00
#   1.3227513e-03 2.2254678e-01]
#  ...
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#   4.2837810e-03 6.6117304e+01]
#  [6.8634180e-04 0.0000000e+00 1.8867925e-02 ... 2.7493696e-02
#   0.0000000e+00 2.8296225e+01]
#  [2.8677947e-04 1.3400005e-02 3.4921828e-01 ... 2.5495074e+01
#   1.4883909e+01 0.0000000e+00]]
#
# tvb_delays:
# [[ 0.         39.98974333 34.00171    ...  0.         47.8
#   44.73333333]
#  [39.98974333  0.         14.00699533 ...  0.          0.
#   23.274074  ]
#  [34.00171    14.00699533  0.         ...  0.         58.33333333
#   37.56438333]
#  ...
#  [ 0.          0.          0.         ...  0.         20.76666667
#    6.62544467]
#  [47.8         0.         58.33333333 ... 20.76666667  0.
#    5.83055433]
#  [44.73333333 23.274074   37.56438333 ...  6.62544467  5.83055433
#    0.        ]]
#
# region_labels:
# ['bankssts_L' 'bankssts_R' 'caudalanteriorcingulate_L'
#  'caudalanteriorcingulate_R' 'caudalmiddlefrontal_L'
#  'caudalmiddlefrontal_R' 'cuneus_L' 'cuneus_R' 'entorhinal_L'
#  'entorhinal_R' 'frontalpole_L' 'frontalpole_R' 'fusiform_L' 'fusiform_R'
#  'inferiorparietal_L' 'inferiorparietal_R' 'inferiortemporal_L'
#  'inferiortemporal_R' 'insula_L' 'insula_R' 'isthmuscingulate_L'
#  'isthmuscingulate_R' 'lateraloccipital_L' 'lateraloccipital_R'
#  'lateralorbitofrontal_L' 'lateralorbitofrontal_R' 'lingual_L' 'lingual_R'
#  'medialorbitofrontal_L' 'medialorbitofrontal_R' 'middletemporal_L'
#  'middletemporal_R' 'paracentral_L' 'paracentral_R' 'parahippocampal_L'
#  'parahippocampal_R' 'parsopercularis_L' 'parsopercularis_R'
#  'parsorbitalis_L' 'parsorbitalis_R' 'parstriangularis_L'
#  'parstriangularis_R' 'pericalcarine_L' 'pericalcarine_R' 'postcentral_L'
#  'postcentral_R' 'posteriorcingulate_L' 'posteriorcingulate_R'
#  'precentral_L' 'precentral_R' 'precuneus_L' 'precuneus_R'
#  'rostralanteriorcingulate_L' 'rostralanteriorcingulate_R'
#  'rostralmiddlefrontal_L' 'rostralmiddlefrontal_R' 'superiorfrontal_L'
#  'superiorfrontal_R' 'superiorparietal_L' 'superiorparietal_R'
#  'superiortemporal_L' 'superiortemporal_R' 'supramarginal_L'
#  'supramarginal_R' 'temporalpole_L' 'temporalpole_R'
#  'transversetemporal_L' 'transversetemporal_R']
#
# number_of_populations:
# 0
#
# populations_models:
# OrderedDict()
#
# populations_nodes:
# OrderedDict()
#
# populations_scales:
# OrderedDict()
#
# populations_sizes:
# OrderedDict()
#
# populations_params:
# OrderedDict()
#
# populations_connections_labels:
# []
#
# populations_connections_models:
# OrderedDict()
#
# populations_connections_nodes:
# OrderedDict()
#
# populations_connections_weights:
# OrderedDict()
#
# populations_connections_delays:
# OrderedDict()
#
# populations_connections_receptor_types:
# OrderedDict()
#
# populations_connections_conn_spec:
# OrderedDict()
#
# nodes_connections_labels:
# []
#
# nodes_connections_models:
# OrderedDict()
#
# nodes_connections_source_nodes:
# OrderedDict()
#
# nodes_connections_target_nodes:
# OrderedDict()
#
# nodes_connections_weights:
# OrderedDict()
#
# nodes_connections_delays:
# OrderedDict()
#
# nodes_connections_receptor_types:
# OrderedDict()
#
# nodes_connections_conn_spec:
# OrderedDict()

# %%
! python ../../../tvb_multiscale/tests/tvb_nest/test_models.py
# Out:
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
# 2026-08-04 13:43:49,416 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2026-08-04 13:43:49,416 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2026-08-04 13:43:49,417 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2026-08-04 13:43:49,417 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2026-08-04 13:43:49,417 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2026-08-04 13:43:49,417 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2026-08-04 13:43:49,417 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2026-08-04 13:43:49,417 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2026-08-04 13:43:49,417 - INFO - tvb_multiscale.tvb_nest.config - NEST_MODULE_PATH: /home/docker/build/nest/lib/nest
# 2026-08-04 13:43:49,417 - INFO - tvb_multiscale.tvb_nest.config - NEST_MODULE_PATH: /home/docker/build/nest/lib/nest
# 2026-08-04 13:43:49,417 - INFO - tvb_multiscale.tvb_nest.config - PATH: /home/docker/build/nest/bin:/home/docker/build/nest/bin:/home/docker/venv/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin;;
# 2026-08-04 13:43:49,417 - INFO - tvb_multiscale.tvb_nest.config - PATH: /home/docker/build/nest/bin:/home/docker/build/nest/bin:/home/docker/venv/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin;;
# 2026-08-04 13:43:49,417 - INFO - tvb_multiscale.tvb_nest.config - LD_LIBRARY_PATH: /home/docker/build/nest/lib/nest::/home/docker/build/nest/lib/nest
# 2026-08-04 13:43:49,417 - INFO - tvb_multiscale.tvb_nest.config - LD_LIBRARY_PATH: /home/docker/build/nest/lib/nest::/home/docker/build/nest/lib/nest
# 2026-08-04 13:43:49,417 - INFO - tvb_multiscale.tvb_nest.config - SLI_PATH: /home/docker/build/nest/share/nest/sli
# 2026-08-04 13:43:49,417 - INFO - tvb_multiscale.tvb_nest.config - SLI_PATH: /home/docker/build/nest/share/nest/sli
# 2026-08-04 13:43:49,418 - INFO - tvb_multiscale.tvb_nest.config - NEST_PYTHON_PREFIX: /home/docker/build/nest/lib/python3.12/site-packages
# 2026-08-04 13:43:49,418 - INFO - tvb_multiscale.tvb_nest.config - NEST_PYTHON_PREFIX: /home/docker/build/nest/lib/python3.12/site-packages
# 2026-08-04 13:43:49,418 - INFO - tvb_multiscale.tvb_nest.config - system path: ['/home/docker/build/nest/lib/python3.12/site-packages', '/home/docker/packages/tvb-multiscale/tvb_multiscale/tests/tvb_nest', '/home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks', '/home/docker/venv', '/home/docker/packages/PySpike', '/home/docker/build/nest/lib/python3.12/site-packages', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '/home/docker/venv/lib/python3.12/site-packages', '/home/docker/packages/tvb-root/tvb_bin', '/home/docker/packages/tvb-root/tvb_build', '/home/docker/packages/tvb-root/tvb_contrib', '/home/docker/packages/tvb-root/tvb_framework', '/home/docker/packages/tvb-root/tvb_library', '/home/docker/packages/tvb-root/tvb_storage', '/home/docker/venv/lib/python3.12/site-packages/NEST_Client-0.1-py3.12.egg', '/home/docker/packages/tvb-multiscale', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages']
# 2026-08-04 13:43:49,418 - INFO - tvb_multiscale.tvb_nest.config - system path: ['/home/docker/build/nest/lib/python3.12/site-packages', '/home/docker/packages/tvb-multiscale/tvb_multiscale/tests/tvb_nest', '/home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks', '/home/docker/venv', '/home/docker/packages/PySpike', '/home/docker/build/nest/lib/python3.12/site-packages', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '/home/docker/venv/lib/python3.12/site-packages', '/home/docker/packages/tvb-root/tvb_bin', '/home/docker/packages/tvb-root/tvb_build', '/home/docker/packages/tvb-root/tvb_contrib', '/home/docker/packages/tvb-root/tvb_framework', '/home/docker/packages/tvb-root/tvb_library', '/home/docker/packages/tvb-root/tvb_storage', '/home/docker/venv/lib/python3.12/site-packages/NEST_Client-0.1-py3.12.egg', '/home/docker/packages/tvb-multiscale', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages']
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
#
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.9.0
#  Built: Aug  4 2026 09:30:46
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.
#
# 2026-08-04 13:43:50,886 - WARNING - tvb_multiscale.core.neotraits - Field seems mutable and has a default value. Consider using a lambda as a value factory
#    attribute tvb_multiscale.tvb_nest.nest_models.node._NESTNodeCollection._nodes = Attr(field_type=(<class 'nest.lib.hl_api_types.NodeCollection'>, <class 'tvb_multiscale.tvb_nest.nest_models.server_client.node_collection.NodeCollection'>), default=NodeCollection(<empty>), required=False)
# 2026-08-04 13:43:50,886 - WARNING - tvb_multiscale.core.neotraits - Field seems mutable and has a default value. Consider using a lambda as a value factory
#    attribute tvb_multiscale.tvb_nest.nest_models.node._NESTNodeCollection._nodes = Attr(field_type=(<class 'nest.lib.hl_api_types.NodeCollection'>, <class 'tvb_multiscale.tvb_nest.nest_models.server_client.node_collection.NodeCollection'>), default=NodeCollection(<empty>), required=False)
# /home/docker/venv/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning:Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
# 2026-08-04 13:43:51,268 - WARNING - tvb.simulator.plot.tools - You need mpl_toolkits for some axe related features
#
# ******************************************************
# ******************************************************
# TestDefaultRATE
# ******************************************************
# ******************************************************
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning:Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#
# ----------------------------------------------------------------------------------------------------
# Find results in /home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks/outputs/DefaultExcIO_RATE_bidir/res !
# ----------------------------------------------------------------------------------------------------
# 2026-08-04 13:43:52,354 - INFO - examples.example -
# Starting App TVBNESTSerialOrchestrator...
# 2026-08-04 13:43:52,354 - INFO - examples.example -
# Starting App TVBNESTSerialOrchestrator...
#
# Starting App TVBNESTSerialOrchestrator...
# 2026-08-04 13:43:52,357 - INFO - examples.example -
# Starting App TVBSerialApp...
# 2026-08-04 13:43:52,357 - INFO - examples.example -
# Starting App TVBSerialApp...
#
# Starting App TVBSerialApp...
# 2026-08-04 13:43:52,357 - INFO - examples.example -
# Setting TVB LIBRARY_PROFILE...
# 2026-08-04 13:43:52,357 - INFO - examples.example -
# Setting TVB LIBRARY_PROFILE...
#
# Setting TVB LIBRARY_PROFILE...
# 2026-08-04 13:43:52,396 - INFO - examples.example -
# Starting App NESTSerialApp...
# 2026-08-04 13:43:52,396 - INFO - examples.example -
# Starting App NESTSerialApp...
#
# Starting App NESTSerialApp...
#
#
# Configuring...
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning:Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#
# Done! in 0.000148 min
#
#
#
# Building...
# 2026-08-04 13:43:52,407 - INFO - examples.example -
# Building with App TVBNESTSerialOrchestrator...
# 2026-08-04 13:43:52,407 - INFO - examples.example -
# Building with App TVBNESTSerialOrchestrator...
#
# Building with App TVBNESTSerialOrchestrator...
# 2026-08-04 13:43:52,407 - INFO - examples.example -
# Building cosimulators with TVBNESTSerialOrchestrator...
# 2026-08-04 13:43:52,407 - INFO - examples.example -
# Building cosimulators with TVBNESTSerialOrchestrator...
#
# Building cosimulators with TVBNESTSerialOrchestrator...
# 2026-08-04 13:43:52,407 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
# 2026-08-04 13:43:52,407 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
#
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
# 2026-08-04 13:43:52,409 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-04 13:43:52,409 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2026-08-04 13:43:52,409 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2026-08-04 13:43:52,415 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2026-08-04 13:43:52,415 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2026-08-04 13:43:52,416 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# 2026-08-04 13:43:52,423 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: 3e950ab7-d937-4e7c-97b2-0cf83ea8b8ee'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: a30d757f-3f27-473f-a6c6-951b11040465
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 6f77dbdc-1655-45f9-bf03-95fc076f4c4d
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 4dfbe3bb-fb33-4502-a160-b44224d28e32
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 87fca389-c719-4f2f-bc4a-1bea0057abd3
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('3e950ab7-d937-4e7c-97b2-0cf83ea8b8ee')
# )
# 2026-08-04 13:43:52,423 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: 3e950ab7-d937-4e7c-97b2-0cf83ea8b8ee'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: a30d757f-3f27-473f-a6c6-951b11040465
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 6f77dbdc-1655-45f9-bf03-95fc076f4c4d
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 4dfbe3bb-fb33-4502-a160-b44224d28e32
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 87fca389-c719-4f2f-bc4a-1bea0057abd3
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('3e950ab7-d937-4e7c-97b2-0cf83ea8b8ee')
# )
#
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: 3e950ab7-d937-4e7c-97b2-0cf83ea8b8ee'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: a30d757f-3f27-473f-a6c6-951b11040465
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 6f77dbdc-1655-45f9-bf03-95fc076f4c4d
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 4dfbe3bb-fb33-4502-a160-b44224d28e32
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 87fca389-c719-4f2f-bc4a-1bea0057abd3
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('3e950ab7-d937-4e7c-97b2-0cf83ea8b8ee')
# )
# 2026-08-04 13:43:52,423 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-04 13:43:52,423 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2026-08-04 13:43:52,423 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2026-08-04 13:43:52,429 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2026-08-04 13:43:52,429 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2026-08-04 13:43:52,430 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2026-08-04 13:43:52,434 - INFO - examples.example -
# Building Spiking Network with builder DefaultExcIOBuilder of App NESTSerialApp...
# 2026-08-04 13:43:52,434 - INFO - examples.example -
# Building Spiking Network with builder DefaultExcIOBuilder of App NESTSerialApp...
#
# Building Spiking Network with builder DefaultExcIOBuilder of App NESTSerialApp...
# 2026-08-04 13:43:52,435 - INFO - examples.example - Configuring spiking network builder...
# 2026-08-04 13:43:52,435 - INFO - examples.example - Configuring spiking network builder...
# 2026-08-04 13:43:52,435 - INFO - examples.example - Configuring populations...
# 2026-08-04 13:43:52,435 - INFO - examples.example - Configuring populations...
# 2026-08-04 13:43:52,435 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2026-08-04 13:43:52,435 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2026-08-04 13:43:52,435 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2026-08-04 13:43:52,435 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2026-08-04 13:43:52,435 - INFO - examples.example - Configuring output devices, if any...
# 2026-08-04 13:43:52,435 - INFO - examples.example - Configuring output devices, if any...
# 2026-08-04 13:43:52,435 - INFO - examples.example - Configuring input devices, if any...
# 2026-08-04 13:43:52,435 - INFO - examples.example - Configuring input devices, if any...
# /home/docker/build/nest/lib/python3.12/site-packages/nest/lib/hl_api_helper.py:114: UserWarning:
# Models is deprecated and will be removed in a future version of NEST.
# Please use nest.node_models or nest.synapse_models instead!
# 2026-08-04 13:43:52,436 - INFO - examples.example - Generating spiking brain...
# 2026-08-04 13:43:52,436 - INFO - examples.example - Generating spiking brain...
# 2026-08-04 13:43:52,436 - INFO - examples.example - Generating spiking brain regions...
# 2026-08-04 13:43:52,436 - INFO - examples.example - Generating spiking brain regions...
# 2026-08-04 13:43:52,436 - INFO - examples.example - Generating spiking region node: bankssts_L...
# 2026-08-04 13:43:52,436 - INFO - examples.example - Generating spiking region node: bankssts_L...
# 2026-08-04 13:43:52,437 - INFO - examples.example - Generating population: E...
# 2026-08-04 13:43:52,437 - INFO - examples.example - Generating population: E...
# 2026-08-04 13:43:52,437 - INFO - examples.example - ...with 10 neurons...
# 2026-08-04 13:43:52,437 - INFO - examples.example - ...with 10 neurons...
# 2026-08-04 13:43:52,438 - INFO - examples.example - Generating spiking region node: bankssts_R...
# 2026-08-04 13:43:52,438 - INFO - examples.example - Generating spiking region node: bankssts_R...
# 2026-08-04 13:43:52,439 - INFO - examples.example - Generating population: E...
# 2026-08-04 13:43:52,439 - INFO - examples.example - Generating population: E...
# 2026-08-04 13:43:52,439 - INFO - examples.example - ...with 10 neurons...
# 2026-08-04 13:43:52,439 - INFO - examples.example - ...with 10 neurons...
# 2026-08-04 13:43:52,440 - INFO - examples.example - Connecting populations within spiking brain regions...
# 2026-08-04 13:43:52,440 - INFO - examples.example - Connecting populations within spiking brain regions...
# 2026-08-04 13:43:52,440 - INFO - examples.example - Connecting E -> E populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:43:52,440 - INFO - examples.example - Connecting E -> E populations
# for spiking region nodes
# [0 1]...
# 2026-08-04 13:43:52,440 - INFO - examples.example - ...100 connections to receptor 0
# 2026-08-04 13:43:52,440 - INFO - examples.example - ...100 connections to receptor 0
# 2026-08-04 13:43:52,441 - INFO - examples.example - ...100 connections to receptor 0
# 2026-08-04 13:43:52,441 - INFO - examples.example - ...100 connections to receptor 0
# 2026-08-04 13:43:52,441 - INFO - examples.example - Connecting populations among spiking brain regions...
# 2026-08-04 13:43:52,441 - INFO - examples.example - Connecting populations among spiking brain regions...
# 2026-08-04 13:43:52,442 - INFO - examples.example - Connecting for 0 -> 1 spiking region nodes ...
# 2026-08-04 13:43:52,442 - INFO - examples.example - Connecting for 0 -> 1 spiking region nodes ...
# 2026-08-04 13:43:52,442 - INFO - examples.example - E -> E populations ...
# 2026-08-04 13:43:52,442 - INFO - examples.example - E -> E populations ...
# 2026-08-04 13:43:52,442 - INFO - examples.example - ...100 connections to receptor 0
# 2026-08-04 13:43:52,442 - INFO - examples.example - ...100 connections to receptor 0
# 2026-08-04 13:43:52,442 - INFO - examples.example - Connecting for 1 -> 0 spiking region nodes ...
# 2026-08-04 13:43:52,442 - INFO - examples.example - Connecting for 1 -> 0 spiking region nodes ...
# 2026-08-04 13:43:52,442 - INFO - examples.example - E -> E populations ...
# 2026-08-04 13:43:52,442 - INFO - examples.example - E -> E populations ...
# 2026-08-04 13:43:52,443 - INFO - examples.example - ...100 connections to receptor 0
# 2026-08-04 13:43:52,443 - INFO - examples.example - ...100 connections to receptor 0
# 2026-08-04 13:43:52,443 - INFO - examples.example - Generating and connecting output devices, if any...
# 2026-08-04 13:43:52,443 - INFO - examples.example - Generating and connecting output devices, if any...
# 2026-08-04 13:43:52,443 - INFO - examples.example - Generating and connecting ['E'] -> ['E'] device set of model spike_recorder
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:43:52,443 - INFO - examples.example - Generating and connecting ['E'] -> ['E'] device set of model spike_recorder
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:43:52,444 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model spike_recorder for E created!
# 2026-08-04 13:43:52,444 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model spike_recorder for E created!
# 2026-08-04 13:43:52,447 - INFO - examples.example - Generating and connecting ['Excitatory'] -> ['E'] device set of model multimeter
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:43:52,447 - INFO - examples.example - Generating and connecting ['Excitatory'] -> ['E'] device set of model multimeter
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:43:52,448 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model multimeter for Excitatory created!
# 2026-08-04 13:43:52,448 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model multimeter for Excitatory created!
# 2026-08-04 13:43:52,451 - INFO - examples.example - Generating and connecting input devices, if any...
# 2026-08-04 13:43:52,451 - INFO - examples.example - Generating and connecting input devices, if any...
# 2026-08-04 13:43:52,451 - INFO - examples.example - Generating and connecting ['Stimulus'] -> [['E']] device set of model poisson_generator
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:43:52,451 - INFO - examples.example - Generating and connecting ['Stimulus'] -> [['E']] device set of model poisson_generator
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-04 13:43:52,452 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model poisson_generator for Stimulus created!
# 2026-08-04 13:43:52,452 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model poisson_generator for Stimulus created!
# 2026-08-04 13:43:52,456 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2026-08-04 13:43:52,456 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2026-08-04 13:43:52,456 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2026-08-04 13:43:52,456 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2026-08-04 13:43:52,456 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2026-08-04 13:43:52,456 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2026-08-04 13:43:52,456 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2026-08-04 13:43:52,456 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2026-08-04 13:43:52,456 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# NESTNetwork (
#   title ....................................... 'NESTNetwork gid: 9f69f24c-6b4d-44fc-b44d-7374f99fb136'
#   Type ........................................ 'NESTNetwork'
#   config ...................................... '--------------------'
#   config.title ................................ 'Config gid: f2fc6f5a-b3e5-4b82-bc16-ec934d278ad1'
#   config.Type ................................. 'Config'
#   config.gid .................................. UUID('f2fc6f5a-b3e5-4b82-bc16-ec934d278ad1')
#   brain_regions ............................... '--------------------'
#   brain_regions.title ......................... 'NESTBrain gid: eec46a4b-8655-4a54-a23e-a96394c48e39'
#   brain_regions.Type .......................... 'NESTBrain'
#   brain_regions.gid ........................... UUID('eec46a4b-8655-4a54-a23e-a96394c48e39')
#   brain_regions.label ......................... ''
#   brain_regions.size .......................... 2
#   brain_regions.Regions ....................... --------------------
#   brain_regions.Regions: shape ................ (2,)
#   brain_regions.Regions: dtype ................ <U10
#   brain_regions.Regions: values ............... ['bankssts_L' 'bankssts_R']
#   brain_regions.bankssts_L .................... '--------------------'
#   brain_regions[bankssts_L].title ............. 'NESTRegionNode gid: ed679feb-3ade-46b4-babc-ea301845233d'
#   brain_regions[bankssts_L].Type .............. 'NESTRegionNode'
#   brain_regions[bankssts_L].gid ............... UUID('ed679feb-3ade-46b4-babc-ea301845233d')
#   brain_regions[bankssts_L].label ............. 'bankssts_L'
#   brain_regions[bankssts_L].size .............. 1
#   brain_regions[bankssts_L].Populations ....... --------------------
#   brain_regions[bankssts_L].Populations: shape  (1,)
#   brain_regions[bankssts_L].Populations: dtype  <U1
#   brain_regions[bankssts_L].Populations: values  E
#   brain_regions.bankssts_R .................... '--------------------'
#   brain_regions[bankssts_R].title ............. 'NESTRegionNode gid: 445f3ae1-8f50-438e-bec0-28734ae4cc3d'
#   brain_regions[bankssts_R].Type .............. 'NESTRegionNode'
#   brain_regions[bankssts_R].gid ............... UUID('445f3ae1-8f50-438e-bec0-28734ae4cc3d')
#   brain_regions[bankssts_R].label ............. 'bankssts_R'
#   brain_regions[bankssts_R].size .............. 1
#   brain_regions[bankssts_R].Populations ....... --------------------
#   brain_regions[bankssts_R].Populations: shape  (1,)
#   brain_regions[bankssts_R].Populations: dtype  <U1
#   brain_regions[bankssts_R].Populations: values  E
#   logger ...................................... <Logger tvb-multiscale (DEBUG)>
#   output_devices .............................. '--------------------'
#   output_devices.title ........................ 'DeviceSets gid: 4e4dd974-c60c-4fe7-9896-71550108937d'
#   output_devices.Type ......................... 'DeviceSets'
#   output_devices.gid .......................... UUID('4e4dd974-c60c-4fe7-9896-71550108937d')
#   output_devices.label ........................ 'output_devices'
#   output_devices.size ......................... 2
#   output_devices.DeviceSets ................... --------------------
#   output_devices.DeviceSets: shape ............ (2,)
#   output_devices.DeviceSets: dtype ............ <U10
#   output_devices.DeviceSets: values ........... ['E' 'Excitatory']
#   output_devices.E ............................ '--------------------'
#   output_devices[E].title ..................... 'DeviceSet gid: 35dfa921-1d39-4be8-b7fc-6bc0fec3c99d'
#   output_devices[E].Type ...................... 'DeviceSet'
#   output_devices[E].model ..................... 'spike_recorder'
#   output_devices[E].gid ....................... UUID('35dfa921-1d39-4be8-b7fc-6bc0fec3c99d')
#   output_devices[E].label ..................... 'E'
#   output_devices[E].size ...................... 2
#   output_devices[E].Devices ................... --------------------
#   output_devices[E].Devices: shape ............ (2,)
#   output_devices[E].Devices: dtype ............ <U10
#   output_devices[E].Devices: values ........... ['bankssts_L' 'bankssts_R']
#   output_devices.Excitatory ................... '--------------------'
#   output_devices[Excitatory].title ............ 'DeviceSet gid: 763a3ac7-3ac0-49c4-a9a2-3f1ef162a93a'
#   output_devices[Excitatory].Type ............. 'DeviceSet'
#   output_devices[Excitatory].model ............ 'multimeter'
#   output_devices[Excitatory].gid .............. UUID('763a3ac7-3ac0-49c4-a9a2-3f1ef162a93a')
#   output_devices[Excitatory].label ............ 'Excitatory'
#   output_devices[Excitatory].size ............. 2
#   output_devices[Excitatory].Devices .......... --------------------
#   output_devices[Excitatory].Devices: shape ... (2,)
#   output_devices[Excitatory].Devices: dtype ... <U10
#   output_devices[Excitatory].Devices: values .. ['bankssts_L' 'bankssts_R']
#   input_devices ............................... '--------------------'
#   input_devices.title ......................... 'DeviceSets gid: 4c8fdd7a-cbb6-402b-a653-6262624d1358'
#   input_devices.Type .......................... 'DeviceSets'
#   input_devices.gid ........................... UUID('4c8fdd7a-cbb6-402b-a653-6262624d1358')
#   input_devices.label ......................... 'input_devices'
#   input_devices.size .......................... 1
#   input_devices.DeviceSets .................... --------------------
#   input_devices.DeviceSets: shape ............. (1,)
#   input_devices.DeviceSets: dtype ............. <U8
#   input_devices.DeviceSets: values ............ Stimulus
#   input_devices.Stimulus ...................... '--------------------'
#   input_devices[Stimulus].title ............... 'DeviceSet gid: 5b5e61c9-5201-498f-8b79-4032e2a1d1b3'
#   input_devices[Stimulus].Type ................ 'DeviceSet'
#   input_devices[Stimulus].model ............... 'poisson_generator'
#   input_devices[Stimulus].gid ................. UUID('5b5e61c9-5201-498f-8b79-4032e2a1d1b3')
#   input_devices[Stimulus].label ............... 'Stimulus'
#   input_devices[Stimulus].size ................ 2
#   input_devices[Stimulus].Devices ............. --------------------
#   input_devices[Stimulus].Devices: shape ...... (2,)
#   input_devices[Stimulus].Devices: dtype ...... <U10
#   input_devices[Stimulus].Devices: values ..... ['bankssts_L' 'bankssts_R']
#   output_proxies .............................. '--------------------'
#   output_proxies.title ........................ 'DeviceSets gid: 34b44ad3-30c1-4ecf-8bdf-ca6a3a456ef3'
#   output_proxies.Type ......................... 'DeviceSets'
#   output_proxies.gid .......................... UUID('34b44ad3-30c1-4ecf-8bdf-ca6a3a456ef3')
#   output_proxies.label ........................ 'output_proxies'
#   output_proxies.size ......................... 0
#   output_proxies.DeviceSets ................... --------------------
#   shape ....................................... (0,)
#   dtype ....................................... float64
#   is empty .................................... True
#   input_proxies ............................... '--------------------'
#   input_proxies.title ......................... 'DeviceSets gid: 33e2d45c-8d8c-414f-827b-00f390bb61ad'
#   input_proxies.Type .......................... 'DeviceSets'
#   input_proxies.gid ........................... UUID('33e2d45c-8d8c-414f-827b-00f390bb61ad')
#   input_proxies.label ......................... 'input_proxies'
#   input_proxies.size .......................... 0
#   input_proxies.DeviceSets .................... --------------------
#   gid ......................................... UUID('9f69f24c-6b4d-44fc-b44d-7374f99fb136')
# )
# 2026-08-04 13:43:52,459 - INFO - examples.example -
# Building interfaces with Orchestrator TVBNESTSerialOrchestrator...
# 2026-08-04 13:43:52,459 - INFO - examples.example -
# Building interfaces with Orchestrator TVBNESTSerialOrchestrator...
#
# Building interfaces with Orchestrator TVBNESTSerialOrchestrator...
# 2026-08-04 13:43:52,460 - INFO - examples.example -
# Building interfaces' with builder TVBNESTInterfaceBuilder of App TVBSerialApp...
# 2026-08-04 13:43:52,460 - INFO - examples.example -
# Building interfaces' with builder TVBNESTInterfaceBuilder of App TVBSerialApp...
#
# Building interfaces' with builder TVBNESTInterfaceBuilder of App TVBSerialApp...
# 2026-08-04 13:43:52,460 - INFO - examples.example -
# Configuring interfaces' builder DefaultTVBNESTInterfaceBuilder of App TVBSerialApp...
# 2026-08-04 13:43:52,460 - INFO - examples.example -
# Configuring interfaces' builder DefaultTVBNESTInterfaceBuilder of App TVBSerialApp...
#
# Configuring interfaces' builder DefaultTVBNESTInterfaceBuilder of App TVBSerialApp...
# 2026-08-04 13:43:52,460 - INFO - examples.example -
# Configuring default interfaces...
# 2026-08-04 13:43:52,460 - INFO - examples.example -
# Configuring default interfaces...
#
# Configuring default interfaces...
# 2026-08-04 13:43:52,463 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model inhomogeneous_poisson_generator for ['R']->E created!
# 2026-08-04 13:43:52,463 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model inhomogeneous_poisson_generator for ['R']->E created!
# 2026-08-04 13:43:52,542 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model spike_recorder for E->['R'] created!
# 2026-08-04 13:43:52,542 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model spike_recorder for E->['R'] created!
# 2026-08-04 13:43:52,546 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-04 13:43:52,547 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2026-08-04 13:43:52,547 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2026-08-04 13:43:52,553 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2026-08-04 13:43:52,553 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2026-08-04 13:43:52,554 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2026-08-04 13:43:52,582 - INFO - examples.example -
# TVBtoNESTInterfaces (
#   title .................................. 'TVBtoNESTInterfaces gid: a2c631d6-55a9-46e3-9402-7d91a3e27272'
#   Type ................................... 'TVBtoNESTInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoNESTInterface gid: e9e231f1-a816-448d-bf51-993eb3060f9b'
#   interfaces[0].Type ..................... 'TVBtoNESTInterface'
#   interfaces[0].proxy .................... NESTInhomogeneousPoissonGeneratorSet gid: a2e09e3b-704a-4a0e-90ba-f789cb12911f
#   interfaces[0].spiking_network .......... NESTNetwork gid: 9f69f24c-6b4d-44fc-b44d-7374f99fb136
#   interfaces[0].transformer .............. LinearRate gid: a254bd61-90c6-45e0-a272-8962fc8f547f
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[np.int64(2), np.int64(67)]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[np.int64(0), np.int64(1)]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('e9e231f1-a816-448d-bf51-993eb3060f9b')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int64
#   interfaces[0].proxy_gids: unique_values  [[np.int64(27), np.int64(92)]]
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('a2c631d6-55a9-46e3-9402-7d91a3e27272')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[np.int64(0), np.int64(1)]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 66
# )
# 2026-08-04 13:43:52,582 - INFO - examples.example -
# TVBtoNESTInterfaces (
#   title .................................. 'TVBtoNESTInterfaces gid: a2c631d6-55a9-46e3-9402-7d91a3e27272'
#   Type ................................... 'TVBtoNESTInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoNESTInterface gid: e9e231f1-a816-448d-bf51-993eb3060f9b'
#   interfaces[0].Type ..................... 'TVBtoNESTInterface'
#   interfaces[0].proxy .................... NESTInhomogeneousPoissonGeneratorSet gid: a2e09e3b-704a-4a0e-90ba-f789cb12911f
#   interfaces[0].spiking_network .......... NESTNetwork gid: 9f69f24c-6b4d-44fc-b44d-7374f99fb136
#   interfaces[0].transformer .............. LinearRate gid: a254bd61-90c6-45e0-a272-8962fc8f547f
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[np.int64(2), np.int64(67)]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[np.int64(0), np.int64(1)]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('e9e231f1-a816-448d-bf51-993eb3060f9b')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int64
#   interfaces[0].proxy_gids: unique_values  [[np.int64(27), np.int64(92)]]
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('a2c631d6-55a9-46e3-9402-7d91a3e27272')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[np.int64(0), np.int64(1)]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 66
# )
#
# TVBtoNESTInterfaces (
#   title .................................. 'TVBtoNESTInterfaces gid: a2c631d6-55a9-46e3-9402-7d91a3e27272'
#   Type ................................... 'TVBtoNESTInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoNESTInterface gid: e9e231f1-a816-448d-bf51-993eb3060f9b'
#   interfaces[0].Type ..................... 'TVBtoNESTInterface'
#   interfaces[0].proxy .................... NESTInhomogeneousPoissonGeneratorSet gid: a2e09e3b-704a-4a0e-90ba-f789cb12911f
#   interfaces[0].spiking_network .......... NESTNetwork gid: 9f69f24c-6b4d-44fc-b44d-7374f99fb136
#   interfaces[0].transformer .............. LinearRate gid: a254bd61-90c6-45e0-a272-8962fc8f547f
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[np.int64(2), np.int64(67)]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[np.int64(0), np.int64(1)]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('e9e231f1-a816-448d-bf51-993eb3060f9b')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int64
#   interfaces[0].proxy_gids: unique_values  [[np.int64(27), np.int64(92)]]
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('a2c631d6-55a9-46e3-9402-7d91a3e27272')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[np.int64(0), np.int64(1)]]
#   n_vois ................................. 1
#   voi .................................... --------------------
# ...
#   voi: dtype .......................... int64
#   voi: values ......................... 0
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[np.int64(0), np.int64(1)]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. RawCosim(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: f7a50d52-2752-4f6b-b4af-f70b751ec76d
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 9d293e2b-c9e8-4f6a-a4ff-c81dd2b972f9
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: e70761a2-8910-40b9-9c87-abe3bb1753b5
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('94738962-7428-4127-b54c-c19afdf9870d')
# )
# 2026-08-04 13:44:20,253 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-04 13:44:20,253 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-04 13:44:20,253 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-04 13:44:20,253 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-04 13:44:20,253 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-04 13:44:20,253 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-04 13:44:20,253 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-04 13:44:20,253 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-04 13:44:20,253 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-04 13:44:20,253 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-04 13:44:20,253 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-04 13:44:20,253 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-04 13:44:20,253 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
#
# Configuring simulation with App NESTSerialApp...
# 2026-08-04 13:44:20,259 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-04 13:44:20,259 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-04 13:44:20,259 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-04 13:44:20,259 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-04 13:44:20,259 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-04 13:44:20,259 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-04 13:44:20,259 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-04 13:44:20,259 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-04 13:44:20,259 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-04 13:44:20,259 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-04 13:44:20,259 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-04 13:44:20,259 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-04 13:44:20,259 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
#
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-04 13:44:20,271 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - No or all NaN valued cosimulator updates at time step 0!
# 2026-08-04 13:44:20,271 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.016 seconds
# 2026-08-04 13:44:20,271 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2026-08-04 13:44:20,271 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 22031
# 2026-08-04 13:44:20,276 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:44:20,287 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...9.091% completed in 0.016427 sec!
# ...9.091% completed in 0.016427 sec!2026-08-04 13:44:20,294 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:44:20,305 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...18.182% completed in 0.034425 sec!
# ...18.182% completed in 0.034425 sec!2026-08-04 13:44:20,312 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:44:20,323 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...27.273% completed in 0.0525091 sec!
# ...27.273% completed in 0.0525091 sec!2026-08-04 13:44:20,330 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:44:20,341 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...36.364% completed in 0.0705669 sec!
# ...36.364% completed in 0.0705669 sec!2026-08-04 13:44:20,348 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:44:20,359 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...45.455% completed in 0.0884182 sec!
# ...45.455% completed in 0.0884182 sec!2026-08-04 13:44:20,366 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:44:20,377 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...54.545% completed in 0.106489 sec!
# ...54.545% completed in 0.106489 sec!2026-08-04 13:44:20,384 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:44:20,396 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...63.636% completed in 0.124942 sec!
# ...63.636% completed in 0.124942 sec!/home/docker/venv/lib/python3.12/site-packages/elephant/conversion.py:1158: UserWarning:Binning discarded 1 last spike(s) of the input spiketrain
# 2026-08-04 13:44:20,402 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:44:20,414 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...72.727% completed in 0.142972 sec!
# ...72.727% completed in 0.142972 sec!2026-08-04 13:44:20,420 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:44:20,431 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...81.818% completed in 0.160921 sec!
# ...81.818% completed in 0.160921 sec!2026-08-04 13:44:20,438 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:44:20,449 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...90.909% completed in 0.178912 sec!
# ...90.909% completed in 0.178912 sec!2026-08-04 13:44:20,456 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-04 13:44:20,468 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...100.000% completed in 0.197017 sec!
# ...100.000% completed in 0.197017 sec!
# Simulated in 0.232574 secs!
#
# 2026-08-04 13:44:20,468 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,468 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,468 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,468 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,468 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,468 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,468 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,468 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,468 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,468 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,468 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,468 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,468 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
#
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,469 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-04 13:44:20,469 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-04 13:44:20,469 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-04 13:44:20,469 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-04 13:44:20,469 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-04 13:44:20,469 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-04 13:44:20,469 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-04 13:44:20,469 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-04 13:44:20,469 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-04 13:44:20,469 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-04 13:44:20,469 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-04 13:44:20,469 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-04 13:44:20,469 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
#
# Cleaning up App TVBSerialApp...
# 2026-08-04 13:44:20,471 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-04 13:44:20,471 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-04 13:44:20,471 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-04 13:44:20,471 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-04 13:44:20,471 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-04 13:44:20,471 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-04 13:44:20,471 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-04 13:44:20,471 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-04 13:44:20,471 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-04 13:44:20,471 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-04 13:44:20,471 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-04 13:44:20,471 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-04 13:44:20,471 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
#
# Cleaning up App NESTSerialApp...
# 2026-08-04 13:44:20,472 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-04 13:44:20,472 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-04 13:44:20,472 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-04 13:44:20,472 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-04 13:44:20,472 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-04 13:44:20,472 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-04 13:44:20,472 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-04 13:44:20,472 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-04 13:44:20,472 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-04 13:44:20,472 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-04 13:44:20,472 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-04 13:44:20,472 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-04 13:44:20,472 - INFO - examples.example -
# Stopping App TVBSerialApp...
#
# Stopping App TVBSerialApp...
# 2026-08-04 13:44:20,473 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-04 13:44:20,473 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-04 13:44:20,473 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-04 13:44:20,473 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-04 13:44:20,473 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-04 13:44:20,473 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-04 13:44:20,473 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-04 13:44:20,473 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-04 13:44:20,473 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-04 13:44:20,473 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-04 13:44:20,473 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-04 13:44:20,473 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-04 13:44:20,473 - INFO - examples.example -
# Stopping App NESTSerialApp...
#
# Stopping App NESTSerialApp...
# 2026-08-04 13:44:20,474 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,474 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,474 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,474 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,474 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,474 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,474 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,474 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,474 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,474 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,474 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,474 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-04 13:44:20,474 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
#
# Stopping App TVBNESTSerialOrchestrator...
#
# Success in 0.586392 sec!
# ******************************************************
#
#
# ******************************************************
# ******************************************************
#
# TestDefaultRATE SUCCESS!
#
# TestDefaultMultisynapseRATE SUCCESS!
#
# TestWilsonCowanRATE SUCCESS!
#
# TestWilsonCowanMultisynapseRATE SUCCESS!
#
# TestDefaultSPIKES SUCCESS!
#
# TestDefaultMultisynapseSPIKES SUCCESS!
#
# TestWilsonCowanSPIKES SUCCESS!
#
# TestWilsonCowanMultisynapseSPIKES SUCCESS!
#
# TestDefaultSPIKES_SINGLE_INTERACTION SUCCESS!
#
# TestDefaultSPIKES_MULTIPLE_INTERACTION SUCCESS!
#
# TestDefaultSPIKES_TO_RATE SUCCESS!
#
# TestDefaultSPIKES_TO_HIST SUCCESS!
# ******************************************************
