# %%
! pwd
# Out:
# /home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks

# %%
! python ../../../tvb_multiscale/tests/tvb_nest/test_simulator.py
# Out:
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
# 2026-08-06 15:42:20,743 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2026-08-06 15:42:20,743 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2026-08-06 15:42:20,743 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2026-08-06 15:42:20,743 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2026-08-06 15:42:20,743 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2026-08-06 15:42:20,743 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2026-08-06 15:42:20,744 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2026-08-06 15:42:20,744 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2026-08-06 15:42:20,744 - INFO - tvb_multiscale.tvb_nest.config - NEST_MODULE_PATH: /home/docker/build/nest/lib/nest
# 2026-08-06 15:42:20,744 - INFO - tvb_multiscale.tvb_nest.config - NEST_MODULE_PATH: /home/docker/build/nest/lib/nest
# 2026-08-06 15:42:20,744 - INFO - tvb_multiscale.tvb_nest.config - PATH: /home/docker/build/nest/bin:/home/docker/build/nest/bin:/home/docker/venv/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin;;
# 2026-08-06 15:42:20,744 - INFO - tvb_multiscale.tvb_nest.config - PATH: /home/docker/build/nest/bin:/home/docker/build/nest/bin:/home/docker/venv/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin;;
# 2026-08-06 15:42:20,744 - INFO - tvb_multiscale.tvb_nest.config - LD_LIBRARY_PATH: /home/docker/build/nest/lib/nest::/home/docker/build/nest/lib/nest
# 2026-08-06 15:42:20,744 - INFO - tvb_multiscale.tvb_nest.config - LD_LIBRARY_PATH: /home/docker/build/nest/lib/nest::/home/docker/build/nest/lib/nest
# 2026-08-06 15:42:20,744 - INFO - tvb_multiscale.tvb_nest.config - SLI_PATH: /home/docker/build/nest/share/nest/sli
# 2026-08-06 15:42:20,744 - INFO - tvb_multiscale.tvb_nest.config - SLI_PATH: /home/docker/build/nest/share/nest/sli
# 2026-08-06 15:42:20,744 - INFO - tvb_multiscale.tvb_nest.config - NEST_PYTHON_PREFIX: /home/docker/build/nest/lib/python3.12/site-packages
# 2026-08-06 15:42:20,744 - INFO - tvb_multiscale.tvb_nest.config - NEST_PYTHON_PREFIX: /home/docker/build/nest/lib/python3.12/site-packages
# 2026-08-06 15:42:20,744 - INFO - tvb_multiscale.tvb_nest.config - system path: ['/home/docker/build/nest/lib/python3.12/site-packages', '/home/docker/packages/tvb-multiscale/tvb_multiscale/tests/tvb_nest', '/home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks', '/home/docker/venv', '/home/docker/packages/PySpike', '/home/docker/build/nest/lib/python3.12/site-packages', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '/home/docker/venv/lib/python3.12/site-packages', '/home/docker/packages/tvb-root/tvb_bin', '/home/docker/packages/tvb-root/tvb_build', '/home/docker/packages/tvb-root/tvb_contrib', '/home/docker/packages/tvb-root/tvb_framework', '/home/docker/packages/tvb-root/tvb_library', '/home/docker/packages/tvb-root/tvb_storage', '/home/docker/venv/lib/python3.12/site-packages/NEST_Client-0.1-py3.12.egg', '/home/docker/packages/tvb-multiscale', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages']
# 2026-08-06 15:42:20,744 - INFO - tvb_multiscale.tvb_nest.config - system path: ['/home/docker/build/nest/lib/python3.12/site-packages', '/home/docker/packages/tvb-multiscale/tvb_multiscale/tests/tvb_nest', '/home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks', '/home/docker/venv', '/home/docker/packages/PySpike', '/home/docker/build/nest/lib/python3.12/site-packages', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '/home/docker/venv/lib/python3.12/site-packages', '/home/docker/packages/tvb-root/tvb_bin', '/home/docker/packages/tvb-root/tvb_build', '/home/docker/packages/tvb-root/tvb_contrib', '/home/docker/packages/tvb-root/tvb_framework', '/home/docker/packages/tvb-root/tvb_library', '/home/docker/packages/tvb-root/tvb_storage', '/home/docker/venv/lib/python3.12/site-packages/NEST_Client-0.1-py3.12.egg', '/home/docker/packages/tvb-multiscale', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages']

# %%
! python ../../../tvb_multiscale/tests/tvb_nest/test_spiking_models_builder_properties_methods.py
# Out:
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
# 2026-08-06 15:42:22,767 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2026-08-06 15:42:22,767 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2026-08-06 15:42:22,767 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2026-08-06 15:42:22,767 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2026-08-06 15:42:22,767 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2026-08-06 15:42:22,767 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2026-08-06 15:42:22,767 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2026-08-06 15:42:22,767 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2026-08-06 15:42:22,768 - INFO - tvb_multiscale.tvb_nest.config - NEST_MODULE_PATH: /home/docker/build/nest/lib/nest
# 2026-08-06 15:42:22,768 - INFO - tvb_multiscale.tvb_nest.config - NEST_MODULE_PATH: /home/docker/build/nest/lib/nest
# 2026-08-06 15:42:22,768 - INFO - tvb_multiscale.tvb_nest.config - PATH: /home/docker/build/nest/bin:/home/docker/build/nest/bin:/home/docker/venv/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin;;
# 2026-08-06 15:42:22,768 - INFO - tvb_multiscale.tvb_nest.config - PATH: /home/docker/build/nest/bin:/home/docker/build/nest/bin:/home/docker/venv/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin;;
# 2026-08-06 15:42:22,768 - INFO - tvb_multiscale.tvb_nest.config - LD_LIBRARY_PATH: /home/docker/build/nest/lib/nest::/home/docker/build/nest/lib/nest
# 2026-08-06 15:42:22,768 - INFO - tvb_multiscale.tvb_nest.config - LD_LIBRARY_PATH: /home/docker/build/nest/lib/nest::/home/docker/build/nest/lib/nest
# 2026-08-06 15:42:22,768 - INFO - tvb_multiscale.tvb_nest.config - SLI_PATH: /home/docker/build/nest/share/nest/sli
# 2026-08-06 15:42:22,768 - INFO - tvb_multiscale.tvb_nest.config - SLI_PATH: /home/docker/build/nest/share/nest/sli
# 2026-08-06 15:42:22,768 - INFO - tvb_multiscale.tvb_nest.config - NEST_PYTHON_PREFIX: /home/docker/build/nest/lib/python3.12/site-packages
# 2026-08-06 15:42:22,768 - INFO - tvb_multiscale.tvb_nest.config - NEST_PYTHON_PREFIX: /home/docker/build/nest/lib/python3.12/site-packages
# 2026-08-06 15:42:22,768 - INFO - tvb_multiscale.tvb_nest.config - system path: ['/home/docker/build/nest/lib/python3.12/site-packages', '/home/docker/packages/tvb-multiscale/tvb_multiscale/tests/tvb_nest', '/home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks', '/home/docker/venv', '/home/docker/packages/PySpike', '/home/docker/build/nest/lib/python3.12/site-packages', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '/home/docker/venv/lib/python3.12/site-packages', '/home/docker/packages/tvb-root/tvb_bin', '/home/docker/packages/tvb-root/tvb_build', '/home/docker/packages/tvb-root/tvb_contrib', '/home/docker/packages/tvb-root/tvb_framework', '/home/docker/packages/tvb-root/tvb_library', '/home/docker/packages/tvb-root/tvb_storage', '/home/docker/venv/lib/python3.12/site-packages/NEST_Client-0.1-py3.12.egg', '/home/docker/packages/tvb-multiscale', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages']
# 2026-08-06 15:42:22,768 - INFO - tvb_multiscale.tvb_nest.config - system path: ['/home/docker/build/nest/lib/python3.12/site-packages', '/home/docker/packages/tvb-multiscale/tvb_multiscale/tests/tvb_nest', '/home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks', '/home/docker/venv', '/home/docker/packages/PySpike', '/home/docker/build/nest/lib/python3.12/site-packages', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '/home/docker/venv/lib/python3.12/site-packages', '/home/docker/packages/tvb-root/tvb_bin', '/home/docker/packages/tvb-root/tvb_build', '/home/docker/packages/tvb-root/tvb_contrib', '/home/docker/packages/tvb-root/tvb_framework', '/home/docker/packages/tvb-root/tvb_library', '/home/docker/packages/tvb-root/tvb_storage', '/home/docker/venv/lib/python3.12/site-packages/NEST_Client-0.1-py3.12.egg', '/home/docker/packages/tvb-multiscale', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages']
#
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.9.0
#  Built: Aug  6 2026 14:34:13
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.
#
# 2026-08-06 15:42:22,899 - WARNING - tvb_multiscale.core.neotraits - Field seems mutable and has a default value. Consider using a lambda as a value factory
#    attribute tvb_multiscale.tvb_nest.nest_models.node._NESTNodeCollection._nodes = Attr(field_type=(<class 'nest.lib.hl_api_types.NodeCollection'>, <class 'tvb_multiscale.tvb_nest.nest_models.server_client.node_collection.NodeCollection'>), default=NodeCollection(<empty>), required=False)
# 2026-08-06 15:42:22,899 - WARNING - tvb_multiscale.core.neotraits - Field seems mutable and has a default value. Consider using a lambda as a value factory
#    attribute tvb_multiscale.tvb_nest.nest_models.node._NESTNodeCollection._nodes = Attr(field_type=(<class 'nest.lib.hl_api_types.NodeCollection'>, <class 'tvb_multiscale.tvb_nest.nest_models.server_client.node_collection.NodeCollection'>), default=NodeCollection(<empty>), required=False)
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning:Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#
# Aug 06 15:42:23 SimulationManager::set_status [Info]:
#     Temporal resolution changed from 0.1 to 0.05 ms.
# <tvb_multiscale.tvb_nest.nest_models.models.default.DefaultExcIOBuilder object at 0xffff50c1e840>
# nest simulator: <module 'nest' from '/home/docker/build/nest/lib/python3.12/site-packages/nest/__init__.py'>
# min_delay:
# 0.05
#
# tvb_dt:
# 0.1
#
# monitor_period:
# 0.1
#
# tvb_model:
# Linear
#
# number_of_regions:
# 68
#
# tvb_weights:
# [[0.0000000e+00 4.8155833e-02 5.5569724e-01 ... 0.0000000e+00
#   9.3632959e-04 1.5197568e-03]
#  [3.4694958e-02 0.0000000e+00 4.0470140e+00 ... 0.0000000e+00
#   0.0000000e+00 6.4991351e-02]
#  [3.3234182e-01 1.6091147e+00 0.0000000e+00 ... 0.0000000e+00
#   1.3227513e-03 2.2254678e-01]
#  ...
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#   4.2837810e-03 6.6117304e+01]
#  [6.8634180e-04 0.0000000e+00 1.8867925e-02 ... 2.7493696e-02
#   0.0000000e+00 2.8296225e+01]
#  [2.8677947e-04 1.3400005e-02 3.4921828e-01 ... 2.5495074e+01
#   1.4883909e+01 0.0000000e+00]]
#
# tvb_delays:
# [[ 0.         39.98974333 34.00171    ...  0.         47.8
#   44.73333333]
#  [39.98974333  0.         14.00699533 ...  0.          0.
#   23.274074  ]
#  [34.00171    14.00699533  0.         ...  0.         58.33333333
#   37.56438333]
#  ...
#  [ 0.          0.          0.         ...  0.         20.76666667
#    6.62544467]
#  [47.8         0.         58.33333333 ... 20.76666667  0.
#    5.83055433]
#  [44.73333333 23.274074   37.56438333 ...  6.62544467  5.83055433
#    0.        ]]
#
# region_labels:
# ['bankssts_L' 'bankssts_R' 'caudalanteriorcingulate_L'
#  'caudalanteriorcingulate_R' 'caudalmiddlefrontal_L'
#  'caudalmiddlefrontal_R' 'cuneus_L' 'cuneus_R' 'entorhinal_L'
#  'entorhinal_R' 'frontalpole_L' 'frontalpole_R' 'fusiform_L' 'fusiform_R'
#  'inferiorparietal_L' 'inferiorparietal_R' 'inferiortemporal_L'
#  'inferiortemporal_R' 'insula_L' 'insula_R' 'isthmuscingulate_L'
#  'isthmuscingulate_R' 'lateraloccipital_L' 'lateraloccipital_R'
#  'lateralorbitofrontal_L' 'lateralorbitofrontal_R' 'lingual_L' 'lingual_R'
#  'medialorbitofrontal_L' 'medialorbitofrontal_R' 'middletemporal_L'
#  'middletemporal_R' 'paracentral_L' 'paracentral_R' 'parahippocampal_L'
#  'parahippocampal_R' 'parsopercularis_L' 'parsopercularis_R'
#  'parsorbitalis_L' 'parsorbitalis_R' 'parstriangularis_L'
#  'parstriangularis_R' 'pericalcarine_L' 'pericalcarine_R' 'postcentral_L'
#  'postcentral_R' 'posteriorcingulate_L' 'posteriorcingulate_R'
#  'precentral_L' 'precentral_R' 'precuneus_L' 'precuneus_R'
#  'rostralanteriorcingulate_L' 'rostralanteriorcingulate_R'
#  'rostralmiddlefrontal_L' 'rostralmiddlefrontal_R' 'superiorfrontal_L'
#  'superiorfrontal_R' 'superiorparietal_L' 'superiorparietal_R'
#  'superiortemporal_L' 'superiortemporal_R' 'supramarginal_L'
#  'supramarginal_R' 'temporalpole_L' 'temporalpole_R'
#  'transversetemporal_L' 'transversetemporal_R']
#
# number_of_populations:
# 0
#
# populations_models:
# OrderedDict()
#
# populations_nodes:
# OrderedDict()
#
# populations_scales:
# OrderedDict()
#
# populations_sizes:
# OrderedDict()
#
# populations_params:
# OrderedDict()
#
# populations_connections_labels:
# []
#
# populations_connections_models:
# OrderedDict()
#
# populations_connections_nodes:
# OrderedDict()
#
# populations_connections_weights:
# OrderedDict()
#
# populations_connections_delays:
# OrderedDict()
#
# populations_connections_receptor_types:
# OrderedDict()
#
# populations_connections_conn_spec:
# OrderedDict()
#
# nodes_connections_labels:
# []
#
# nodes_connections_models:
# OrderedDict()
#
# nodes_connections_source_nodes:
# OrderedDict()
#
# nodes_connections_target_nodes:
# OrderedDict()
#
# nodes_connections_weights:
# OrderedDict()
#
# nodes_connections_delays:
# OrderedDict()
#
# nodes_connections_receptor_types:
# OrderedDict()
#
# nodes_connections_conn_spec:
# OrderedDict()

# %%
! python ../../../tvb_multiscale/tests/tvb_nest/test_models.py
# Out:
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
# 2026-08-06 15:42:25,573 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2026-08-06 15:42:25,573 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2026-08-06 15:42:25,573 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2026-08-06 15:42:25,573 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2026-08-06 15:42:25,574 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2026-08-06 15:42:25,574 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2026-08-06 15:42:25,574 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2026-08-06 15:42:25,574 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2026-08-06 15:42:25,574 - INFO - tvb_multiscale.tvb_nest.config - NEST_MODULE_PATH: /home/docker/build/nest/lib/nest
# 2026-08-06 15:42:25,574 - INFO - tvb_multiscale.tvb_nest.config - NEST_MODULE_PATH: /home/docker/build/nest/lib/nest
# 2026-08-06 15:42:25,574 - INFO - tvb_multiscale.tvb_nest.config - PATH: /home/docker/build/nest/bin:/home/docker/build/nest/bin:/home/docker/venv/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin;;
# 2026-08-06 15:42:25,574 - INFO - tvb_multiscale.tvb_nest.config - PATH: /home/docker/build/nest/bin:/home/docker/build/nest/bin:/home/docker/venv/bin:/usr/local/sbin:/usr/local/bin:/usr/sbin:/usr/bin:/sbin:/bin;;
# 2026-08-06 15:42:25,574 - INFO - tvb_multiscale.tvb_nest.config - LD_LIBRARY_PATH: /home/docker/build/nest/lib/nest::/home/docker/build/nest/lib/nest
# 2026-08-06 15:42:25,574 - INFO - tvb_multiscale.tvb_nest.config - LD_LIBRARY_PATH: /home/docker/build/nest/lib/nest::/home/docker/build/nest/lib/nest
# 2026-08-06 15:42:25,574 - INFO - tvb_multiscale.tvb_nest.config - SLI_PATH: /home/docker/build/nest/share/nest/sli
# 2026-08-06 15:42:25,574 - INFO - tvb_multiscale.tvb_nest.config - SLI_PATH: /home/docker/build/nest/share/nest/sli
# 2026-08-06 15:42:25,574 - INFO - tvb_multiscale.tvb_nest.config - NEST_PYTHON_PREFIX: /home/docker/build/nest/lib/python3.12/site-packages
# 2026-08-06 15:42:25,574 - INFO - tvb_multiscale.tvb_nest.config - NEST_PYTHON_PREFIX: /home/docker/build/nest/lib/python3.12/site-packages
# 2026-08-06 15:42:25,574 - INFO - tvb_multiscale.tvb_nest.config - system path: ['/home/docker/build/nest/lib/python3.12/site-packages', '/home/docker/packages/tvb-multiscale/tvb_multiscale/tests/tvb_nest', '/home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks', '/home/docker/venv', '/home/docker/packages/PySpike', '/home/docker/build/nest/lib/python3.12/site-packages', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '/home/docker/venv/lib/python3.12/site-packages', '/home/docker/packages/tvb-root/tvb_bin', '/home/docker/packages/tvb-root/tvb_build', '/home/docker/packages/tvb-root/tvb_contrib', '/home/docker/packages/tvb-root/tvb_framework', '/home/docker/packages/tvb-root/tvb_library', '/home/docker/packages/tvb-root/tvb_storage', '/home/docker/venv/lib/python3.12/site-packages/NEST_Client-0.1-py3.12.egg', '/home/docker/packages/tvb-multiscale', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages']
# 2026-08-06 15:42:25,574 - INFO - tvb_multiscale.tvb_nest.config - system path: ['/home/docker/build/nest/lib/python3.12/site-packages', '/home/docker/packages/tvb-multiscale/tvb_multiscale/tests/tvb_nest', '/home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks', '/home/docker/venv', '/home/docker/packages/PySpike', '/home/docker/build/nest/lib/python3.12/site-packages', '/usr/lib/python312.zip', '/usr/lib/python3.12', '/usr/lib/python3.12/lib-dynload', '/home/docker/venv/lib/python3.12/site-packages', '/home/docker/packages/tvb-root/tvb_bin', '/home/docker/packages/tvb-root/tvb_build', '/home/docker/packages/tvb-root/tvb_contrib', '/home/docker/packages/tvb-root/tvb_framework', '/home/docker/packages/tvb-root/tvb_library', '/home/docker/packages/tvb-root/tvb_storage', '/home/docker/venv/lib/python3.12/site-packages/NEST_Client-0.1-py3.12.egg', '/home/docker/packages/tvb-multiscale', '/usr/local/lib/python3.12/dist-packages', '/usr/lib/python3/dist-packages']
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning: Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#   array_result = numpy.loadtxt(file_stream, dtype=dtype, skiprows=skip_rows, usecols=use_cols)
#
#               -- N E S T --
#   Copyright (C) 2004 The NEST Initiative
#
#  Version: 3.9.0
#  Built: Aug  6 2026 14:34:13
#
#  This program is provided AS IS and comes with
#  NO WARRANTY. See the file LICENSE for details.
#
#  Problems or suggestions?
#    Visit https://www.nest-simulator.org
#
#  Type 'nest.help()' to find out more about NEST.
#
# 2026-08-06 15:42:27,100 - WARNING - tvb_multiscale.core.neotraits - Field seems mutable and has a default value. Consider using a lambda as a value factory
#    attribute tvb_multiscale.tvb_nest.nest_models.node._NESTNodeCollection._nodes = Attr(field_type=(<class 'nest.lib.hl_api_types.NodeCollection'>, <class 'tvb_multiscale.tvb_nest.nest_models.server_client.node_collection.NodeCollection'>), default=NodeCollection(<empty>), required=False)
# 2026-08-06 15:42:27,100 - WARNING - tvb_multiscale.core.neotraits - Field seems mutable and has a default value. Consider using a lambda as a value factory
#    attribute tvb_multiscale.tvb_nest.nest_models.node._NESTNodeCollection._nodes = Attr(field_type=(<class 'nest.lib.hl_api_types.NodeCollection'>, <class 'tvb_multiscale.tvb_nest.nest_models.server_client.node_collection.NodeCollection'>), default=NodeCollection(<empty>), required=False)
# /home/docker/venv/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning:Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
# 2026-08-06 15:42:27,423 - WARNING - tvb.simulator.plot.tools - You need mpl_toolkits for some axe related features
#
# ******************************************************
# ******************************************************
# TestDefaultRATE
# ******************************************************
# ******************************************************
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning:Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#
# ----------------------------------------------------------------------------------------------------
# Find results in /home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks/outputs/DefaultExcIO_RATE_bidir/res !
# ----------------------------------------------------------------------------------------------------
# 2026-08-06 15:42:28,563 - INFO - examples.example -
# Starting App TVBNESTSerialOrchestrator...
# 2026-08-06 15:42:28,563 - INFO - examples.example -
# Starting App TVBNESTSerialOrchestrator...
#
# Starting App TVBNESTSerialOrchestrator...
# 2026-08-06 15:42:28,563 - INFO - examples.example -
# Starting App TVBSerialApp...
# 2026-08-06 15:42:28,563 - INFO - examples.example -
# Starting App TVBSerialApp...
#
# Starting App TVBSerialApp...
# 2026-08-06 15:42:28,563 - INFO - examples.example -
# Setting TVB LIBRARY_PROFILE...
# 2026-08-06 15:42:28,563 - INFO - examples.example -
# Setting TVB LIBRARY_PROFILE...
#
# Setting TVB LIBRARY_PROFILE...
# 2026-08-06 15:42:28,603 - INFO - examples.example -
# Starting App NESTSerialApp...
# 2026-08-06 15:42:28,603 - INFO - examples.example -
# Starting App NESTSerialApp...
#
# Starting App NESTSerialApp...
#
#
# Configuring...
# /home/docker/packages/tvb-root/tvb_library/tvb/basic/readers.py:122: UserWarning:Input line 1 contained no data and will not be counted towards `max_rows=50000`.  This differs from the behaviour in NumPy <=1.22 which counted lines rather than rows.  If desired, the previous behaviour can be achieved by using `itertools.islice`.
# Please see the 1.23 release notes for an example on how to do this.  If you wish to ignore this warning, use `warnings.filterwarnings`.  This warning is expected to be removed in the future and is given only once per `loadtxt` call.
#
# Done! in 0.000145 min
#
#
#
# Building...
# 2026-08-06 15:42:28,613 - INFO - examples.example -
# Building with App TVBNESTSerialOrchestrator...
# 2026-08-06 15:42:28,613 - INFO - examples.example -
# Building with App TVBNESTSerialOrchestrator...
#
# Building with App TVBNESTSerialOrchestrator...
# 2026-08-06 15:42:28,613 - INFO - examples.example -
# Building cosimulators with TVBNESTSerialOrchestrator...
# 2026-08-06 15:42:28,613 - INFO - examples.example -
# Building cosimulators with TVBNESTSerialOrchestrator...
#
# Building cosimulators with TVBNESTSerialOrchestrator...
# 2026-08-06 15:42:28,613 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
# 2026-08-06 15:42:28,613 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
#
# Building TVB CoSimulator with builder CoSimulatorSerialBuilder of App TVBSerialApp...
# 2026-08-06 15:42:28,615 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-06 15:42:28,615 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2026-08-06 15:42:28,616 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2026-08-06 15:42:28,621 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2026-08-06 15:42:28,621 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2026-08-06 15:42:28,622 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# 2026-08-06 15:42:28,628 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: feda0b11-d623-4c95-84ca-d0e92791cd7a'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: a4fc5e89-9267-488f-b86e-8be3155b1047
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: e4054bc4-2841-42f5-b3e4-64fcf1892c20
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 99066664-1acc-4eeb-b890-fba42edba9c7
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 82982951-3c20-46eb-96d1-d82bf61f3cd8
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('feda0b11-d623-4c95-84ca-d0e92791cd7a')
# )
# 2026-08-06 15:42:28,628 - INFO - examples.example -
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: feda0b11-d623-4c95-84ca-d0e92791cd7a'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: a4fc5e89-9267-488f-b86e-8be3155b1047
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: e4054bc4-2841-42f5-b3e4-64fcf1892c20
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 99066664-1acc-4eeb-b890-fba42edba9c7
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 82982951-3c20-46eb-96d1-d82bf61f3cd8
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('feda0b11-d623-4c95-84ca-d0e92791cd7a')
# )
#
# CoSimulatorSerial (
#   title ............................... 'CoSimulatorSerial gid: feda0b11-d623-4c95-84ca-d0e92791cd7a'
#   Type ................................ 'CoSimulatorSerial'
#   model ............................... Linear gid: a4fc5e89-9267-488f-b86e-8be3155b1047
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: e4054bc4-2841-42f5-b3e4-64fcf1892c20
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 99066664-1acc-4eeb-b890-fba42edba9c7
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 82982951-3c20-46eb-96d1-d82bf61f3cd8
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('feda0b11-d623-4c95-84ca-d0e92791cd7a')
# )
# 2026-08-06 15:42:28,629 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-06 15:42:28,629 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2026-08-06 15:42:28,629 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2026-08-06 15:42:28,634 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2026-08-06 15:42:28,634 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2026-08-06 15:42:28,635 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2026-08-06 15:42:28,639 - INFO - examples.example -
# Building Spiking Network with builder DefaultExcIOBuilder of App NESTSerialApp...
# 2026-08-06 15:42:28,639 - INFO - examples.example -
# Building Spiking Network with builder DefaultExcIOBuilder of App NESTSerialApp...
#
# Building Spiking Network with builder DefaultExcIOBuilder of App NESTSerialApp...
# 2026-08-06 15:42:28,640 - INFO - examples.example - Configuring spiking network builder...
# 2026-08-06 15:42:28,640 - INFO - examples.example - Configuring spiking network builder...
# 2026-08-06 15:42:28,640 - INFO - examples.example - Configuring populations...
# 2026-08-06 15:42:28,640 - INFO - examples.example - Configuring populations...
# 2026-08-06 15:42:28,640 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2026-08-06 15:42:28,640 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2026-08-06 15:42:28,640 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2026-08-06 15:42:28,640 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2026-08-06 15:42:28,640 - INFO - examples.example - Configuring output devices, if any...
# 2026-08-06 15:42:28,640 - INFO - examples.example - Configuring output devices, if any...
# 2026-08-06 15:42:28,641 - INFO - examples.example - Configuring input devices, if any...
# 2026-08-06 15:42:28,641 - INFO - examples.example - Configuring input devices, if any...
# /home/docker/build/nest/lib/python3.12/site-packages/nest/lib/hl_api_helper.py:114: UserWarning:
# Models is deprecated and will be removed in a future version of NEST.
# Please use nest.node_models or nest.synapse_models instead!
# 2026-08-06 15:42:28,641 - INFO - examples.example - Generating spiking brain...
# 2026-08-06 15:42:28,641 - INFO - examples.example - Generating spiking brain...
# 2026-08-06 15:42:28,641 - INFO - examples.example - Generating spiking brain regions...
# 2026-08-06 15:42:28,641 - INFO - examples.example - Generating spiking brain regions...
# 2026-08-06 15:42:28,641 - INFO - examples.example - Generating spiking region node: bankssts_L...
# 2026-08-06 15:42:28,641 - INFO - examples.example - Generating spiking region node: bankssts_L...
# 2026-08-06 15:42:28,643 - INFO - examples.example - Generating population: E...
# 2026-08-06 15:42:28,643 - INFO - examples.example - Generating population: E...
# 2026-08-06 15:42:28,643 - INFO - examples.example - ...with 10 neurons...
# 2026-08-06 15:42:28,643 - INFO - examples.example - ...with 10 neurons...
# 2026-08-06 15:42:28,644 - INFO - examples.example - Generating spiking region node: bankssts_R...
# 2026-08-06 15:42:28,644 - INFO - examples.example - Generating spiking region node: bankssts_R...
# 2026-08-06 15:42:28,645 - INFO - examples.example - Generating population: E...
# 2026-08-06 15:42:28,645 - INFO - examples.example - Generating population: E...
# 2026-08-06 15:42:28,645 - INFO - examples.example - ...with 10 neurons...
# 2026-08-06 15:42:28,645 - INFO - examples.example - ...with 10 neurons...
# 2026-08-06 15:42:28,645 - INFO - examples.example - Connecting populations within spiking brain regions...
# 2026-08-06 15:42:28,645 - INFO - examples.example - Connecting populations within spiking brain regions...
# 2026-08-06 15:42:28,646 - INFO - examples.example - Connecting E -> E populations
# for spiking region nodes
# [0 1]...
# 2026-08-06 15:42:28,646 - INFO - examples.example - Connecting E -> E populations
# for spiking region nodes
# [0 1]...
# 2026-08-06 15:42:28,646 - INFO - examples.example - ...100 connections to receptor 0
# 2026-08-06 15:42:28,646 - INFO - examples.example - ...100 connections to receptor 0
# 2026-08-06 15:42:28,647 - INFO - examples.example - ...100 connections to receptor 0
# 2026-08-06 15:42:28,647 - INFO - examples.example - ...100 connections to receptor 0
# 2026-08-06 15:42:28,647 - INFO - examples.example - Connecting populations among spiking brain regions...
# 2026-08-06 15:42:28,647 - INFO - examples.example - Connecting populations among spiking brain regions...
# 2026-08-06 15:42:28,647 - INFO - examples.example - Connecting for 0 -> 1 spiking region nodes ...
# 2026-08-06 15:42:28,647 - INFO - examples.example - Connecting for 0 -> 1 spiking region nodes ...
# 2026-08-06 15:42:28,648 - INFO - examples.example - E -> E populations ...
# 2026-08-06 15:42:28,648 - INFO - examples.example - E -> E populations ...
# 2026-08-06 15:42:28,648 - INFO - examples.example - ...100 connections to receptor 0
# 2026-08-06 15:42:28,648 - INFO - examples.example - ...100 connections to receptor 0
# 2026-08-06 15:42:28,648 - INFO - examples.example - Connecting for 1 -> 0 spiking region nodes ...
# 2026-08-06 15:42:28,648 - INFO - examples.example - Connecting for 1 -> 0 spiking region nodes ...
# 2026-08-06 15:42:28,648 - INFO - examples.example - E -> E populations ...
# 2026-08-06 15:42:28,648 - INFO - examples.example - E -> E populations ...
# 2026-08-06 15:42:28,648 - INFO - examples.example - ...100 connections to receptor 0
# 2026-08-06 15:42:28,648 - INFO - examples.example - ...100 connections to receptor 0
# 2026-08-06 15:42:28,649 - INFO - examples.example - Generating and connecting output devices, if any...
# 2026-08-06 15:42:28,649 - INFO - examples.example - Generating and connecting output devices, if any...
# 2026-08-06 15:42:28,649 - INFO - examples.example - Generating and connecting ['E'] -> ['E'] device set of model spike_recorder
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-06 15:42:28,649 - INFO - examples.example - Generating and connecting ['E'] -> ['E'] device set of model spike_recorder
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-06 15:42:28,650 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model spike_recorder for E created!
# 2026-08-06 15:42:28,650 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model spike_recorder for E created!
# 2026-08-06 15:42:28,654 - INFO - examples.example - Generating and connecting ['Excitatory'] -> ['E'] device set of model multimeter
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-06 15:42:28,654 - INFO - examples.example - Generating and connecting ['Excitatory'] -> ['E'] device set of model multimeter
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-06 15:42:28,655 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model multimeter for Excitatory created!
# 2026-08-06 15:42:28,655 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model multimeter for Excitatory created!
# 2026-08-06 15:42:28,659 - INFO - examples.example - Generating and connecting input devices, if any...
# 2026-08-06 15:42:28,659 - INFO - examples.example - Generating and connecting input devices, if any...
# 2026-08-06 15:42:28,659 - INFO - examples.example - Generating and connecting ['Stimulus'] -> [['E']] device set of model poisson_generator
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-06 15:42:28,659 - INFO - examples.example - Generating and connecting ['Stimulus'] -> [['E']] device set of model poisson_generator
# for nodes [np.int64(0), np.int64(1)]...
# 2026-08-06 15:42:28,660 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model poisson_generator for Stimulus created!
# 2026-08-06 15:42:28,660 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model poisson_generator for Stimulus created!
# 2026-08-06 15:42:28,664 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2026-08-06 15:42:28,664 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2026-08-06 15:42:28,664 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2026-08-06 15:42:28,664 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2026-08-06 15:42:28,664 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2026-08-06 15:42:28,664 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2026-08-06 15:42:28,664 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2026-08-06 15:42:28,664 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# 2026-08-06 15:42:28,664 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_nest.nest_models.network.NESTNetwork'> created!
# NESTNetwork (
#   title ....................................... 'NESTNetwork gid: 91a24209-90fe-46a9-8b80-7a58031817ba'
#   Type ........................................ 'NESTNetwork'
#   config ...................................... '--------------------'
#   config.title ................................ 'Config gid: dc8dc087-b081-443e-b84a-a57ed9c5f66c'
#   config.Type ................................. 'Config'
#   config.gid .................................. UUID('dc8dc087-b081-443e-b84a-a57ed9c5f66c')
#   brain_regions ............................... '--------------------'
#   brain_regions.title ......................... 'NESTBrain gid: 73035db1-da6f-4ddc-9f88-ecf5fc044adc'
#   brain_regions.Type .......................... 'NESTBrain'
#   brain_regions.gid ........................... UUID('73035db1-da6f-4ddc-9f88-ecf5fc044adc')
#   brain_regions.label ......................... ''
#   brain_regions.size .......................... 2
#   brain_regions.Regions ....................... --------------------
#   brain_regions.Regions: shape ................ (2,)
#   brain_regions.Regions: dtype ................ <U10
#   brain_regions.Regions: values ............... ['bankssts_L' 'bankssts_R']
#   brain_regions.bankssts_L .................... '--------------------'
#   brain_regions[bankssts_L].title ............. 'NESTRegionNode gid: effc5ea9-74f1-40c4-bc6f-e5d49cc01fa2'
#   brain_regions[bankssts_L].Type .............. 'NESTRegionNode'
#   brain_regions[bankssts_L].gid ............... UUID('effc5ea9-74f1-40c4-bc6f-e5d49cc01fa2')
#   brain_regions[bankssts_L].label ............. 'bankssts_L'
#   brain_regions[bankssts_L].size .............. 1
#   brain_regions[bankssts_L].Populations ....... --------------------
#   brain_regions[bankssts_L].Populations: shape  (1,)
#   brain_regions[bankssts_L].Populations: dtype  <U1
#   brain_regions[bankssts_L].Populations: values  E
#   brain_regions.bankssts_R .................... '--------------------'
#   brain_regions[bankssts_R].title ............. 'NESTRegionNode gid: e4f4ee46-8180-4031-a43e-c21632d7b496'
#   brain_regions[bankssts_R].Type .............. 'NESTRegionNode'
#   brain_regions[bankssts_R].gid ............... UUID('e4f4ee46-8180-4031-a43e-c21632d7b496')
#   brain_regions[bankssts_R].label ............. 'bankssts_R'
#   brain_regions[bankssts_R].size .............. 1
#   brain_regions[bankssts_R].Populations ....... --------------------
#   brain_regions[bankssts_R].Populations: shape  (1,)
#   brain_regions[bankssts_R].Populations: dtype  <U1
#   brain_regions[bankssts_R].Populations: values  E
#   logger ...................................... <Logger tvb-multiscale (DEBUG)>
#   output_devices .............................. '--------------------'
#   output_devices.title ........................ 'DeviceSets gid: 062aeb3f-457a-4ef8-b56b-c35225cbe379'
#   output_devices.Type ......................... 'DeviceSets'
#   output_devices.gid .......................... UUID('062aeb3f-457a-4ef8-b56b-c35225cbe379')
#   output_devices.label ........................ 'output_devices'
#   output_devices.size ......................... 2
#   output_devices.DeviceSets ................... --------------------
#   output_devices.DeviceSets: shape ............ (2,)
#   output_devices.DeviceSets: dtype ............ <U10
#   output_devices.DeviceSets: values ........... ['E' 'Excitatory']
#   output_devices.E ............................ '--------------------'
#   output_devices[E].title ..................... 'DeviceSet gid: edc6edd5-cea8-4b23-bbfd-ab273e0f9fef'
#   output_devices[E].Type ...................... 'DeviceSet'
#   output_devices[E].model ..................... 'spike_recorder'
#   output_devices[E].gid ....................... UUID('edc6edd5-cea8-4b23-bbfd-ab273e0f9fef')
#   output_devices[E].label ..................... 'E'
#   output_devices[E].size ...................... 2
#   output_devices[E].Devices ................... --------------------
#   output_devices[E].Devices: shape ............ (2,)
#   output_devices[E].Devices: dtype ............ <U10
#   output_devices[E].Devices: values ........... ['bankssts_L' 'bankssts_R']
#   output_devices.Excitatory ................... '--------------------'
#   output_devices[Excitatory].title ............ 'DeviceSet gid: c3fa96b2-766f-4567-bf8c-41bdbf32d10e'
#   output_devices[Excitatory].Type ............. 'DeviceSet'
#   output_devices[Excitatory].model ............ 'multimeter'
#   output_devices[Excitatory].gid .............. UUID('c3fa96b2-766f-4567-bf8c-41bdbf32d10e')
#   output_devices[Excitatory].label ............ 'Excitatory'
#   output_devices[Excitatory].size ............. 2
#   output_devices[Excitatory].Devices .......... --------------------
#   output_devices[Excitatory].Devices: shape ... (2,)
#   output_devices[Excitatory].Devices: dtype ... <U10
#   output_devices[Excitatory].Devices: values .. ['bankssts_L' 'bankssts_R']
#   input_devices ............................... '--------------------'
#   input_devices.title ......................... 'DeviceSets gid: 490efc69-6b6e-41bd-8b3a-e55630b34425'
#   input_devices.Type .......................... 'DeviceSets'
#   input_devices.gid ........................... UUID('490efc69-6b6e-41bd-8b3a-e55630b34425')
#   input_devices.label ......................... 'input_devices'
#   input_devices.size .......................... 1
#   input_devices.DeviceSets .................... --------------------
#   input_devices.DeviceSets: shape ............. (1,)
#   input_devices.DeviceSets: dtype ............. <U8
#   input_devices.DeviceSets: values ............ Stimulus
#   input_devices.Stimulus ...................... '--------------------'
#   input_devices[Stimulus].title ............... 'DeviceSet gid: 62af48ba-19b9-447a-93ef-306a7bbe857b'
#   input_devices[Stimulus].Type ................ 'DeviceSet'
#   input_devices[Stimulus].model ............... 'poisson_generator'
#   input_devices[Stimulus].gid ................. UUID('62af48ba-19b9-447a-93ef-306a7bbe857b')
#   input_devices[Stimulus].label ............... 'Stimulus'
#   input_devices[Stimulus].size ................ 2
#   input_devices[Stimulus].Devices ............. --------------------
#   input_devices[Stimulus].Devices: shape ...... (2,)
#   input_devices[Stimulus].Devices: dtype ...... <U10
#   input_devices[Stimulus].Devices: values ..... ['bankssts_L' 'bankssts_R']
#   output_proxies .............................. '--------------------'
#   output_proxies.title ........................ 'DeviceSets gid: d71677df-c07b-4741-9f5a-a4fac723bcb7'
#   output_proxies.Type ......................... 'DeviceSets'
#   output_proxies.gid .......................... UUID('d71677df-c07b-4741-9f5a-a4fac723bcb7')
#   output_proxies.label ........................ 'output_proxies'
#   output_proxies.size ......................... 0
#   output_proxies.DeviceSets ................... --------------------
#   shape ....................................... (0,)
#   dtype ....................................... float64
#   is empty .................................... True
#   input_proxies ............................... '--------------------'
#   input_proxies.title ......................... 'DeviceSets gid: bbfdd1bd-4569-4e16-bade-fb7a1a2576ba'
#   input_proxies.Type .......................... 'DeviceSets'
#   input_proxies.gid ........................... UUID('bbfdd1bd-4569-4e16-bade-fb7a1a2576ba')
#   input_proxies.label ......................... 'input_proxies'
#   input_proxies.size .......................... 0
#   input_proxies.DeviceSets .................... --------------------
#   gid ......................................... UUID('91a24209-90fe-46a9-8b80-7a58031817ba')
# )
# 2026-08-06 15:42:28,667 - INFO - examples.example -
# Building interfaces with Orchestrator TVBNESTSerialOrchestrator...
# 2026-08-06 15:42:28,667 - INFO - examples.example -
# Building interfaces with Orchestrator TVBNESTSerialOrchestrator...
#
# Building interfaces with Orchestrator TVBNESTSerialOrchestrator...
# 2026-08-06 15:42:28,667 - INFO - examples.example -
# Building interfaces' with builder TVBNESTInterfaceBuilder of App TVBSerialApp...
# 2026-08-06 15:42:28,667 - INFO - examples.example -
# Building interfaces' with builder TVBNESTInterfaceBuilder of App TVBSerialApp...
#
# Building interfaces' with builder TVBNESTInterfaceBuilder of App TVBSerialApp...
# 2026-08-06 15:42:28,667 - INFO - examples.example -
# Configuring interfaces' builder DefaultTVBNESTInterfaceBuilder of App TVBSerialApp...
# 2026-08-06 15:42:28,667 - INFO - examples.example -
# Configuring interfaces' builder DefaultTVBNESTInterfaceBuilder of App TVBSerialApp...
#
# Configuring interfaces' builder DefaultTVBNESTInterfaceBuilder of App TVBSerialApp...
# 2026-08-06 15:42:28,667 - INFO - examples.example -
# Configuring default interfaces...
# 2026-08-06 15:42:28,667 - INFO - examples.example -
# Configuring default interfaces...
#
# Configuring default interfaces...
# 2026-08-06 15:42:28,671 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model inhomogeneous_poisson_generator for ['R']->E created!
# 2026-08-06 15:42:28,671 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model inhomogeneous_poisson_generator for ['R']->E created!
# 2026-08-06 15:42:28,755 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model spike_recorder for E->['R'] created!
# 2026-08-06 15:42:28,755 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model spike_recorder for E->['R'] created!
# 2026-08-06 15:42:28,760 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-08-06 15:42:28,760 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2026-08-06 15:42:28,761 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 1, 68, 1)
# 2026-08-06 15:42:28,767 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2026-08-06 15:42:28,767 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2026-08-06 15:42:28,768 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2026-08-06 15:42:28,796 - INFO - examples.example -
# TVBtoNESTInterfaces (
#   title .................................. 'TVBtoNESTInterfaces gid: 282da063-63ec-4f08-9ebd-0fb8b1f08776'
#   Type ................................... 'TVBtoNESTInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoNESTInterface gid: d6e83b87-8b60-4061-8ca6-364ab965d30b'
#   interfaces[0].Type ..................... 'TVBtoNESTInterface'
#   interfaces[0].proxy .................... NESTInhomogeneousPoissonGeneratorSet gid: 4d9f98fd-c147-428e-92d5-3d60dbd8c849
#   interfaces[0].spiking_network .......... NESTNetwork gid: 91a24209-90fe-46a9-8b80-7a58031817ba
#   interfaces[0].transformer .............. LinearRate gid: c96f06a6-9e81-4092-bac2-7ceaeb163a39
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[np.int64(2), np.int64(67)]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[np.int64(0), np.int64(1)]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('d6e83b87-8b60-4061-8ca6-364ab965d30b')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int64
#   interfaces[0].proxy_gids: unique_values  [[np.int64(27), np.int64(92)]]
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('282da063-63ec-4f08-9ebd-0fb8b1f08776')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[np.int64(0), np.int64(1)]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 66
# )
# 2026-08-06 15:42:28,796 - INFO - examples.example -
# TVBtoNESTInterfaces (
#   title .................................. 'TVBtoNESTInterfaces gid: 282da063-63ec-4f08-9ebd-0fb8b1f08776'
#   Type ................................... 'TVBtoNESTInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoNESTInterface gid: d6e83b87-8b60-4061-8ca6-364ab965d30b'
#   interfaces[0].Type ..................... 'TVBtoNESTInterface'
#   interfaces[0].proxy .................... NESTInhomogeneousPoissonGeneratorSet gid: 4d9f98fd-c147-428e-92d5-3d60dbd8c849
#   interfaces[0].spiking_network .......... NESTNetwork gid: 91a24209-90fe-46a9-8b80-7a58031817ba
#   interfaces[0].transformer .............. LinearRate gid: c96f06a6-9e81-4092-bac2-7ceaeb163a39
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[np.int64(2), np.int64(67)]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[np.int64(0), np.int64(1)]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('d6e83b87-8b60-4061-8ca6-364ab965d30b')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int64
#   interfaces[0].proxy_gids: unique_values  [[np.int64(27), np.int64(92)]]
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('282da063-63ec-4f08-9ebd-0fb8b1f08776')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[np.int64(0), np.int64(1)]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... R
#   number_of_proxy_nodes .................. 66
# )
#
# TVBtoNESTInterfaces (
#   title .................................. 'TVBtoNESTInterfaces gid: 282da063-63ec-4f08-9ebd-0fb8b1f08776'
#   Type ................................... 'TVBtoNESTInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoNESTInterface gid: d6e83b87-8b60-4061-8ca6-364ab965d30b'
#   interfaces[0].Type ..................... 'TVBtoNESTInterface'
#   interfaces[0].proxy .................... NESTInhomogeneousPoissonGeneratorSet gid: 4d9f98fd-c147-428e-92d5-3d60dbd8c849
#   interfaces[0].spiking_network .......... NESTNetwork gid: 91a24209-90fe-46a9-8b80-7a58031817ba
#   interfaces[0].transformer .............. LinearRate gid: c96f06a6-9e81-4092-bac2-7ceaeb163a39
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... None
#   interfaces[0].coupling_mode ............ 'spikeNet'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (66,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: unique_values  [[np.int64(2), np.int64(67)]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... R
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[np.int64(0), np.int64(1)]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('d6e83b87-8b60-4061-8ca6-364ab965d30b')
#   interfaces[0].number_of_proxy_nodes .... 66
#   interfaces[0].number_of_proxy_gids ..... 66
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (66,)
#   interfaces[0].proxy_gids: dtype ........ int64
#   interfaces[0].proxy_gids: unique_values  [[np.int64(27), np.int64(92)]]
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('282da063-63ec-4f08-9ebd-0fb8b1f08776')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[np.int64(0), np.int64(1)]]
#   n_vois ................................. 1
#   voi .................................... --------------------
# ...
#   voi: dtype .......................... int64
#   voi: values ......................... 0
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[np.int64(0), np.int64(1)]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. RawCosim(period=0.100000, voi=[0])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: be9b6ad8-6a78-43e6-bf78-ff976de08af0
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 172afa0c-77a9-4b1c-8a32-d144cbf65093
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 0b4c85f8-889a-404e-be06-eff28fc9a57e
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 1, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('268973ef-b03d-4ed5-a168-14df4f2c9b56')
# )
# 2026-08-06 15:43:00,344 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-06 15:43:00,344 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-06 15:43:00,344 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-06 15:43:00,344 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-06 15:43:00,344 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-06 15:43:00,344 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-06 15:43:00,344 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-06 15:43:00,344 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-06 15:43:00,344 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-06 15:43:00,344 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-06 15:43:00,344 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-06 15:43:00,344 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
# 2026-08-06 15:43:00,344 - INFO - examples.example -
# Configuring simulation with App NESTSerialApp...
#
# Configuring simulation with App NESTSerialApp...
# 2026-08-06 15:43:00,354 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-06 15:43:00,354 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-06 15:43:00,354 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-06 15:43:00,354 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-06 15:43:00,354 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-06 15:43:00,354 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-06 15:43:00,354 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-06 15:43:00,354 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-06 15:43:00,354 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-06 15:43:00,354 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-06 15:43:00,354 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-06 15:43:00,354 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-06 15:43:00,354 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
#
# Simulating for 36ms with App TVBSerialApp...
# 2026-08-06 15:43:00,367 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - No or all NaN valued cosimulator updates at time step 0!
# 2026-08-06 15:43:00,367 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.016 seconds
# 2026-08-06 15:43:00,367 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2026-08-06 15:43:00,367 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 22031
# 2026-08-06 15:43:00,378 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-06 15:43:00,409 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...9.091% completed in 0.0425587 sec!
# ...9.091% completed in 0.0425587 sec!2026-08-06 15:43:00,418 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-06 15:43:00,444 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...18.182% completed in 0.077291 sec!
# ...18.182% completed in 0.077291 sec!2026-08-06 15:43:00,455 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-06 15:43:00,473 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...27.273% completed in 0.10691 sec!
# ...27.273% completed in 0.10691 sec!2026-08-06 15:43:00,489 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-06 15:43:00,519 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...36.364% completed in 0.1529 sec!
# ...36.364% completed in 0.1529 sec!2026-08-06 15:43:00,527 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-06 15:43:00,557 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...45.455% completed in 0.190772 sec!
# ...45.455% completed in 0.190772 sec!2026-08-06 15:43:00,567 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-06 15:43:00,581 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...54.545% completed in 0.214885 sec!
# ...54.545% completed in 0.214885 sec!2026-08-06 15:43:00,605 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-06 15:43:00,619 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...63.636% completed in 0.253009 sec!
# ...63.636% completed in 0.253009 sec!/home/docker/venv/lib/python3.12/site-packages/elephant/conversion.py:1158: UserWarning:Binning discarded 1 last spike(s) of the input spiketrain
# 2026-08-06 15:43:00,627 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-06 15:43:00,657 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...72.727% completed in 0.290298 sec!
# ...72.727% completed in 0.290298 sec!2026-08-06 15:43:00,665 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-06 15:43:00,679 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...81.818% completed in 0.312304 sec!
# ...81.818% completed in 0.312304 sec!2026-08-06 15:43:00,697 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-06 15:43:00,721 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...90.909% completed in 0.354966 sec!
# ...90.909% completed in 0.354966 sec!2026-08-06 15:43:00,730 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2026-08-06 15:43:00,760 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...100.000% completed in 0.393307 sec!
# ...100.000% completed in 0.393307 sec!
# Simulated in 0.453268 secs!
#
# 2026-08-06 15:43:00,760 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,760 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,760 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,760 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,760 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,760 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,760 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,760 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,760 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,760 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,760 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,760 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,760 - INFO - examples.example -
# Cleaning up App TVBNESTSerialOrchestrator...
#
# Cleaning up App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,761 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-06 15:43:00,761 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-06 15:43:00,761 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-06 15:43:00,761 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-06 15:43:00,761 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-06 15:43:00,761 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-06 15:43:00,761 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-06 15:43:00,761 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-06 15:43:00,761 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-06 15:43:00,761 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-06 15:43:00,761 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-06 15:43:00,761 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2026-08-06 15:43:00,761 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
#
# Cleaning up App TVBSerialApp...
# 2026-08-06 15:43:00,764 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-06 15:43:00,764 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-06 15:43:00,764 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-06 15:43:00,764 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-06 15:43:00,764 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-06 15:43:00,764 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-06 15:43:00,764 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-06 15:43:00,764 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-06 15:43:00,764 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-06 15:43:00,764 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-06 15:43:00,764 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-06 15:43:00,764 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
# 2026-08-06 15:43:00,764 - INFO - examples.example -
# Cleaning up App NESTSerialApp...
#
# Cleaning up App NESTSerialApp...
# 2026-08-06 15:43:00,765 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-06 15:43:00,765 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-06 15:43:00,765 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-06 15:43:00,765 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-06 15:43:00,765 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-06 15:43:00,765 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-06 15:43:00,765 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-06 15:43:00,765 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-06 15:43:00,765 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-06 15:43:00,765 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-06 15:43:00,765 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-06 15:43:00,765 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2026-08-06 15:43:00,765 - INFO - examples.example -
# Stopping App TVBSerialApp...
#
# Stopping App TVBSerialApp...
# 2026-08-06 15:43:00,767 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-06 15:43:00,767 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-06 15:43:00,767 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-06 15:43:00,767 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-06 15:43:00,767 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-06 15:43:00,767 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-06 15:43:00,767 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-06 15:43:00,767 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-06 15:43:00,767 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-06 15:43:00,767 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-06 15:43:00,767 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-06 15:43:00,767 - INFO - examples.example -
# Stopping App NESTSerialApp...
# 2026-08-06 15:43:00,767 - INFO - examples.example -
# Stopping App NESTSerialApp...
#
# Stopping App NESTSerialApp...
# 2026-08-06 15:43:00,768 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,768 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,768 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,768 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,768 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,768 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,768 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,768 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,768 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,768 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,768 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,768 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
# 2026-08-06 15:43:00,768 - INFO - examples.example -
# Stopping App TVBNESTSerialOrchestrator...
#
# Stopping App TVBNESTSerialOrchestrator...
#
# Success in 1.03774 sec!
# ******************************************************
#
#
# ******************************************************
# ******************************************************
#
# TestDefaultRATE SUCCESS!
#
# TestDefaultMultisynapseRATE SUCCESS!
#
# TestWilsonCowanRATE SUCCESS!
#
# TestWilsonCowanMultisynapseRATE SUCCESS!
#
# TestDefaultSPIKES SUCCESS!
#
# TestDefaultMultisynapseSPIKES SUCCESS!
#
# TestWilsonCowanSPIKES SUCCESS!
#
# TestWilsonCowanMultisynapseSPIKES SUCCESS!
#
# TestDefaultSPIKES_SINGLE_INTERACTION SUCCESS!
#
# TestDefaultSPIKES_MULTIPLE_INTERACTION SUCCESS!
#
# TestDefaultSPIKES_TO_RATE SUCCESS!
#
# TestDefaultSPIKES_TO_HIST SUCCESS!
# ******************************************************
