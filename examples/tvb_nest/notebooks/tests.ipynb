# %%
! pwd
# Out:
# /home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks

# %%
! python ../../../tvb_multiscale/tests/tvb_nest/test_simulator.py
# Out:
# 2023-10-04 18:13:39,824 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:13:39,824 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:13:39,824 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:13:39,824 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:13:39,825 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:13:39,825 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:13:39,825 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2023-10-04 18:13:39,825 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# ...

# %%
! python ../../../tvb_multiscale/tests/tvb_nest/test_spiking_models_builder_properties_methods.py
# Out:
# 2023-10-04 18:13:41,435 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:13:41,435 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:13:41,435 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:13:41,435 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:13:41,435 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:13:41,435 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:13:41,435 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2023-10-04 18:13:41,435 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# ...

# %%
! python ../../../tvb_multiscale/tests/tvb_nest/test_models.py 0
# Out:
# 2023-10-04 18:13:44,451 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:13:44,451 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:13:44,451 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:13:44,451 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:13:44,451 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:13:44,451 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:13:44,451 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2023-10-04 18:13:44,451 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# ...

# %%
! python ../../../tvb_multiscale/tests/tvb_nest/test_models.py 1
# Out:
# 2023-10-04 18:13:49,829 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:13:49,829 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:13:49,830 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:13:49,830 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:13:49,830 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:13:49,830 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:13:49,830 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2023-10-04 18:13:49,830 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# ...

# %%
! python ../../../tvb_multiscale/tests/tvb_nest/test_models.py 2
# Out:
# 2023-10-04 18:13:55,139 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:13:55,139 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:13:55,139 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:13:55,139 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:13:55,139 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:13:55,139 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:13:55,139 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2023-10-04 18:13:55,139 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# ...

# %%
! python ../../../tvb_multiscale/tests/tvb_nest/test_models.py 3
# Out:
# 2023-10-04 18:14:00,291 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:14:00,291 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:14:00,291 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:14:00,291 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:14:00,291 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:14:00,291 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:14:00,292 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2023-10-04 18:14:00,292 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# ...

# %%
! python ../../../tvb_multiscale/tests/tvb_nest/test_models.py 4
# Out:
# 2023-10-04 18:14:05,600 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:14:05,600 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:14:05,600 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:14:05,600 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:14:05,600 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:14:05,600 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:14:05,601 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2023-10-04 18:14:05,601 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# ...

# %%
! python ../../../tvb_multiscale/tests/tvb_nest/test_models.py 5
# Out:
# 2023-10-04 18:14:11,349 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:14:11,349 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:14:11,350 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:14:11,350 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:14:11,350 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:14:11,350 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:14:11,350 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2023-10-04 18:14:11,350 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# ...

# %%
! python ../../../tvb_multiscale/tests/tvb_nest/test_models.py 6
# Out:
# 2023-10-04 18:14:17,079 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:14:17,079 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:14:17,080 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:14:17,080 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:14:17,080 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:14:17,080 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:14:17,080 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2023-10-04 18:14:17,080 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# ...

# %%
! python ../../../tvb_multiscale/tests/tvb_nest/test_models.py 7
# Out:
# 2023-10-04 18:14:22,533 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:14:22,533 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:14:22,533 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:14:22,533 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:14:22,533 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:14:22,533 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:14:22,534 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2023-10-04 18:14:22,534 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# ...

# %%
! python ../../../tvb_multiscale/tests/tvb_nest/test_models.py -1
# Out:
# 2023-10-04 18:14:28,086 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:14:28,086 - INFO - tvb_multiscale.tvb_nest.config - Configuring NEST path...
# 2023-10-04 18:14:28,086 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:14:28,086 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/build/nest
# 2023-10-04 18:14:28,087 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:14:28,087 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/build/nest/share/nest
# 2023-10-04 18:14:28,087 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# 2023-10-04 18:14:28,087 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/build/nest/share/doc/nest
# ...
