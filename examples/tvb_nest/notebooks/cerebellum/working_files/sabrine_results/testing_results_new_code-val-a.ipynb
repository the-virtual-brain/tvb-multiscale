# %%
! pwd
# Out:
# /home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks/cerebellum/working_files/sabrine_results

# %%
import os
from examples.tvb_nest.notebooks.cerebellum.scripts.base import configure
from examples.tvb_nest.notebooks.cerebellum.scripts.sbi_script import *

config = configure()[0]
# Out:
# 2023-06-15 18:32:01,286 - INFO - tvb_multiscale.tvb_nest.config - Loading a NEST instance...
# 2023-06-15 18:32:01,286 - INFO - tvb_multiscale.tvb_nest.config - Loading a NEST instance...
# 2023-06-15 18:32:01,292 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/env/neurosci/nest_build
# 2023-06-15 18:32:01,292 - INFO - tvb_multiscale.tvb_nest.config - NEST_INSTALL_DIR: /home/docker/env/neurosci/nest_build
# 2023-06-15 18:32:01,298 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/env/neurosci/nest_build/share/nest
# 2023-06-15 18:32:01,298 - INFO - tvb_multiscale.tvb_nest.config - NEST_DATA_DIR: /home/docker/env/neurosci/nest_build/share/nest
# 2023-06-15 18:32:01,302 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/env/neurosci/nest_build/share/doc/nest
# 2023-06-15 18:32:01,302 - INFO - tvb_multiscale.tvb_nest.config - NEST_DOC_DIR: /home/docker/env/neurosci/nest_build/share/doc/nest
# ...

# %%
print(config.out.FOLDER_RES)
respath = str(config.out.FOLDER_RES)
# Out:
# /home/docker/packages/tvb-multiscale/examples/tvb_nest/notebooks/cerebellum/working_files/sabrine_results/outputs/cwc/res

# %%
iGs = [2]
TRAIN_SAMPLES =config.N_TRAIN_SAMPLES_LIST
nruns = 10

# %%
# for nts in TRAIN_SAMPLES:
#     for iG in iGs:
#         for iR in range(nruns):
#             samples = load_posterior_samples(iG=iG, iR=iR, 
#                                              label = "%04d_Train" % nts, config=config)
#             ns = len(samples["mean"])
#             print("\n-------------------------------------------")
#             try:
#                 assert ns == 1
#             except:
#                 print("iG=%d, iR=%d, nts=%d, len(samples)=%d" % (iG, iR, nts, ns))
#             shape = np.concatenate(samples["mean"]).shape
#             try:
#                 assert np.all(shape == (1200, 3))
#             except:
#                 print("iG=%d, iR=%d, nts=%d, samples[0].shape=%s" % (iG, iR, nts, str(shape)))

# %%
# for iG in iGs:
#     for nts in TRAIN_SAMPLES:
#         for iR in range(nruns):
#             samples_fit = sbi_train_and_test_for_iG(iG, config, iR=iR, n_train_samples=nts)

# %%
plot_all_together(config, iGs=iGs, diagnostics=["diff", "accuracy", "zscore_prior", "zscore", "shrinkage"],
                  params=None, num_train_samples=TRAIN_SAMPLES, runs=None, confidence="5%",
                  colors=['b', "g", "m"], marker='.', linestyle='-', figsize=(6,3))
# Out:
# (<Figure size 1080x1080 with 5 Axes>,
#  array([[<AxesSubplot:title={'center':'G=6'}, ylabel='diff'>],
#         [<AxesSubplot:ylabel='accuracy'>],
#         [<AxesSubplot:ylabel='zscore_prior'>],
#         [<AxesSubplot:ylabel='zscore'>],
#         [<AxesSubplot:xlabel='N training samples', ylabel='shrinkage'>]],
#        dtype=object))
