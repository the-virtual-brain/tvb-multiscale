# %%
! pwd
# Out:
# /home/docker/packages/tvb-multiscale/examples/notebooks

# %%
! python ../../tvb_multiscale/tests/core/test_time_series_objects.py
# Out:
# 2023-09-20 18:16:16,248 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-20 18:16:16,248 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-09-20 18:16:16,249 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 2, 68, 1) using model.initial()
# 2023-09-20 18:16:16,258 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-09-20 18:16:16,258 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-09-20 18:16:16,259 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-20 18:16:16,259 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# 2023-09-20 18:16:16,434 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-20 18:16:16,434 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-09-20 18:16:16,435 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-09-20 18:16:16,435 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 2, 68, 1) using model.initial()
# 2023-09-20 18:16:16,445 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-09-20 18:16:16,445 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-09-20 18:16:16,446 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-20 18:16:16,446 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
#
#
# Simulating...
# 2023-09-20 18:16:16,446 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.089 seconds
# 2023-09-20 18:16:16,446 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2023-09-20 18:16:16,446 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 122400
#
# Simulated in 0.022320 secs!

# %%
! python ../../tvb_multiscale/tests/core/test_io_time_series.py
# Out:
# 2023-09-20 18:16:18,408 - INFO - tvb.storage.h5.encryption.data_encryption_handler - Cannot import syncrypto library.

# %%
! python ../../tvb_multiscale/tests/core/test_simulator_serialization.py

# %%
! python ../../tvb_multiscale/tests/core/test_models.py
# Out:
# ******************************************************
# ******************************************************
# TestLinear
# ******************************************************
# ******************************************************
# 2023-09-20 18:16:24,570 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-20 18:16:24,571 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2023-09-20 18:16:24,571 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 1, 68, 1) using model.initial()
# 2023-09-20 18:16:24,577 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2023-09-20 18:16:24,577 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2023-09-20 18:16:24,578 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-20 18:16:24,578 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# 2023-09-20 18:16:26,068 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-20 18:16:26,068 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2023-09-20 18:16:26,068 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 1, 68, 1) using model.initial()
# 2023-09-20 18:16:26,074 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2023-09-20 18:16:26,074 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2023-09-20 18:16:26,075 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-20 18:16:26,075 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
#
#
# Simulating...
# 2023-09-20 18:16:26,075 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.161 seconds
# 2023-09-20 18:16:26,075 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2023-09-20 18:16:26,075 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 220320
#
# Simulated in 0.042309 secs!
#
#
# Success in 1.55834 sec!
# ******************************************************
#
#
# ******************************************************
# ******************************************************
#
# ******************************************************
# ******************************************************
# TestWilsonCowan
# ******************************************************
# ******************************************************
# 2023-09-20 18:16:27,205 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-20 18:16:27,205 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-09-20 18:16:27,206 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 2, 68, 1) using model.initial()
# 2023-09-20 18:16:27,215 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-09-20 18:16:27,215 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-09-20 18:16:27,216 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-20 18:16:27,216 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# 2023-09-20 18:16:28,652 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-20 18:16:28,652 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-09-20 18:16:28,653 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-09-20 18:16:28,653 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 2, 68, 1) using model.initial()
# 2023-09-20 18:16:28,661 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-09-20 18:16:28,661 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-09-20 18:16:28,662 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-09-20 18:16:28,662 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
#
#
# Simulating...
# 2023-09-20 18:16:28,662 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.322 seconds
# 2023-09-20 18:16:28,662 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2023-09-20 18:16:28,662 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 440640
#
# Simulated in 0.061536 secs!
#
#
# Success in 1.54266 sec!
# ******************************************************
#
#
# ******************************************************
# ******************************************************
#
# ******************************************************
# ******************************************************
# TestLinearReducedWongWangExcIO
# ******************************************************
# ******************************************************
# 2023-09-20 18:16:29,818 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-20 18:16:29,819 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-09-20 18:16:29,819 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 2, 68, 1) using model.initial()
# 2023-09-20 18:16:29,828 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-09-20 18:16:29,828 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-09-20 18:16:29,829 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.8 MB
# 2023-09-20 18:16:29,829 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# 2023-09-20 18:16:31,264 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-20 18:16:31,265 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-09-20 18:16:31,265 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (1, 1, 1)
# 2023-09-20 18:16:31,265 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 2, 68, 1) using model.initial()
# 2023-09-20 18:16:31,274 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-09-20 18:16:31,274 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-09-20 18:16:31,275 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.8 MB
# 2023-09-20 18:16:31,275 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
#
#
# Simulating...
# 2023-09-20 18:16:31,275 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.322 seconds
# 2023-09-20 18:16:31,275 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2023-09-20 18:16:31,275 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 440640
# Simulated in 0.079573 secs!
#
#
# Success in 1.56918 sec!
# ******************************************************
#
#
# ******************************************************
# ******************************************************
#
# ******************************************************
# ******************************************************
# TestReducedWongWangExcIO
# ******************************************************
# ******************************************************
# 2023-09-20 18:16:32,444 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-20 18:16:32,444 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-09-20 18:16:32,446 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 2, 68, 1) using model.initial()
# 2023-09-20 18:16:32,454 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-09-20 18:16:32,455 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-09-20 18:16:32,456 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.8 MB
# 2023-09-20 18:16:32,456 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# 2023-09-20 18:16:33,884 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-20 18:16:33,884 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-09-20 18:16:33,885 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (1, 1, 1)
# 2023-09-20 18:16:33,885 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 2, 68, 1) using model.initial()
# 2023-09-20 18:16:33,894 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-09-20 18:16:33,894 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-09-20 18:16:33,895 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.8 MB
# 2023-09-20 18:16:33,895 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
#
#
# Simulating...
# 2023-09-20 18:16:33,895 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.322 seconds
# 2023-09-20 18:16:33,895 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2023-09-20 18:16:33,895 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 440640
#
# Simulated in 0.079266 secs!
#
#
# Success in 1.5558 sec!
# ******************************************************
#
#
# ******************************************************
# ******************************************************
#
# ******************************************************
# ******************************************************
# TestReducedWongWangExcIOInhI
# ******************************************************
# ******************************************************
# 2023-09-20 18:16:35,066 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-20 18:16:35,066 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 4.5 MB
# 2023-09-20 18:16:35,067 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 4, 68, 1) using model.initial()
# 2023-09-20 18:16:35,082 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 4, 68, 1)
# 2023-09-20 18:16:35,082 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (4, 68, 1)
# 2023-09-20 18:16:35,083 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 3.3 MB
# 2023-09-20 18:16:35,083 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# 2023-09-20 18:16:36,507 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-09-20 18:16:36,508 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 4.4 MB
# 2023-09-20 18:16:36,508 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-09-20 18:16:36,508 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 4, 68, 1) using model.initial()
# 2023-09-20 18:16:36,524 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 4, 68, 1)
# 2023-09-20 18:16:36,524 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (4, 68, 1)
# 2023-09-20 18:16:36,525 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 3.3 MB
# 2023-09-20 18:16:36,525 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
#
#
# Simulating...
# 2023-09-20 18:16:36,525 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.643 seconds
# 2023-09-20 18:16:36,525 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2023-09-20 18:16:36,526 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 881280
#
# Simulated in 0.113647 secs!
#
#
# Success in 1.6019 sec!
# ******************************************************
#
#
# ******************************************************
# ******************************************************
#
# TestLinear SUCCESS!
#
# TestWilsonCowan SUCCESS!
#
# TestLinearReducedWongWangExcIO SUCCESS!
#
# TestReducedWongWangExcIO SUCCESS!
#
# TestReducedWongWangExcIOInhI SUCCESS!
# ******************************************************
