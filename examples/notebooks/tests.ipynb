# %%
! pwd
# Out:
# /home/docker/packages/tvb-multiscale/examples/notebooks

# %%
! python ../../tvb_multiscale/tests/core/test_time_series_objects.py
# Out:
# 2025-02-19 11:15:31,476 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2025-02-19 11:15:31,476 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2025-02-19 11:15:31,476 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 2, 68, 1) using model.initial()
# 2025-02-19 11:15:31,485 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2025-02-19 11:15:31,486 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2025-02-19 11:15:31,486 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2025-02-19 11:15:31,486 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# 2025-02-19 11:15:31,642 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2025-02-19 11:15:31,642 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2025-02-19 11:15:31,643 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2025-02-19 11:15:31,643 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 2, 68, 1) using model.initial()
# 2025-02-19 11:15:31,652 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2025-02-19 11:15:31,652 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2025-02-19 11:15:31,653 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2025-02-19 11:15:31,653 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
#
#
# Simulating...
# 2025-02-19 11:15:31,653 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.089 seconds
# 2025-02-19 11:15:31,653 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2025-02-19 11:15:31,653 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 122400
#
# Simulated in 0.016540 secs!

# %%
! python ../../tvb_multiscale/tests/core/test_io_time_series.py
# Out:
# Traceback (most recent call last):
#   File "/home/docker/packages/tvb-multiscale/examples/notebooks/../../tvb_multiscale/tests/core/test_io_time_series.py", line 9, in <module>
#     from tvb_multiscale.core.tvb.io.h5_writer import H5Writer, h5
#   File "/home/docker/packages/tvb-multiscale/tvb_multiscale/core/tvb/io/h5_writer.py", line 9, in <module>
#     from tvb.core.neocom import h5
#   File "/home/docker/packages/tvb-root/tvb_framework/tvb/core/neocom/h5.py", line 35, in <module>
#     from tvb.core.neocom._h5loader import Loader, DirLoader, TVBLoader, ViewModelLoader, DtLoader
#   File "/home/docker/packages/tvb-root/tvb_framework/tvb/core/neocom/_h5loader.py", line 36, in <module>
#     from tvb.core.neocom._registry import Registry
#   File "/home/docker/packages/tvb-root/tvb_framework/tvb/core/neocom/_registry.py", line 33, in <module>
#     from tvb.core.neotraits.h5 import H5File
#   File "/home/docker/packages/tvb-root/tvb_framework/tvb/core/neotraits/h5.py", line 31, in <module>
#     from ._h5core import H5File, ViewModelH5
#   File "/home/docker/packages/tvb-root/tvb_framework/tvb/core/neotraits/_h5core.py", line 43, in <module>
#     from tvb.storage.storage_interface import StorageInterface
#   File "/home/docker/.local/lib/python3.10/site-packages/tvb_storage-2.8.1-py3.10.egg/tvb/storage/storage_interface.py", line 39, in <module>
#     from tvb.storage.h5.encryption.data_encryption_handler import FoldersQueueConsumer, encryption_handler
#   File "/home/docker/.local/lib/python3.10/site-packages/tvb_storage-2.8.1-py3.10.egg/tvb/storage/h5/encryption/data_encryption_handler.py", line 46, in <module>
#     from tvb.storage.kube.kube_notifier import KubeNotifier
#   File "/home/docker/.local/lib/python3.10/site-packages/tvb_storage-2.8.1-py3.10.egg/tvb/storage/kube/kube_notifier.py", line 42, in <module>
#     class KubeNotifier(object):
#   File "/home/docker/.local/lib/python3.10/site-packages/tvb_storage-2.8.1-py3.10.egg/tvb/storage/kube/kube_notifier.py", line 58, in KubeNotifier
#     def notify_pods(url, target_application=TvbProfile.current.web.OPENSHIFT_APPLICATION):
# AttributeError: 'WebSettings' object has no attribute 'OPENSHIFT_APPLICATION'

# %%
! python ../../tvb_multiscale/tests/core/test_simulator_serialization.py

# %%
! python ../../tvb_multiscale/tests/core/test_models.py
# Out:
# ******************************************************
# ******************************************************
# TestLinear
# ******************************************************
# ******************************************************
# 2025-02-19 11:15:39,138 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2025-02-19 11:15:39,139 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2025-02-19 11:15:39,139 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 1, 68, 1) using model.initial()
# 2025-02-19 11:15:39,145 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2025-02-19 11:15:39,145 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2025-02-19 11:15:39,146 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2025-02-19 11:15:39,146 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# 2025-02-19 11:15:40,501 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2025-02-19 11:15:40,502 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2025-02-19 11:15:40,502 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880,