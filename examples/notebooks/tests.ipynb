# %%
! pwd
# Out:
# /home/docker/packages/tvb-multiscale/examples/notebooks

# %%
! python ../../tvb_multiscale/tests/core/test_time_series_objects.py
# Out:
# /home/docker/venv/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# 2026-02-24 14:42:08,192 - WARNING - tvb.simulator.plot.tools - You need mpl_toolkits for some axe related features
# /home/docker/packages/PySpike/pyspike/PieceWiseConstFunc.py:160: SyntaxWarning: invalid escape sequence '\i'
#   """ Computes the average of the piece-wise const function:
# /home/docker/packages/PySpike/pyspike/PieceWiseLinFunc.py:196: SyntaxWarning: invalid escape sequence '\i'
#   """ Computes the average of the piece-wise linear function:
# /home/docker/packages/PySpike/pyspike/spike_sync.py:168: SyntaxWarning: invalid escape sequence '\s'
#   """ Computes the spike synchronization value of the given spike
# 2026-02-24 14:42:08,644 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-02-24 14:42:08,644 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2026-02-24 14:42:08,645 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 2, 68, 1) using model.initial()
# 2026-02-24 14:42:08,654 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2026-02-24 14:42:08,654 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2026-02-24 14:42:08,656 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2026-02-24 14:42:08,766 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-02-24 14:42:08,766 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2026-02-24 14:42:08,766 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2026-02-24 14:42:08,767 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 2, 68, 1) using model.initial()
# 2026-02-24 14:42:08,776 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2026-02-24 14:42:08,777 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2026-02-24 14:42:08,778 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
#
#
# Simulating...
# 2026-02-24 14:42:08,779 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.089 seconds
# 2026-02-24 14:42:08,779 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2026-02-24 14:42:08,779 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 122400
#
# Simulated in 0.017517 secs!

# %%
! python ../../tvb_multiscale/tests/core/test_io_time_series.py
# Out:
# /home/docker/venv/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# 2026-02-24 14:42:10,563 - WARNING - tvb.simulator.plot.tools - You need mpl_toolkits for some axe related features
# 2026-02-24 14:42:11,024 - INFO - tvb.storage.h5.encryption.data_encryption_handler - Cannot import syncrypto library.

# %%
! python ../../tvb_multiscale/tests/core/test_simulator_serialization.py

# %%
! python ../../tvb_multiscale/tests/core/test_models.py
# Out:
# /home/docker/venv/lib/python3.12/site-packages/matplotlib/projections/__init__.py:63: UserWarning: Unable to import Axes3D. This may be due to multiple versions of Matplotlib being installed (e.g. as a system package and as a pip package). As a result, the 3D projection is not available.
#   warnings.warn("Unable to import Axes3D. This may be due to multiple versions of "
# 2026-02-24 14:42:17,493 - WARNING - tvb.simulator.plot.tools - You need mpl_toolkits for some axe related features
#
# ******************************************************
# ******************************************************
# TestLinear
# ******************************************************
# ******************************************************
# 2026-02-24 14:42:17,832 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-02-24 14:42:17,832 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2026-02-24 14:42:17,833 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 1, 68, 1) using model.initial()
# 2026-02-24 14:42:17,838 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2026-02-24 14:42:17,838 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2026-02-24 14:42:17,839 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2026-02-24 14:42:18,808 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-02-24 14:42:18,809 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 1.1 MB
# 2026-02-24 14:42:18,809 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 1, 68, 1) using model.initial()
# 2026-02-24 14:42:18,815 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 1, 68, 1)
# 2026-02-24 14:42:18,815 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (1, 68, 1)
# 2026-02-24 14:42:18,816 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
#
#
# Simulating...
# 2026-02-24 14:42:18,816 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.161 seconds
# 2026-02-24 14:42:18,816 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2026-02-24 14:42:18,816 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 220320
#
# Simulated in 0.046784 secs!
#
#
# Success in 1.10664 sec!
# ******************************************************
#
#
# ******************************************************
# ******************************************************
#
# ******************************************************
# ******************************************************
# TestWilsonCowan
# ******************************************************
# ******************************************************
# 2026-02-24 14:42:20,020 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-02-24 14:42:20,020 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2026-02-24 14:42:20,020 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 2, 68, 1) using model.initial()
# 2026-02-24 14:42:20,029 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2026-02-24 14:42:20,029 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2026-02-24 14:42:20,030 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2026-02-24 14:42:20,895 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-02-24 14:42:20,895 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2026-02-24 14:42:20,895 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2026-02-24 14:42:20,895 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 2, 68, 1) using model.initial()
# 2026-02-24 14:42:20,904 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2026-02-24 14:42:20,904 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2026-02-24 14:42:20,906 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
#
#
# Simulating...
# 2026-02-24 14:42:20,906 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.322 seconds
# 2026-02-24 14:42:20,906 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2026-02-24 14:42:20,906 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 440640
#
# Simulated in 0.061258 secs!
#
#
# Success in 1.02837 sec!
# ******************************************************
#
#
# ******************************************************
# ******************************************************
#
# ******************************************************
# ******************************************************
# TestLinearReducedWongWangExcIO
# ******************************************************
# ******************************************************
# 2026-02-24 14:42:22,147 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-02-24 14:42:22,147 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2026-02-24 14:42:22,147 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 2, 68, 1) using model.initial()
# 2026-02-24 14:42:22,156 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2026-02-24 14:42:22,157 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2026-02-24 14:42:22,158 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.8 MB
# 2026-02-24 14:42:23,030 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-02-24 14:42:23,030 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2026-02-24 14:42:23,031 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (1, 1, 1)
# 2026-02-24 14:42:23,031 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 2, 68, 1) using model.initial()
# 2026-02-24 14:42:23,040 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2026-02-24 14:42:23,040 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2026-02-24 14:42:23,041 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.8 MB
#
#
# Simulating...
# 2026-02-24 14:42:23,041 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.322 seconds
# 2026-02-24 14:42:23,041 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2026-02-24 14:42:23,041 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 440640
#
# Simulated in 0.083511 secs!
#
#
# Success in 1.08246 sec!
# ******************************************************
#
#
# ******************************************************
# ******************************************************
#
# ******************************************************
# ******************************************************
# TestReducedWongWangExcIO
# ******************************************************
# ******************************************************
# 2026-02-24 14:42:24,282 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-02-24 14:42:24,283 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2026-02-24 14:42:24,283 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 2, 68, 1) using model.initial()
# 2026-02-24 14:42:24,293 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2026-02-24 14:42:24,293 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2026-02-24 14:42:24,294 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.8 MB
# 2026-02-24 14:42:25,184 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-02-24 14:42:25,184 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2026-02-24 14:42:25,185 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (1, 1, 1)
# 2026-02-24 14:42:25,185 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 2, 68, 1) using model.initial()
# 2026-02-24 14:42:25,195 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2026-02-24 14:42:25,195 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2026-02-24 14:42:25,196 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.8 MB
#
#
# Simulating...
# 2026-02-24 14:42:25,196 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.322 seconds
# 2026-02-24 14:42:25,196 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2026-02-24 14:42:25,196 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 440640
#
# Simulated in 0.083718 secs!
#
#
# Success in 1.08823 sec!
# ******************************************************
#
#
# ******************************************************
# ******************************************************
#
# ******************************************************
# ******************************************************
# TestReducedWongWangExcIOInhI
# ******************************************************
# ******************************************************
# 2026-02-24 14:42:26,449 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-02-24 14:42:26,449 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 4.5 MB
# 2026-02-24 14:42:26,449 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 4, 68, 1) using model.initial()
# 2026-02-24 14:42:26,465 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 4, 68, 1)
# 2026-02-24 14:42:26,465 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (4, 68, 1)
# 2026-02-24 14:42:26,467 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 3.3 MB
# 2026-02-24 14:42:27,343 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2026-02-24 14:42:27,343 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 4.4 MB
# 2026-02-24 14:42:27,343 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2026-02-24 14:42:27,343 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Preparing initial history of shape (880, 4, 68, 1) using model.initial()
# 2026-02-24 14:42:27,360 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 4, 68, 1)
# 2026-02-24 14:42:27,360 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (4, 68, 1)
# 2026-02-24 14:42:27,361 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 3.3 MB
#
#
# Simulating...
# 2026-02-24 14:42:27,362 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.643 seconds
# 2026-02-24 14:42:27,362 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2026-02-24 14:42:27,362 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 881280
#
# Simulated in 0.126466 secs!
#
#
# Success in 1.13627 sec!
# ******************************************************
#
#
# ******************************************************
# ******************************************************
#
# TestLinear SUCCESS!
#
# TestWilsonCowan SUCCESS!
#
# TestLinearReducedWongWangExcIO SUCCESS!
#
# TestReducedWongWangExcIO SUCCESS!
#
# TestReducedWongWangExcIOInhI SUCCESS!
# ******************************************************
