# %%
! pwd
# Out:
# /home/docker/packages/tvb-multiscale/examples/tvb_netpyne/notebooks

# %%
! python ../../../tvb_multiscale/tests/tvb_netpyne/test_spiking_models_builder_properties_methods.py
# Out:
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.
# NetPyNE will load mod-files from /home/docker/packages/tvb-multiscale/tvb_multiscale/tvb_netpyne/netpyne/mod.
# <tvb_multiscale.tvb_netpyne.netpyne_models.models.default_exc_io_inh_i.DefaultExcIOInhIBuilder object at 0xffff389bcb50>
# min_delay:
# 0.05
#
# tvb_dt:
# 0.1
#
# monitor_period:
# 0.1
#
# tvb_model:
# Linear
#
# number_of_regions:
# 68
#
# tvb_weights:
# [[0.0000000e+00 4.8155833e-02 5.5569724e-01 ... 0.0000000e+00
#   9.3632959e-04 1.5197568e-03]
#  [3.4694958e-02 0.0000000e+00 4.0470140e+00 ... 0.0000000e+00
#   0.0000000e+00 6.4991351e-02]
#  [3.3234182e-01 1.6091147e+00 0.0000000e+00 ... 0.0000000e+00
#   1.3227513e-03 2.2254678e-01]
#  ...
#  [0.0000000e+00 0.0000000e+00 0.0000000e+00 ... 0.0000000e+00
#   4.2837810e-03 6.6117304e+01]
#  [6.8634180e-04 0.0000000e+00 1.8867925e-02 ... 2.7493696e-02
#   0.0000000e+00 2.8296225e+01]
#  [2.8677947e-04 1.3400005e-02 3.4921828e-01 ... 2.5495074e+01
#   1.4883909e+01 0.0000000e+00]]
#
# tvb_delays:
# [[ 0.         39.98974333 34.00171    ...  0.         47.8
#   44.73333333]
#  [39.98974333  0.         14.00699533 ...  0.          0.
#   23.274074  ]
#  [34.00171    14.00699533  0.         ...  0.         58.33333333
#   37.56438333]
#  ...
#  [ 0.          0.          0.         ...  0.         20.76666667
#    6.62544467]
#  [47.8         0.         58.33333333 ... 20.76666667  0.
#    5.83055433]
#  [44.73333333 23.274074   37.56438333 ...  6.62544467  5.83055433
#    0.        ]]
#
# region_labels:
# ['bankssts_L' 'bankssts_R' 'caudalanteriorcingulate_L'
#  'caudalanteriorcingulate_R' 'caudalmiddlefrontal_L'
#  'caudalmiddlefrontal_R' 'cuneus_L' 'cuneus_R' 'entorhinal_L'
#  'entorhinal_R' 'frontalpole_L' 'frontalpole_R' 'fusiform_L' 'fusiform_R'
#  'inferiorparietal_L' 'inferiorparietal_R' 'inferiortemporal_L'
#  'inferiortemporal_R' 'insula_L' 'insula_R' 'isthmuscingulate_L'
#  'isthmuscingulate_R' 'lateraloccipital_L' 'lateraloccipital_R'
#  'lateralorbitofrontal_L' 'lateralorbitofrontal_R' 'lingual_L' 'lingual_R'
#  'medialorbitofrontal_L' 'medialorbitofrontal_R' 'middletemporal_L'
#  'middletemporal_R' 'paracentral_L' 'paracentral_R' 'parahippocampal_L'
#  'parahippocampal_R' 'parsopercularis_L' 'parsopercularis_R'
#  'parsorbitalis_L' 'parsorbitalis_R' 'parstriangularis_L'
#  'parstriangularis_R' 'pericalcarine_L' 'pericalcarine_R' 'postcentral_L'
#  'postcentral_R' 'posteriorcingulate_L' 'posteriorcingulate_R'
#  'precentral_L' 'precentral_R' 'precuneus_L' 'precuneus_R'
#  'rostralanteriorcingulate_L' 'rostralanteriorcingulate_R'
#  'rostralmiddlefrontal_L' 'rostralmiddlefrontal_R' 'superiorfrontal_L'
#  'superiorfrontal_R' 'superiorparietal_L' 'superiorparietal_R'
#  'superiortemporal_L' 'superiortemporal_R' 'supramarginal_L'
#  'supramarginal_R' 'temporalpole_L' 'temporalpole_R'
#  'transversetemporal_L' 'transversetemporal_R']
#
# number_of_populations:
# 0
#
# populations_models:
# OrderedDict()
#
# populations_nodes:
# OrderedDict()
#
# populations_scales:
# OrderedDict()
#
# populations_sizes:
# OrderedDict()
#
# populations_params:
# OrderedDict()
#
# populations_connections_labels:
# []
#
# populations_connections_models:
# OrderedDict()
#
# populations_connections_nodes:
# OrderedDict()
#
# populations_connections_weights:
# OrderedDict()
#
# populations_connections_delays:
# OrderedDict()
#
# populations_connections_receptor_types:
# OrderedDict()
#
# populations_connections_conn_spec:
# OrderedDict()
#
# nodes_connections_labels:
# []
#
# nodes_connections_models:
# OrderedDict()
#
# nodes_connections_source_nodes:
# OrderedDict()
#
# nodes_connections_target_nodes:
# OrderedDict()
#
# nodes_connections_weights:
# OrderedDict()
#
# nodes_connections_delays:
# OrderedDict()
#
# nodes_connections_receptor_types:
# OrderedDict()
#
# nodes_connections_conn_spec:
# OrderedDict()

# %%
! python ../../../tvb_multiscale/tests/tvb_netpyne/test_models.py 0
# Out:
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.
#
#
# Testing model 0
# ******************************************************
# ******************************************************
# Using Reduced Wong-Wang ExcIO InhI as a default model
#
# ----------------------------------------------------------------------------------------------------
# Find results in /home/docker/packages/tvb-multiscale/examples/tvb_netpyne/notebooks/outputs/DefaultExcIOInhI_RATE_bidir/res !
# ----------------------------------------------------------------------------------------------------
# 2023-10-04 18:15:16,460 - INFO - examples.example -
# Starting App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:16,460 - INFO - examples.example -
# Starting App TVBNetpyneSerialOrchestrator...
#
# Starting App TVBNetpyneSerialOrchestrator...
#
# Starting App TVBSerialApp...
#
# Setting TVB LIBRARY_PROFILE...
# NetPyNE will load mod-files from /home/docker/packages/tvb-multiscale/tvb_multiscale/tvb_netpyne/netpyne/mod.
#
#
# Configuring...
# Orchestrator spiking cosimulator1:
# <tvb_multiscale.tvb_netpyne.netpyne.module.NetpyneModule object at 0xffff3714ae00>
# Orchestrator spiking cosimulator2:
# <tvb_multiscale.tvb_netpyne.netpyne.module.NetpyneModule object at 0xffff3714ae00>
#
# Done! in 0.000062 min
#
#
#
# Building...
# 2023-10-04 18:15:16,468 - INFO - examples.example -
# Building with App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:16,468 - INFO - examples.example -
# Building with App TVBNetpyneSerialOrchestrator...
#
# Building with App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:16,468 - INFO - examples.example -
# Building cosimulators with TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:16,468 - INFO - examples.example -
# Building cosimulators with TVBNetpyneSerialOrchestrator...
#
# Building cosimulators with TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:16,468 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorNetpyneBuilder of App TVBSerialApp...
# 2023-10-04 18:15:16,468 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorNetpyneBuilder of App TVBSerialApp...
#
# Building TVB CoSimulator with builder CoSimulatorNetpyneBuilder of App TVBSerialApp...
# 2023-10-04 18:15:16,470 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-10-04 18:15:16,470 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 4.5 MB
# 2023-10-04 18:15:16,470 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 4, 68, 1)
# 2023-10-04 18:15:16,487 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 4, 68, 1)
# 2023-10-04 18:15:16,487 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (4, 68, 1)
# 2023-10-04 18:15:16,488 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 3.3 MB
# 2023-10-04 18:15:16,488 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# 2023-10-04 18:15:16,493 - INFO - examples.example -
# CoSimulatorNetpyne (
#   title ............................... 'CoSimulatorNetpyne gid: 87166bee-ffe4-4c9e-affb-4dc6b2f168b8'
#   Type ................................ 'CoSimulatorNetpyne'
#   model ............................... ReducedWongWangExcIOInhI gid: 0d6af6d8-fe05-47e3-b521-916e8e1dfc97
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 5677f577-70c7-4523-b0f1-e040760be680
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: edf7146e-3d82-48c9-8fd6-48c916bd9203
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 1c051477-ed22-4177-9112-d1595d862268
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 4, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('87166bee-ffe4-4c9e-affb-4dc6b2f168b8')
# )
# 2023-10-04 18:15:16,493 - INFO - examples.example -
# CoSimulatorNetpyne (
#   title ............................... 'CoSimulatorNetpyne gid: 87166bee-ffe4-4c9e-affb-4dc6b2f168b8'
#   Type ................................ 'CoSimulatorNetpyne'
#   model ............................... ReducedWongWangExcIOInhI gid: 0d6af6d8-fe05-47e3-b521-916e8e1dfc97
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 5677f577-70c7-4523-b0f1-e040760be680
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: edf7146e-3d82-48c9-8fd6-48c916bd9203
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 1c051477-ed22-4177-9112-d1595d862268
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 4, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('87166bee-ffe4-4c9e-affb-4dc6b2f168b8')
# )
#
# CoSimulatorNetpyne (
#   title ............................... 'CoSimulatorNetpyne gid: 87166bee-ffe4-4c9e-affb-4dc6b2f168b8'
#   Type ................................ 'CoSimulatorNetpyne'
#   model ............................... ReducedWongWangExcIOInhI gid: 0d6af6d8-fe05-47e3-b521-916e8e1dfc97
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 5677f577-70c7-4523-b0f1-e040760be680
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: edf7146e-3d82-48c9-8fd6-48c916bd9203
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 1c051477-ed22-4177-9112-d1595d862268
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 4, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('87166bee-ffe4-4c9e-affb-4dc6b2f168b8')
# )
# 2023-10-04 18:15:16,493 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-10-04 18:15:16,494 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 4.4 MB
# 2023-10-04 18:15:16,494 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-10-04 18:15:16,494 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 4, 68, 1)
# 2023-10-04 18:15:16,511 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 4, 68, 1)
# 2023-10-04 18:15:16,511 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (4, 68, 1)
# 2023-10-04 18:15:16,511 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 3.3 MB
# 2023-10-04 18:15:16,512 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# 2023-10-04 18:15:16,519 - INFO - examples.example -
# Building Spiking Network with builder DefaultExcIOInhIBuilder of App NetpyneSerialApp...
# 2023-10-04 18:15:16,519 - INFO - examples.example -
# Building Spiking Network with builder DefaultExcIOInhIBuilder of App NetpyneSerialApp...
#
# Building Spiking Network with builder DefaultExcIOInhIBuilder of App NetpyneSerialApp...
# 2023-10-04 18:15:16,519 - INFO - examples.example - Configuring spiking network builder...
# 2023-10-04 18:15:16,519 - INFO - examples.example - Configuring spiking network builder...
# 2023-10-04 18:15:16,519 - INFO - examples.example - Configuring populations...
# 2023-10-04 18:15:16,519 - INFO - examples.example - Configuring populations...
# 2023-10-04 18:15:16,520 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2023-10-04 18:15:16,520 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2023-10-04 18:15:16,520 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2023-10-04 18:15:16,520 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2023-10-04 18:15:16,520 - INFO - examples.example - Configuring output devices, if any...
# 2023-10-04 18:15:16,520 - INFO - examples.example - Configuring output devices, if any...
# 2023-10-04 18:15:16,520 - INFO - examples.example - Configuring input devices, if any...
# 2023-10-04 18:15:16,520 - INFO - examples.example - Configuring input devices, if any...
# 2023-10-04
- INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-10-04 18:15:17,677 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...90.909% completed in 0.851342 sec!
# ...90.909% completed in 0.851342 sec!2023-10-04 18:15:17,688 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-10-04 18:15:17,760 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...100.000% completed in 0.934843 sec!
# ...100.000% completed in 0.934843 sec!
# Simulated in 1.029300 secs!
#
# 2023-10-04 18:15:17,761 - INFO - examples.example -
# Cleaning up App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:17,761 - INFO - examples.example -
# Cleaning up App TVBNetpyneSerialOrchestrator...
#
# Cleaning up App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:17,761 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2023-10-04 18:15:17,761 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
#
# Cleaning up App TVBSerialApp...
#   Done; run time = 1.00 s; real-time ratio: 0.04.
#
# Gathering data...
#   Done; gather time = 0.03 s.
#
# Analyzing...
#   Cells: 824
#   Connections: 1594 (1.93 per cell)
#   Spikes: 18 (0.61 Hz)
#   Simulated time: 0.0 s; 1 workers
#   Run time: 1.00 s
# Warning: data won't be saved. No output format specified (consider sim.cfg.savePickle, sim.cfg.saveJson etc.)
# Plotting recorded cell traces ... cell
# Preparing spike data...
# Plotting raster...
#   Done; plotting time = 0.25 s
#
# Total time = 1.46 s
# 2023-10-04 18:15:18,043 - INFO - examples.example -
# Stopping App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:18,043 - INFO - examples.example -
# Stopping App TVBNetpyneSerialOrchestrator...
#
# Stopping App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:18,043 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2023-10-04 18:15:18,043 - INFO - examples.example -
# Stopping App TVBSerialApp...
#
# Stopping App TVBSerialApp...
#
# Success in 1.58619 sec!
# ******************************************************
#
# {'TestDefaultRATE': True}

# %%
! python ../../../tvb_multiscale/tests/tvb_netpyne/test_models.py 1
# Out:
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.
#
#
# Testing model 1
# ******************************************************
# ******************************************************
#
# ----------------------------------------------------------------------------------------------------
# Find results in /home/docker/packages/tvb-multiscale/examples/tvb_netpyne/notebooks/outputs/WilsonCowan_RATE_bidir/res !
# ----------------------------------------------------------------------------------------------------
# 2023-10-04 18:15:23,080 - INFO - examples.example -
# Starting App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:23,080 - INFO - examples.example -
# Starting App TVBNetpyneSerialOrchestrator...
#
# Starting App TVBNetpyneSerialOrchestrator...
#
# Starting App TVBSerialApp...
#
# Setting TVB LIBRARY_PROFILE...
# NetPyNE will load mod-files from /home/docker/packages/tvb-multiscale/tvb_multiscale/tvb_netpyne/netpyne/mod.
#
#
# Configuring...
# Orchestrator spiking cosimulator1:
# <tvb_multiscale.tvb_netpyne.netpyne.module.NetpyneModule object at 0xffff605eae00>
# Orchestrator spiking cosimulator2:
# <tvb_multiscale.tvb_netpyne.netpyne.module.NetpyneModule object at 0xffff605eae00>
#
# Done! in 0.000063 min
#
#
#
# Building...
# 2023-10-04 18:15:23,086 - INFO - examples.example -
# Building with App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:23,086 - INFO - examples.example -
# Building with App TVBNetpyneSerialOrchestrator...
#
# Building with App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:23,086 - INFO - examples.example -
# Building cosimulators with TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:23,086 - INFO - examples.example -
# Building cosimulators with TVBNetpyneSerialOrchestrator...
#
# Building cosimulators with TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:23,087 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorNetpyneBuilder of App TVBSerialApp...
# 2023-10-04 18:15:23,087 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorNetpyneBuilder of App TVBSerialApp...
#
# Building TVB CoSimulator with builder CoSimulatorNetpyneBuilder of App TVBSerialApp...
# 2023-10-04 18:15:23,088 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-10-04 18:15:23,089 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-10-04 18:15:23,089 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2023-10-04 18:15:23,098 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-10-04 18:15:23,099 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-10-04 18:15:23,099 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-10-04 18:15:23,100 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# 2023-10-04 18:15:23,104 - INFO - examples.example -
# CoSimulatorNetpyne (
#   title ............................... 'CoSimulatorNetpyne gid: 791a0d1c-1a98-4b1f-a783-50f0dafb60c3'
#   Type ................................ 'CoSimulatorNetpyne'
#   model ............................... WilsonCowan gid: 848ba366-ca94-479d-a28a-eba6c7acf368
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 7832da80-a9fe-4570-b22d-f8150620b0c9
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 7b41023e-b741-42d9-90c3-57b278b77175
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: b4033255-9db6-4369-96ce-d291e86ea4a0
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('791a0d1c-1a98-4b1f-a783-50f0dafb60c3')
# )
# 2023-10-04 18:15:23,104 - INFO - examples.example -
# CoSimulatorNetpyne (
#   title ............................... 'CoSimulatorNetpyne gid: 791a0d1c-1a98-4b1f-a783-50f0dafb60c3'
#   Type ................................ 'CoSimulatorNetpyne'
#   model ............................... WilsonCowan gid: 848ba366-ca94-479d-a28a-eba6c7acf368
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 7832da80-a9fe-4570-b22d-f8150620b0c9
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 7b41023e-b741-42d9-90c3-57b278b77175
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: b4033255-9db6-4369-96ce-d291e86ea4a0
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('791a0d1c-1a98-4b1f-a783-50f0dafb60c3')
# )
#
# CoSimulatorNetpyne (
#   title ............................... 'CoSimulatorNetpyne gid: 791a0d1c-1a98-4b1f-a783-50f0dafb60c3'
#   Type ................................ 'CoSimulatorNetpyne'
#   model ............................... WilsonCowan gid: 848ba366-ca94-479d-a28a-eba6c7acf368
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 7832da80-a9fe-4570-b22d-f8150620b0c9
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 7b41023e-b741-42d9-90c3-57b278b77175
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: b4033255-9db6-4369-96ce-d291e86ea4a0
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 2, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('791a0d1c-1a98-4b1f-a783-50f0dafb60c3')
# )
# 2023-10-04 18:15:23,105 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-10-04 18:15:23,105 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-10-04 18:15:23,105 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-10-04 18:15:23,105 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2023-10-04 18:15:23,115 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-10-04 18:15:23,115 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-10-04 18:15:23,115 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-10-04 18:15:23,116 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# 2023-10-04 18:15:23,121 - INFO - examples.example -
# Building Spiking Network with builder WilsonCowanBuilder of App NetpyneSerialApp...
# 2023-10-04 18:15:23,121 - INFO - examples.example -
# Building Spiking Network with builder WilsonCowanBuilder of App NetpyneSerialApp...
#
# Building Spiking Network with builder WilsonCowanBuilder of App NetpyneSerialApp...
# 2023-10-04 18:15:23,121 - INFO - examples.example - Configuring spiking network builder...
# 2023-10-04 18:15:23,121 - INFO - examples.example - Configuring spiking network builder...
# 2023-10-04 18:15:23,121 - INFO - examples.example - Configuring populations...
# 2023-10-04 18:15:23,121 - INFO - examples.example - Configuring populations...
# 2023-10-04 18:15:23,122 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2023-10-04 18:15:23,122 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2023-10-04 18:15:23,122 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2023-10-04 18:15:23,122 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2023-10-04 18:15:23,122 - INFO - examples.example - Configuring output devices, if any...
# 2023-10-04 18:15:23,122 - INFO - examples.example - Configuring output devices, if any...
# 2023-10-04 18:15:23,122 - INFO - examples.example - Configuring input devices, if any...
# 2023-10-04 18:15:23,122 - INFO - examples.example - Configuring input devices, if any...
# 2023-10-04 18:15:23,122 - INFO - examples.example - Generating spiking brain...
# 2023-10-04 18:15:23,122 - INFO - examples.example - Generating spiking brain...
# 2023-10-04 18:15:23,123 - INFO - examples.example - Generating spiking brain regions...
# 2023-10-04 18:15:23,123 - INFO - examples.example - Generating spiking brain regions...
# 2023-10-04 18:15:23,123 - INFO - examples.example - Generating spiking region node: bankssts_L...
# 2023-10-04 18:15:23,123 - INFO - examples.example - Generating spiking region node: bankssts_L...
# 2023-10-04 18:15:23,124 - INFO - examples.example - Generating population: E...
# 2023-10-04 18:15:23,124 - INFO - examples.example - Generating population: E...
# Netpyne:: Creating spiking population 'bankssts_L.E' of 12 neurons of type 'PYR'.
# 2023-10-04 18:15:23,124 - INFO - examples.example - Generating population: I...
# 2023-10-04 18:15:23,124 - INFO - examples.example - Generating population: I...
# Netpyne:: Creating spiking population 'bankssts_L.I' of 4 neurons of type 'PYR'.
# 2023-10-04 18:15:23,125 - INFO - examples.example - Generating spiking region node: bankssts_R...
# 2023-10-04 18:15:23,125 - INFO - examples.example - Generating spiking region node: bankssts_R...
# 2023-10-04
bankssts_L. Model: spike_recorder, params: {}
# Netpyne:: will connect output device spike_recorder -- bankssts_L.I
# Netpyne:: will create internal device I->['I'] - bankssts_R. Model: spike_recorder, params: {}
# Netpyne:: will connect output device spike_recorder -- bankssts_R.I
# 2023-10-04 18:15:23,144 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-10-04 18:15:23,144 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-10-04 18:15:23,145 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-10-04 18:15:23,145 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2023-10-04 18:15:23,154 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 2, 68, 1)
# 2023-10-04 18:15:23,154 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (2, 68, 1)
# 2023-10-04 18:15:23,154 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 1.0 MB
# 2023-10-04 18:15:23,154 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
#
# Start time:  2023-10-04 18:15:23.158003
#
# Creating network of 6 cell populations on 1 hosts...
#   Number of cells on node 0: 56
#   Done; cell creation time = 0.00 s.
# Making connections...
#   Number of connections on node 0: 58
#   Done; cell connection time = 0.01 s.
#   Number of stims on node 0: 0
#   Done; cell stims creation time = 0.00 s.
# 2023-10-04 18:15:23,167 - INFO - examples.example -
# TVBtoNetpyneInterfaces (
#   title .................................. 'TVBtoNetpyneInterfaces gid: 3fe4a6a2-3fbb-49e9-adf9-8b20078a4d5c'
#   Type ................................... 'TVBtoNetpyneInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoNetpyneInterface gid: 6ea25c88-da1a-4041-bbe2-01f2e6789861'
#   interfaces[0].Type ..................... 'TVBtoNetpyneInterface'
#   interfaces[0].proxy .................... NetpynePoissonGeneratorSet gid: eb2753d5-daa7-4183-8ce4-eb50373d8975
#   interfaces[0].spiking_network .......... NetpyneNetwork gid: ee3eeed5-c677-4058-bf03-94116f8bcea2
#   interfaces[0].transformer .............. LinearRate gid: 941399f0-2fac-4d13-b43a-27294e46ce27
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... --------------------
#   interfaces[0].cvoi: shape .............. (1,)
#   interfaces[0].cvoi: dtype .............. int64
#   interfaces[0].cvoi: values ............. 0
#   interfaces[0].coupling_mode ............ 'TVB'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (2,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: values ....... [[0, 1]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... E
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('6ea25c88-da1a-4041-bbe2-01f2e6789861')
#   interfaces[0].number_of_proxy_nodes .... 2
#   interfaces[0].number_of_proxy_gids ..... 2
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (2,)
#   interfaces[0].proxy_gids: dtype ........ object
#   interfaces[0].proxy_gids: unique_values  None
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('3fe4a6a2-3fbb-49e9-adf9-8b20078a4d5c')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[0, 1]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... E
#   number_of_proxy_nodes .................. 2
# )
# 2023-10-04 18:15:23,167 - INFO - examples.example -
# TVBtoNetpyneInterfaces (
#   title .................................. 'TVBtoNetpyneInterfaces gid: 3fe4a6a2-3fbb-49e9-adf9-8b20078a4d5c'
#   Type ................................... 'TVBtoNetpyneInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoNetpyneInterface gid: 6ea25c88-da1a-4041-bbe2-01f2e6789861'
#   interfaces[0].Type ..................... 'TVBtoNetpyneInterface'
#   interfaces[0].proxy .................... NetpynePoissonGeneratorSet gid: eb2753d5-daa7-4183-8ce4-eb50373d8975
#   interfaces[0].spiking_network .......... NetpyneNetwork gid: ee3eeed5-c677-4058-bf03-94116f8bcea2
#   interfaces[0].transformer .............. LinearRate gid: 941399f0-2fac-4d13-b43a-27294e46ce27
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... --------------------
#   interfaces[0].cvoi: shape .............. (1,)
#   interfaces[0].cvoi: dtype .............. int64
#   interfaces[0].cvoi: values ............. 0
#   interfaces[0].coupling_mode ............ 'TVB'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (2,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: values ....... [[0, 1]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... E
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('6ea25c88-da1a-4041-bbe2-01f2e6789861')
#   interfaces[0].number_of_proxy_nodes .... 2
#   interfaces[0].number_of_proxy_gids ..... 2
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (2,)
#   interfaces[0].proxy_gids: dtype ........ object
#   interfaces[0].proxy_gids: unique_values  None
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('3fe4a6a2-3fbb-49e9-adf9-8b20078a4d5c')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[0, 1]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... E
#   number_of_proxy_nodes .................. 2
# )
#
# TVBtoNetpyneInterfaces (
#   title .................................. 'TVBtoNetpyneInterfaces gid: 3fe4a6a2-3fbb-49e9-adf9-8b20078a4d5c'
#   Type ................................... 'TVBtoNetpyneInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'TVBtoNetpyneInterface gid: 6ea25c88-da1a-4041-bbe2-01f2e6789861'
#   interfaces[0].Type ..................... 'TVBtoNetpyneInterface'
#   interfaces[0].proxy .................... NetpynePoissonGeneratorSet gid: eb2753d5-daa7-4183-8ce4-eb50373d8975
#   interfaces[0].spiking_network .......... NetpyneNetwork gid: ee3eeed5-c677-4058-bf03-94116f8bcea2
#   interfaces[0].transformer .............. LinearRate gid: 941399f0-2fac-4d13-b43a-27294e46ce27
#   interfaces[0].monitor_ind .............. 0
#   interfaces[0].cvoi ..................... --------------------
#   interfaces[0].cvoi: shape .............. (1,)
#   interfaces[0].cvoi: dtype .............. int64
#   interfaces[0].cvoi: values ............. 0
#   interfaces[0].coupling_mode ............ 'TVB'
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (2,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: values ....... [[0, 1]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... E
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'RATE'
#   interfaces[0].gid ...................... UUID('6ea25c88-da1a-4041-bbe2-01f2e6789861')
#   interfaces[0].number_of_proxy_nodes .... 2
#   interfaces[0].number_of_proxy_gids ..... 2
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (2,)
#   interfaces[0].proxy_gids: dtype ........ object
#   interfaces[0].proxy_gids: unique_values  None
#   interfaces[0].n_voi .................... 1
#   dt ..................................... 0.1
#   min_idelay ............................. 36
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('3fe4a6a2-3fbb-49e9-adf9-8b20078a4d5c')
#   number_of_interfaces ................... 1
#   number_of_populations .................. 1
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (1,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. E
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (2,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: values ............. [[0, 1]]
#   n_vois ................................. 1
#   voi .................................... --------------------
#   voi: shape ............................. (1,)
#   voi: dtype ............................. int64
#   voi: values ............................ 0
#   voi_labels ............................. --------------------
#   voi_labels: shape ...................... (1,)
#   voi_labels: dtype ...................... <U1
#   voi_labels: values ..................... E
#   number_of_proxy_nodes .................. 2
# )
# 2023-10-04 18:15:23,169 - INFO - examples.example -
# NetpyneToTVBInterfaces (
#   title .................................. 'NetpyneToTVBInterfaces gid: 4fe0f228-cb9f-4a38-b9b4-1886ebae4d6d'
#   Type ................................... 'NetpyneToTVBInterfaces'
#   interfaces[0] .......................... '--------------------'
#   interfaces[0].title .................... 'NetpyneToTVBInterface gid: c5d64819-408c-4f34-afff-efcde3942905'
#   interfaces[0].Type ..................... 'NetpyneToTVBInterface'
#   interfaces[0].proxy .................... NetpyneSpikeRecorderTotalSet gid: 8ba76c71-3edd-4c3e-ab6b-b88bfac085ac
#   interfaces[0].spiking_network .......... NetpyneNetwork gid: ee3eeed5-c677-4058-bf03-94116f8bcea2
#   interfaces[0].transformer .............. ElephantSpikesHistogramRate gid: 825e9889-1364-4a15-b10d-9cd07b649cc3
#   interfaces[0].proxy_inds ............... --------------------
#   interfaces[0].proxy_inds: shape ........ (2,)
#   interfaces[0].proxy_inds: dtype ........ int64
#   interfaces[0].proxy_inds: values ....... [[0, 1]]
#   interfaces[0].voi ...................... --------------------
#   interfaces[0].voi: shape ............... (1,)
#   interfaces[0].voi: dtype ............... int64
#   interfaces[0].voi: values .............. 0
#   interfaces[0].voi_labels ............... --------------------
#   interfaces[0].voi_labels: shape ........ (1,)
#   interfaces[0].voi_labels: dtype ........ <U128
#   interfaces[0].voi_labels: values ....... E
#   interfaces[0].dt ....................... 0.1
#   interfaces[0].times .................... --------------------
#   interfaces[0].times: shape ............. (2,)
#   interfaces[0].times: dtype ............. int64
#   interfaces[0].times: values ............ [[0, 1]]
#   interfaces[0].spiking_proxy_inds ....... --------------------
#   interfaces[0].spiking_proxy_inds: shape  (2,)
#   interfaces[0].spiking_proxy_inds: dtype  int64
#   interfaces[0].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[0].populations .............. --------------------
#   interfaces[0].populations: shape ....... ()
#   interfaces[0].populations: dtype ....... <U128
#   interfaces[0].populations: values ...... E
#   interfaces[0].model .................... 'spike_recorder'
#   interfaces[0].gid ...................... UUID('c5d64819-408c-4f34-afff-efcde3942905')
#   interfaces[0].number_of_proxy_nodes .... 2
#   interfaces[0].number_of_proxy_gids ..... 2
#   interfaces[0].proxy_gids ............... --------------------
#   interfaces[0].proxy_gids: shape ........ (2,)
#   interfaces[0].proxy_gids: dtype ........ object
#   interfaces[0].proxy_gids: unique_values  None
#   interfaces[0].n_voi .................... 1
#   interfaces[1] .......................... '--------------------'
#   interfaces[1].title .................... 'NetpyneToTVBInterface gid: 068c96cb-5c4d-4d71-9c6a-7ab15b802a72'
#   interfaces[1].Type ..................... 'NetpyneToTVBInterface'
#   interfaces[1].proxy .................... NetpyneSpikeRecorderTotalSet gid: 76da83c2-9f74-4dbe-b2ad-a56d11563b11
#   interfaces[1].spiking_network .......... NetpyneNetwork gid: ee3eeed5-c677-4058-bf03-94116f8bcea2
#   interfaces[1].transformer .............. ElephantSpikesHistogramRate gid: 011c0780-d7f1-4d5a-b7b2-f6dcda8372f6
#   interfaces[1].proxy_inds ............... --------------------
#   interfaces[1].proxy_inds: shape ........ (2,)
#   interfaces[1].proxy_inds: dtype ........ int64
#   interfaces[1].proxy_inds: values ....... [[0, 1]]
#   interfaces[1].voi ...................... --------------------
#   interfaces[1].voi: shape ............... (1,)
#   interfaces[1].voi: dtype ............... int64
#   interfaces[1].voi: values .............. 1
#   interfaces[1].voi_labels ............... --------------------
#   interfaces[1].voi_labels: shape ........ (1,)
#   interfaces[1].voi_labels: dtype ........ <U128
#   interfaces[1].voi_labels: values ....... I
#   interfaces[1].dt ....................... 0.1
#   interfaces[1].times .................... --------------------
#   interfaces[1].times: shape ............. (2,)
#   interfaces[1].times: dtype ............. int64
#   interfaces[1].times: values ............ [[0, 1]]
#   interfaces[1].spiking_proxy_inds ....... --------------------
#   interfaces[1].spiking_proxy_inds: shape  (2,)
#   interfaces[1].spiking_proxy_inds: dtype  int64
#   interfaces[1].spiking_proxy_inds: values  [[0, 1]]
#   interfaces[1].populations .............. --------------------
#   interfaces[1].populations: shape ....... ()
#   interfaces[1].populations: dtype ....... <U128
#   interfaces[1].populations: values ...... I
#   interfaces[1].model .................... 'spike_recorder'
#   interfaces[1].gid ...................... UUID('068c96cb-5c4d-4d71-9c6a-7ab15b802a72')
#   interfaces[1].number_of_proxy_nodes .... 2
#   interfaces[1].number_of_proxy_gids ..... 2
#   interfaces[1].proxy_gids ............... --------------------
#   interfaces[1].proxy_gids: shape ........ (2,)
#   interfaces[1].proxy_gids: dtype ........ object
#   interfaces[1].proxy_gids: unique_values  None
#   interfaces[1].n_voi .................... 1
#   synchronization_time ................... 3.6
#   synchronization_n_step ................. 36
#   gid .................................... UUID('4fe0f228-cb9f-4a38-b9b4-1886ebae4d6d')
#   number_of_interfaces ................... 2
#   number_of_populations .................. 2
#   populations_unique ..................... --------------------
#   populations_unique: shape .............. (2,)
#   populations_unique: dtype .............. <U128
#   populations_unique: values ............. ['E' 'I']
#   spiking_proxy_inds ..................... --------------------
#   spiking_proxy_inds: shape .............. (4,)
#   spiking_proxy_inds: dtype .............. int64
#   spiking_proxy_inds: =0 ................. {0, 2}
#   spiking_proxy_inds: =1 ................. {1, 3}
#   n_vois ................................. 2
#   voi .................................... --------------------
#   voi: shape ............................. (2,)
#   voi: dtype ............................. int64
#   voi: values ............................ [[0, 1]]
# ...
#   gid .............................................................................. UUID('4d478397-6152-4231-b117-742aecba4ddd')
# )
# None
#
#
# Simulating...
# 2023-10-04 18:15:23,192 - INFO - examples.example -
# Simulating for 36ms with App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:23,192 - INFO - examples.example -
# Simulating for 36ms with App TVBNetpyneSerialOrchestrator...
#
# Simulating for 36ms with App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:23,192 - INFO - examples.example -
# Configuring simulation with App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:23,192 - INFO - examples.example -
# Configuring simulation with App TVBNetpyneSerialOrchestrator...
#
# Configuring simulation with App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:23,193 - INFO - examples.example -
# Configuring simulation with App TVBSerialApp...
# 2023-10-04 18:15:23,193 - INFO - examples.example -
# Configuring simulation with App TVBSerialApp...
#
# Configuring simulation with App TVBSerialApp...
# 2023-10-04 18:15:23,193 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-10-04 18:15:23,193 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 2.2 MB
# 2023-10-04 18:15:23,193 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-10-04 18:15:23,194 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 2, 68, 1)
# 2023-10-04 18:15:23,202 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880,
- INFO - examples.example -
# Cleaning up App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:23,392 - INFO - examples.example -
# Cleaning up App TVBNetpyneSerialOrchestrator...
#
# Cleaning up App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:23,392 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2023-10-04 18:15:23,392 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
#
# Cleaning up App TVBSerialApp...
#   Done; run time = 0.18 s; real-time ratio: 0.20.
#
# Gathering data...
#   Done; gather time = 0.00 s.
#
# Analyzing...
#   Cells: 56
#   Connections: 58 (1.04 per cell)
#   Spikes: 0 (0.00 Hz)
#   Simulated time: 0.0 s; 1 workers
#   Run time: 0.18 s
# Warning: data won't be saved. No output format specified (consider sim.cfg.savePickle, sim.cfg.saveJson etc.)
# Plotting recorded cell traces ... cell
# Preparing spike data...
# No spikes available to plot raster
# Plotting raster...
#
# There was an exception in plotRaster()
# Traceback (most recent call last):
#   File "/home/docker/.local/lib/python3.10/site-packages/netpyne/analysis/utils.py", line 87, in wrapper
#     return function(*args, **kwargs)
#   File "/home/docker/.local/lib/python3.10/site-packages/netpyne/plotting/plotRaster.py", line 243, in plotRaster
#     popNumCells = [max(spkInds)]
# UnboundLocalError: local variable 'spkInds' referenced before assignment
#   Done; plotting time = 0.20 s
#
# Total time = 0.44 s
# 2023-10-04 18:15:23,597 - INFO - examples.example -
# Stopping App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:23,597 - INFO - examples.example -
# Stopping App TVBNetpyneSerialOrchestrator...
#
# Stopping App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:23,598 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2023-10-04 18:15:23,598 - INFO - examples.example -
# Stopping App TVBSerialApp...
#
# Stopping App TVBSerialApp...
#
# Success in 0.521635 sec!
# ******************************************************
#
# {'TestWilsonCowanRATE': True}

# %%
! python ../../../tvb_multiscale/tests/tvb_netpyne/test_models.py 2
# Out:
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.
#
#
# Testing model 2
# ******************************************************
# ******************************************************
#
# ----------------------------------------------------------------------------------------------------
# Find results in /home/docker/packages/tvb-multiscale/examples/tvb_netpyne/notebooks/outputs/DefaultExcIOInhI_RATE_bidir/res !
# ----------------------------------------------------------------------------------------------------
# 2023-10-04 18:15:28,590 - INFO - examples.example -
# Starting App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:28,590 - INFO - examples.example -
# Starting App TVBNetpyneSerialOrchestrator...
#
# Starting App TVBNetpyneSerialOrchestrator...
#
# Starting App TVBSerialApp...
#
# Setting TVB LIBRARY_PROFILE...
# NetPyNE will load mod-files from /home/docker/packages/tvb-multiscale/tvb_multiscale/tvb_netpyne/netpyne/mod.
#
#
# Configuring...
# Orchestrator spiking cosimulator1:
# <tvb_multiscale.tvb_netpyne.netpyne.module.NetpyneModule object at 0xffff5f5eae00>
# Orchestrator spiking cosimulator2:
# <tvb_multiscale.tvb_netpyne.netpyne.module.NetpyneModule object at 0xffff5f5eae00>
#
# Done! in 0.000061 min
#
#
#
# Building...
# 2023-10-04 18:15:28,596 - INFO - examples.example -
# Building with App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:28,596 - INFO - examples.example -
# Building with App TVBNetpyneSerialOrchestrator...
#
# Building with App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:28,597 - INFO - examples.example -
# Building cosimulators with TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:28,597 - INFO - examples.example -
# Building cosimulators with TVBNetpyneSerialOrchestrator...
#
# Building cosimulators with TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:28,597 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorNetpyneBuilder of App TVBSerialApp...
# 2023-10-04 18:15:28,597 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorNetpyneBuilder of App TVBSerialApp...
#
# Building TVB CoSimulator with builder CoSimulatorNetpyneBuilder of App TVBSerialApp...
# 2023-10-04 18:15:28,598 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-10-04 18:15:28,598 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 4.5 MB
# 2023-10-04 18:15:28,599 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 4, 68, 1)
# 2023-10-04 18:15:28,615 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 4, 68, 1)
# 2023-10-04 18:15:28,615 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (4, 68, 1)
# 2023-10-04 18:15:28,616 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 3.3 MB
# 2023-10-04 18:15:28,616 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# 2023-10-04 18:15:28,621 - INFO - examples.example -
# CoSimulatorNetpyne (
#   title ............................... 'CoSimulatorNetpyne gid: bd94fedd-e577-445f-9b80-085b08ba9dc1'
#   Type ................................ 'CoSimulatorNetpyne'
#   model ............................... ReducedWongWangExcIOInhI gid: 83e92ea8-beee-4f01-a976-7bfd18f71e53
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: e780849c-f3df-44e1-adff-cb36bae11327
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 2d2ca869-04e5-4336-968a-cbc6ce691d45
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 78486ed2-3430-4682-ac63-fd74195d5c82
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 4, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('bd94fedd-e577-445f-9b80-085b08ba9dc1')
# )
# 2023-10-04 18:15:28,621 - INFO - examples.example -
# CoSimulatorNetpyne (
#   title ............................... 'CoSimulatorNetpyne gid: bd94fedd-e577-445f-9b80-085b08ba9dc1'
#   Type ................................ 'CoSimulatorNetpyne'
#   model ............................... ReducedWongWangExcIOInhI gid: 83e92ea8-beee-4f01-a976-7bfd18f71e53
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: e780849c-f3df-44e1-adff-cb36bae11327
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 2d2ca869-04e5-4336-968a-cbc6ce691d45
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 78486ed2-3430-4682-ac63-fd74195d5c82
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 4, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('bd94fedd-e577-445f-9b80-085b08ba9dc1')
# )
#
# CoSimulatorNetpyne (
#   title ............................... 'CoSimulatorNetpyne gid: bd94fedd-e577-445f-9b80-085b08ba9dc1'
#   Type ................................ 'CoSimulatorNetpyne'
#   model ............................... ReducedWongWangExcIOInhI gid: 83e92ea8-beee-4f01-a976-7bfd18f71e53
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: e780849c-f3df-44e1-adff-cb36bae11327
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 2d2ca869-04e5-4336-968a-cbc6ce691d45
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: 78486ed2-3430-4682-ac63-fd74195d5c82
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 4, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('bd94fedd-e577-445f-9b80-085b08ba9dc1')
# )
# 2023-10-04 18:15:28,622 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-10-04 18:15:28,622 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 4.4 MB
# 2023-10-04 18:15:28,622 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-10-04 18:15:28,622 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 4, 68, 1)
# 2023-10-04 18:15:28,640 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 4, 68, 1)
# 2023-10-04 18:15:28,640 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (4, 68, 1)
# 2023-10-04 18:15:28,641 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 3.3 MB
# 2023-10-04 18:15:28,641 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# 2023-10-04 18:15:28,644 - INFO - examples.example -
# Building Spiking Network with builder DefaultExcIOInhIBuilder of App NetpyneSerialApp...
# 2023-10-04 18:15:28,644 - INFO - examples.example -
# Building Spiking Network with builder DefaultExcIOInhIBuilder of App NetpyneSerialApp...
#
# Building Spiking Network with builder DefaultExcIOInhIBuilder of App NetpyneSerialApp...
# 2023-10-04 18:15:28,645 - INFO - examples.example - Configuring spiking network builder...
# 2023-10-04 18:15:28,645 - INFO - examples.example - Configuring spiking network builder...
# 2023-10-04 18:15:28,645 - INFO - examples.example - Configuring populations...
# 2023-10-04 18:15:28,645 - INFO - examples.example - Configuring populations...
# 2023-10-04 18:15:28,645 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2023-10-04 18:15:28,645 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2023-10-04 18:15:28,646 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2023-10-04 18:15:28,646 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2023-10-04 18:15:28,646 - INFO - examples.example - Configuring output devices, if any...
# 2023-10-04 18:15:28,646 - INFO - examples.example - Configuring output devices, if any...
# 2023-10-04 18:15:28,646 - INFO - examples.example - Configuring input devices, if any...
# 2023-10-04 18:15:28,646 - INFO - examples.example - Configuring input devices, if any...
# 2023-10-04 18:15:28,646 - INFO - examples.example - Generating spiking brain...
# 2023-10-04 18:15:28,646 - INFO - examples.example - Generating spiking brain...
# 2023-10-04 18:15:28,646 - INFO - examples.example - Generating spiking brain regions...
# 2023-10-04 18:15:28,646 - INFO - examples.example - Generating spiking brain regions...
# 2023-10-04 18:15:28,647 - INFO - examples.example - Generating spiking region node: bankssts_L...
# 2023-10-04
- INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...63.636% completed in 0.58975 sec!
# ...63.636% completed in 0.58975 sec!Netpyne:: recorded 1 spikes from bankssts_L.E. Approx. rate: 23.148148148149463. Timeframe 21.59999999999984 + 3.5999999999997954
# 2023-10-04 18:15:29,561 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-10-04 18:15:29,636 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...72.727% completed in 0.676428 sec!
# ...72.727% completed in 0.676428 sec!2023-10-04 18:15:29,647 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-10-04 18:15:29,722 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...81.818% completed in 0.76222 sec!
# ...81.818% completed in 0.76222 sec!2023-10-04 18:15:29,732 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-10-04 18:15:29,809 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...90.909% completed in 0.848835 sec!
# ...90.909% completed in 0.848835 sec!2023-10-04 18:15:29,820 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-10-04 18:15:29,891 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...100.000% completed in 0.931023 sec!
# ...100.000% completed in 0.931023 sec!
# Simulated in 1.027697 secs!
#
# 2023-10-04 18:15:29,891 - INFO - examples.example -
# Cleaning up App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:29,891 - INFO - examples.example -
# Cleaning up App TVBNetpyneSerialOrchestrator...
#
# Cleaning up App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:29,892 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2023-10-04 18:15:29,892 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
#
# Cleaning up App TVBSerialApp...
#   Done; run time = 1.00 s; real-time ratio: 0.04.
#
# Gathering data...
#   Done; gather time = 0.03 s.
#
# Analyzing...
#   Cells: 824
#   Connections: 1594 (1.93 per cell)
#   Spikes: 18 (0.61 Hz)
#   Simulated time: 0.0 s; 1 workers
#   Run time: 1.00 s
# Warning: data won't be saved. No output format specified (consider sim.cfg.savePickle, sim.cfg.saveJson etc.)
# Plotting recorded cell traces ... cell
# Preparing spike data...
# Plotting raster...
#   Done; plotting time = 0.25 s
#
# Total time = 1.46 s
# 2023-10-04 18:15:30,172 - INFO - examples.example -
# Stopping App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:30,172 - INFO - examples.example -
# Stopping App TVBNetpyneSerialOrchestrator...
#
# Stopping App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:30,173 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2023-10-04 18:15:30,173 - INFO - examples.example -
# Stopping App TVBSerialApp...
#
# Stopping App TVBSerialApp...
#
# Success in 1.58635 sec!
# ******************************************************
#
# {'TestRedWongWangRATE': True}

# %%
! python ../../../tvb_multiscale/tests/tvb_netpyne/test_models.py -1
# Out:
# Warning: no DISPLAY environment variable.
# --No graphics will be displayed.
#
# ******************************************************
# ******************************************************
# TestDefaultRATE
# ******************************************************
# ******************************************************
# Using Reduced Wong-Wang ExcIO InhI as a default model
#
# ----------------------------------------------------------------------------------------------------
# Find results in /home/docker/packages/tvb-multiscale/examples/tvb_netpyne/notebooks/outputs/DefaultExcIOInhI_RATE_bidir/res !
# ----------------------------------------------------------------------------------------------------
# 2023-10-04 18:15:35,147 - INFO - examples.example -
# Starting App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:35,147 - INFO - examples.example -
# Starting App TVBNetpyneSerialOrchestrator...
#
# Starting App TVBNetpyneSerialOrchestrator...
#
# Starting App TVBSerialApp...
#
# Setting TVB LIBRARY_PROFILE...
# NetPyNE will load mod-files from /home/docker/packages/tvb-multiscale/tvb_multiscale/tvb_netpyne/netpyne/mod.
#
#
# Configuring...
# Orchestrator spiking cosimulator1:
# <tvb_multiscale.tvb_netpyne.netpyne.module.NetpyneModule object at 0xffff6458ae00>
# Orchestrator spiking cosimulator2:
# <tvb_multiscale.tvb_netpyne.netpyne.module.NetpyneModule object at 0xffff6458ae00>
#
# Done! in 0.000064 min
#
#
#
# Building...
# 2023-10-04 18:15:35,154 - INFO - examples.example -
# Building with App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:35,154 - INFO - examples.example -
# Building with App TVBNetpyneSerialOrchestrator...
#
# Building with App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:35,154 - INFO - examples.example -
# Building cosimulators with TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:35,154 - INFO - examples.example -
# Building cosimulators with TVBNetpyneSerialOrchestrator...
#
# Building cosimulators with TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:35,154 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorNetpyneBuilder of App TVBSerialApp...
# 2023-10-04 18:15:35,154 - INFO - examples.example -
# Building TVB CoSimulator with builder CoSimulatorNetpyneBuilder of App TVBSerialApp...
#
# Building TVB CoSimulator with builder CoSimulatorNetpyneBuilder of App TVBSerialApp...
# 2023-10-04 18:15:35,156 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-10-04 18:15:35,156 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 4.5 MB
# 2023-10-04 18:15:35,156 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 4, 68, 1)
# 2023-10-04 18:15:35,173 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 4, 68, 1)
# 2023-10-04 18:15:35,174 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (4, 68, 1)
# 2023-10-04 18:15:35,175 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 3.3 MB
# 2023-10-04 18:15:35,175 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# Failed to summarize:
# monitors
# tuple
# 'NoneType' object has no attribute 'tolist'
# 2023-10-04 18:15:35,180 - INFO - examples.example -
# CoSimulatorNetpyne (
#   title ............................... 'CoSimulatorNetpyne gid: ae59ee69-bd28-4339-a904-98c48d273112'
#   Type ................................ 'CoSimulatorNetpyne'
#   model ............................... ReducedWongWangExcIOInhI gid: 8f40fcd2-0564-4c74-bd12-28d3ff943e7b
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: b1e0d387-8348-4d74-99a9-e81dfc3d761e
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 59e13dc8-b86e-42f4-9cd9-4f46509b13b5
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: d4012b93-7aa8-4f15-b1de-03c310d2f087
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 4, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('ae59ee69-bd28-4339-a904-98c48d273112')
# )
# 2023-10-04 18:15:35,180 - INFO - examples.example -
# CoSimulatorNetpyne (
#   title ............................... 'CoSimulatorNetpyne gid: ae59ee69-bd28-4339-a904-98c48d273112'
#   Type ................................ 'CoSimulatorNetpyne'
#   model ............................... ReducedWongWangExcIOInhI gid: 8f40fcd2-0564-4c74-bd12-28d3ff943e7b
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: b1e0d387-8348-4d74-99a9-e81dfc3d761e
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 59e13dc8-b86e-42f4-9cd9-4f46509b13b5
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: d4012b93-7aa8-4f15-b1de-03c310d2f087
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 4, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('ae59ee69-bd28-4339-a904-98c48d273112')
# )
#
# CoSimulatorNetpyne (
#   title ............................... 'CoSimulatorNetpyne gid: ae59ee69-bd28-4339-a904-98c48d273112'
#   Type ................................ 'CoSimulatorNetpyne'
#   model ............................... ReducedWongWangExcIOInhI gid: 8f40fcd2-0564-4c74-bd12-28d3ff943e7b
#   output_interfaces ................... None
#   input_interfaces .................... None
#   out_proxy_inds ...................... --------------------
#   shape ............................... (0,)
#   dtype ............................... float64
#   is empty ............................ True
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... False
#   voi ................................. --------------------
#   proxy_inds .......................... --------------------
#   cosim_monitors ...................... --------------------
#   synchronization_time ................ 0.0
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: b1e0d387-8348-4d74-99a9-e81dfc3d761e
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: 59e13dc8-b86e-42f4-9cd9-4f46509b13b5
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: d4012b93-7aa8-4f15-b1de-03c310d2f087
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 4, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('ae59ee69-bd28-4339-a904-98c48d273112')
# )
# 2023-10-04 18:15:35,181 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Region simulation with 68 ROI nodes
# 2023-10-04 18:15:35,181 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement estimate: simulation will need about 4.4 MB
# 2023-10-04 18:15:35,181 - ERROR - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Bad Simulator.integrator.noise.nsig shape: (2, 1, 1)
# 2023-10-04 18:15:35,181 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Using provided initial history of shape (1, 4, 68, 1)
# 2023-10-04 18:15:35,197 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Final initial history shape is (880, 4, 68, 1)
# 2023-10-04 18:15:35,198 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - initial state has shape (4, 68, 1)
# 2023-10-04 18:15:35,198 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Memory requirement census: simulation will need about 3.3 MB
# 2023-10-04 18:15:35,199 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - There are no existing connections (i.e., with nonzero weights)!
# Setting minimum delay to 1 integrator time step = 0.1!.
# 2023-10-04 18:15:35,202 - INFO - examples.example -
# Building Spiking Network with builder DefaultExcIOInhIBuilder of App NetpyneSerialApp...
# 2023-10-04 18:15:35,202 - INFO - examples.example -
# Building Spiking Network with builder DefaultExcIOInhIBuilder of App NetpyneSerialApp...
#
# Building Spiking Network with builder DefaultExcIOInhIBuilder of App NetpyneSerialApp...
# 2023-10-04 18:15:35,203 - INFO - examples.example - Configuring spiking network builder...
# 2023-10-04 18:15:35,203 - INFO - examples.example - Configuring spiking network builder...
# 2023-10-04 18:15:35,203 - INFO - examples.example - Configuring populations...
# 2023-10-04 18:15:35,203 - INFO - examples.example - Configuring populations...
# 2023-10-04 18:15:35,203 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2023-10-04 18:15:35,203 - INFO - examples.example - Configuring populations' connections within spiking region nodes...
# 2023-10-04 18:15:35,204 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2023-10-04 18:15:35,204 - INFO - examples.example - Configuring populations' connections among spiking region nodes...
# 2023-10-04 18:15:35,204 - INFO - examples.example - Configuring output devices, if any...
# 2023-10-04 18:15:35,204 - INFO - examples.example - Configuring output devices, if any...
# 2023-10-04 18:15:35,204 - INFO - examples.example - Configuring input devices, if any...
# 2023-10-04 18:15:35,204 - INFO - examples.example - Configuring input devices, if any...
# 2023-10-04 18:15:35,204 - INFO - examples.example - Generating spiking brain...
# 2023-10-04 18:15:35,204 - INFO - examples.example - Generating spiking brain...
# 2023-10-04 18:15:35,204 - INFO - examples.example - Generating spiking brain regions...
# 2023-10-04 18:15:35,204 - INFO - examples.example - Generating spiking brain regions...
# 2023-10-04 18:15:35,205 - INFO - examples.example - Generating spiking region node: bankssts_L...
# 2023-10-04 18:15:35,205 - INFO - examples.example - Generating spiking region node: bankssts_L...
# 2023-10-04 18:15:35,206 - INFO - examples.example - Generating population: E...
# 2023-10-04 18:15:35,206 - INFO - examples.example - Generating population: E...
# Netpyne:: Creating spiking population 'bankssts_L.E' of 12 neurons of type 'PYR'.
# 2023-10-04 18:15:35,206 - INFO - examples.example - Generating population: I...
# 2023-10-04 18:15:35,206 - INFO - examples.example - Generating population: I...
# Netpyne:: Creating spiking population 'bankssts_L.I' of 4 neurons of type 'PYR'.
# 2023-10-04 18:15:35,207 - INFO - examples.example - Generating spiking region node: bankssts_R...
# 2023-10-04 18:15:35,207 - INFO - examples.example - Generating spiking region node: bankssts_R...
# 2023-10-04 18:15:35,207 - INFO - examples.example - Generating population: E...
# 2023-10-04 18:15:35,207 - INFO - examples.example - Generating population: E...
# Netpyne:: Creating spiking population 'bankssts_R.E' of 12 neurons of type 'PYR'.
# 2023-10-04 18:15:35,208 - INFO - examples.example - Generating population: I...
# 2023-10-04 18:15:35,208 - INFO - examples.example - Generating population: I...
# Netpyne:: Creating spiking population 'bankssts_R.I' of 4 neurons of type 'PYR'.
# 2023-10-04 18:15:35,209 - INFO - examples.example - Connecting populations within spiking brain regions...
# 2023-10-04 18:15:35,209 - INFO - examples.example - Connecting populations within spiking brain regions...
# 2023-10-04 18:15:35,209 - INFO - examples.example - Connecting E -> E populations
# for spiking region nodes
# [0 1]...
# 2023-10-04 18:15:35,209 - INFO - examples.example - Connecting E -> E populations
# for spiking region nodes
# [0 1]...
# 2023-10-04 18:15:35,209 - INFO - examples.example - Connecting E -> I populations
# for spiking region nodes
# [0 1]...
# 2023-10-04 18:15:35,209 - INFO - examples.example - Connecting E -> I populations
# for spiking region nodes
# [0 1]...
# 2023-10-04 18:15:35,210 - INFO - examples.example - Connecting I -> E populations
# for spiking region nodes
# [0 1]...
# 2023-10-04 18:15:35,210 - INFO - examples.example - Connecting I -> E populations
# for spiking region nodes
# [0 1]...
# 2023-10-04 18:15:35,210 - INFO - examples.example - Connecting I -> I populations
# for spiking region nodes
# [0 1]...
# 2023-10-04 18:15:35,210 - INFO - examples.example - Connecting I -> I populations
# for spiking region nodes
# [0 1]...
# 2023-10-04 18:15:35,210 - INFO - examples.example - Connecting populations among spiking brain regions...
# 2023-10-04 18:15:35,210 - INFO - examples.example - Connecting populations among spiking brain regions...
# 2023-10-04 18:15:35,211 - INFO - examples.example - Connecting for 0 -> 1 spiking region nodes ...
# 2023-10-04 18:15:35,211 - INFO - examples.example - Connecting for 0 -> 1 spiking region nodes ...
# 2023-10-04 18:15:35,211 - INFO - examples.example - E -> E populations ...
# 2023-10-04 18:15:35,211 - INFO - examples.example - E -> E populations ...
# 2023-10-04 18:15:35,211 - INFO - examples.example - Connecting for 1 -> 0 spiking region nodes ...
# 2023-10-04 18:15:35,211 - INFO - examples.example - Connecting for 1 -> 0 spiking region nodes ...
# 2023-10-04 18:15:35,212 - INFO - examples.example - E -> E populations ...
# 2023-10-04 18:15:35,212 - INFO - examples.example - E -> E populations ...
# 2023-10-04 18:15:35,212 - INFO - examples.example - Generating and connecting output devices, if any...
# 2023-10-04 18:15:35,212 - INFO - examples.example - Generating and connecting output devices, if any...
# 2023-10-04 18:15:35,212 - INFO - examples.example - Generating and connecting ['E', 'I'] -> ['E', 'I'] device set of model spike_recorder
# for nodes [0, 1]...
# 2023-10-04 18:15:35,212 - INFO - examples.example - Generating and connecting ['E', 'I'] -> ['E', 'I'] device set of model spike_recorder
# for nodes [0, 1]...
# 2023-10-04 18:15:35,213 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model spike_recorder for E created!
# 2023-10-04 18:15:35,213 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model spike_recorder for E created!
# Netpyne:: will create internal device E - bankssts_L. Model: spike_recorder, params: {}
# Netpyne:: will connect output device spike_recorder -- bankssts_L.E
# Netpyne:: will create internal device E - bankssts_R. Model: spike_recorder, params: {}
# Netpyne:: will connect output device spike_recorder -- bankssts_R.E
# 2023-10-04 18:15:35,215 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model spike_recorder for I created!
# 2023-10-04 18:15:35,215 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model spike_recorder for I created!
# Netpyne:: will create internal device I - bankssts_L. Model: spike_recorder, params: {}
# Netpyne:: will connect output device spike_recorder -- bankssts_L.I
# Netpyne:: will create internal device I - bankssts_R. Model: spike_recorder, params: {}
# Netpyne:: will connect output device spike_recorder -- bankssts_R.I
# 2023-10-04 18:15:35,217 - INFO - examples.example - Generating and connecting input devices, if any...
# 2023-10-04 18:15:35,217 - INFO - examples.example - Generating and connecting input devices, if any...
# 2023-10-04 18:15:35,218 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_netpyne.netpyne_models.network.NetpyneNetwork'> created!
# 2023-10-04 18:15:35,218 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_netpyne.netpyne_models.network.NetpyneNetwork'> created!
# 2023-10-04 18:15:35,218 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_netpyne.netpyne_models.network.NetpyneNetwork'> created!
# 2023-10-04 18:15:35,218 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_netpyne.netpyne_models.network.NetpyneNetwork'> created!
# 2023-10-04 18:15:35,218 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_netpyne.netpyne_models.network.NetpyneNetwork'> created!
# 2023-10-04 18:15:35,218 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_netpyne.netpyne_models.network.NetpyneNetwork'> created!
# 2023-10-04 18:15:35,218 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_netpyne.netpyne_models.network.NetpyneNetwork'> created!
# 2023-10-04 18:15:35,218 - INFO - tvb-multiscale - <class 'tvb_multiscale.tvb_netpyne.netpyne_models.network.NetpyneNetwork'> created!
# NetpyneNetwork (
#   title ....................................... 'NetpyneNetwork gid: 7337586d-ba6e-49be-9ae6-a6c54bf478c3'
#   Type ........................................ 'NetpyneNetwork'
#   config ...................................... '--------------------'
#   config.title ................................ 'Config gid: 72203ac3-a928-40d7-81e8-9003cdb07046'
#   config.Type ................................. 'Config'
#   config.gid .................................. UUID('72203ac3-a928-40d7-81e8-9003cdb07046')
#   logger ...................................... <Logger tvb-multiscale (DEBUG)>
#   brain_regions ............................... '--------------------'
#   brain_regions.title ......................... 'NetpyneBrain gid: 0c47721f-c47d-4dd8-937c-07687a17181e'
#   brain_regions.Type .......................... 'NetpyneBrain'
#   brain_regions.gid ........................... UUID('0c47721f-c47d-4dd8-937c-07687a17181e')
#   brain_regions.label ......................... ''
#   brain_regions.size .......................... 2
#   brain_regions.Regions ....................... --------------------
#   brain_regions.Regions: shape ................ (2,)
#   brain_regions.Regions: dtype ................ <U10
#   brain_regions.Regions: values ............... ['bankssts_L' 'bankssts_R']
#   brain_regions.bankssts_L .................... '--------------------'
#   brain_regions[bankssts_L].title ............. 'NetpyneRegionNode gid: 5d931808-2bc6-4617-a40e-765b74321993'
#   brain_regions[bankssts_L].Type .............. 'NetpyneRegionNode'
#   brain_regions[bankssts_L].gid ............... UUID('5d931808-2bc6-4617-a40e-765b74321993')
#   brain_regions[bankssts_L].label ............. 'bankssts_L'
#   brain_regions[bankssts_L].size .............. 2
#   brain_regions[bankssts_L].Populations ....... --------------------
#   brain_regions[bankssts_L].Populations: shape  (2,)
#   brain_regions[bankssts_L].Populations: dtype  <U1
#   brain_regions[bankssts_L].Populations: values  ['E' 'I']
#   brain_regions.bankssts_R .................... '--------------------'
#   brain_regions[bankssts_R].title ............. 'NetpyneRegionNode gid: 3007d55f-fb91-4318-8502-f2aeb9256960'
#   brain_regions[bankssts_R].Type .............. 'NetpyneRegionNode'
#   brain_regions[bankssts_R].gid ............... UUID('3007d55f-fb91-4318-8502-f2aeb9256960')
#   brain_regions[bankssts_R].label ............. 'bankssts_R'
#   brain_regions[bankssts_R].size .............. 2
#   brain_regions[bankssts_R].Populations ....... --------------------
#   brain_regions[bankssts_R].Populations: shape  (2,)
#   brain_regions[bankssts_R].Populations: dtype  <U1
#   brain_regions[bankssts_R].Populations: values  ['E' 'I']
#   output_devices .............................. '--------------------'
#   output_devices.title ........................ 'DeviceSets gid: f8189e56-0d63-430f-b02f-95692078ed89'
#   output_devices.Type ......................... 'DeviceSets'
#   output_devices.gid .......................... UUID('f8189e56-0d63-430f-b02f-95692078ed89')
#   output_devices.label ........................ 'output_devices'
#   output_devices.size ......................... 2
#   output_devices.DeviceSets ................... --------------------
#   output_devices.DeviceSets: shape ............ (2,)
#   output_devices.DeviceSets: dtype ............ <U1
#   output_devices.DeviceSets: values ........... ['E' 'I']
#   output_devices.E ............................ '--------------------'
#   output_devices[E].title ..................... 'DeviceSet gid: f757228c-9b36-4cc1-ae71-ed640ab661ed'
#   output_devices[E].Type ...................... 'DeviceSet'
#   output_devices[E].model ..................... 'spike_recorder'
#   output_devices[E].gid ....................... UUID('f757228c-9b36-4cc1-ae71-ed640ab661ed')
#   output_devices[E].label ..................... 'E'
#   output_devices[E].size ...................... 2
#   output_devices[E].Devices ................... --------------------
#   output_devices[E].Devices: shape ............ (2,)
#   output_devices[E].Devices: dtype ............ <U10
#   output_devices[E].Devices: values ........... ['bankssts_L' 'bankssts_R']
#   output_devices.I ............................ '--------------------'
#   output_devices[I].title ..................... 'DeviceSet gid: d7855e02-670e-4eed-a56b-d02053d429ee'
#   output_devices[I].Type ...................... 'DeviceSet'
#   output_devices[I].model ..................... 'spike_recorder'
#   output_devices[I].gid ....................... UUID('d7855e02-670e-4eed-a56b-d02053d429ee')
#   output_devices[I].label ..................... 'I'
#   output_devices[I].size ...................... 2
#   output_devices[I].Devices ................... --------------------
#   output_devices[I].Devices: shape ............ (2,)
#   output_devices[I].Devices: dtype ............ <U10
#   output_devices[I].Devices: values ........... ['bankssts_L' 'bankssts_R']
#   input_devices ............................... '--------------------'
#   input_devices.title ......................... 'DeviceSets gid: d6ab4653-f2d8-4a7a-8f84-eaf586dc0a04'
#   input_devices.Type .......................... 'DeviceSets'
#   input_devices.gid ........................... UUID('d6ab4653-f2d8-4a7a-8f84-eaf586dc0a04')
#   input_devices.label ......................... 'input_devices'
#   input_devices.size .......................... 0
#   input_devices.DeviceSets .................... --------------------
#   shape ....................................... (0,)
#   dtype ....................................... float64
#   is empty .................................... True
#   output_proxies .............................. '--------------------'
#   output_proxies.title ........................ 'DeviceSets gid: 22f20b8d-559c-45db-8dbf-039d14b15052'
#   output_proxies.Type ......................... 'DeviceSets'
#   output_proxies.gid .......................... UUID('22f20b8d-559c-45db-8dbf-039d14b15052')
#   output_proxies.label ........................ 'output_proxies'
#   output_proxies.size ......................... 0
#   output_proxies.DeviceSets ................... --------------------
#   input_proxies ............................... '--------------------'
#   input_proxies.title ......................... 'DeviceSets gid: a4f3fde3-5772-40d2-9047-2aac1a7de4ae'
#   input_proxies.Type .......................... 'DeviceSets'
#   input_proxies.gid ........................... UUID('a4f3fde3-5772-40d2-9047-2aac1a7de4ae')
#   input_proxies.label ......................... 'input_proxies'
#   input_proxies.size .......................... 0
#   input_proxies.DeviceSets .................... --------------------
#   gid ......................................... UUID('7337586d-ba6e-49be-9ae6-a6c54bf478c3')
# )
# 2023-10-04 18:15:35,221 - INFO - examples.example -
# Building interfaces with Orchestrator TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:35,221 - INFO - examples.example -
# Building interfaces with Orchestrator TVBNetpyneSerialOrchestrator...
#
# Building interfaces with Orchestrator TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:35,221 - INFO - examples.example -
# Building interfaces' with builder TVBNetpyneInterfaceBuilder of App TVBSerialApp...
# 2023-10-04 18:15:35,221 - INFO - examples.example -
# Building interfaces' with builder TVBNetpyneInterfaceBuilder of App TVBSerialApp...
#
# Building interfaces' with builder TVBNetpyneInterfaceBuilder of App TVBSerialApp...
# 2023-10-04 18:15:35,221 - INFO - examples.example -
# Configuring interfaces' builder RedWongWangExcIOInhITVBNetpyneInterfaceBuilder of App TVBSerialApp...
# 2023-10-04 18:15:35,221 - INFO - examples.example -
# Configuring interfaces' builder RedWongWangExcIOInhITVBNetpyneInterfaceBuilder of App TVBSerialApp...
#
# Configuring interfaces' builder RedWongWangExcIOInhITVBNetpyneInterfaceBuilder of App TVBSerialApp...
# 2023-10-04 18:15:35,221 - INFO - examples.example -
# Configuring default interfaces...
# 2023-10-04 18:15:35,221 - INFO - examples.example -
# Configuring default interfaces...
#
# Configuring default interfaces...
# 2023-10-04 18:15:35,224 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model poisson_generator for ['R_e']->E created!
# 2023-10-04 18:15:35,224 - INFO - tvb_multiscale.core.spiking_models.devices - <class 'tvb_multiscale.core.spiking_models.devices.DeviceSet'> of model poisson_generator for ['R_e']->E created!
# Netpyne:: will create internal device ['R_e']->E - caudalanteriorcingulate_L. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - caudalanteriorcingulate_L' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - caudalanteriorcingulate_L -> bankssts_L.E (weight: 7.997816847869266e-06, delay: 30.450000762939453)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - caudalanteriorcingulate_L -> bankssts_R.E (weight: 5.8246243499000976e-05, delay: 10.449999809265137)
# Netpyne:: will create internal device ['R_e']->E - caudalanteriorcingulate_R. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - caudalanteriorcingulate_R' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - caudalanteriorcingulate_R -> bankssts_L.E (weight: 7.292142229552125e-05, delay: 21.549999237060547)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - caudalanteriorcingulate_R -> bankssts_R.E (weight: 0.0, delay: 0.05000000074505806)
# Netpyne:: will create internal device ['R_e']->E - caudalmiddlefrontal_L. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - caudalmiddlefrontal_L' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - caudalmiddlefrontal_L -> bankssts_L.E (weight: 0.0, delay: 0.05000000074505806)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - caudalmiddlefrontal_L -> bankssts_R.E (weight: 2.419051531159143e-07, delay: 37.45000076293945)
# Netpyne:: will create internal device ['R_e']->E - caudalmiddlefrontal_R. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - caudalmiddlefrontal_R' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - caudalmiddlefrontal_R -> bankssts_L.E (weight: 7.49273831675158e-06, delay: 20.549999237060547)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - caudalmiddlefrontal_R -> bankssts_R.E (weight: 1.0803424490294984e-07, delay: 36.95000076293945)
# Netpyne:: will create internal device ['R_e']->E - cuneus_L. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - cuneus_L' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - cuneus_L -> bankssts_L.E (weight: 0.0033080432971674596, delay: 7.550000190734863)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - cuneus_L -> bankssts_R.E (weight: 6.564141113191563e-07, delay: 36.650001525878906)
# Netpyne:: will create internal device ['R_e']->E - cuneus_R. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - cuneus_R' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - cuneus_R -> bankssts_L.E (weight: 0.00021397334786776176, delay: 12.949999809265137)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - cuneus_R -> bankssts_R.E (weight: 7.695142089366375e-07, delay: 36.45000076293945)
# Netpyne:: will create internal device ['R_e']->E - entorhinal_L. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - entorhinal_L' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - entorhinal_L -> bankssts_L.E (weight: 2.5788677609829197e-05, delay: 18.149999618530273)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - entorhinal_L -> bankssts_R.E (weight: 0.00021793340228133844, delay: 10.449999809265137)
# Netpyne:: will create internal device ['R_e']->E - entorhinal_R. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - entorhinal_R' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - entorhinal_R -> bankssts_L.E (weight: 0.00027056530014853066, delay: 17.049999237060547)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - entorhinal_R -> bankssts_R.E (weight: 1.0819679986253226e-07, delay: 53.04999923706055)
# Netpyne:: will create internal device ['R_e']->E - frontalpole_L. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - frontalpole_L' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - frontalpole_L -> bankssts_L.E (weight: 5.223626662822948e-06, delay: 31.25)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - frontalpole_L -> bankssts_R.E (weight: 2.6667958247993992e-05, delay: 9.850000381469727)
# Netpyne:: will create internal device ['R_e']->E - frontalpole_R. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - frontalpole_R' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - frontalpole_R -> bankssts_L.E (weight: 1.0670372223222095e-05, delay: 17.25)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - frontalpole_R -> bankssts_R.E (weight: 2.0968323254948778e-07, delay: 36.349998474121094)
# Netpyne:: will create internal device ['R_e']->E - fusiform_L. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - fusiform_L' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - fusiform_L -> bankssts_L.E (weight: 1.2094959877043775e-06, delay: 34.45000076293945)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - fusiform_L -> bankssts_R.E (weight: 0.00029090250947588916, delay: 8.050000190734863)
# Netpyne:: will create internal device ['R_e']->E - fusiform_R. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - fusiform_R' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - fusiform_R -> bankssts_L.E (weight: 0.002098901089042656, delay: 4.650000095367432)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - fusiform_R -> bankssts_R.E (weight: 1.056316079037668e-06, delay: 41.45000076293945)
# Netpyne:: will create internal device ['R_e']->E - inferiorparietal_L. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - inferiorparietal_L' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - inferiorparietal_L -> bankssts_L.E (weight: 2.5734854352283455e-07, delay: 27.25)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - inferiorparietal_L -> bankssts_R.E (weight: 2.4299831345060133e-06, delay: 29.850000381469727)
# Netpyne:: will create internal device ['R_e']->E - inferiorparietal_R. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - inferiorparietal_R' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - inferiorparietal_R -> bankssts_L.E (weight: 4.0680510957553837e-07, delay: 29.549999237060547)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - inferiorparietal_R -> bankssts_R.E (weight: 2.984425725938272e-05, delay: 15.75)
# Netpyne:: will create internal device ['R_e']->E - inferiortemporal_L. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - inferiortemporal_L' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - inferiortemporal_L -> bankssts_L.E (weight: 0.0004853313238278787, delay: 27.549999237060547)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - inferiortemporal_L -> bankssts_R.E (weight: 0.000236077612865814, delay: 14.149999618530273)
# Netpyne:: will create internal device ['R_e']->E - inferiortemporal_R. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - inferiortemporal_R' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - inferiortemporal_R -> bankssts_L.E (weight: 9.263402593848065e-07, delay: 37.150001525878906)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - inferiortemporal_R -> bankssts_R.E (weight: 1.2267717320999008e-05, delay: 14.550000190734863)
# Netpyne:: will create internal device ['R_e']->E - insula_L. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - insula_L' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - insula_L -> bankssts_L.E (weight: 3.4637362483714865e-05, delay: 32.54999923706055)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - insula_L -> bankssts_R.E (weight: 0.0002837458886735203, delay: 13.850000381469727)
# Netpyne:: will create internal device ['R_e']->E - insula_R. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - insula_R' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - insula_R -> bankssts_L.E (weight: 4.001112476040565e-05, delay: 20.25)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - insula_R -> bankssts_R.E (weight: 1.792328724748936e-08, delay: 53.150001525878906)
# Netpyne:: will create internal device ['R_e']->E - isthmuscingulate_L. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - isthmuscingulate_L' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - isthmuscingulate_L -> bankssts_L.E (weight: 9.002379728224955e-05, delay: 19.549999237060547)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - isthmuscingulate_L -> bankssts_R.E (weight: 2.442812663614992e-05, delay: 22.350000381469727)
# Netpyne:: will create internal device ['R_e']->E - isthmuscingulate_R. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - isthmuscingulate_R' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - isthmuscingulate_R -> bankssts_L.E (weight: 9.601796985879666e-06, delay: 18.450000762939453)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - isthmuscingulate_R -> bankssts_R.E (weight: 0.0016845692293189977, delay: 3.1500000953674316)
# Netpyne:: will create internal device ['R_e']->E - lateraloccipital_L. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - lateraloccipital_L' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - lateraloccipital_L -> bankssts_L.E (weight: 0.000233849280781413, delay: 24.149999618530273)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - lateraloccipital_L -> bankssts_R.E (weight: 1.4916866048703152e-05, delay: 21.450000762939453)
# Netpyne:: will create internal device ['R_e']->E - lateraloccipital_R. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - lateraloccipital_R' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - lateraloccipital_R -> bankssts_L.E (weight: 0.00024799954285077426, delay: 17.549999237060547)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - lateraloccipital_R -> bankssts_R.E (weight: 0.0003041821033191281, delay: 17.350000381469727)
# Netpyne:: will create internal device ['R_e']->E - lateralorbitofrontal_L. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - lateralorbitofrontal_L' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - lateralorbitofrontal_L -> bankssts_L.E (weight: 0.0, delay: 0.05000000074505806)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - lateralorbitofrontal_L -> bankssts_R.E (weight: 0.0006247112094744493, delay: 3.25)
# Netpyne:: will create internal device ['R_e']->E - lateralorbitofrontal_R. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - lateralorbitofrontal_R' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - lateralorbitofrontal_R -> bankssts_L.E (weight: 1.8452531769269368e-05, delay: 38.25)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - lateralorbitofrontal_R -> bankssts_R.E (weight: 0.0004210532111787649, delay: 11.649999618530273)
# Netpyne:: will create internal device ['R_e']->E - lingual_L. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - lingual_L' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - lingual_L -> bankssts_L.E (weight: 2.2239362137289186e-05, delay: 40.54999923706055)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - lingual_L -> bankssts_R.E (weight: 0.004748127391781739, delay: 7.449999809265137)
# Netpyne:: will create internal device ['R_e']->E - lingual_R. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - lingual_R' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - lingual_R -> bankssts_L.E (weight: 0.0009345112565253372, delay: 17.350000381469727)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - lingual_R -> bankssts_R.E (weight: 4.474423814463622e-05, delay: 22.75)
# Netpyne:: will create internal device ['R_e']->E - medialorbitofrontal_L. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - medialorbitofrontal_L' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - medialorbitofrontal_L -> bankssts_L.E (weight: 0.002071706073917652, delay: 4.150000095367432)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - medialorbitofrontal_L -> bankssts_R.E (weight: 3.4436542450774464e-06, delay: 31.649999618530273)
# Netpyne:: will create internal device ['R_e']->E - medialorbitofrontal_R. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - medialorbitofrontal_R' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - medialorbitofrontal_R -> bankssts_L.E (weight: 0.0013003404698474713, delay: 8.350000381469727)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - medialorbitofrontal_R -> bankssts_R.E (weight: 5.708495386136336e-06, delay: 25.350000381469727)
# Netpyne:: will create internal device ['R_e']->E - middletemporal_L. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - middletemporal_L' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - middletemporal_L -> bankssts_L.E (weight: 0.0, delay: 0.05000000074505806)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - middletemporal_L -> bankssts_R.E (weight: 1.4733331287926944e-05, delay: 14.649999618530273)
# Netpyne:: will create internal device ['R_e']->E - middletemporal_R. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - middletemporal_R' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - middletemporal_R -> bankssts_L.E (weight: 1.6875100283708792e-06, delay: 24.350000381469727)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - middletemporal_R -> bankssts_R.E (weight: 0.0, delay: 0.05000000074505806)
# Netpyne:: will create internal device ['R_e']->E - paracentral_L. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - paracentral_L' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - paracentral_L -> bankssts_L.E (weight: 1.0069627122761496e-05, delay: 14.949999809265137)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - paracentral_L -> bankssts_R.E (weight: 0.0, delay: 0.05000000074505806)
# Netpyne:: will create internal device ['R_e']->E - paracentral_R. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - paracentral_R' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - paracentral_R -> bankssts_L.E (weight: 0.00043763486770135684, delay: 12.149999618530273)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - paracentral_R -> bankssts_R.E (weight: 5.669834377859754e-05, delay: 16.950000762939453)
# Netpyne:: will create internal device ['R_e']->E - parahippocampal_L. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - parahippocampal_L' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - parahippocampal_L -> bankssts_L.E (weight: 1.660022991453859e-08, delay: 48.45000076293945)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - parahippocampal_L -> bankssts_R.E (weight: 2.0919186162779112e-08, delay: 42.349998474121094)
# Netpyne:: will create internal device ['R_e']->E - parahippocampal_R. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - parahippocampal_R' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - parahippocampal_R -> bankssts_L.E (weight: 2.79464077769933e-08, delay: 46.75)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - parahippocampal_R -> bankssts_R.E (weight: 9.97324697823632e-05, delay: 2.3499999046325684)
# Netpyne:: will create internal device ['R_e']->E - parsopercularis_L. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - parsopercularis_L' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - parsopercularis_L -> bankssts_L.E (weight: 5.045422846934017e-07, delay: 56.349998474121094)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - parsopercularis_L -> bankssts_R.E (weight: 3.909172530778815e-06, delay: 18.549999237060547)
# Netpyne:: will create internal device ['R_e']->E - parsopercularis_R. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - parsopercularis_R' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - parsopercularis_R -> bankssts_L.E (weight: 0.0, delay: 0.05000000074505806)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - parsopercularis_R -> bankssts_R.E (weight: 0.0, delay: 0.05000000074505806)
# Netpyne:: will create internal device ['R_e']->E - parsorbitalis_L. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - parsorbitalis_L' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - parsorbitalis_L -> bankssts_L.E (weight: 0.0, delay: 0.05000000074505806)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - parsorbitalis_L -> bankssts_R.E (weight: 0.0, delay: 0.05000000074505806)
# Netpyne:: will create internal device ['R_e']->E - parsorbitalis_R. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - parsorbitalis_R' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - parsorbitalis_R -> bankssts_L.E (weight: 0.0, delay: 0.05000000074505806)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - parsorbitalis_R -> bankssts_R.E (weight: 0.0, delay: 0.05000000074505806)
# Netpyne:: will create internal device ['R_e']->E - parstriangularis_L. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - parstriangularis_L' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - parstriangularis_L -> bankssts_L.E (weight: 1.297277392966858e-06, delay: 46.25)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - parstriangularis_L -> bankssts_R.E (weight: 2.454983596508955e-07, delay: 42.25)
# Netpyne:: will create internal device ['R_e']->E - parstriangularis_R. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - parstriangularis_R' of 12 neurons
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - parstriangularis_R -> bankssts_L.E (weight: 0.0, delay: 0.05000000074505806)
# Netpyne:: will connect input device poisson_generator. ['R_e']->E - parstriangularis_R -> bankssts_R.E (weight: 0.0, delay: 0.05000000074505806)
# Netpyne:: will create internal device ['R_e']->E - pericalcarine_L. Model: poisson_generator, params: {'number_of_neurons': 12}
# Netpyne:: Creating artif cells for node '['R_e']->E - pericalcarine_L' of 12 neurons
# ...
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[0, 1]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. RawCosim(period=0.100000, voi=[2])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 7ed317d6-c7d1-4f0b-aa21-05747688037b
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: e88c9273-cc64-4a10-9e28-8038d0f03109
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: d4012b93-7aa8-4f15-b1de-03c310d2f087
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 4, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('fd27d295-69dd-4453-afa1-c846d0576d13')
# )
# 2023-10-04 18:15:40,004 - INFO - examples.example -
# CoSimulatorNetpyne (
#   title ............................... 'CoSimulatorNetpyne gid: fd27d295-69dd-4453-afa1-c846d0576d13'
#   Type ................................ 'CoSimulatorNetpyne'
#   model ............................... ReducedWongWangExcIOInhI gid: 6a645e60-5344-4049-9f62-24c99b809068
#   output_interfaces ................... TVBtoNetpyneInterfaces gid: 425ed881-fd3a-4636-aad1-b2a442617c08
#   input_interfaces .................... NetpyneToTVBInterfaces gid: 2dc61d5b-5cad-477f-ac10-f331e71c70a9
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (66,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: unique_values ....... [[2, 67]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (4,)
#   voi: dtype .......................... int64
#   voi: unique_values .................. [[0, 3]]
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[0, 1]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. RawCosim(period=0.100000, voi=[2])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 7ed317d6-c7d1-4f0b-aa21-05747688037b
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: e88c9273-cc64-4a10-9e28-8038d0f03109
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: d4012b93-7aa8-4f15-b1de-03c310d2f087
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 4, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('fd27d295-69dd-4453-afa1-c846d0576d13')
# )
# 2023-10-04 18:15:40,004 - INFO - examples.example -
# CoSimulatorNetpyne (
#   title ............................... 'CoSimulatorNetpyne gid: fd27d295-69dd-4453-afa1-c846d0576d13'
#   Type ................................ 'CoSimulatorNetpyne'
#   model ............................... ReducedWongWangExcIOInhI gid: 6a645e60-5344-4049-9f62-24c99b809068
#   output_interfaces ................... TVBtoNetpyneInterfaces gid: 425ed881-fd3a-4636-aad1-b2a442617c08
#   input_interfaces .................... NetpyneToTVBInterfaces gid: 2dc61d5b-5cad-477f-ac10-f331e71c70a9
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (66,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: unique_values ....... [[2, 67]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (4,)
#   voi: dtype .......................... int64
#   voi: unique_values .................. [[0, 3]]
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[0, 1]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. RawCosim(period=0.100000, voi=[2])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 7ed317d6-c7d1-4f0b-aa21-05747688037b
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: e88c9273-cc64-4a10-9e28-8038d0f03109
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: d4012b93-7aa8-4f15-b1de-03c310d2f087
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 4, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('fd27d295-69dd-4453-afa1-c846d0576d13')
# )
#
# CoSimulatorNetpyne (
#   title ............................... 'CoSimulatorNetpyne gid: fd27d295-69dd-4453-afa1-c846d0576d13'
#   Type ................................ 'CoSimulatorNetpyne'
#   model ............................... ReducedWongWangExcIOInhI gid: 6a645e60-5344-4049-9f62-24c99b809068
#   output_interfaces ................... TVBtoNetpyneInterfaces gid: 425ed881-fd3a-4636-aad1-b2a442617c08
#   input_interfaces .................... NetpyneToTVBInterfaces gid: 2dc61d5b-5cad-477f-ac10-f331e71c70a9
#   out_proxy_inds ...................... --------------------
#   out_proxy_inds: shape ............... (66,)
#   out_proxy_inds: dtype ............... int64
#   out_proxy_inds: unique_values ....... [[2, 67]]
#   min_idelay_sync_n_step_ratio ........ 1
#   relative_output_interfaces_time_steps  0
#   exclusive ........................... True
#   voi ................................. --------------------
#   voi: shape .......................... (4,)
#   voi: dtype .......................... int64
#   voi: unique_values .................. [[0, 3]]
#   proxy_inds .......................... --------------------
#   proxy_inds: shape ................... (2,)
#   proxy_inds: dtype ................... int64
#   proxy_inds: values .................. [[0, 1]]
#   cosim_monitors ...................... --------------------
#   cosim_monitors: shape ............... (1,)
#   cosim_monitors: dtype ............... object
#   cosim_monitors: values .............. RawCosim(period=0.100000, voi=[2])
#   synchronization_time ................ 3.6
#   relative_output_time_steps .......... 0
#   connectivity ........................ Connectivity gid: 7ed317d6-c7d1-4f0b-aa21-05747688037b
#   conduction_speed .................... 3.0
#   coupling ............................ Linear gid: e88c9273-cc64-4a10-9e28-8038d0f03109
#   surface ............................. None
#   stimulus ............................ None
#   integrator .......................... HeunStochastic gid: d4012b93-7aa8-4f15-b1de-03c310d2f087
#   initial_conditions .................. --------------------
#   initial_conditions: shape ........... (1, 4, 68, 1)
#   initial_conditions: dtype ........... float64
#   initial_conditions: unique_values ... [0.]
#   simulation_length ................... 36.0
#   gid ................................. UUID('fd27d295-69dd-4453-afa1-c846d0576d13')
# )
# 2023-10-04 18:15:40,005 - INFO - examples.example -
# Configuring simulation with App NetpyneSerialApp...
# 2023-10-04 18:15:40,005 - INFO - examples.example -
# Configuring simulation with App NetpyneSerialApp...
# 2023-10-04 18:15:40,005 - INFO - examples.example -
# Configuring simulation with App NetpyneSerialApp...
# 2023-10-04 18:15:40,005 - INFO - examples.example -
# Configuring simulation with App NetpyneSerialApp...
#
# Configuring simulation with App NetpyneSerialApp...
# Recording 4 traces of 1 types on node 0
#
# Running with interval func using NEURON for 36.0 ms...
# 2023-10-04 18:15:40,010 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2023-10-04 18:15:40,010 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2023-10-04 18:15:40,010 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
# 2023-10-04 18:15:40,010 - INFO - examples.example -
# Simulating for 36ms with App TVBSerialApp...
#
# Simulating for 36ms with App TVBSerialApp...
# 2023-10-04 18:15:40,073 - WARNING - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - No or all NaN valued cosimulator updates at time step 0!
# 2023-10-04 18:15:40,073 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulation runtime should be about 0.064 seconds
# 2023-10-04 18:15:40,073 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-10-04 18:15:40,073 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculating storage requirement for ...
# 2023-10-04 18:15:40,079 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Calculated storage requirement for simulation: 88127
# 2023-10-04 18:15:40,151 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...9.091% completed in 0.0785875 sec!
# ...9.091% completed in 0.0785875 sec!2023-10-04 18:15:40,161 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-10-04 18:15:40,234 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...18.182% completed in 0.161848 sec!
# ...18.182% completed in 0.161848 sec!2023-10-04 18:15:40,245 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-10-04 18:15:40,319 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...27.273% completed in 0.246796 sec!
# ...27.273% completed in 0.246796 sec!Netpyne:: recorded 3 spikes from bankssts_L.E. Approx. rate: 69.44444444444346. Timeframe 7.200000000000035 + 3.600000000000051
# 2023-10-04 18:15:40,329 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-10-04 18:15:40,403 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...36.364% completed in 0.330775 sec!
# ...36.364% completed in 0.330775 sec!Netpyne:: recorded 5 spikes from bankssts_L.E. Approx. rate: 115.7407407407391. Timeframe 10.800000000000086 + 3.600000000000051
# 2023-10-04 18:15:40,414 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-10-04 18:15:40,489 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...45.455% completed in 0.416395 sec!
# ...45.455% completed in 0.416395 sec!2023-10-04 18:15:40,500 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-10-04 18:15:40,573 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...54.545% completed in 0.500499 sec!
# ...54.545% completed in 0.500499 sec!2023-10-04 18:15:40,584 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-10-04 18:15:40,656 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...63.636% completed in 0.584089 sec!
# ...63.636% completed in 0.584089 sec!2023-10-04 18:15:40,668 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-10-04 18:15:40,743 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...72.727% completed in 0.671108 sec!
# ...72.727% completed in 0.671108 sec!2023-10-04 18:15:40,755 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-10-04 18:15:40,830 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...81.818% completed in 0.757585 sec!
# ...81.818% completed in 0.757585 sec!2023-10-04 18:15:40,841 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-10-04 18:15:40,915 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...90.909% completed in 0.843276 sec!
# ...90.909% completed in 0.843276 sec!2023-10-04 18:15:40,927 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - Simulating the spiking network for 36 time steps...
# 2023-10-04 18:15:40,999 - INFO - tvb_multiscale.core.tvb.cosimulator.cosimulator_serial - ...100.000% completed in 0.926296 sec!
# ...100.000% completed in 0.926296 sec!
# Simulated in 1.023406 secs!
#
# 2023-10-04 18:15:40,999 - INFO - examples.example -
# Cleaning up App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:40,999 - INFO - examples.example -
# Cleaning up App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:40,999 - INFO - examples.example -
# Cleaning up App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:40,999 - INFO - examples.example -
# Cleaning up App TVBNetpyneSerialOrchestrator...
#
# Cleaning up App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:41,000 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2023-10-04 18:15:41,000 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2023-10-04 18:15:41,000 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
# 2023-10-04 18:15:41,000 - INFO - examples.example -
# Cleaning up App TVBSerialApp...
#
# Cleaning up App TVBSerialApp...
#   Done; run time = 0.99 s; real-time ratio: 0.04.
#
# Gathering data...
#   Done; gather time = 0.03 s.
#
# Analyzing...
#   Cells: 824
#   Connections: 1594 (1.93 per cell)
#   Spikes: 8 (0.27 Hz)
#   Simulated time: 0.0 s; 1 workers
#   Run time: 0.99 s
# Warning: data won't be saved. No output format specified (consider sim.cfg.savePickle, sim.cfg.saveJson etc.)
# Plotting recorded cell traces ... cell
# Preparing spike data...
# Plotting raster...
#   Done; plotting time = 0.24 s
#
# Total time = 1.44 s
# 2023-10-04 18:15:41,271 - INFO - examples.example -
# Stopping App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:41,271 - INFO - examples.example -
# Stopping App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:41,271 - INFO - examples.example -
# Stopping App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:41,271 - INFO - examples.example -
# Stopping App TVBNetpyneSerialOrchestrator...
#
# Stopping App TVBNetpyneSerialOrchestrator...
# 2023-10-04 18:15:41,272 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2023-10-04 18:15:41,272 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2023-10-04 18:15:41,272 - INFO - examples.example -
# Stopping App TVBSerialApp...
# 2023-10-04 18:15:41,272 - INFO - examples.example -
# Stopping App TVBSerialApp...
#
# Stopping App TVBSerialApp...
#
# Success in 1.70821 sec!
# ******************************************************
#
#
# ******************************************************
# ******************************************************
#
# TestDefaultRATE SUCCESS!
#
# TestWilsonCowanRATE SUCCESS!
#
# TestRedWongWangRATE SUCCESS!
# ******************************************************
